# %% [markdown]
# ![configuring_python.png](attachment:configuring_python.png)

# %% [markdown]
# # Configuring Settings
# #### by Joe Eberle  created on  : 9/20/2022  ---  Refactored on  : 10/19/2022 - Revised 10/20/2022

# %% [markdown]
# Process Steps :
# 1. Import the configparser module
# 2. Create the configparser object and pass it to a ‘config’ variable
# 3. Create a config section name to organize settings into categories
# 4. Populate the section with name - value pairs
# 5. Repeat items 3 and 4 for any subsequent sections.
# 6. Finally, open a file of your chosen name at your chosen directory location using ‘w’ to write
# 7. Write the configuration file

# %%
# Import the necessary Libraries 
import configparser
import pyttsx3
import talking_code_configuring_settings as tc
# Initialize the confuration settings parser engine to get and set parameters 
config = configparser.ConfigParser()
cfg = config.read('config.ini')

# %%
# OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
global talking_code
talking_code = False # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
tc.set_talking_code_on_or_off(talking_code) # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
if talking_code:
    tc.explain_the_whole_project() # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
doc = tc.document_the_whole_project()
print(doc)
# Out:
# This jupiter notebook will establish a configuration file that contains configuration settings.
# The configuration file will allow you to quickly and easily customize settings and global variables.
# The configuration file will be maliable allowing users to reset configurations as needed.
#
#
#
# The high level steps for this solution are:
# Step 1: Establish the configuration parser engine.
# Step 2: Establish all the Sections for initial configuration settingsnStep 3: Write out name value pairs for all of the configuration settings.
# Step 4: Repeat steps 2 and 3 until all of the sections and configuration settings are complete.
# Step 5: Write out the config.ini file .
# Step 6: Test a singular Config.ini setting.
# Step 7: Print out the entire config.ini file and visually inspect it.
#
#
#
# The design goals for this code are :
# EXTENSIBILITY: Extensibility is an ability to add or extend additional elements and features to the existing code.
# ...

# %%
path_to_directory = 'C:/Users/josep/'
filename = 'configuring_sttings_documentation.doc'
file_full_name = path_to_directory + filename
tc.save_documentation(file_full_name) 
print(tc.read_documentation(file_full_name))
# Out:
# This jupiter notebook will establish a configuration file that contains configuration settings.
# The configuration file will allow you to quickly and easily customize settings and global variables.
# The configuration file will be maliable allowing users to reset configurations as needed.
#
#
#
# The high level steps for this solution are:
# Step 1: Establish the configuration parser engine.
# Step 2: Establish all the Sections for initial configuration settingsnStep 3: Write out name value pairs for all of the configuration settings.
# Step 4: Repeat steps 2 and 3 until all of the sections and configuration settings are complete.
# Step 5: Write out the config.ini file .
# Step 6: Test a singular Config.ini setting.
# Step 7: Print out the entire config.ini file and visually inspect it.
#
#
#
# The design goals for this code are :
# EXTENSIBILITY: Extensibility is an ability to add or extend additional elements and features to the existing code.
# ...

# %%
talking_code = True # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
tc.set_talking_code_on_or_off(talking_code) # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow 
if talking_code:
    tc.explain_the_whole_project() # OPTIONAL !!!! WARNING - Explaining the whole project is VERY Slow

# %%
talking_code_documentation = help(tc)

# %%
# Step 1 - Import the configparser module
import configparser
# Step 2 - Create the configparser object and pass it to a ‘config’ variable
config = configparser.ConfigParser()
# Step 3 - Create a config section name to organize settings into categories 
config.add_section('table_name_standards')
# Step 4 - Populate the section with name - value pairs 
config.set('table_name_standards', 'table_name_extension_daily', '_DI')
config.set('table_name_standards', 'table_name_extension_administrative', '_AD')
config.set('table_name_standards', 'table_name_extension_reject_records', '_RJ')
# Step 5 - Repeat items 3 and 4 for any subsequent sections.
config.add_section('SQL_server_schemas')
config.set('SQL_server_schemas', 'development_environment', '[pbic_1_0].')
 
config.add_section('SQLite')
config.set('SQLite', 'connect_string', 'sqlite_database.db')
config.set('SQLite', 'database_name', 'sqlite_database.db')

config.add_section('color_settings')
config.set('color_settings', 'LIGHT_BLUE', 'C5D9F1')
config.set('color_settings', 'YELLOW', 'FFFF00')
config.set('color_settings', 'GRAY', 'E4DFEC')
config.set('color_settings', 'DEEP_BLUE', '1072BA')
config.set('color_settings', 'DEEP_BLUE2', '1072BA')
config.set('color_settings', 'WHITE', 'FFFFFF')

config.set('color_settings', 'Green_Good', '85F386')
config.set('color_settings', 'Purple_Perfect', 'E951F6')
config.set('color_settings', 'Yellow_OK', 'F7F173')
config.set('color_settings', 'Gray_None', '696968')
config.set('color_settings', 'Red_Bad', 'E8241B')
config.set('color_settings', 'LIGHT_BLUE', 'C5D9F1')

config.set('color_settings', 'CONTENT_TAB_COLOR', 'C5D9F1') # Light Blue 
config.set('color_settings', 'USER_TAB_COLOR', 'FFFF00')   # Yellow 
config.set('color_settings', 'BLANK_WHITE', 'FFFFFF')   #White 
config.set('color_settings', 'HEADER_COLOR', 'C5D9F1') # Light Blue - Light Blue indicates relevant content for validation 
config.set('color_settings', 'HEADER_COLOR_USER_ENTRY', 'FFFF00') # Yellow - Yellow indicates a field for User Entry 
config.set('color_settings', 'HEADER_COLOR_INFORMATIONAL_ONLY', 'E4DFEC') # Gray - Indicates a field that maybe helpful but for information purposes only 

# Set up settings for text to spech and talking code
config.add_section('talking_code')
config.set('talking_code', 'talking_code', 'True')
config.set('talking_code', 'reading_introduction', 'True')
config.set('talking_code', 'reading_credits', 'True')
config.set('talking_code', 'reading_goals', 'True')
config.set('talking_code', 'reading_steps', 'True')
config.set('talking_code', 'reading_terms','True')
config.set('talking_code', 'Process_Name', 'talking_code') 
  
# Establish some import parameters for data discovery 
config.add_section('Data_Discovery')
config.set('Data_Discovery', 'importing_xlsx_files', 'False') 
config.set('Data_Discovery', 'importing_parquet_files', 'False')    
config.set('Data_Discovery', 'importing_csv_files', 'True')    
config.set('Data_Discovery', 'Data_Import_Starting_Directory_Home', 'C:/Data/')    
config.set('Data_Discovery', 'Data_Import_Starting_Directory_Work', 'Y:/_Kaleida_Input/')    
config.set('Data_Discovery', 'Data_Import_Starting_Directory', 'Y:/_Kaleida_Input/')   
config.set('Data_Discovery', 'process_name', 'Data_Discovery')    

# Establish some settings for this confugration and settings solution 
config.add_section('configuring_settings')
config.set('configuring_settings', 'configuration_file_name', 'config.ini') 
config.set('configuring_settings', 'configuration_file_directory_home', 'C:/Users/JAE670/') 
config.set('configuring_settings', 'configuration_file_directory_work', 'C:/Users/JAE670/') # if working from home 
config.set('configuring_settings', 'configuration_file_directory', 'C:/Users/JAE670/')  # Default location 

# Write the new structure to the new file
with open(r"config.ini", 'w') as configfile:
    config.write(configfile)

# %% [markdown]
# ## Testing reading from Configuration Setting

# %%
import configparser
config = configparser.ConfigParser()

config.read('config.ini')
print('Test config_get on SQLite :',config.get('SQLite','connect_string'))
print('Test configuration file name  :',config.get('configuring_settings','configuration_file_name'))
print('Test configuration file directory  :',config.get('configuring_settings','configuration_file_directory')) 
print('Test configuration file name  :',config.get('configuring_settings','configuration_file_name'))

# %% [markdown]
# ## Testing and Printing out configuration file

# %%
# Print out the Resulting Config File
path_to_directory = 'C:/Users/JAE670/'
path_to_directory = 'C:/Users/josep/'
filename = 'config.ini'
file_full_name = path_to_directory + filename
with open(file_full_name, 'r') as f:
    print('File {} opened with mode {} :\n'.format(file_full_name,f.mode)) 
    for line in f:
        print(line, end='')
