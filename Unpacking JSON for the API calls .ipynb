# %%
# Organization Test
o = h.Organization()
foo = o.get_organization()
print(pd.json_normalize(foo['items']))
# Cerner Organization DataFrame
master = pd.DataFrame(foo['items'])[['id','name']]
alias = pd.json_normalize(foo['items']
                        , record_path ='aliases'
                        , meta = ['id','name'])
addresses = pd.json_normalize(foo['items']
                        , record_path ='addresses'
                        , meta = ['id','name'])
telecoms = pd.json_normalize(foo['items']
                        , record_path ='telecoms'
                        , meta = ['id','name'])
temp = pd.merge(pd.merge(pd.merge(master,alias, how = 'left', on='id')
                         ,addresses, how= 'left',on='id')
                ,telecoms, how= 'left',on='id')
print(temp)
# Personnel Test
# p = h.Personnel()
# bar = p.get_personnel()
import hiduu.hiduu as h
from set
from Gagnon, Patrick (privately):    2:08 PM
import hiduu.hiduu as h
from settings import *
h.hiduu_upload_win(hiduu_path=HIDUU_PATH,
                   upload_command='uploadDataSetFile',
                   system_account_id=SOURCE_ID,
                   system_account_secret=SYSTEM_SECRET,
                   source_id=SOURCE_ID,
                   data_set_id='PYTHON_EDW_DIRECT',
                   file_id=FILE_TYPE_ID,
                   file_release= '20211214',
                   spec_version=SV,
                   file='C:/Users/plg846/Documents/hi-data-upload-utility-1.6/iris.csv',
                   reason=None,
                   sub_source=None, record_count=None, discovery=None, args=None, encryption=None,
                   client_mnemonic=None)

# %% [markdown]
# # Unpacking HealtheIntent API JSON Content
# ### Patrick Gagnon

# %%
# Import necessary Libraries 
import pandas as pd
import importlib  
import healtheintentAPI as h

# %%
# Organization Test
o = h.Organization()
foo = o.get_organization()
print(pd.json_normalize(foo['items']))
# Out:
#                                       id  \
# 0   e4dba7a2-6896-4878-8f32-560d4a0c0c38
# 1   cbbc83fe-6994-4889-a915-499380903fad
# 2   71522c48-58cd-467b-9b06-eaa22dcb94ee
# 3   76c26e90-91ce-4d24-b5d6-510d484fee72
# 4   ecb258a9-ad4d-4671-87fc-51ba2484c5f8
# 5   c71a2630-bb55-49c2-beda-1574e78bc3bc
# 6   70b0304a-954f-4c8f-a7d6-038b5ab6b707
# 7   1414c45f-3ab6-41c9-821e-8316d801a113
# 8   cbc9c430-1b7b-4f54-bcb8-9554a2f90652
# 9   4d99ec80-1bff-4bd0-902f-df2bdd98172d
# 10  7c758d7b-409d-47cd-ae43-166c69d3af2d
# 11  3ff64674-97f5-446e-932c-f2cc7f49e8f0
# 12  ef1e4aad-08ab-4d59-9e32-8017b17e8bf3
# 13  5124b6b5-f83b-45bb-befc-e8cb7a091831
# 14  d8b0a834-7e52-46b8-bdf5-8ca2644ae57d
# 15  32d80e35-a02f-4085-b646-042abeb4de90
# 16  57f4c1d7-77ea-422c-9129-cecd7daca672
# 17  c9b7dc2b-dd38-40b6-ab0b-d4e89b7351f1
# 18  86d347ec-4aee-4099-b506-22759766a17d
# 19  8b6eea16-1312-4d0f-b7e1-c738f18b8f8f
#
#                                         name telecoms  \
# ...

# %%
# Cerner Organization DataFrame
master = pd.DataFrame(foo['items'])[['id','name']]
alias = pd.json_normalize(foo['items']
                        , record_path ='aliases'
                        , meta = ['id','name'])
addresses = pd.json_normalize(foo['items']
                        , record_path ='addresses'
                        , meta = ['id','name'])
telecoms = pd.json_normalize(foo['items']
                        , record_path ='telecoms'
                        , meta = ['id','name'])
temp = pd.merge(pd.merge(pd.merge(master,alias, how = 'left', on='id')
                         ,addresses, how= 'left',on='id')
                ,telecoms, how= 'left',on='id')
print(temp)
