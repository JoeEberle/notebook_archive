# %% [markdown]
# ![library_installation.png](attachment:library_installation.png)

# %% [markdown]
# # Step 1 - Update and Install any libraries you need.  There is no harm in updateing to the latest version. There is no harm in adding more libraries !

# %%
# !pip install configparser
# !pip install schedule
# !pip install pyttsx3
# !pip install ipynbname   # error found in this library by Joe Eberle 11_4_2022 - Do not use !!!! 
# !pip install pandas 
# !pip install pyarrow
# !pip install fastparquet
# !pip install glob2 
# !pip install pathlib
# !pip install pyodbc
# !pip install sqlalchemy

# %% [markdown]
# # Step 2 - Import all the libraries used in the entire suite of solutions to make sure you have everything !! Import more libraries if you want. VISUALLY INSPECT and look for errors - you should get no errors!!!!

# %%
# Import the necessary Libraries 
import webbrowser as wb
import configparser as cg 
import schedule as sc
import time as time
import datetime as datetime
import pyttsx3 as td 
import ipynbname as nb 
import pandas as pd 
import pyarrow
import fastparquet
import glob 
import os
import pathlib
import pyodbc
import sqlalchemy

# %% [markdown]
# # Step 3 - Import any custom (non standard) libraries used !! Import more libraries if you want. VISUALLY INSPECT and look for errors - you should get no errors!!!

# %%
# Import the the Infrastructure Libraries that ARE NOT Standard Libraries 
import design_goal as dg
import glossary_of_terms as gt
import library_registry as lr
import solution_registry as sr

# %% [markdown]
# ## This <b><u>OPTIONAL</u></b> step produces <b><u>OPTIONAL</u></b> documentation and  <b><u>OPTIONAL</u></b> education . This step will document if documenting is set to True in the configuration file. This step will only explain itself to you via text to speech if Talking_code is set to True.

# %%
# optional education - The following code will only run if educating is set to True for this solution
import configparser   # Step 1 - Import the configparser module
config = configparser.ConfigParser() # Step 2 - Create the configparser object and pass it to a ‘config’ variable to get and set parameters 
cfg = config.read('config.ini')   
solution_name = 'library_installer' # Hard coded - replace with notebook name as discovered 
if config.get('global_infrastructure', 'documenting') == 'True':
    import os 
    import solution_documentation_library_installer as sd    # Establish the solutions documentation as sd 
    solution_documentation = sd.get_solution_documentation()  
    print(solution_documentation) 
    solution_document_file_name =config.get('global_infrastructure', 'infrastructure_directory') + '/' + config.get('global_infrastructure', 'documentation_directory')+ '/' + solution_name + config.get('global_infrastructure', 'documentation_extension')
    sd.save_documentation(solution_document_file_name) 
    print('Solution Documention saved to file: {} '.format(solution_document_file_name))           
if config.get(solution_name, 'talking_code') == 'True': 
    import talking_code as tc  
    tc.say(solution_documentation)
# Out:
# This solution documentation:
#
# This jupiter notebook will install and update all libraries.
# This solution is easily extended to include any libraries you choose.
#
# This Jupiter notebook was developed:
# In collaboration by Joe Eberle and others.
# The solution was developed in Python starting on 11/03/2022 and revised on 11/03/2022
# This solution is free and open source and the code is openly available for general use.
#
# The high level steps for this solution are:
# Step 1: pip install all librairies used.
# Step 2: test all STANDARD libraries by importing them and visually inspecting for import errors.
# Step 3:test all NON STANDARD or custom libraries by importing them and visually inspecting for import errors.
#
#
#
# The additional notes for this solution are:
# ...
