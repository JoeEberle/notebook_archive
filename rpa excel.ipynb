# %% [markdown]
# ![python%20pandas%20openpyxl.png](attachment:python%20pandas%20openpyxl.png)

# %%
import openpyxl
from openpyxl import Workbook, load_workbook
import pandas as pd
import glob
# Out:
# C:\Users\josep\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already up-to-date: numpy in c:\users\josep\anaconda3\lib\site-packages (1.24.1)

# %%
# !pip freeze | %{$_.split('==')[0]} | %{pip install --upgrade $_}
# Out:
# '%{$_.split' is not recognized as an internal or external command,
# operable program or batch file.

# %%
excel_directory = 'C:\working_directory\excel' 
filename = 'C://working_directory//excel//design_goal.xlsx'

# %%
def format_workbook(excel_filename):
    ''' The format_workbook function formaqts a worksheets so that it is functional and visually appealing.  '''
    status = f'formating workbook for file{excel_filename}'
    work_book = load_workbook(excel_filename)
    ws = work_book.active
    return ws 

Testing = True
if Testing:
    ws =format_workbook(filename)
    print(ws['A2'].value,'  ',ws['B2'].value)
    print(ws['A3'].value,'  ',ws['B3'].value)
# Out:
# EXTENSIBILITY    Extensibility is an ability to add or extend additional elements and features to the existing solution.
# ACCESSIBILITY    The ability for authorized users to easily access and use the solution from anywhere.
