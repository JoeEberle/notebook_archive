# %% [markdown]
# ![git%20%20and%20github.png](attachment:git%20%20and%20github.png)

# %% [markdown]
# # Git repo Setup and Github Automation
# #### by Joe Eberle started on 08-01-2023

# %%
first_time = False
if first_time:
    # !pip install PyGithub

# %%
# import the libraries necessary for the process 
import os, glob
import schedule
import time
from shutil import copyfile, copytree 
import schedule
import file_manager as fm 
from github import Github

# %%
token = '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'

# %%
g = Github(token)

# %%
for idx, repo in enumerate(g.get_user().get_repos()):
    print(f"\nGithub Repository {idx} :{repo.full_name}")
    repo_content = repo.get_contents("")
    for content_file in repo_content:
        print(f'\n file: {content_file}')
# Out:
# Github Repository 0 :JoeEberle/creating_settings
#
#  file: ContentFile(path="README.md")
#
#  file: ContentFile(path="configuring_settings.ipynb")
#
#  file: ContentFile(path="quick_logger.py")
#
#  file: ContentFile(path="talking_code.py")
#
# Github Repository 1 :JoeEberle/data_profiling
#
#  file: ContentFile(path="README.md")
#
# Github Repository 2 :JoeEberle/infrastructure_setup
#
#  file: ContentFile(path="README.md")
#
# Github Repository 3 :JoeEberle/system_information
#
#  file: ContentFile(path="README.md")
#
# Github Repository 4 :JoeEberle/talking_code
#
#  file: ContentFile(path="README.md")
#
#  file: ContentFile(path="quick_logger.py")
#
#  file: ContentFile(path="talking code.ipynb")
#
#  file: ContentFile(path="talking_code.py")

# %%
repo = g.get_repo("JoeEberle/creating_settings")
# Out:
# Repository(full_name="JoeEberle/creating_settings")

# %%
repo_content = repo.get_contents("")
for idx, content_file in enumerate(repo_content):
    print(f'Repostory Content {idx}: {content_file}')
# Out:
# Repostory Content 0: ContentFile(path="README.md")
# Repostory Content 1: ContentFile(path="quick_logger.py")
# Repostory Content 2: ContentFile(path="talking code.ipynb")
# Repostory Content 3: ContentFile(path="talking_code.py")

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
def create_directory_tree(directory):
    ''' The create_directory_tree function will create an organized directory for housing your files and infrastructure '''
    logging.info(f'{solution_name} - Step 1 establish infrastructure directory to organize all files')       
    status = 'Creating Directories: \n' + '\n' + fm.create_directory(directory)
    directory_list = ['updating_libraries','talking_code','system_information','logging_and_debugging' 
                      ,'infrastructure_setup','remote_process_automation_excel','data_discovery','Data_profiling'
                      ,'task_scheduling','data_delta_calculator','word_cloud','simple_chatbot_NLP_response' 
                      ,'intelligent_chatbot_web_scrapping','intelligent_chatbot_corpus_Learning' 
                      ,'intelligent_chatbot_data_serialization', 'intelligent_chatbot_generative_digital_assistent' 
                      ,'library_registry','solution_registry','design_goals','glossary_of_terms'
                      ,'data_loader_reference_tables','sdata_loader_transactional_tables'                      
                      ,'recurrent_nueral_network_chatbot_response_generator']
    for subdir in directory_list:
        status = status + '\n' + fm.create_directory(directory + '//' + subdir)
        logging.info(f'{solution_name} - Creating if non-existent : {directory + "/" + subdir}')                
    return status 

developing_and_testing = True # Unit test for this function  - set this to True or False to turn testing on or off 
if developing_and_testing:
    infrastructure_directory = "c://projects"
    if len(infrastructure_directory)  < 3:
        status = create_directory_tree('c://projects') # establish a default if none exists
    status = create_directory_tree(infrastructure_directory)        
    print(status)
# Out:
# Creating Directories:
#
# Error attempting to create directory:c://projects
# Error attempting to create directory:c://projects//updating_libraries
# Error attempting to create directory:c://projects//talking_code
# Error attempting to create directory:c://projects//system_information
# Error attempting to create directory:c://projects//logging_and_debugging
# Error attempting to create directory:c://projects//infrastructure_setup
# Error attempting to create directory:c://projects//remote_process_automation_excel
# Error attempting to create directory:c://projects//data_discovery
# Error attempting to create directory:c://projects//Data_profiling
# Error attempting to create directory:c://projects//task_scheduling
# Error attempting to create directory:c://projects//data_delta_calculator
# Error attempting to create directory:c://projects//word_cloud
# Error attempting to create directory:c://projects//simple_chatbot_NLP_response
# Error attempting to create directory:c://projects//intelligent_chatbot_web_scrapping
# Error attempting to create directory:c://projects//intelligent_chatbot_corpus_Learning
# Error attempting to create directory:c://projects//intelligent_chatbot_data_serialization
# Error attempting to create directory:c://projects//intelligent_chatbot_generative_digital_assistent
# Error attempting to create directory:c://projects//library_registry
# Error attempting to create directory:c://projects//solution_registry
# Error attempting to create directory:c://projects//design_goals
# Error attempting to create directory:c://projects//glossary_of_terms
# Error attempting to create directory:c://projects//data_loader_reference_tables
# Error attempting to create directory:c://projects//sdata_loader_transactional_tables
# Error attempting to create directory:c://projects//recurrent_nueral_network_chatbot_response_generator
