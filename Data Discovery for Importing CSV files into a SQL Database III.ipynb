# %% [markdown]
# # Create SQL Schema from CSV Files
# #### Joe Eberle, Alan Calhoun, Helmi (Al)  Seoud Code Refactored ON  : 9/20/2022  ---  Revised ON  : 10/6/2022

# %% [markdown]
# ### Project Setup - Importing Libraries and Initializing Global Variables

# %%
#install dependent Libraries is not already installed 
#!pip install pyttsx3

# Import the necessary Libraries 
import glob, os
import pandas as pd
# import logging 
from pathlib import Path
import pyttsx3
import pyodbc 
import timeit
import time
from datetime import date
from datetime import datetime
import sqlalchemy

# Establish some import parameters 

importing_xlsx_files = False 
importing_csv_files = True 
Data_Import_Starting_Directory = 'Y:/_Kaleida_Input/'
#Data_Import_Starting_Directory = 'C:/Data/'
Process_Name = 'Importing CSV data into SQL'

step_debugging = True
detail_debugging = True
detail_Talking = False # only talk on major steps 
Process_Step_Name = ''  
Reading_Intro = False
Reading_Credits =  False
Reading_Steps = False 
Reading_Terms = False 
printing_output = True
Talking_Code = True
Talking_Voice_Male_Gender = True        # Set to False for Female Voice 
Code_Logging  = True 
event_log_row = 0 

# Create some Global Variables for SQL Constructs 
column_inserts = ''
column_question_mark   = ''
create_table_SQL  = ''
create_real_table_SQL  = ''
insert_records_SQL  = ''
create_schema_SQL  = '' 
create_real_schema_SQL  = '' 
Table_Name_Extension_Daily = '_DI'
Table_Name_Extension_Historical = '_HX'
Table_Name_Extension_Rejected = '_RJ'
Table_Name_Extension_Administrative = '_AD'
Table_Name_Prefix = '[pbic_1_0].'

# Create some Global Variables for SQL Connection
server = 'Kalpwvsqlgppc01' 
database  = 'GPPC_DEV' 
username ='GPPC'
pwd = 'Elephant-Trunk-06'
sql_connector = 'DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection=No;UID='+username+';PWD='+pwd
# log_filename='data_importing_log.log'

# Configure the Logging to the DEBUG Level 
# logging.basicConfig(level=logging.DEBUG, filename=log_filename, format= '%(asctime)s %(clientip)-15s %(user)-8s %(message)s')
Text_to_Speech = pyttsx3.init()

## Dictionary For character_replacements List 
character_replacements = { " ":"_","#":"Number","%":"Percentage" \
                         ,'_Unnamed':'','_Level':'',"$":"Dollar",'_1':'' \
                         ,'_2':'','_3':'','_4':'','_5':''  \
                         ,'_6':'','_7':'','_8':'','_9':''  \
                         ,'_0':'',':7':'',':8':'',':':'' }
## Dictionary For replacing data types in databases 
data_type_replacements = { "object":"varchar","float64":"float","int64":"int","%":"Percentage" \
                         ,'_Unnamed':'','datetime64':'timestamp',"timedelta64[ns]":"varchar"}    

## add the glaobal data frames for event loggging and Schema Creation 
df_event_log = pd.DataFrame(columns = ('Event_ID','Process_Name','Event_Name','Event_Date','Event_Time','Task_Start_Time','Task_End_Time','TASk_Duration','Comments'))
df_import_directories = pd.DataFrame(columns = ('Root_Directory','Sub_Directory'))
df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','Import_File_Name','File_Size','File_Modified_Date','File_Created_Date'))
import_directory_file_Number  = 0
import_file_Number  = 0 
event_log_row = 0
sub_directory_count = 0 
import_csv_file_count = 0 
total_csv_file_count = 0

# %% [markdown]
# ### Customization - Special Formulas for GPPC

# %%
def customize_table_names(table_name):
    table_name = table_name.replace('ADPDaily_Time_Card','Time_Card').replace('Available_Slots_Past','Available_Slots')  \
    .replace('Available_Slots_Past','Available_Slots').replace('DailyAppointments','Appointments') \
    .replace('DailyAppointments','Appointments').replace('HXDX','Historical') \
    .replace('PatientInformationMain18Under','Patient_Information')  \
    .replace('QualityPrimaryCareAnnualVisitReport','Primary_Care_Annual_Visit') \
    .replace('RCM_Adujstments','RCM_Adjustments') \
    .replace('SurgicalAppointmentSummar2DaysAgo','Surgical_Appointment') \
    .replace('SurgicalAppointmentSummar2DaysAgo','Primary_Care_Annual_Visit') \
    .replace('Third_Next_Available','Third_Next_Available') \
    .replace('ADPEmployee_Census','Employee_Census') \
    .replace('Third_Next_Available','Third_Next_Available')
    return table_name



def customize_column_name_clean_up(df_to_clean):
    df_to_clean = df_to_clean.rename(columns={'Name_':'Name','Appt_Date':'Appointment_Date','Appt_Type':'Appointment_Type' \
                                ,'EbillEsuperbillNumber':'Ebill_Esuper_Bill_Number' \
                                ,'Referral_FromTodo_Selection':'Referral_From_To_Do_Selection' \
                                ,'Wellnow_LocationTodo_Selection':'Wellnow_Location_To_Do_Selection' \
                                ,'Access_Vip':'Access_VIP' \
                                ,'Vip':'VIP' \
                                ,'Todo_DateCreate_Date':'To_Do_Date_Create_Date' \
                               }, inplace = True)
    return df_to_clean

# %% [markdown]
# ## Project Setup -    Establishing DataFrames & Establishing Global Functions

# %%
global Talking_Code
global import_directory_file_Number 
global event_log_row 
global printing_output


def set_up_python_infrastructure():
    initialize_replacement_Dictionaries()    # Set up control libraries for syntactic Consistency 
    Initialize_Text_to_Speach()              # Intitialize Text to Speech Engine 
    df_e_log = create_event_log_dataframe()  # Set up the Event Logging 
    
# Say Whatever the user wants 
def say(speech):
    if Talking_Code:
        Text_to_Speech.say(speech)
        Text_to_Speech.runAndWait()    
    
# Intitialize Text to Speech Engine 
def Initialize_Text_to_Speach():
    Text_to_Speech = pyttsx3.init()
    Text_to_Speech.setProperty('Rate',187)
    voices = Text_to_Speech.getProperty('voices')
    if Talking_Voice_Male_Gender:
        Text_to_Speech.setProperty('voice', voices[0].id)    # Default Male voice registered as 'Dave'
    else: 
        Text_to_Speech.setProperty('voice', voices[1].id)    # Alternate Female voice registered as 'Tina'
    speech = 'The text to speech engine is initialized using pythons pyttsx3 engine'
    Text_to_Speech.say(speech)
    Text_to_Speech.runAndWait()    
    
    
# Say Whatever the user wants 
def say(speech):
    Text_to_Speech.say(speech)
    Text_to_Speech.runAndWait()       
    
# Create dataframe to house Directories 
def create_directory_dataframe():
    df_import_directories = pd.DataFrame(columns = ('Root_Directory','Sub_Directory'))
    return df_import_directories  

def create_import_files_dataframe():
    df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','File_Name','File_Size_Bytes','File_Created','File_Modified'))
    return df_import_files  

def add_import_directory(Root_Directory,Sub_Directory):
    global import_directory_file_Number 
    import_directory_file_Number += 1  
    df_import_directories.loc[import_directory_file_Number] = [Root_Directory,Sub_Directory]
    return import_directory_file_Number 

def add_import_file(Root_Directory,Sub_Directory,Table_Name,File_Name,File_Size_Bytes,File_Created,File_Modified):
    global import_file_Number 
    import_file_Number += 1  
    df_import_files.loc[import_file_Number] = [Root_Directory,Sub_Directory,Table_Name,File_Name,File_Size_Bytes,File_Created,File_Modified]
    return import_directory_file_Number  

# Create dataframe to house Directories 
def create_event_log_dataframe():
    df_event_log = pd.DataFrame(columns = ('Event_ID','Process_Name','Event_Name','Event_Date','Event_Time','Task_Start_Time','Task_End_Time','TASk_Duration','Comments'))
    return df_event_log


df_event_log = create_event_log_dataframe()

# Create dataframe to database schema 
def create_database_schema_dataframe():
    df_schema = pd.DataFrame(columns = ('Database_Name','Table_Name','Column_Number','Column_Name','Column_Data_Type','Column_Sample_Data','Column_Description'))
    return df_schema

# Create dataframe to house Directories 
def add_log_event(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]

    
# Add Log Events 
def add_log_event_timer(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    Event_Date = date.today()
    Event_Time = time.time() 
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]
    
# Reset the Event timer start time 
def reset_event_timer(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    Event_Date = date.today()
    Event_Time = time.time() 
    Task_Start_Time    = time.time()  
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]

    # Get a list of all the Subfiles to iterate through 
def list_all_csv_files(path):
    extension = 'csv'
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        out('CSV File #{} filename: {}  '.format(str(csv_file_count),file))

# Get a list of all the Subfiles to iterate through 
def register_all_csv_files_for_import(path, table_name):
    global total_csv_file_count  
    extension = 'csv'
    os.chdir(path)
#     print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        total_csv_file_count += 1         
        File_Size = os.path.getsize(file)
        File_Last_Modified =  time.ctime(os.path.getmtime(file))
        File_Create_Date =  time.ctime(os.path.getctime(file))
        Full_Path_File_Name = path + '\\' + file
        Full_Path_File_Name = Full_Path_File_Name.replace('/','\**').replace('\\','\**').replace('**','')
        out('CSV Total#{} File #{} filename: {}  '.format(str(total_csv_file_count),str(csv_file_count),file)) 
        file_Number = add_import_file(path,path,table_name,file,File_Size,File_Last_Modified,File_Create_Date)
        
def create_import_files_dataframe():
    df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','File_Name'))
    return df_import_files  

def add_import_directory(Root_Directory,Sub_Directory):
    global import_directory_file_Number 
    import_directory_file_Number += 1  
    df_import_directories.loc[import_directory_file_Number] = [Root_Directory,Sub_Directory]
    return import_directory_file_Number 

def add_import_File(Root_Directory,Sub_Directory,Table_Name,File_Name):
    global import_file_Number 
    import_file_Number += 1  
    df_import_files.loc[import_file_Number] = [Root_Directory,Sub_Directory,Table_Name,File_Name]
    return import_directory_file_Number          
        
    
def infer_table_name_from_path(path):
    table_name = path.replace(Data_Import_Starting_Directory,"").replace('Y:/_Kaleida_Input/','').replace('Y:_Kaleida_Input','').replace(' ','_').replace('/','').replace('\\','')
    table_name = customize_table_names(table_name)
    return table_name 
        
# Introduction - Overview of CSV to SQL Import Process Steps 
def read_credits(): 
    Dialog = 'This Jupiter Notebook Was  : '
    Dialog = Dialog + 'Developed in Collaboration by Joe Eberle, Alan Calhoun, Helmi (Al) Seoud  '
    Dialog = Dialog + 'Developed in Python starting on 9/20/2022 '
    Dialog = Dialog + 'This package is free AND Open Source and the code is openly available for general Use. '    
    say(Dialog)         
    
# Introduction - Overview of CSV to SQL Import Process Steps 
def read_terms(): 
    Dialog = 'The terminology for this process is : '
    Dialog = Dialog + 'Python. Python is a general-purpose programming language that is widely used for data science.  '
    Dialog = Dialog + 'Structured Query Language (SQL) is one of the worlds most widely used programming languages for manipulating and querying data. '
    Dialog = Dialog + 'CSV. A Comma-Separated Values (CSV)  file is a text file in which information is separated by commas. '
    Dialog = Dialog + 'PANDAS. Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.  '
    Dialog = Dialog + 'OS PACKAGE - The OS python library provides a portable way of using operating system dependent functionality to allow your python code to run on all platforms '
    say(Dialog)  
    
# Process Steps - Overview of CSV to SQL Import Process Steps 
def read_process_steps():
    Dialog = 'The data flow for this process is : '
    Dialog = Dialog + 'Precursor Step 1: The clinician or administrator enters the patients data into the Electronic Medical Record (EMR). '
    Dialog = Dialog + 'Precursor Step 2: At the end of the day the EMR data is exported into Comma Seperated Values (CSV) files and shared via SFTP. '
    Dialog = Dialog + 'Step 1: Establish The Root Directory. '
    Dialog = Dialog + 'Step 2: Walk the directory structure discovering data to discover all data directories  '
    Dialog = Dialog + 'Step 3: Register the directories in an excel spreadsheet for future processing. '
    Dialog = Dialog + 'Step 4: Register the CSV Files in an excel spreadsheet for future processing. ' 
    say(Dialog)    
    
    
# Introduction - Overview of NoteBooks  
def read_introduction():
    Dialog = 'This jupiter notebook will discover all of the CSV files under a specific root directory. '
    Dialog = Dialog +  'This python code will take the CSV files exported from an Electronic Medical Record platform. '
    Dialog = Dialog + 'and import them into a faster database such as SQL Lite or PostgreSQL or SQL Server or SNOW Flake. '
    Dialog = Dialog + 'The directories will then be available for future importing. '
    say(Dialog)  
    
    
def column_create_SQL (import_df):
    column_name_List = [x.title() for x in import_df.columns] # Create a List of Columns 
    column_Str =  (', '.join(column_name_List)) # Convert List into one String with commas 
    out('Columns =',column_Str)  
    return column_Str            
    
    
def out(dialog):
    global detail_Talking
    if printing_output: 
        print(dialog) 
    if Talking_Code and detail_Talking == True:
        say(dialog)   
    if Talking_Code and (detail_Talking == False) and (dialog.find('step') >= 0):
        say(dialog)     

        
def list_all_xlsx_files(path):
    extension = 'xlsx'
    os.chdir(path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        out('File #{}   is {} '.format(csv_file_count,file))     \
        
        
def explain_the_project():
    if Reading_Intro:
        read_introduction()
    if Reading_Credits:    
        read_credits() 
    if Reading_Steps:
        read_process_steps()
    if Reading_Terms:
        read_terms()        
        
        
        
def convert_data_types(input_df):
    column_datatype_str = str(input_df.dtypes)
    column_datatype_str =  column_datatype_str.replace('dtype: object','').replace('object','varchar[255], ').replace('datetime64[ns]','timestamp, ').replace('float64','float, ')
    out('create column SQL string: {} \n'.format(column_datatype_str))        
        
def read_and_clean_file(data_folder, filename):

    print('Import File =', filename)                 
    df_input_csv = pd.read_csv(filename, nrows=10)
    out('Reading Dataframe Columns before cleanups:{}'.format(df_input_csv.columns))
    df_input_csv.columns = df_input_csv.columns.map('^'.join)
    df_input_csv.columns  = [x.strip().title().replace("^","").replace(" ","_").replace("#","Number").replace("#","Number").replace("%","Percentage") \
                             .replace('_Unnamed','').replace('Unnamed','').replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_input_csv.columns]
    return df_input_csv    
 
        
    
def set_up_python_infrastructure():
    initialize_replacement_Dictionaries()    # Set up control libraries for syntactic Consistency 
    Initialize_Text_to_Speach()              # Intitialize Text to Speech Engine 
    df_event_log = create_event_log_dataframe()  # Set up the Event Logging to housae the events of this process 
    create_database_schema_dataframe()       # Set up the Database Schema dataframe to house the schema

# %%
print('Talking Code Setting: ',Talking_Code)
print('Talking Code Detail Setting: ',detail_Talking)
if Talking_Code:
    if Talking_Voice_Male_Gender: 
        out('Talking_Code: Text to Voice set to ON. Voice set  to  Default Male Voice. ')
    else: 
        out('Talking_Code: Text to Voice set to ON. Voice set  to  Alternate Female Voice. ')
    if  detail_Talking:   
        out('Talking  Details is set to True say all detailed outputs..  this will be slow and boring ') 
    else: 
        out('Talking  Details is set to False to say only major steps..  this setting will execute fast and tell you the high level steps of the process. ')
# Out:
# Talking Code Setting:  True
# Talking Code Detail Setting:  False
# Talking_Code: Text to Voice set to ON. Voice set  to  Default Male Voice.
# Talking  Details is set to False to say only major steps..  this setting will execute fast and tell you the high level steps of the process.

# %% [markdown]
# ## Process Reinitialize - Re initialize the Data Frames and all Global Counters to Zero

# %%
global import_directory_file_Number 
global import_file_Number  
global event_log_row 
global sub_directory_count  

# recreate the dataframes 
create_directory_dataframe() 
create_import_files_dataframe() 
create_database_schema_dataframe() 

# reset all the global Counters  
import_directory_file_Number  = 0
import_file_Number  = 0 
event_log_row = 0
sub_directory_count = 0

# %% [markdown]
# ## Optional Precursor Step  - Explain the Project

# %%
explain_the_project()

# %% [markdown]
# ## Step 1 - Establish the root Directory

# %%
add_log_event(Process_Name,'step 1 - Establish the root Directory: {}'.format(Data_Import_Starting_Directory),datetime.now(),datetime.now(),time.time(),time.time(), 0 ,'Step 1 - Establish the root Directory: {}'.format(Data_Import_Starting_Directory))
Process_Step_Name = 'Step 1 - Establish the root Directory' 
out('Step 1 - Establish the root Directory')
out('The root directory to walk is : {}'.format(Data_Import_Starting_Directory))  
df_event_log.head()
# Out:
# Step 1 - Establish the root Directory
# The root directory to walk is : Y:/_Kaleida_Input/
#   Event_ID                 Process_Name  \
# 1        1  Importing CSV data into SQL
#
#                                           Event_Name  \
# 1  step 1 - Establish the root Directory: Y:/_Kal...
#
#                   Event_Date                 Event_Time  Task_Start_Time  \
# 1 2022-10-18 17:24:31.900737 2022-10-18 17:24:31.900737     1.666128e+09
#
#    Task_End_Time TASk_Duration  \
# 1   1.666128e+09             0
#
#                                             Comments
# 1  Step 1 - Establish the root Directory: Y:/_Kal...

# %% [markdown]
# ## Step 2 - Walk the directory structure discovering data to discover all data directories

# %%
global sub_directory_count
# Get a list of all the Subfiles to iterate through 
def walk_sub_directories(root_directory):
    global sub_directory_count
    Process_Step_Name = 'Step 2 - Walk the directory structure discovering data to discover all data directories' 
    df_import_directories = create_directory_dataframe() 
    directory_entry = 0 
 
    for root, subdirectories, files in os.walk(root_directory):
        # hard coded - remove this later!!!!!! 
        # old data and Excel data should NOT BE Included under root 
        if (root.find('old') == -1) and (root.find('excel') == -1):
            out('Registering Directory # {} {}  '.format(directory_entry,root ))            
            directory_entry += 1 
            sub_directory_count += 1     
            num = add_import_directory(root, root)        
         
    return df_import_directories

out('Step 2 - Walk the directory structure  to discover all data directories')
add_log_event(Process_Name,'Step 2 - Walk the directory structure  to discover all data directories',datetime.now(),datetime.now(),time.time(),time.time(), 0 ,'Step 2 - Walk the directory structure  to discover all data directories'.format(Data_Import_Starting_Directory))
walk_sub_directories(Data_Import_Starting_Directory)  
out('Step 2 Done - Listing all Registered data Directories: ')
# Out:
# Step 2 - Walk the directory structure  to discover all data directories
# Registering Directory # 0 Y:/_Kaleida_Input/
# Registering Directory # 1 Y:/_Kaleida_Input/Access
# Registering Directory # 2 Y:/_Kaleida_Input/ADP
# Registering Directory # 3 Y:/_Kaleida_Input/ADP\Daily Time Card
# Registering Directory # 4 Y:/_Kaleida_Input/ADP\Employee Census
# Registering Directory # 5 Y:/_Kaleida_Input/Available_Slots
# Registering Directory # 6 Y:/_Kaleida_Input/Available_Slots_Past
# Registering Directory # 7 Y:/_Kaleida_Input/DailyAppointments
# Registering Directory # 8 Y:/_Kaleida_Input/Future Surgeries
# Registering Directory # 9 Y:/_Kaleida_Input/FutureAppointmentVisits
# Registering Directory # 10 Y:/_Kaleida_Input/Hx
# Registering Directory # 11 Y:/_Kaleida_Input/HXDX
# Registering Directory # 12 Y:/_Kaleida_Input/Incident
# Registering Directory # 13 Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# Registering Directory # 14 Y:/_Kaleida_Input/LungCancerScreeningTracker
# Registering Directory # 15 Y:/_Kaleida_Input/MissingNPIAudit
# Registering Directory # 16 Y:/_Kaleida_Input/OncologyNavigation
# Registering Directory # 17 Y:/_Kaleida_Input/PatientExperience
# Registering Directory # 18 Y:/_Kaleida_Input/PatientInformation
# Registering Directory # 19 Y:/_Kaleida_Input/PatientInformation\Main18Under
# Registering Directory # 20 Y:/_Kaleida_Input/PaymentMismatch
# Registering Directory # 21 Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# Registering Directory # 22 Y:/_Kaleida_Input/ProviderPanel
# Registering Directory # 23 Y:/_Kaleida_Input/Quality
# Registering Directory # 24 Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVisitReport
# Registering Directory # 25 Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# Registering Directory # 26 Y:/_Kaleida_Input/RCM-InpatientCharges
# Registering Directory # 27 Y:/_Kaleida_Input/RCM_Adujstments
# Registering Directory # 28 Y:/_Kaleida_Input/RCM_OpenSuperbills
# Registering Directory # 29 Y:/_Kaleida_Input/RCM_Productivity
# Registering Directory # 30 Y:/_Kaleida_Input/Referrals - Recommendation
# Registering Directory # 31 Y:/_Kaleida_Input/ReferringProviders
# Registering Directory # 32 Y:/_Kaleida_Input/SurgicalAppointmentSummar2DaysAgo
# Registering Directory # 33 Y:/_Kaleida_Input/Third_Next_Available
# Step 2 Done - Listing all Registered data Directories:

# %%
# Persist the directories in an excel file Registry 
Data_Import_Starting_Directory =  'J:/IT GLIN Data Services Shared/TempData/'
Excel_file_Name = Data_Import_Starting_Directory + 'Import_Directory_Registry.xlsx'
out('Registering Directories in excel File:{} '.format(Excel_file_Name))
df_import_directories.to_excel(Excel_file_Name, index=False)
# Out:
# Registering Directories in excel File:J:/IT GLIN Data Services Shared/TempData/Import_Directory_Registry.xlsx

# %%
df_import_directories.shape
# Out:
# (34, 2)

# %%
df_import_directories.head(100)
# Out:
#                                        Root_Directory  \
# 1                                  Y:/_Kaleida_Input/
# 2                            Y:/_Kaleida_Input/Access
# 3                               Y:/_Kaleida_Input/ADP
# 4               Y:/_Kaleida_Input/ADP\Daily Time Card
# 5               Y:/_Kaleida_Input/ADP\Employee Census
# 6                   Y:/_Kaleida_Input/Available_Slots
# 7              Y:/_Kaleida_Input/Available_Slots_Past
# 8                 Y:/_Kaleida_Input/DailyAppointments
# 9                  Y:/_Kaleida_Input/Future Surgeries
# 10          Y:/_Kaleida_Input/FutureAppointmentVisits
# 11                               Y:/_Kaleida_Input/Hx
# 12                             Y:/_Kaleida_Input/HXDX
# 13                         Y:/_Kaleida_Input/Incident
# 14     Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# 15       Y:/_Kaleida_Input/LungCancerScreeningTracker
# 16                  Y:/_Kaleida_Input/MissingNPIAudit
# 17               Y:/_Kaleida_Input/OncologyNavigation
# 18                Y:/_Kaleida_Input/PatientExperience
# 19               Y:/_Kaleida_Input/PatientInformation
# 20   Y:/_Kaleida_Input/PatientInformation\Main18Under
# 21                  Y:/_Kaleida_Input/PaymentMismatch
# 22   Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# 23                    Y:/_Kaleida_Input/ProviderPanel
# 24                          Y:/_Kaleida_Input/Quality
# 25  Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVis...
# 26      Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# 27             Y:/_Kaleida_Input/RCM-InpatientCharges
# 28                  Y:/_Kaleida_Input/RCM_Adujstments
# 29               Y:/_Kaleida_Input/RCM_OpenSuperbills
# 30                 Y:/_Kaleida_Input/RCM_Productivity
# 31       Y:/_Kaleida_Input/Referrals - Recommendation
# 32               Y:/_Kaleida_Input/ReferringProviders
# 33  Y:/_Kaleida_Input/SurgicalAppointmentSummar2Da...
# 34             Y:/_Kaleida_Input/Third_Next_Available
#
#                                         Sub_Directory
# 1                                  Y:/_Kaleida_Input/
# 2                            Y:/_Kaleida_Input/Access
# 3                               Y:/_Kaleida_Input/ADP
# 4               Y:/_Kaleida_Input/ADP\Daily Time Card
# 5               Y:/_Kaleida_Input/ADP\Employee Census
# 6                   Y:/_Kaleida_Input/Available_Slots
# 7              Y:/_Kaleida_Input/Available_Slots_Past
# 8                 Y:/_Kaleida_Input/DailyAppointments
# 9                  Y:/_Kaleida_Input/Future Surgeries
# 10          Y:/_Kaleida_Input/FutureAppointmentVisits
# 11                               Y:/_Kaleida_Input/Hx
# 12                             Y:/_Kaleida_Input/HXDX
# 13                         Y:/_Kaleida_Input/Incident
# 14     Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# 15       Y:/_Kaleida_Input/LungCancerScreeningTracker
# 16                  Y:/_Kaleida_Input/MissingNPIAudit
# 17               Y:/_Kaleida_Input/OncologyNavigation
# 18                Y:/_Kaleida_Input/PatientExperience
# 19               Y:/_Kaleida_Input/PatientInformation
# 20   Y:/_Kaleida_Input/PatientInformation\Main18Under
# 21                  Y:/_Kaleida_Input/PaymentMismatch
# 22   Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# 23                    Y:/_Kaleida_Input/ProviderPanel
# 24                          Y:/_Kaleida_Input/Quality
# 25  Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVis...
# 26      Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# 27             Y:/_Kaleida_Input/RCM-InpatientCharges
# 28                  Y:/_Kaleida_Input/RCM_Adujstments
# 29               Y:/_Kaleida_Input/RCM_OpenSuperbills
# 30                 Y:/_Kaleida_Input/RCM_Productivity
# 31       Y:/_Kaleida_Input/Referrals - Recommendation
# 32               Y:/_Kaleida_Input/ReferringProviders
# 33  Y:/_Kaleida_Input/SurgicalAppointmentSummar2Da...
# 34             Y:/_Kaleida_Input/Third_Next_Available

# %% [markdown]
# ## Step 3 - Discover and Register all CSV files to import

# %%
def iterate_directories_to_import_files(Import_Directory_Data_Frame):
    out('Step 3 - Discover and Register all CSV files to import ')
    Process_Step_Name = 'Step 3 - Discover and Register all CSV files to import'  
    list_of_Directories = df_import_directories['Root_Directory']
    dir_count = 0
    for dir in list_of_Directories:
        dir_count += 1
        out('Directory #{} to find import files : {} \n   '.format(dir_count,dir))
        SQL_Table_Name = infer_table_name_from_path(dir)
        register_all_csv_files_for_import(dir, SQL_Table_Name   )

iterate_directories_to_import_files(df_import_directories)
# Out:
# Step 3 - Discover and Register all CSV files to import
# Directory #1 to find import files : Y:/_Kaleida_Input/
#
# Directory #2 to find import files : Y:/_Kaleida_Input/Access
#
# Directory #3 to find import files : Y:/_Kaleida_Input/ADP
#
# Directory #4 to find import files : Y:/_Kaleida_Input/ADP\Daily Time Card
#
# CSV Total#1 File #1 filename: DailyTimecardReport.050421190755.csv
# CSV Total#2 File #2 filename: DailyTimecardReport.051821190747.csv
# CSV Total#3 File #3 filename: DailyTimecardReport.060121190842.csv
# CSV Total#4 File #4 filename: DailyTimecardReport.061521190831.csv
# CSV Total#5 File #5 filename: DailyTimecardReport.062921190854.csv
# CSV Total#6 File #6 filename: DailyTimecardReport.071321190908.csv
# CSV Total#7 File #7 filename: DailyTimecardReport.072721190859.csv
# CSV Total#8 File #8 filename: DailyTimecardReport.081021190954.csv
# CSV Total#9 File #9 filename: DailyTimecardReport.082421190545.csv
# CSV Total#10 File #10 filename: DailyTimecardReport.090721191026.csv
# CSV Total#11 File #11 filename: DailyTimecardReport.092121190806.csv
# CSV Total#12 File #12 filename: DailyTimecardReport.100521190616.csv
# CSV Total#13 File #13 filename: DailyTimecardReport.101921190707.csv
# CSV Total#14 File #14 filename: DailyTimecardReport.110221190902.csv
# CSV Total#15 File #15 filename: DailyTimecardReport.111621190810.csv
# CSV Total#16 File #16 filename: DailyTimecardReport.113021190601.csv
# CSV Total#17 File #17 filename: DailyTimecardReport.121421190704.csv
# CSV Total#18 File #18 filename: DailyTimecardReport.122821191049.csv
# CSV Total#19 File #19 filename: DailyTimecardReport.csv
# Directory #5 to find import files : Y:/_Kaleida_Input/ADP\Employee Census
#
# CSV Total#20 File #1 filename: EmployeeCensus.043021190734.csv
# CSV Total#21 File #2 filename: EmployeeCensus.053121190439.csv
# CSV Total#22 File #3 filename: EmployeeCensus.063021190840.csv
# CSV Total#23 File #4 filename: EmployeeCensus.073121190558.csv
# CSV Total#24 File #5 filename: EmployeeCensus.083121190751.csv
# CSV Total#25 File #6 filename: EmployeeCensus.093021190526.csv
# CSV Total#26 File #7 filename: EmployeeCensus.103121190215.csv
# CSV Total#27 File #8 filename: EmployeeCensus.113021190508.csv
# CSV Total#28 File #9 filename: EmployeeCensus.123121190308.csv
# CSV Total#29 File #10 filename: EmployeeCensus.csv
# Directory #6 to find import files : Y:/_Kaleida_Input/Available_Slots
#
# CSV Total#30 File #1 filename: February 2022 Available Slot.csv
# CSV Total#31 File #2 filename: January 2022 available slots.csv
# CSV Total#32 File #3 filename: Main 4.12 to 10.13.csv
# CSV Total#33 File #4 filename: Main 4.13 to 10.14.csv
# CSV Total#34 File #5 filename: Main 4.14 to 10.15.csv
# CSV Total#35 File #6 filename: Main 4.15 to 10.16.csv
# CSV Total#36 File #7 filename: Main 4.16 to 10.17.csv
# CSV Total#37 File #8 filename: Main 4.19 to 10.20.csv
# CSV Total#38 File #9 filename: Main 4.20 to 10.21.csv
# CSV Total#39 File #10 filename: Main 4.21 to 10.22.csv
# CSV Total#40 File #11 filename: Main 4.22 to 10.23.csv
# CSV Total#41 File #12 filename: Main 4.23 to 10.24.csv
# CSV Total#42 File #13 filename: Main 4.26 to 10.27.csv
# CSV Total#43 File #14 filename: Main 4.27 to 10.28.csv
# CSV Total#44 File #15 filename: Main 4.28 to 10.29.csv
# CSV Total#45 File #16 filename: Main 4.29 to 10.30.csv
# CSV Total#46 File #17 filename: Main 4.30 to 10.31.csv
# CSV Total#47 File #18 filename: Main 4_2 to 10_2.csv
# CSV Total#48 File #19 filename: Main 4_5 to 10_5.csv
# CSV Total#49 File #20 filename: Main 4_7 to 10_7.csv
# CSV Total#50 File #21 filename: Main 5.10 to 11.11.csv
# CSV Total#51 File #22 filename: Main 5.11 to 11.12.csv
# CSV Total#52 File #23 filename: Main 5.12 to 11.13.csv
# CSV Total#53 File #24 filename: Main 5.13 to 11.14.csv
# CSV Total#54 File #25 filename: Main 5.14 to 11.15.csv
# CSV Total#55 File #26 filename: Main 5.17 to 11.18.csv
# CSV Total#56 File #27 filename: Main 5.18 to 11.19.csv
# CSV Total#57 File #28 filename: Main 5.19 to 11.20.csv
# CSV Total#58 File #29 filename: Main 5.2 to 11.2.csv
# CSV Total#59 File #30 filename: Main 5.20 to 11.21.csv
# CSV Total#60 File #31 filename: Main 5.21 to 11.22.csv
# CSV Total#61 File #32 filename: Main 5.24 to 11.25.csv
# CSV Total#62 File #33 filename: Main 5.25 to 11.26.csv
# CSV Total#63 File #34 filename: Main 5.26 to 11.27.csv
# CSV Total#64 File #35 filename: Main 5.27 to 11.28.csv
# CSV Total#65 File #36 filename: Main 5.28 to 11.29.csv
# CSV Total#66 File #37 filename: Main 5.4 to 11.4.csv
# CSV Total#67 File #38 filename: Main 5.5 to 11.5.csv
# CSV Total#68 File #39 filename: Main 5.6 to 11.7.csv
# CSV Total#69 File #40 filename: Main 5.7 to  11.8.csv
# CSV Total#70 File #41 filename: Main 6.1 to 12.1.csv
# CSV Total#71 File #42 filename: Main 6.10 to 12.11.csv
# CSV Total#72 File #43 filename: Main 6.11 to 12.12.csv
# CSV Total#73 File #44 filename: Main 6.14 to 12.15.csv
# CSV Total#74 File #45 filename: Main 6.15 to 12.16.csv
# CSV Total#75 File #46 filename: Main 6.16 to 12.17.csv
# CSV Total#76 File #47 filename: Main 6.17 to 12.18.csv
# CSV Total#77 File #48 filename: Main 6.18 to 12.19.csv
# CSV Total#78 File #49 filename: Main 6.2 to 12.2.csv
# CSV Total#79 File #50 filename: Main 6.21 to 12.22.csv
# CSV Total#80 File #51 filename: Main 6.22 to 12.23.csv
# CSV Total#81 File #52 filename: Main 6.23 to 12.24.csv
# CSV Total#82 File #53 filename: Main 6.24 to 12.25.csv
# CSV Total#83 File #54 filename: Main 6.25 to 12.26.csv
# CSV Total#84 File #55 filename: Main 6.28 to 12.29.csv
# CSV Total#85 File #56 filename: Main 6.29 to 12.30.csv
# CSV Total#86 File #57 filename: Main 6.3 to 12.4.csv
# CSV Total#87 File #58 filename: Main 6.30 to 12.31.csv
# CSV Total#88 File #59 filename: Main 6.4 to 12.5.csv
# CSV Total#89 File #60 filename: Main 6.7 to 12.8.csv
# CSV Total#90 File #61 filename: Main 6.8 to 12.9.csv
# CSV Total#91 File #62 filename: Main 6.9 to 12.10.csv
# CSV Total#92 File #63 filename: Main 7.1 to 1.1.csv
# CSV Total#93 File #64 filename: Main 7.2 to 1.2.csv
# CSV Total#94 File #65 filename: Main 7.6 to 1.7.csv
# CSV Total#95 File #66 filename: Main 7.8 to 1.9.csv
# CSV Total#96 File #67 filename: Main 7.9 to 1.10.csv
# CSV Total#97 File #68 filename: Main 7_12 to 1_13.csv
# CSV Total#98 File #69 filename: Main 7_7 to 1_8.csv
# CSV Total#99 File #70 filename: March 2022 List of Available Slot.csv
# CSV Total#100 File #71 filename: Sub II 4.12 to 10.13.csv
# CSV Total#101 File #72 filename: Sub II 4.13 to 10.14.csv
# CSV Total#102 File #73 filename: Sub II 4.14 to 10.15.csv
# CSV Total#103 File #74 filename: Sub II 4.15 to 10.16.csv
# CSV Total#104 File #75 filename: Sub II 4.16 to 10.17.csv
# CSV Total#105 File #76 filename: Sub II 4.19 to 10.20.csv
# CSV Total#106 File #77 filename: Sub II 4.20 to 10.21.csv
# CSV Total#107 File #78 filename: Sub II 4.21 to 10.22.csv
# CSV Total#108 File #79 filename: Sub II 4.22 to 10.23.csv
# CSV Total#109 File #80 filename: Sub II 4.23 to 10.24.csv
# CSV Total#110 File #81 filename: Sub II 4.26 to 10.27.csv
# CSV Total#111 File #82 filename: Sub II 4.27 to 10.28.csv
# CSV Total#112 File #83 filename: Sub II 4.28 to 10.29.csv
# CSV Total#113 File #84 filename: Sub II 4.29 to 10.30.csv
# CSV Total#114 File #85 filename: Sub II 4.30 to 10.31.csv
# CSV Total#115 File #86 filename: Sub II 4.7 to 10.7.csv
# CSV Total#116 File #87 filename: Sub II 4_1 to 10_2.csv
# CSV Total#117 File #88 filename: Sub II 4_5 to 10_5.csv
# CSV Total#118 File #89 filename: Sub II 5.10 to 11.11.csv
# CSV Total#119 File #90 filename: Sub II 5.11 to 11.12.csv
# CSV Total#120 File #91 filename: Sub II 5.12 to 11.13.csv
# CSV Total#121 File #92 filename: Sub II 5.13 to 11.14.csv
# CSV Total#122 File #93 filename: Sub II 5.14 to 11.15.csv
# CSV Total#123 File #94 filename: Sub II 5.17 to 11.18.csv
# CSV Total#124 File #95 filename: Sub II 5.18 to 11.19.csv
# CSV Total#125 File #96 filename: Sub II 5.19 to 11.20.csv
# CSV Total#126 File #97 filename: Sub II 5.2 to 11.2.csv
# CSV Total#127 File #98 filename: Sub II 5.20 to 11.21.csv
# CSV Total#128 File #99 filename: Sub II 5.21 to 11.22.csv
# CSV Total#129 File #100 filename: Sub II 5.24 to 11.25.csv
# CSV Total#130 File #101 filename: Sub II 5.25 to 11.26.csv
# CSV Total#131 File #102 filename: Sub II 5.26 to 11.27.csv
# CSV Total#132 File #103 filename: Sub II 5.27 to 11.28.csv
# CSV Total#133 File #104 filename: SUb II 5.28 to 11.29.csv
# CSV Total#134 File #105 filename: Sub II 5.4 to 11.4.csv
# CSV Total#135 File #106 filename: Sub II 5.5 to 11.5.csv
# CSV Total#136 File #107 filename: Sub II 5.6 to 11.7.csv
# CSV Total#137 File #108 filename: Sub II 5.7 to 11.8.csv
# CSV Total#138 File #109 filename: Sub II 6.1 to 12.1.csv
# CSV Total#139 File #110 filename: Sub II 6.10 to 12.11.csv
# CSV Total#140 File #111 filename: Sub II 6.11 to 12.12.csv
# CSV Total#141 File #112 filename: Sub II 6.14 to 12.15.csv
# CSV Total#142 File #113 filename: Sub II 6.15 to 12.16.csv
# CSV Total#143 File #114 filename: Sub II 6.16 to 12.17.csv
# CSV Total#144 File #115 filename: Sub II 6.17 to 12.18.csv
# CSV Total#145 File #116 filename: Sub II 6.18 to 12.19.csv
# CSV Total#146 File #117 filename: Sub II 6.2 to 12.2.csv
# CSV Total#147 File #118 filename: Sub II 6.21 to 12.22.csv
# CSV Total#148 File #119 filename: Sub II 6.22 to 12.23.csv
# CSV Total#149 File #120 filename: Sub II 6.23 to 12.24.csv
# CSV Total#150 File #121 filename: Sub II 6.24 to 12.25.csv
# CSV Total#151 File #122 filename: Sub II 6.25 to 12.26.csv
# CSV Total#152 File #123 filename: Sub II 6.28 to 12.29.csv
# CSV Total#153 File #124 filename: Sub II 6.29 to 12.30.csv
# CSV Total#154 File #125 filename: Sub II 6.3 to 12.4.csv
# CSV Total#155 File #126 filename: Sub II 6.30 to 12.31.csv
# CSV Total#156 File #127 filename: Sub II 6.4 to 12.5.csv
# CSV Total#157 File #128 filename: Sub II 6.7 to 12.8.csv
# CSV Total#158 File #129 filename: Sub II 6.8 to 12.9.csv
# CSV Total#159 File #130 filename: Sub II 6.9 to 12.10.csv
# CSV Total#160 File #131 filename: Sub II 7.1 to 1.1.csv
# CSV Total#161 File #132 filename: Sub II 7.2 to 1.2.csv
# CSV Total#162 File #133 filename: Sub II 7.6 to 1.7.csv
# CSV Total#163 File #134 filename: Sub II 7.8 to 1.9.csv
# CSV Total#164 File #135 filename: Sub II 7.9 to 1.10.csv
# CSV Total#165 File #136 filename: Sub II 7_12 to 1_13.csv
# CSV Total#166 File #137 filename: Sub II 7_7 to 1_8.csv
# CSV Total#167 File #138 filename: Sub III 4_1 to 10_2.csv
# Directory #7 to find import files : Y:/_Kaleida_Input/Available_Slots_Past
#
# CSV Total#168 File #1 filename: February 2022 Available Slot.csv
# CSV Total#169 File #2 filename: January 2022 available slots.csv
# CSV Total#170 File #3 filename: Main 4.11.csv
# CSV Total#171 File #4 filename: Main 4.12.csv
# CSV Total#172 File #5 filename: Main 4.13.csv
# CSV Total#173 File #6 filename: Main 4.14.csv
# CSV Total#174 File #7 filename: Main 4.15.csv
# CSV Total#175 File #8 filename: Main 4.18.csv
# CSV Total#176 File #9 filename: Main 4.19.csv
# CSV Total#177 File #10 filename: Main 4.20.csv
# CSV Total#178 File #11 filename: Main 4.21.csv
# CSV Total#179 File #12 filename: Main 4.22.csv
# CSV Total#180 File #13 filename: Main 4.25.csv
# CSV Total#181 File #14 filename: Main 4.26.csv
# CSV Total#182 File #15 filename: Main 4.27.csv
# CSV Total#183 File #16 filename: Main 4.28..csv
# CSV Total#184 File #17 filename: Main 4.29.csv
# CSV Total#185 File #18 filename: Main 4.5.csv
# CSV Total#186 File #19 filename: Main 4.7 to 4.8.csv
# CSV Total#187 File #20 filename: Main 5.10.csv
# CSV Total#188 File #21 filename: Main 5.11.csv
# CSV Total#189 File #22 filename: Main 5.12.csv
# CSV Total#190 File #23 filename: Main 5.13.csv
# CSV Total#191 File #24 filename: Main 5.16.csv
# CSV Total#192 File #25 filename: Main 5.17.csv
# CSV Total#193 File #26 filename: Main 5.18.csv
# CSV Total#194 File #27 filename: Main 5.19.csv
# CSV Total#195 File #28 filename: Main 5.2.csv
# CSV Total#196 File #29 filename: Main 5.20.csv
# CSV Total#197 File #30 filename: Main 5.23.csv
# CSV Total#198 File #31 filename: Main 5.24.csv
# CSV Total#199 File #32 filename: Main 5.25.csv
# CSV Total#200 File #33 filename: Main 5.26.csv
# CSV Total#201 File #34 filename: Main 5.27 to 5.30.csv
# CSV Total#202 File #35 filename: Main 5.3.csv
# CSV Total#203 File #36 filename: Main 5.31.csv
# CSV Total#204 File #37 filename: Main 5.4.csv
# CSV Total#205 File #38 filename: Main 5.5.csv
# CSV Total#206 File #39 filename: Main 5.6.csv
# CSV Total#207 File #40 filename: Main 5.9.csv
# CSV Total#208 File #41 filename: Main 6.1.csv
# CSV Total#209 File #42 filename: Main 6.10.csv
# CSV Total#210 File #43 filename: Main 6.13.csv
# CSV Total#211 File #44 filename: Main 6.14.csv
# CSV Total#212 File #45 filename: Main 6.15.csv
# CSV Total#213 File #46 filename: Main 6.16.csv
# CSV Total#214 File #47 filename: Main 6.17.csv
# CSV Total#215 File #48 filename: Main 6.2.csv
# CSV Total#216 File #49 filename: Main 6.20.csv
# CSV Total#217 File #50 filename: Main 6.21.csv
# CSV Total#218 File #51 filename: Main 6.22.csv
# CSV Total#219 File #52 filename: Main 6.23.csv
# CSV Total#220 File #53 filename: Main 6.24.csv
# CSV Total#221 File #54 filename: Main 6.27.csv
# CSV Total#222 File #55 filename: Main 6.28.csv
# CSV Total#223 File #56 filename: Main 6.29.csv
# CSV Total#224 File #57 filename: Main 6.3.csv
# CSV Total#225 File #58 filename: Main 6.30.csv
# CSV Total#226 File #59 filename: Main 6.6.csv
# CSV Total#227 File #60 filename: Main 6.7.csv
# CSV Total#228 File #61 filename: Main 6.8.csv
# CSV Total#229 File #62 filename: Main 6.9.csv
# CSV Total#230 File #63 filename: Main 7.1.csv
# CSV Total#231 File #64 filename: Main 7.11.csv
# CSV Total#232 File #65 filename: Main 7.12.csv
# CSV Total#233 File #66 filename: Main 7.4.csv
# CSV Total#234 File #67 filename: Main 7.5.csv
# CSV Total#235 File #68 filename: Main 7.6.csv
# CSV Total#236 File #69 filename: Main 7.7.csv
# CSV Total#237 File #70 filename: Main 7.8.csv
# CSV Total#238 File #71 filename: March 2022 List of Available Slot.csv
# CSV Total#239 File #72 filename: Sub II 4.11.csv
# CSV Total#240 File #73 filename: Sub II 4.12.csv
# CSV Total#241 File #74 filename: Sub II 4.13.csv
# CSV Total#242 File #75 filename: Sub II 4.14.csv
# CSV Total#243 File #76 filename: Sub II 4.15.csv
# CSV Total#244 File #77 filename: Sub II 4.18.csv
# CSV Total#245 File #78 filename: Sub II 4.19.csv
# CSV Total#246 File #79 filename: Sub II 4.20.csv
# CSV Total#247 File #80 filename: Sub II 4.21.csv
# CSV Total#248 File #81 filename: Sub II 4.22.csv
# CSV Total#249 File #82 filename: Sub II 4.25.csv
# CSV Total#250 File #83 filename: Sub II 4.26.csv
# CSV Total#251 File #84 filename: Sub II 4.27.csv
# CSV Total#252 File #85 filename: Sub II 4.28.csv
# CSV Total#253 File #86 filename: Sub II 4.29.csv
# CSV Total#254 File #87 filename: Sub II 4.5.csv
# CSV Total#255 File #88 filename: Sub II 4.7 to 4.8.csv
# CSV Total#256 File #89 filename: Sub II 5.10.csv
# CSV Total#257 File #90 filename: Sub II 5.11.csv
# CSV Total#258 File #91 filename: Sub II 5.12.csv
# CSV Total#259 File #92 filename: Sub II 5.13.csv
# CSV Total#260 File #93 filename: Sub II 5.16.csv
# CSV Total#261 File #94 filename: Sub II 5.17.csv
# CSV Total#262 File #95 filename: Sub II 5.18.csv
# CSV Total#263 File #96 filename: Sub II 5.19.csv
# CSV Total#264 File #97 filename: Sub II 5.2.csv
# CSV Total#265 File #98 filename: Sub II 5.20.csv
# CSV Total#266 File #99 filename: Sub II 5.23.csv
# CSV Total#267 File #100 filename: Sub II 5.24.csv
# CSV Total#268 File #101 filename: Sub II 5.25.csv
# CSV Total#269 File #102 filename: Sub II 5.26.csv
# CSV Total#270 File #103 filename: Sub II 5.27 to 5.30.csv
# CSV Total#271 File #104 filename: Sub II 5.3.csv
# CSV Total#272 File #105 filename: Sub II 5.31.csv
# CSV Total#273 File #106 filename: Sub II 5.4.csv
# CSV Total#274 File #107 filename: Sub II 5.5.csv
# CSV Total#275 File #108 filename: Sub II 5.6.csv
# CSV Total#276 File #109 filename: Sub II 5.9.csv
# CSV Total#277 File #110 filename: Sub II 6.1.csv
# CSV Total#278 File #111 filename: Sub II 6.10.csv
# CSV Total#279 File #112 filename: Sub II 6.13.csv
# CSV Total#280 File #113 filename: Sub II 6.14.csv
# CSV Total#281 File #114 filename: Sub II 6.15.csv
# CSV Total#282 File #115 filename: Sub II 6.16.csv
# CSV Total#283 File #116 filename: Sub II 6.17.csv
# CSV Total#284 File #117 filename: Sub II 6.2.csv
# CSV Total#285 File #118 filename: Sub II 6.20.csv
# CSV Total#286 File #119 filename: Sub II 6.21.csv
# CSV Total#287 File #120 filename: Sub II 6.22.csv
# CSV Total#288 File #121 filename: Sub II 6.23.csv
# CSV Total#289 File #122 filename: Sub II 6.24.csv
# CSV Total#290 File #123 filename: Sub II 6.27.csv
# CSV Total#291 File #124 filename: Sub II 6.28.csv
# CSV Total#292 File #125 filename: Sub II 6.29.csv
# CSV Total#293 File #126 filename: Sub II 6.3.csv
# CSV Total#294 File #127 filename: Sub II 6.30.csv
# CSV Total#295 File #128 filename: Sub II 6.6.csv
# CSV Total#296 File #129 filename: Sub II 6.7.csv
# CSV Total#297 File #130 filename: Sub II 6.8.csv
# CSV Total#298 File #131 filename: Sub II 6.9.csv
# CSV Total#299 File #132 filename: Sub II 7.1.csv
# CSV Total#300 File #133 filename: Sub II 7.11.csv
# CSV Total#301 File #134 filename: Sub II 7.12.csv
# CSV Total#302 File #135 filename: Sub II 7.4.csv
# CSV Total#303 File #136 filename: Sub II 7.5.csv
# CSV Total#304 File #137 filename: Sub II 7.6.csv
# CSV Total#305 File #138 filename: Sub II 7.7.csv
# CSV Total#306 File #139 filename: Sub II 7.8.csv
# Directory #8 to find import files : Y:/_Kaleida_Input/DailyAppointments
#
# CSV Total#307 File #1 filename: April 2019.csv
# CSV Total#308 File #2 filename: April 2020.csv
# CSV Total#309 File #3 filename: April 2021.csv
# CSV Total#310 File #4 filename: April 2022.csv
# CSV Total#311 File #5 filename: August 2019.csv
# CSV Total#312 File #6 filename: August 2020.csv
# CSV Total#313 File #7 filename: August 2021.csv
# CSV Total#314 File #8 filename: August 2022.csv
# CSV Total#315 File #9 filename: December 2019.csv
# CSV Total#316 File #10 filename: December 2020.csv
# CSV Total#317 File #11 filename: December 2021.csv
# CSV Total#318 File #12 filename: February 2019.csv
# CSV Total#319 File #13 filename: february 2020.csv
# CSV Total#320 File #14 filename: February 2021.csv
# CSV Total#321 File #15 filename: February 2022.csv
# CSV Total#322 File #16 filename: January 2019.csv
# CSV Total#323 File #17 filename: January 2020.csv
# CSV Total#324 File #18 filename: January 2021.csv
# CSV Total#325 File #19 filename: January 2022.csv
# CSV Total#326 File #20 filename: July 2019.csv
# CSV Total#327 File #21 filename: July 2020.csv
# CSV Total#328 File #22 filename: July 2021.csv
# CSV Total#329 File #23 filename: July 2022.csv
# CSV Total#330 File #24 filename: June 2019.csv
# CSV Total#331 File #25 filename: June 2020.csv
# CSV Total#332 File #26 filename: June 2021.csv
# CSV Total#333 File #27 filename: June 2022.csv
# CSV Total#334 File #28 filename: March 2019.csv
# CSV Total#335 File #29 filename: March 2020.csv
# CSV Total#336 File #30 filename: March 2021.csv
# CSV Total#337 File #31 filename: March 2022.csv
# CSV Total#338 File #32 filename: May 2019.csv
# CSV Total#339 File #33 filename: May 2020.csv
# CSV Total#340 File #34 filename: May 2021.csv
# CSV Total#341 File #35 filename: May 2022.csv
# CSV Total#342 File #36 filename: November 2019.csv
# CSV Total#343 File #37 filename: November 2020.csv
# CSV Total#344 File #38 filename: November 2021.csv
# CSV Total#345 File #39 filename: October 2019.csv
# CSV Total#346 File #40 filename: October 2020.csv
# CSV Total#347 File #41 filename: October 2021.csv
# CSV Total#348 File #42 filename: September 2019.csv
# CSV Total#349 File #43 filename: September 2020.csv
# CSV Total#350 File #44 filename: September 2021.csv
# CSV Total#351 File #45 filename: Sub II 2019.csv
# CSV Total#352 File #46 filename: Sub II 2020.csv
# CSV Total#353 File #47 filename: Sub II 2021.csv
# CSV Total#354 File #48 filename: Sub II 2022 YTD 8_16_22.csv
# Directory #9 to find import files : Y:/_Kaleida_Input/Future Surgeries
#
# Directory #10 to find import files : Y:/_Kaleida_Input/FutureAppointmentVisits
#
# Directory #11 to find import files : Y:/_Kaleida_Input/Hx
#
# Directory #12 to find import files : Y:/_Kaleida_Input/HXDX
#
# CSV Total#355 File #1 filename: 2018 Sub II.csv
# CSV Total#356 File #2 filename: 65 April 2019.csv
# CSV Total#357 File #3 filename: 65 April 2020.csv
# CSV Total#358 File #4 filename: 65 April 2021.csv
# CSV Total#359 File #5 filename: 65 April 2022.csv
# CSV Total#360 File #6 filename: 65 August 2019.csv
# CSV Total#361 File #7 filename: 65 August 2020.csv
# CSV Total#362 File #8 filename: 65 August 2021.csv
# CSV Total#363 File #9 filename: 65 December 2019.csv
# CSV Total#364 File #10 filename: 65 December 2020.csv
# CSV Total#365 File #11 filename: 65 December 2021.csv
# CSV Total#366 File #12 filename: 65 Feb 2020.csv
# CSV Total#367 File #13 filename: 65 February 2019.csv
# CSV Total#368 File #14 filename: 65 February 2021.csv
# CSV Total#369 File #15 filename: 65 February 2022.csv
# CSV Total#370 File #16 filename: 65 Jan 2020.csv
# CSV Total#371 File #17 filename: 65 January 2019.csv
# CSV Total#372 File #18 filename: 65 January 2021.csv
# CSV Total#373 File #19 filename: 65 January 2022.csv
# CSV Total#374 File #20 filename: 65 July 2019.csv
# CSV Total#375 File #21 filename: 65 July 2020.csv
# CSV Total#376 File #22 filename: 65 July 2021.csv
# CSV Total#377 File #23 filename: 65 July 2022.csv
# CSV Total#378 File #24 filename: 65 June 2019.csv
# CSV Total#379 File #25 filename: 65 June 2020.csv
# CSV Total#380 File #26 filename: 65 June 2021.csv
# CSV Total#381 File #27 filename: 65 June 2022.csv
# CSV Total#382 File #28 filename: 65 Main 8.10.csv
# CSV Total#383 File #29 filename: 65 Main 8.11.csv
# CSV Total#384 File #30 filename: 65 Main 8.12.csv
# CSV Total#385 File #31 filename: 65 Main 8.15.csv
# CSV Total#386 File #32 filename: 65 Main 8.16.csv
# CSV Total#387 File #33 filename: 65 March 2019.csv
# CSV Total#388 File #34 filename: 65 March 2020.csv
# CSV Total#389 File #35 filename: 65 March 2021.csv
# CSV Total#390 File #36 filename: 65 March 2022.csv
# CSV Total#391 File #37 filename: 65 May 2019.csv
# CSV Total#392 File #38 filename: 65 May 2020.csv
# CSV Total#393 File #39 filename: 65 May 2021.csv
# CSV Total#394 File #40 filename: 65 May 2022.csv
# CSV Total#395 File #41 filename: 65 November 2019.csv
# CSV Total#396 File #42 filename: 65 November 2020.csv
# CSV Total#397 File #43 filename: 65 November 2021.csv
# CSV Total#398 File #44 filename: 65 October 2019.csv
# CSV Total#399 File #45 filename: 65 October 2020.csv
# CSV Total#400 File #46 filename: 65 October 2021.csv
# CSV Total#401 File #47 filename: 65 September 2019.csv
# CSV Total#402 File #48 filename: 65 September 2020.csv
# CSV Total#403 File #49 filename: 65 September 2021.csv
# CSV Total#404 File #50 filename: 65 Sub II 2018.csv
# CSV Total#405 File #51 filename: 65 Sub II 2019.csv
# CSV Total#406 File #52 filename: 65 Sub II 2020.csv
# CSV Total#407 File #53 filename: 65 Sub II 2021.csv
# CSV Total#408 File #54 filename: 65 Sub II 8.10.csv
# CSV Total#409 File #55 filename: 65 Sub II 8.12.csv
# CSV Total#410 File #56 filename: 65 Sub II 8.15.csv
# CSV Total#411 File #57 filename: 65 Sub II 8.16.csv
# CSV Total#412 File #58 filename: 65 Sub II Jan to July 2022.csv
# Directory #13 to find import files : Y:/_Kaleida_Input/Incident
#
# Directory #14 to find import files : Y:/_Kaleida_Input/InsuranceIDVerificationAudit
#
# Directory #15 to find import files : Y:/_Kaleida_Input/LungCancerScreeningTracker
#
# Directory #16 to find import files : Y:/_Kaleida_Input/MissingNPIAudit
#
# Directory #17 to find import files : Y:/_Kaleida_Input/OncologyNavigation
#
# Directory #18 to find import files : Y:/_Kaleida_Input/PatientExperience
#
# Directory #19 to find import files : Y:/_Kaleida_Input/PatientInformation
#
# Directory #20 to find import files : Y:/_Kaleida_Input/PatientInformation\Main18Under
#
# CSV Total#413 File #1 filename: 2459588_144_20220108022428_dmhmreport_EHRSUPPORT_2697197.csv
# CSV Total#414 File #2 filename: 2459605_158_20220125023834_dmhmreport_JENNIFERDUP_3361737.csv
# CSV Total#415 File #3 filename: 2459612_209_20220201032944_dmhmreport_JENNIFERDUP_4325181.csv
# CSV Total#416 File #4 filename: 2459612_20_20220201002044_dmhmreport_DAVIDK_433365.csv
# CSV Total#417 File #5 filename: 2459612_21_20220201002151_dmhmreport_DAVIDK_499798.csv
# CSV Total#418 File #6 filename: 2459619_104_20220208014459_dmhmreport_JENNIFERDUP_5855729.csv
# CSV Total#419 File #7 filename: 2459619_18_20220208001819_dmhmreport_DAVIDK_1831086.csv
# CSV Total#420 File #8 filename: 2459619_19_20220208001921_dmhmreport_DAVIDK_2038850.csv
# CSV Total#421 File #9 filename: 2459626_122_20220215020227_dmhmreport_JENNIFERDUP_2584879.csv
# CSV Total#507 File #35 filename: 2459612_33_20220201003332_dmhmreport_EHRSUPPORT_3033211.csv
# CSV Total#508 File #36 filename: 2459612_39_20220201003948_dmhmreport_EHRSUPPORT_4548543.csv
# CSV Total#509 File #37 filename: 2459612_532_20220201085244_dmhmreport_EHRSUPPORT_3424247.csv
# CSV Total#510 File #38 filename: 2459640_51_20220301005105_dmhmreport_EHRSUPPORT_425889.csv
# CSV Total#511 File #39 filename: 2459640_53_20220301005341_dmhmreport_EHRSUPPORT_3942776.csv
# CSV Total#512 File #40 filename: 2459641_376_20220302061611_dmhmreport_EHRSUPPORT_234503.csv
# CSV Total#513 File #41 filename: 2459671_62_20220401010243_dmhmreport_EHRSUPPORT_428943.csv
# CSV Total#514 File #42 filename: 2459671_77_20220401011759_dmhmreport_EHRSUPPORT_5743399.csv
# CSV Total#515 File #43 filename: 2459672_361_20220402060116_dmhmreport_EHRSUPPORT_832432.csv
# CSV Total#516 File #44 filename: 2459701_33_20220501003328_dmhmreport_EHRSUPPORT_27874.csv
# CSV Total#517 File #45 filename: 2459701_498_20220501081829_dmhmreport_EHRSUPPORT_2243187.csv
# CSV Total#518 File #46 filename: 2459732_387_20220601062745_dmhmreport_EHRSUPPORT_3850985.csv
# CSV Total#519 File #47 filename: 2459732_65_20220601010518_dmhmreport_EHRSUPPORT_1730697.csv
# CSV Total#520 File #48 filename: 2459762_429_20220701070935_dmhmreport_EHRSUPPORT_2933347.csv
# CSV Total#521 File #49 filename: December Report.csv
# Directory #26 to find import files : Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
#
# Directory #27 to find import files : Y:/_Kaleida_Input/RCM-InpatientCharges
#
# Directory #28 to find import files : Y:/_Kaleida_Input/RCM_Adujstments
#
# CSV Total#522 File #1 filename: GP April 2022 Adjustments.csv
# CSV Total#523 File #2 filename: GP August 2021 Adjustments.csv
# CSV Total#524 File #3 filename: GP December 2021 Adjustments.csv
# CSV Total#525 File #4 filename: GP February 2022 Adjustments.csv
# CSV Total#526 File #5 filename: GP January 2022 Adjustments.csv
# CSV Total#527 File #6 filename: GP July 2021 Adjustments.csv
# CSV Total#528 File #7 filename: GP June 2021 Adjustments.csv
# CSV Total#529 File #8 filename: GP June 2022 Adjustments.csv
# CSV Total#530 File #9 filename: GP March 2022 Adjustments.csv
# CSV Total#531 File #10 filename: GP May 2021 Adjustments.csv
# CSV Total#532 File #11 filename: GP May 2022 Adjustments.csv
# CSV Total#533 File #12 filename: GP November 2021 Adjustments.csv
# CSV Total#534 File #13 filename: GP October 2021 Adjustments.csv
# CSV Total#535 File #14 filename: GP September 2021 Adjustments.csv
# CSV Total#536 File #15 filename: Medent Export Adj Report October GPPC Main.csv
# CSV Total#537 File #16 filename: Sub 1 April 2022 Adjustments.csv
# CSV Total#538 File #17 filename: Sub 1 August 2021 Adjustments.csv
# CSV Total#539 File #18 filename: Sub 1 December 2021 Adjustments.csv
# CSV Total#540 File #19 filename: Sub 1 February 2022 Adjustments.csv
# CSV Total#541 File #20 filename: Sub 1 July 2021 Adjustments.csv
# CSV Total#542 File #21 filename: Sub 1 June 2021 Adjustments.csv
# CSV Total#543 File #22 filename: Sub 1 June 2022 Adjustments.csv
# CSV Total#544 File #23 filename: Sub 1 March 2022 Adjustments.csv
# CSV Total#545 File #24 filename: Sub 1 May 2021 Adjustments.csv
# CSV Total#546 File #25 filename: Sub 1 May 2022 Adjustments.csv
# CSV Total#547 File #26 filename: Sub 1 November 2021 Adjustments.csv
# CSV Total#548 File #27 filename: Sub 1 October 2021 Adjustments.csv
# CSV Total#549 File #28 filename: Sub 1 September 2021 Adjustments.csv
# CSV Total#550 File #29 filename: Sub 2 April 2022 Adjustments.csv
# CSV Total#551 File #30 filename: Sub 2 August 2021 Adjustments.csv
# CSV Total#552 File #31 filename: Sub 2 December 2021 Adjustments.csv
# CSV Total#553 File #32 filename: Sub 2 February 2022 Adjustments.csv
# CSV Total#554 File #33 filename: Sub 2 January 2022 Adjustments.csv
# CSV Total#555 File #34 filename: Sub 2 July 2021 Adjustments.csv
# CSV Total#556 File #35 filename: Sub 2 June 2021 Adjustments.csv
# CSV Total#557 File #36 filename: Sub 2 June 2022 Adjustments.csv
# CSV Total#558 File #37 filename: Sub 2 March 2022 Adjustments.csv
# CSV Total#559 File #38 filename: Sub 2 May 2021 Adjustments.csv
# CSV Total#560 File #39 filename: Sub 2 May 2022 Adjustments.csv
# CSV Total#561 File #40 filename: Sub 2 November 2021 Adjustments.csv
# CSV Total#562 File #41 filename: Sub 2 October 2021 Adjustments.csv
# CSV Total#563 File #42 filename: Sub 2 September 2021 Adjustments.csv
# CSV Total#564 File #43 filename: Sub 3 April 2022 Adjustments.csv
# CSV Total#565 File #44 filename: Sub 3 August 2021 Adjustments.csv
# CSV Total#566 File #45 filename: Sub 3 December 2021 Adjustments.csv
# CSV Total#567 File #46 filename: Sub 3 February 2022 Adjustments.csv
# CSV Total#568 File #47 filename: Sub 3 January 2022 Adjustments.csv
# CSV Total#569 File #48 filename: Sub 3 July 2021 Adjustments.csv
# CSV Total#570 File #49 filename: Sub 3 June 2021 Adjustments.csv
# CSV Total#571 File #50 filename: Sub 3 June 2022 Adjustments.csv
# CSV Total#572 File #51 filename: Sub 3 March 2022 Adjustments.csv
# CSV Total#573 File #52 filename: Sub 3 May 2021 Adjustments.csv
# CSV Total#574 File #53 filename: Sub 3 May 2022 Adjustments.csv
# CSV Total#575 File #54 filename: Sub 3 November 2021 Adjustments.csv
# CSV Total#576 File #55 filename: Sub 3 October 2021 Adjustments.csv
# CSV Total#577 File #56 filename: Sub 3 September 2021 Adjustments.csv
# Directory #29 to find import files : Y:/_Kaleida_Input/RCM_OpenSuperbills
#
# Directory #30 to find import files : Y:/_Kaleida_Input/RCM_Productivity
#
# CSV Total#578 File #1 filename: 2021_Imports By Month (2020 Rates).csv
# CSV Total#579 File #2 filename: April 2022 Productivity.csv
# CSV Total#580 File #3 filename: February 2022 Productivity.csv
# CSV Total#581 File #4 filename: January 2022 Productivity.csv
# CSV Total#582 File #5 filename: June 2022 Productivity.csv
# CSV Total#583 File #6 filename: March 2022 Productivity.csv
# CSV Total#584 File #7 filename: May 2022 Productivity.csv
# CSV Total#585 File #8 filename: Sub 1 April 2022.csv
# CSV Total#586 File #9 filename: Sub 1 February 2022.csv
# CSV Total#587 File #10 filename: Sub 1 January 2022.csv
# CSV Total#588 File #11 filename: Sub 1 March 2022.csv
# CSV Total#589 File #12 filename: Sub II April 2022.csv
# CSV Total#590 File #13 filename: Sub II February 2022.csv
# CSV Total#591 File #14 filename: Sub II January 2022.csv
# CSV Total#592 File #15 filename: Sub II June 2022.csv
# CSV Total#593 File #16 filename: Sub II March 2022.csv
# CSV Total#594 File #17 filename: Sub II May 2022.csv
# Directory #31 to find import files : Y:/_Kaleida_Input/Referrals - Recommendation
#
# Directory #32 to find import files : Y:/_Kaleida_Input/ReferringProviders
#
# Directory #33 to find import files : Y:/_Kaleida_Input/SurgicalAppointmentSummar2DaysAgo
#
# CSV Total#595 File #1 filename: 2459258_656_dmhmrep_MICHAELO_41146806.csv
# CSV Total#596 File #2 filename: 2459258_657_dmhmrep_MICHAELO_3623363.csv
# CSV Total#597 File #3 filename: 2459259_72_20210213011221_dmhmreport_MICHAELO_1918694.csv
# CSV Total#598 File #4 filename: 2459259_84_20210213012436_dmhmreport_EHRSUPPORT_34144238.csv
# CSV Total#599 File #5 filename: 2459260_346_20210214054615_dmhmreport_EHRSUPPORT_1490842.csv
# CSV Total#600 File #6 filename: 2459260_34_20210214003457_dmhmreport_MICHAELO_5535058.csv
# CSV Total#601 File #7 filename: 2459261_108_20210215014834_dmhmreport_EHRSUPPORT_3058120.csv
# CSV Total#602 File #8 filename: 2459261_32_20210215003205_dmhmreport_MICHAELO_331442.csv
# CSV Total#603 File #9 filename: 2459262_85_20210216012515_dmhmreport_EHRSUPPORT_1419310.csv
# CSV Total#604 File #10 filename: 2459263_85_20210217012508_dmhmreport_EHRSUPPORT_712292.csv
# CSV Total#605 File #11 filename: 2459264_107_20210218014708_dmhmreport_EHRSUPPORT_2111206.csv
# CSV Total#606 File #12 filename: 2459265_117_20210219015725_dmhmreport_EHRSUPPORT_195157.csv
# CSV Total#607 File #13 filename: 2459266_124_20210220020407_dmhmreport_EHRSUPPORT_5101165.csv
# CSV Total#608 File #14 filename: 2459267_87_20210221012730_dmhmreport_EHRSUPPORT_20110196.csv
# CSV Total#609 File #15 filename: 2459268_82_20210222012258_dmhmreport_EHRSUPPORT_5711451.csv
# CSV Total#610 File #16 filename: 2459269_146_20210223022631_dmhmreport_EHRSUPPORT_2991841.csv
# CSV Total#611 File #17 filename: 2459270_84_20210224012458_dmhmreport_EHRSUPPORT_5746348.csv
# CSV Total#612 File #18 filename: 2459271_127_20210225020726_dmhmreport_EHRSUPPORT_2634363.csv
# CSV Total#613 File #19 filename: 2459272_85_20210226012535_dmhmreport_EHRSUPPORT_33138346.csv
# CSV Total#614 File #20 filename: 2459273_85_20210227012541_dmhmreport_EHRSUPPORT_3978967.csv
# CSV Total#1558 File #964 filename: 2459754_17_20220623001711_dmhmreport_JUSTINJ_1038288.csv
# CSV Total#1559 File #965 filename: 2459754_89_20220623012951_dmhmreport_EHRSUPPORT_498720.csv
# CSV Total#1560 File #966 filename: 2459755_13_20220624001304_dmhmreport_JUSTINJ_419580.csv
# CSV Total#1561 File #967 filename: 2459755_88_20220624012849_dmhmreport_EHRSUPPORT_4878011.csv
# CSV Total#1562 File #968 filename: 2459756_105_20220625014551_dmhmreport_EHRSUPPORT_49104818.csv
# CSV Total#1563 File #969 filename: 2459756_6_20220625000624_dmhmreport_JUSTINJ_2241992.csv
# CSV Total#1564 File #970 filename: 2459757_10_20220626001047_dmhmreport_JUSTINJ_4533080.csv
# CSV Total#1565 File #971 filename: 2459757_82_20220626012202_dmhmreport_EHRSUPPORT_1127437.csv
# CSV Total#1566 File #972 filename: 2459758_14_20220627001428_dmhmreport_JUSTINJ_2712503.csv
# CSV Total#1567 File #973 filename: 2459758_82_20220627012227_dmhmreport_EHRSUPPORT_2615453.csv
# CSV Total#1568 File #974 filename: 2459759_7_20220628000728_dmhmreport_JUSTINJ_2637035.csv
# CSV Total#1569 File #975 filename: 2459759_89_20220628012909_dmhmreport_EHRSUPPORT_768971.csv
# CSV Total#1570 File #976 filename: 2459760_11_20220629001116_dmhmreport_JUSTINJ_1510083.csv
# CSV Total#1571 File #977 filename: 2459760_99_20220629013937_dmhmreport_EHRSUPPORT_3669165.csv
# CSV Total#1572 File #978 filename: 2459761_104_20220630014440_dmhmreport_EHRSUPPORT_3951989.csv
# CSV Total#1573 File #979 filename: 2459761_12_20220630001226_dmhmreport_JUSTINJ_2638188.csv
# CSV Total#1574 File #980 filename: 2459762_12_20220701001254_dmhmreport_JUSTINJ_53688.csv
# CSV Total#1575 File #981 filename: 2459762_94_20220701013429_dmhmreport_EHRSUPPORT_2743914.csv
# CSV Total#1576 File #982 filename: 2459763_6_20220702000607_dmhmreport_JUSTINJ_513027.csv
# CSV Total#1577 File #983 filename: 2459763_87_20220702012737_dmhmreport_EHRSUPPORT_3554051.csv
# CSV Total#1578 File #984 filename: 2459764_6_20220703000611_dmhmreport_JUSTINJ_1037550.csv
# CSV Total#1579 File #985 filename: 2459764_82_20220703012202_dmhmreport_EHRSUPPORT_076774.csv
# CSV Total#1580 File #986 filename: 2459765_6_20220704000607_dmhmreport_JUSTINJ_78892.csv
# CSV Total#1581 File #987 filename: 2459765_82_20220704012205_dmhmreport_EHRSUPPORT_485348.csv
# CSV Total#1582 File #988 filename: 2459766_105_20220705014532_dmhmreport_EHRSUPPORT_30137418.csv
# CSV Total#1583 File #989 filename: 2459766_16_20220705001628_dmhmreport_JUSTINJ_2821424.csv

# %%
# Persist the csv files in an excel import file Registry 
Data_Import_Starting_Directory =  'J:/IT GLIN Data Services Shared/TempData/'
Excel_file_Name = Data_Import_Starting_Directory + 'Discovered_CSV_files_to_import.xlsx'
out('Registering Directories in excel File:{} '.format(Excel_file_Name))
df_import_files.to_excel(Excel_file_Name, index=False)
