# %% [markdown]
# ## Data Synthesis - Demographic with ADA Risk Survey

# %%
import pandas as pd
import numpy as np
import random as rd

# %%
#df = pd.read_csv("C:/Users/josep/documents/datasets/dg.csv", nrows=5000)
df = pd.read_csv("C:/Users/josep/documents/datasets/Demographic_ADA_Risk.csv")
cols = df.columns
df.head(5)
# Out:
#   Patient  Ordinal Birth  Date  Age  Decade  Gender  \
# 0   Patient_2018_1   4/12/1972   49       4    Male
# 1   Patient_2018_2    9/3/1947   73       7  Female
# 2   Patient_2018_3   9/16/1971   49       4    Male
# 3   Patient_2018_4    1/8/1934   87       8  Female
# 4   Patient_2018_5   5/12/1934   87       8    Male
#
#    Imputed Diabetic Metabolic Syndrome (OUTCOME)  \
# 0                                              1
# 1                                              0
# 2                                              1
# 3                                              0
# 4                                              0
#
#    Simulated Imputed ADA Risk (outcome)  \
# 0                                     1
# 1                                     1
# 2                                     1
# 3                                     1
# 4                                     1
#
#    Simulated Family Member with Diabetes  Simulated Activity Level  \
# 0                                      0                         0
# 1                                      0                         1
# 2                                      0                         1
# 3                                      1                         1
# 4                                      0                         1
#
#    Simulated Hypertension  Simulated Height CM  Simulated Weight KG  \
# 0                       1                  168                  110
# 1                       1                  161                   60
# 2                       1                  177                   85
# 3                       1                  160                  101
# 4                       1                  182                  121
#
#    Simulated Height IN  Simulated Weight LBS  Simulated BMI  ADA Family Risk   \
# 0                  5.5                 242.5           39.0                 0
# 1                  5.3                 132.3           23.1                 0
# 2                  5.8                 187.4           27.1                 0
# 3                  5.2                 222.7           39.5                 1
# 4                  6.0                 266.8           36.5                 0
#
#    ADA Age Risk   ADA Gender Risk   ADA BMI Risk  ADA Hypertension Risk  \
# 0              1                 1             2                      1
# 1              3                 0             0                      1
# 2              1                 1             1                      1
# 3              3                 0             2                      1
# 4              3                 1             2                      1
#
#    Total Calculated ADA pre-Diabetes Risk  AIHS Age Risk  AIHS BMI Risk  \
# 0                                       6            1.9           2.80
# 1                                       5            4.3           0.00
# 2                                       6            1.9           1.11
# 3                                       8            5.7           2.85
# 4                                       8            5.7           2.55
#
#    Total Calculated AIHS Risk Stratifcation Simulated BMI Class  \
# 0                                      6.70               Obese
# 1                                      5.30      Healthy Weight
# 2                                      5.01         Over Weight
# 3                                      9.55               Obese
# 4                                     10.25               Obese
#
#   Simulated Activity Class          Patient Cohort
# 0                Sedentary        Obese, Sedentary
# 1                   Active  Healthy Weight, Active
# 2                   Active     Over Weight, Active
# 3                   Active           Obese, Active
# 4                   Active           Obese, Active

# %%
#df = pd.read_csv("C:/Users/josep/documents/datasets/dg.csv", nrows=5000)
df.to_csv("C:/Users/josep/documents/datasets/Demographic_ADA_Risk_2.csv")

# %%
# Calculate the AIHS health risk stratification 
def calc_age_risk(age):
    if age < 40: 
        age_risk =  0.0
    elif age < 50: 
        age_risk =  1 + ((age-40) * .1)
    elif age  < 60: 
        age_risk =  2 + ((age-50) * .1)
    elif age  < 90: 
        age_risk =  3 + ((age-60) * .1)
    elif age  < 110:    # Age over 90 non actionable ????
        age_risk =  0      
    
    return age_risk

# %%
kilo_grams = float(input('Enter weight in Kg to Convert into pounds:'))
pounds = kilo_grams * 2.2046
print(kilo_grams,' Kilograms =', pounds,' Pounds')

# %%
def calc_AIHS_age_risk(row):
    # The row is a single Series object which is a single row indexed by column values
    # Let's extract the firstname and create a new entry in the series
    if row['Age'] < 40: 
        row['AIHS Age Risk']=  0.0
    elif row['Age'] < 50: 
        row['AIHS Age Risk']=  1 + ((row['Age']-40) * .1)
    elif row['Age']  < 60: 
        row['AIHS Age Risk']=  2 + ((row['Age']-50) * .1)
    elif row['Age']  < 90: 
        row['AIHS Age Risk']=  3 + ((row['Age']-60) * .1)
    elif row['Age']  < 110:    # Age over 90 non actionable ????
        row['AIHS Age Risk']=  0      
   
    return row

# %%
def calc_height_in_feet(row):
    # Converts from centimeters to feet and inches 
    row['Simulated Height IN']=  round(row['Simulated Height CM']  * 0.0328,1) 
    return row

# %%
def calc_weight_in_pounds(row):
    # Converts from centimeters to feet and inches 
    row['Simulated Weight LBS']=   round(row['Simulated Weight KG']  * 2.2046,1)
    return row

# %%
def calc_body_mass_index(row):
    # Converts from centimeters to feet and inches 
    row['Simulated BMI']=  row['Simulated Weight KG']/(row['Simulated Height CM']**2)  
    return row

# %%
def calc_ADA_age_risk(row):
    # The row is a single Series object which is a single row indexed by column values
    # Let's extract the firstname and create a new entry in the series
    if row['Age'] < 40: 
        row['ADA Age Risk']= 0
    elif row['Age'] < 50: 
        row['ADA Age Risk']=  1  
    elif row['Age']  < 60: 
        row['ADA Age Risk']=  2  
    elif row['Age']  < 90: 
        row['ADA Age Risk']=  3  
    elif row['Age']  < 110:    # Age over 90 non actionable ????
        row['ADA Age Risk']=  0      
    return row

# %%
def calc_ADA_BMI_risk(row):
    # The row is a single Series object which is a single row indexed by column values
    # Let's extract the firstname and create a new entry in the series
    if row['Simulated BMI'] < 18.5: 
        row['ADA BMI Risk']= 0
    elif row['Simulated BMI'] < 25: 
        row['ADA BMI Risk']=  0  
    elif row['Simulated BMI']  < 30: 
        row['ADA BMI Risk']=  1  
    elif row['Simulated BMI']  < 40: 
        row['ADA BMI Risk']=  2  
    elif row['Simulated BMI']  < 60:    # Age over 90 non actionable ????
        row['ADA BMI Risk']=  3      
    return row

# %%
def calc_AIHS_BMI_risk(row):
    # The row is a single Series object which is a single row indexed by column values
    # Let's extract the firstname and create a new entry in the series
    if row['Simulated BMI'] < 18.5: 
        row['AIHS BMI Risk']= 0
    elif row['Simulated BMI'] < 25: 
        row['AIHS BMI Risk']=  0  
    elif row['Simulated BMI']  < 30: 
        row['AIHS BMI Risk']=  1 +  ((row['Simulated BMI']-26) * .1)
    elif row['Simulated BMI']  < 40: 
        row['AIHS BMI Risk']=  2 +  ((row['Simulated BMI']-31) * .1) 
    elif row['Simulated BMI']  < 60:    # Age over 90 non actionable ????
        row['AIHS BMI Risk']=  3 +  ((row['Simulated BMI']-41) * .1)      
    return row

# %% [markdown]
# ## Read In the core demographic data set

# %%
#df = pd.read_csv("C:/Users/josep/documents/datasets/dg.csv", nrows=5000)
df = pd.read_csv("C:/Users/josep/documents/datasets/dg_BMI_risk.csv")
df.head(5)

# %%
df.head()

# %%
cols = df.columns
print(cols)

# %%
df['Simulated Height CM'] = np.random.randint(155, 187, df.shape[0])
df['Simulated Weight KG'] = np.random.randint(60, 130, df.shape[0])
df['Simulated BMI']=  round(df['Simulated Weight KG']/((df['Simulated Height CM']/100)**2),1)  
df.head()

# %%
height = float(input("Enter height in meters: "))

weight = float(input("Enter weight in kg: "))

bmi = weight/(height**2)

print("Your BMI is: {0} and you are: ".format(bmi), end='')

if ( bmi < 16):
    print("severely underweight")

elif ( bmi >= 16 and bmi < 18.5):
    print("underweight")

elif ( bmi >= 18.5 and bmi < 25):
    print("Healthy")

elif ( bmi >= 25 and bmi < 30):
    print("overweight")

elif ( bmi >=30):
    print("severely overweight")

# %%
df.to_csv("C:/Users/josep/documents/datasets/dg_BMI_risk_III.csv")

# %%
df_BRFSS = pd.read_csv("C:/Data/brfss cdc/BRFSS_2015.csv",nrows=5000)
df_BRFSS.shape

# %%
df_BRFSS["Patient Number"]= np.arange(len(df_BRFSS)) + 1

# %%
df_BRFSS["Patient ID"]= "Patient_Number_" + df_BRFSS["Patient Number"].astype(str)

# %%
df_BRFSS.head()

# %%
df["Age Decade"]=df['Age'] / 10 
df["Patient Number"]= np.arange(len(df)) + 1 
cols = df.columns
df.head()

# %%
df["Age Dec"]=df['Age Decade'].astype(int) 
df["Patient ID"]= "Patient_Number_" + df["Patient Number"].astype(str)
cols = df.columns
df.head()

# %%
dfm = df.merge(df_BRFSS, how='left', on='Patient ID')

# %%
dfm.shape

# %%
#take input from user
cm=int(input("Enter the height in centimeters:"))
 
#convert centimeter to feet
feet=0.0328*cm
 
#print result
print("The length in feet",round(feet,2))

# %%
dfm.head()

# %%
df.head()

# %%
dfm.to_csv("C:/Users/josep/documents/datasets/patient_demo_behavior.csv")

# %%
df["Age Dec"]=df['Age Decade'].astype(int) 
df["Patient ID"]= "Patient_Number_" + df["Patient Number"].astype(str)
cols = df.columns
df.head()

# %%
#df=df.apply(calc_ADS_age_risk, axis='columns')
df=df.apply(calc_height_in_feet, axis='columns')
df.head()

# %%
#df=df.apply(calc_ADS_age_risk, axis='columns')
df=df.apply(calc_weight_in_pounds, axis='columns')
df.head()

# %%
#cols = cols + 'Computed AIHS Age Risk'
df = df[cols]
df.head(10)

# %%
#df=df.apply(calc_ADS_age_risk, axis='columns')
df=df.apply(calc_AIHS_age_risk, axis='columns')
df.head()
# Out:
#   Patient  Ordinal Birth  Date  Age  Decade  Gender  \
# 0   Patient_2018_1   4/12/1972   49       4    Male
# 1   Patient_2018_2    9/3/1947   73       7  Female
# 2   Patient_2018_3   9/16/1971   49       4    Male
# 3   Patient_2018_4    1/8/1934   87       8  Female
# 4   Patient_2018_5   5/12/1934   87       8    Male
#
#    Simulated Imputed Diabetic Metabolic Syndrome (OUTCOME)  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Imputed ADA Risk (outcome)  Simulated Family Member with Diabetes  \
# 0                           1                                      0
# 1                           1                                      0
# 2                           1                                      0
# 3                           1                                      1
# 4                           1                                      0
#
#    Simulated Activity Level  Simulated Hypertension  ...  ADA Gender Risk   \
# 0                         0                       1  ...                 1
# 1                         1                       1  ...                 0
# 2                         1                       1  ...                 1
# 3                         1                       1  ...                 0
# 4                         1                       1  ...                 1
#
#    ADA BMI Risk   ADA Hypertension Risk  \
# 0              3                      1
# 1              0                      1
# 2              3                      1
# 3              3                      1
# 4              3                      1
#
#    Total Calculated ADA pre-Diabetes Risk  AIHS Age Risk  AIHS BMI Risk  \
# 0                                       6            1.9           1.23
# 1                                       5            4.3           1.23
# 2                                       6            1.9           1.23
# 3                                       8            5.7           1.23
# 4                                       8            5.7           1.23
#
#    Simulated BMI Class  Simulated Activity Class  Total Calculated AIHS Risk  \
# 0                Obese                 Sedentary                        4.23
# 1       Healthy Weight                    Active                        4.23
# 2          Over Weight                    Active                        4.23
# 3                Obese                    Active                        4.23
# 4                Obese                    Active                        4.23
#
#            Patient Cohort
# 0        Obese, Sedentary
# 1  Healthy Weight, Active
# 2     Over Weight, Active
# 3           Obese, Active
# 4           Obese, Active
#
# [5 rows x 27 columns]

# %%
#df=df.apply(calc_ADS_age_risk, axis='columns')
df=df.apply(calc_ADA_BMI_risk, axis='columns')
df.head()
# Out:
#   Patient  Ordinal Birth  Date  Age  Decade  Gender  \
# 0   Patient_2018_1   4/12/1972   49       4    Male
# 1   Patient_2018_2    9/3/1947   73       7  Female
# 2   Patient_2018_3   9/16/1971   49       4    Male
# 3   Patient_2018_4    1/8/1934   87       8  Female
# 4   Patient_2018_5   5/12/1934   87       8    Male
#
#    Simulated Imputed Diabetic Metabolic Syndrome (OUTCOME)  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Imputed ADA Risk (outcome)  Simulated Family Member with Diabetes  \
# 0                           1                                      0
# 1                           1                                      0
# 2                           1                                      0
# 3                           1                                      1
# 4                           1                                      0
#
#    Simulated Activity Level  Simulated Hypertension  Simulated Height CM  \
# 0                         0                       1                  168
# 1                         1                       1                  161
# 2                         1                       1                  177
# 3                         1                       1                  160
# 4                         1                       1                  182
#
#    Simulated Weight KG  Simulated Height IN  Simulated Weight LBS  \
# 0                  110                  5.5                 242.5
# 1                   60                  5.3                 132.3
# 2                   85                  5.8                 187.4
# 3                  101                  5.2                 222.7
# 4                  121                  6.0                 266.8
#
#    Simulated BMI  ADA Family Risk   ADA Age Risk   ADA Gender Risk   \
# 0           39.0                 0              1                 1
# 1           23.1                 0              3                 0
# 2           27.1                 0              1                 1
# 3           39.5                 1              3                 0
# 4           36.5                 0              3                 1
#
#    ADA BMI Risk   ADA Hypertension Risk  \
# 0              3                      1
# 1              0                      1
# 2              3                      1
# 3              3                      1
# 4              3                      1
#
#    Total Calculated ADA pre-Diabetes Risk  AIHS Age Risk  AIHS BMI Risk  \
# 0                                       6            1.9           2.80
# 1                                       5            4.3           0.00
# 2                                       6            1.9           1.11
# 3                                       8            5.7           2.85
# 4                                       8            5.7           2.55
#
#   Simulated BMI Class Simulated Activity Class  Total Calculated AIHS Risk  \
# 0               Obese                Sedentary                        4.23
# 1      Healthy Weight                   Active                        4.23
# 2         Over Weight                   Active                        4.23
# 3               Obese                   Active                        4.23
# 4               Obese                   Active                        4.23
#
#            Patient Cohort  ADA BMI Risk
# 0        Obese, Sedentary             2
# 1  Healthy Weight, Active             0
# 2     Over Weight, Active             1
# 3           Obese, Active             2
# 4           Obese, Active             2

# %%
#df=df.apply(calc_ADS_age_risk, axis='columns')
df=df.apply(calc_AIHS_BMI_risk, axis='columns')
pd.options.display.max_columns = None
df.head(5)
# Out:
#   Patient  Ordinal Birth  Date  Age  Decade  Gender  \
# 0   Patient_2018_1   4/12/1972   49       4    Male
# 1   Patient_2018_2    9/3/1947   73       7  Female
# 2   Patient_2018_3   9/16/1971   49       4    Male
# 3   Patient_2018_4    1/8/1934   87       8  Female
# 4   Patient_2018_5   5/12/1934   87       8    Male
#
#    Simulated Imputed Diabetic Metabolic Syndrome (OUTCOME)  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  0
#
#    Imputed ADA Risk (outcome)  Simulated Family Member with Diabetes  \
# 0                           1                                      0
# 1                           1                                      0
# 2                           1                                      0
# 3                           1                                      1
# 4                           1                                      0
#
#    Simulated Activity Level  Simulated Hypertension  Simulated Height CM  \
# 0                         0                       1                  168
# 1                         1                       1                  161
# 2                         1                       1                  177
# 3                         1                       1                  160
# 4                         1                       1                  182
#
#    Simulated Weight KG  Simulated Height IN  Simulated Weight LBS  \
# 0                  110                  5.5                 242.5
# 1                   60                  5.3                 132.3
# 2                   85                  5.8                 187.4
# 3                  101                  5.2                 222.7
# 4                  121                  6.0                 266.8
#
#    Simulated BMI  ADA Family Risk   ADA Age Risk   ADA Gender Risk   \
# 0           39.0                 0              1                 1
# 1           23.1                 0              3                 0
# 2           27.1                 0              1                 1
# 3           39.5                 1              3                 0
# 4           36.5                 0              3                 1
#
#    ADA BMI Risk   ADA Hypertension Risk  \
# 0              3                      1
# 1              0                      1
# 2              3                      1
# 3              3                      1
# 4              3                      1
#
#    Total Calculated ADA pre-Diabetes Risk  AIHS Age Risk  AIHS BMI Risk  \
# 0                                       6            1.9           2.80
# 1                                       5            4.3           0.00
# 2                                       6            1.9           1.11
# 3                                       8            5.7           2.85
# 4                                       8            5.7           2.55
#
#   Simulated BMI Class Simulated Activity Class  Total Calculated AIHS Risk  \
# 0               Obese                Sedentary                        4.23
# 1      Healthy Weight                   Active                        4.23
# 2         Over Weight                   Active                        4.23
# 3               Obese                   Active                        4.23
# 4               Obese                   Active                        4.23
#
#            Patient Cohort  ADA BMI Risk
# 0        Obese, Sedentary             2
# 1  Healthy Weight, Active             0
# 2     Over Weight, Active             1
# 3           Obese, Active             2
# 4           Obese, Active             2
