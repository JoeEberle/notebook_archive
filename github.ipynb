# %% [markdown]
# ![github.png](attachment:github.png)

# %% [markdown]
# Process Steps :
# 1. Import the pyttsx3 text to speech module
# 2. Instantiate the text to speech engine
# 3. Configure the TTS dialogues and settings
# 4. Test the Text to Speech Engine

# %%
import pyttsx3
import talking_code_talking_code as talking_code
import configparser as configparser
import os

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'github'
cwd = os.getcwd()

# %% [markdown]
# ## Step 0 - Optional - Establish Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(True)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Process.')
# Out:
# Process talking code Step 0 - Initializing and starting Process.

# %% [markdown]
# ## Step 0 - Orientation and Setup of Git / GitHUB

# %%
import talking_code as tc

definition = 'Git is a distributed version control system designed to track changes in source code during software development, allowing multiple developers to collaborate, manage different versions, and merge their work seamlessly. It enables efficient code management, fosters collaboration, and ensures the integrity and history of a projects development.'
tc.say(definition)

speech = 'to get started with git:'
speech = speech + ' 1 Configure Git with your username'   # git config --global user JoeEberle
speech = speech + ' 2 Configure Git with your email '     # git config --global email josepheberle@outlook.com
speech = speech + ' 3 Establish a file root directory for your projects called "projects" '
speech = speech + ' 4 Establish a project directory for each of your projects under the new root directory" '
speech = speech + ' 5 Initialize git in each project folder '
tc.say(speech)

# GitHub is a web-based platform that provides hosting for Git repositories, offering tools for code collaboration, version control, issue tracking, and project management.

# %%
import talking_code as tc

definition = 'GitHub is a web-based platform that provides hosting for Git repositories, offering tools for code collaboration, version control, issue tracking, and project management.'
tc.say(definition)

speech = 'to get started with git:'
# speech = speech + ' 1 Configure Git with your username'
# speech = speech + ' 2 Configure Git with your email '
# speech = speech + ' 3 Establish a file root directory for your projects called "projects" '
# speech = speech + ' 4 Establish a project directory for each of your projects under the new root directory" '
# speech = speech + ' 5 Initialize git in each project folder '
tc.say(speech)

# G

# %%
# Set text to speech preferences for project 
ql.pvlog('info',f'Process {solution_name} Step 1 - Initialize The Test to Speech Engine.') 
Text_to_Speech = talking_code.Initialize_Text_to_Speach()
# Out:
# Process talking code Step 1 - Initialize The Test to Speech Engine.

# %%
if config.get('talk_to_me','Talking_Code'):  
        ql.pvlog('info',f'Process {solution_name} Step 2 - Read the Solution documentation.')     
        talking_code.read_introduction()
        talking_code.read_credits()  
        talking_code.read_process_steps()  
        talking_code.read_terms()
# Out:
# Process talking code Step 2 - Read the Solution documentation.
#
#
# This jupiter notebook will quickly and easily setup text to speech so that the code can explain itself and reduce learning curve.
#
#
#
# This Jupiter Notebook Was:
# Developed in Collaboration by Joe Eberle
# Developed in Python 3 starting on 9/20/2022
# This package is free AND Open Source and the code is openly available for general Use.
#
#
#
# The steps of this process are :
# Optional Install: Pip or conda install the latest pytsx3 library if not already Loaded
# Step 1: Import the pytsx3 text to speech library.
# Step 2: Instantiate the text to speech engine.
# Step 3: Test the Project dialogues to ensure text to speech is working.
#
#
#
# The terminology for this process is :
# Python. Python is a general-purpose programming language that is widely used for data science.
# pyttsx3 PACKAGE - The pyttsx3 library is a text to speech engine that is customizable to multiple voices and settings.

# %%
ql.pvlog('info',f'Process {solution_name} Step 3 - If speaking occurred then this process was successfull - End Process')
# Out:
# Process talking code Step 3 - If speaking occurred then this process was successfull - End Process

# %% [markdown]
# ## Optional - Log overall performance and Append the Log File to Historical Log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-07-22 21:00:50,402 - INFO - START talking code =============================================
# 2023-07-22 21:00:50,402 - INFO - START talking code Start Time = 2023-07-22 21:00:50
# 2023-07-22 21:00:50,402 - INFO - talking code Step 0 - Initialize the configuration file parser
# 2023-07-22 21:00:50,542 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2023-07-22 21:00:50,542 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2023-07-22 21:00:55,975 - INFO - Process talking code Step 0 - Initializing and starting Process.
# 2023-07-22 21:01:00,391 - INFO - Process talking code Step 1 - Initialize The Test to Speech Engine.
# 2023-07-22 21:01:09,527 - INFO - Process talking code Step 2 - Read the Solution documentation.
# ...
