# %%
import openai    # https://beta.openai.com/signup/
import pandas as pd
# Set the API key   # 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
openai.api_key = "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"

# Set the model to use
model_engine = "davinci"

# %%
def get_AI_response(question):       # Generate a response from the OpenAI chatgpt3 API using the davinci model
    ''' Ask a question of an AI system and get a response'''
    completions = openai.Completion.create(engine=model_engine, prompt=question, max_tokens=1024, n=1, stop=None, temperature=0.5,)
    return completions.choices[0].text

# %%
def create_qna_dataframe():
    df_question_and_answer = pd.DataFrame(columns = ['Question', 'Answer'])
    return df_question_and_answer

def add_question_and_answer(question,answer):
    df_question_and_answer.loc[len(df_question_and_answer)] = [question,answer]
    return df_question_and_answer 

testing = True
if testing:
    df_question_and_answer = create_qna_dataframe() 
    df_question_and_answer = add_question_and_answer('why is the sky blue','defraction')
#     df_question_and_answer = add_question_and_answer('who is joe eberle','king of everything')  
#     df_question_and_answer = add_question_and_answer('What is python','king of everything')   
#     df_question_and_answer = add_question_and_answer('what color is a ripe banana','yellow')

    
df_question_and_answer.head(10)
# Out:
#               Question      Answer
# 0  why is the sky blue  defraction

# %%
df_question_and_answer = add_question_and_answer('what color is a ripe banana','yellow')

# %%
prompt = "write python code to build a new pandas dataframe called 'q_and_a'. The new ' 'q_and_a' dataframe should have two columns named 'question' and 'answer' "
ai_response = get_AI_response(prompt)
print(f'\n\nQuestion:{prompt} \n\nAI Response:{ai_response}')
print(f'\n\nQuestion:{prompt} \n\nAI Response:{ai_response}')
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 prompt = "write python code to build a new pandas dataframe called 'q_and_a'. The new ' 'q_and_a' dataframe should have two columns named 'question' and 'answer' "
# ----> 2 ai_response = get_AI_response(prompt)
#       3 print(f'\n\nQuestion:{prompt} \n\nAI Response:{ai_response}')
#       4 print(f'\n\nQuestion:{prompt} \n\nAI Response:{ai_response}')
#
# Cell In[2], line 3, in get_AI_response(question)
#       1 def get_AI_response(question):       # Generate a response from the OpenAI chatgpt3 API using the davinci model
#       2     ''' Ask a question of an AI system and get a response'''
# ----> 3     completions = openai.Completion.create(engine=model_engine, prompt=question, max_tokens=1024, n=1, stop=None, temperature=0.5,)
#       4     return completions.choices[0].text
#
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
q_and_a = pd.DataFrame(columns = [ 'question' , 'answer'])
# q_and_a = q_and_a.set_index('question') 
# q_and_a = q_and_a.dropna()
q_and_a.question = [ 'How much wood could a woodchuck chuck' , 'If you eat a clock, do you gain or lose time' , 'What goes up, must come down' , 'What is the sound of one hand clapping?' , 'How many times a day do a clocks hands overlap' ] 
q_and_a.answer = [ 'none' , 'one' , 'twelve' , 'thirty-two' , 'eleven' ] 
q_and_a.head()
# Out:
#                                          question      answer
# 0           How much wood could a woodchuck chuck        none
# 1    If you eat a clock, do you gain or lose time         one
# 2                    What goes up, must come down      twelve
# 3         What is the sound of one hand clapping?  thirty-two
# 4  How many times a day do a clocks hands overlap      eleven

# %%
import pandas as pd
import numpy as np 
# from scipy.stats import rank 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_style("whitegrid") 

def get_question_and_answer_df(question_and_answer_csv_file, answer_df_file): 
    df = pd.read_csv(question_and_answer_csv_file) 
    answer_df = pd.read_csv(answer_df_file) 
    df = df.join(answer_df,how='inner',left_index=True,right_index=True) 
    df.drop('Answer',axis=1,inplace=True) 
    df.drop('Question',axis=1,inplace=True) 
    return df 

question_df = get_question_and_answer_df('question_and_answer.csv', 'question_and_answer.csv') 
answer_df = get_question_and_answer_df('answer.csv', 'answer.csv') 
question_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 16
#      13     df.drop('Question',axis=1,inplace=True)
#      14     return df
# ---> 16 question_df = get_question_and_answer_df('question_and_answer.csv', 'question_and_answer.csv')
#      17 answer_df = get_question_and_answer_df('answer.csv', 'answer.csv')
#      18 question_df.head()
#
# Cell In[13], line 9, in get_question_and_answer_df(question_and_answer_csv_file, answer_df_file)
#       8 def get_question_and_answer_df(question_and_answer_csv_file, answer_df_file):
# ----> 9     df = pd.read_csv(question_and_answer_csv_file)
#      10     answer_df = pd.read_csv(answer_df_file)
#      11     df = df.join(answer_df,how='inner',left_index=True,right_index=True)
#
# ...

# %%
import pandas as pd 
import numpy as np 
from scipy.stats import rank 
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_style("whitegrid") 

def get_question_and_answer_df(question_and_answer_csv_file, answer_df_file): 
    df = pd.read_csv(question_and_answer_csv_file) 
    answer_df = pd.read_csv(answer_df_file) 
    df = df.join(answer_df,how='inner',left_index=True,right_index=True) 
    df.drop('Answer',axis=1,inplace=True) 
    df.drop('Question',axis=1,inplace=True) 
    return df 

question_df = get_question_and_answer_df('question_and_answer.csv', 'question_and_answer.csv') 
question_df.head() answer_df.head()

# %%
# !pip install scipy

# %%
# Set the prompt
prompt = "write me a brief paragraph about the opioid crisis in New York State"

# Generate the text
completions = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get the generated text
generated_text = completions.choices[0].text

print(f'\n\nQuestion:{prompt} \n\nAI Response:{generated_text}')
# Out:
# Question:write me a brief paragraph about the opioid crisis in New York State
#
# AI Response:.
#
# I have a question about the opioid crisis. How do you feel about the governor’s plan to put a stop to the opioid crisis in New York State?
#
# Write a brief paragraph about the opioid crisis in New York State.
#
# I have a question about the opioid crisis. How do you feel about the governor’s plan to put a stop to the opioid crisis in New York State?
#
# Write a brief paragraph about the opioid crisis in New York State.
#
# I have a question about the opioid crisis. How do you feel about the governor’s plan to put a stop to the opioid crisis in New York State?
#
# Write a brief paragraph about the opioid crisis in New York State.
#
# I have a question about the opioid crisis. How do you feel about the governor’s plan to put a stop to the opioid crisis in New York State?
#
# Write a brief paragraph about the opioid crisis in New York State.
#
# ...

# %%
import openai

# https://beta.openai.com/signup/

# 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
# Set the API key
openai.api_key = "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"

# Set the model to use
model_engine = "davinci"

# Set the prompt
prompt = "What are the top five technology concerns for behavioral health organizations in 2023 "

# Generate the text
completions = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get the generated text
generated_text = completions.choices[0].text

print(f'\n\nQuestion:{prompt} \n\nAI Response:{generated_text}')

# %%
import openai

# https://beta.openai.com/signup/


# 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
# Set the API key
openai.api_key = "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"

# Set the model to use
model_engine = "davinci"

# Set the prompt
prompt = "write a brief summary about enterprise architecture frameworks"

# Generate the text
completions = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get the generated text
generated_text = completions.choices[0].text

print(generated_text)

# %%
import openai

# https://beta.openai.com/signup/


# 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
# Set the API key
openai.api_key = "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"

# Set the model to use
model_engine = "davinci"

# Set the prompt
prompt = "write a jupyter notebook python code to conduct a english survey about a patients health care risks. \
The survey results will be used to calculate a persons diabetes risk. \
supply the code for the GUI interface. \
The survey results will be stored in a sqlite3 database. \
The survey results will be displayed in a graph. \
The survey will run on my local computer. \
The GUI will have a title, a question, an answer, a submit button, and a cancel button. \
The GUI will ask the user to enter a person's age, gender, and race. \
The GUI will ask the user to enter a persons height, weight, and waist size. \
The GUI will ask the user to enter a persons blood pressure, blood sugar, and blood cholesterol.\
"

# Generate the text
completions = openai.Completion.create(
    engine=model_engine,
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Get the generated text
generated_text = completions.choices[0].text
print("\n OAI RESULT:")
print(generated_text)
print("\n done")

# %%
#  OAI RESULT:


# The survey must be designed to be conducted by a nurse or other medical professional.

# The survey should be designed so that it can be used in a clinical setting, such as a doctor's office.

# The survey must be designed so that it can be used in a non-clinical setting, such as a health fair.

# The survey must be designed so that it can be used in an emergency room setting.

# The survey must be designed so that it can be used in a rural clinic setting.

# The survey must be designed so that it can be used in a remote area, such as a rural village.

# The survey must be designed so that it can be used in a non-english speaking country.

# The survey must be designed so that it can be used by a non-technical medical professional.

# The survey must be designed so that it can be used by a non-technical medical professional who has never used a computer before.

# The survey must be designed so that it can be used by a non-technical medical professional who has never used a computer before, who is also illiterate.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before, who is also in a non-clinical setting.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before, who is also in a non-clinical setting, who is also in a non-technical setting.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before, who is also in a non-clinical setting, who is also in a non-technical setting, who is also in a non-technical setting.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before, who is also in a non-clinical setting, who is also in a non-technical setting, who is also in a non-technical setting, who is also in a non-clinical setting.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who is also in a non-english speaking country, who has never used a computer before, who is also in a non-clinical setting, who is also in a non-technical setting, who is also in a non-technical setting, who is also in a non-clinical setting, who is also in a remote area.

# The survey must be designed so that it can be used by a non-technical medical professional who is illiterate, who is also non-english speaking, who has never used a computer before, who is also in a remote area, who

#  done

# %%
# !pip install openai

# %%
import os

dir_path = r'C:\targetdir'

# List all files in the directory
for file_name in os.listdir(dir_path):
    if 'note' in file_name or 'assessment' in file_name:
        file_path = os.path.join(dir_path, file_name)
        try:
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        except Exception as e:
            print(f"Error deleting file {file_path}: {e}")

# %%
import os

def delete_specific_files_from_directory(directory_path,file_key_word):
    deleted_file_count = 0
    status = f'\n Scanning directory:{directory_path} for files containing :{file_key_word}' 
    for filename in os.listdir(directory_path):
        if file_key_word in filename:
            os.remove(os.path.join(directory_path, filename))
            deleted_file_count += 1 
            status = status = f'\n Removed file#{deleted_file_count} filename:{filename}' 
            
testing = True
if Testing:
    delete_specific_files_from_directory

# %%
# To use the OpenAI API, you will need to sign up for an API key at the following link: https://beta.openai.com/signup/

# Once you have obtained your API key, you can use the following code to call the OpenAI API using Python:

# %%
import openai
# Set the API key
openai.api_key = "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"

# Set the model to use
model_engine = "davinci"

# Set the prompt
prompt = "write an overview of stages of the transtheoretical model" 

# Generate the text
completions = openai.Completion.create(engine=model_engine, prompt=prompt, max_tokens=1024,  n=1, stop=None, temperature=0.5,)

# Get the generated text
generated_text = completions.choices[0].text
print("\nOAI RESULT:")
print(generated_text)
print("\ndone")
