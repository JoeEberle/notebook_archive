# %% [markdown]
# ![Infrastructure_setup.png](attachment:Infrastructure_setup.png)

# %% [markdown]
# # Development Environment and Infrastructure Setup - House Cleaning
# #### by Joe Eberle started on 11_5_2022 and refactored on 11_5_2022 and revised on 11_5_2022

# %% [markdown]
# ![credits%20II%20.png](attachment:credits%20II%20.png)

# %%
# import the libraries necessary for the process 
import os, glob
from shutil import copyfile, copytree 
import schedule
import file_manager as fm

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'infrastructure_setup'
cwd = os.getcwd()

# %% [markdown]
# ## Optional Step 0 - Initiate logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_Start(solution_name, start_time)

# %% [markdown]
# ## Step 1 establish infrastructure directory to organize all files

# %%
def create_directory_tree(directory):
    ''' The create_directory_tree function will create an organized directory for housing your files and infrastructure '''
    logging.info(f'{solution_name} - Step 1 establish infrastructure directory to organize all files')       
    status = 'Creating Directories: \n' + '\n' + fm.create_directory(directory)
    directory_list = ['html','excel','jupyter_notebook','documentation'\
                      ,'database','powerbi','tableau','images','csv','parquet','feather','pickle'\
                      ,'text','presentation', 'jaepy','py','log']
    for subdir in directory_list:
        status = status + '\n' + fm.create_directory(directory + '/' + subdir)
        logging.info(f'{solution_name} - Creating if non-existent : {directory + "/" + subdir}')                
    return status 

developing_and_testing = True # Unit test for this function  - set this to True or False to turn testing on or off 
if developing_and_testing:
    infrastructure_directory = config.get('global_infrastructure', 'infrastructure_directory')  
    if len(infrastructure_directory)  < 3:
        status = create_directory_tree('c://infrastructure') # establish a default if none exists
    status = create_directory_tree(infrastructure_directory)        
    print(status)
# Out:
# Creating Directories:
#
# Error attempting to create directory:c://infrastructure
# Error attempting to create directory:c://infrastructure/html
# Error attempting to create directory:c://infrastructure/excel
# Error attempting to create directory:c://infrastructure/jupyter_notebook
# Error attempting to create directory:c://infrastructure/documentation
# Error attempting to create directory:c://infrastructure/database
# Error attempting to create directory:c://infrastructure/powerbi
# Error attempting to create directory:c://infrastructure/tableau
# Error attempting to create directory:c://infrastructure/images
# Error attempting to create directory:c://infrastructure/csv
# Error attempting to create directory:c://infrastructure/parquet
# Error attempting to create directory:c://infrastructure/feather
# Error attempting to create directory:c://infrastructure/pickle
# Error attempting to create directory:c://infrastructure/text
# Error attempting to create directory:c://infrastructure/presentation
# Error attempting to create directory:c://infrastructure/jaepy
# Error attempting to create directory:c://infrastructure/py
# Error attempting to create directory:c://infrastructure/log

# %% [markdown]
# ## Step 2 Organize (copy all file types) into appropriate infrastructure directories

# %%
# Move all python .py libraries for easy location 
def copy_and_organize_files(cwd):
    logging.info(f'{solution_name} - Step 3 Organize (copy all file types) into appropriate infrastructure directories')          
    status = 'backup one file type at a time: \n'
    target = "C:/Infrastructure/"
#     status = status + '\n' + fm.copy_all_files(cwd,"jaepy",target+"jaepy/")    # backup python files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"ipynb",target+"jupyter_notebook/")   # backup python files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"html",target+"html/")  # backup python files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"excel",target+"excel/") # backup excel files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"doc",target+"documentation/")  # backup files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"png",target+"images/")  # backup documentation files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"parquet",target+"parquet/") # backup parquet files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"feather",target+"feather/") # backup feather files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"pickle",target+"pickle/") # backup pickle files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"py",target+"py/") # backup python files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"py",target+"jaepy/") # backup python files to archive and easy location     
    status = status + '\n' + fm.copy_all_files(cwd,"pbix",target+"powerbi/")  # backup powerbi files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"tbwx",target+"tableua/") # backup tableua files to archive and easy location        
    status = status + '\n' + fm.copy_all_files(cwd,"txt",target+"text/")  # backup text files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"pptx",target+"presentation/") # backup presentation files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"csv",target+"csv/") # backup presentation files to archive and easy location 
    status = status + '\n' + fm.copy_all_files(cwd,"log",target+"log/") # backup presentation files to archive and easy location 
    
    return(status)


developing_and_testing = True # Unit test for this function  - set this to True or False to turn testing on or off 
if developing_and_testing: 
    import os 
    cwd = os.getcwd() 
    status = copy_and_organize_files(cwd)
    print(status)
# Out:
# backup one file type at a time:
#
#
# Disovering files of extension:ipynb in directory:C:\Users\josep to move to directoryC:/Infrastructure/jupyter_notebook/
# File #1 copying file  Poor Emotional Risk Calculation.ipynb to C:/Infrastructure/jupyter_notebook/ Poor Emotional Risk Calculation.ipynb
# File #2 copying file ADT_Manager.ipynb to C:/Infrastructure/jupyter_notebook/ADT_Manager.ipynb
# File #3 copying file AI Chatbot Diabetes Combined.ipynb to C:/Infrastructure/jupyter_notebook/AI Chatbot Diabetes Combined.ipynb
# File #4 copying file AI Chatbot Diabetes.ipynb to C:/Infrastructure/jupyter_notebook/AI Chatbot Diabetes.ipynb
# File #5 copying file AI Chatbot FamilyServices.ipynb to C:/Infrastructure/jupyter_notebook/AI Chatbot FamilyServices.ipynb
# File #6 copying file AI Chatbot GCASA.ipynb to C:/Infrastructure/jupyter_notebook/AI Chatbot GCASA.ipynb
# File #7 copying file AI Corpus classification.ipynb to C:/Infrastructure/jupyter_notebook/AI Corpus classification.ipynb
# File #8 copying file aihs_patient_measures.ipynb to C:/Infrastructure/jupyter_notebook/aihs_patient_measures.ipynb
# File #9 copying file AI_chatterbot.ipynb to C:/Infrastructure/jupyter_notebook/AI_chatterbot.ipynb
# File #10 copying file AI_Health_Coach tkinter-Copy1.ipynb to C:/Infrastructure/jupyter_notebook/AI_Health_Coach tkinter-Copy1.ipynb
# File #11 copying file AI_Health_Coach tkinter.ipynb to C:/Infrastructure/jupyter_notebook/AI_Health_Coach tkinter.ipynb
# File #12 copying file AI_Health_Coach.ipynb to C:/Infrastructure/jupyter_notebook/AI_Health_Coach.ipynb
# File #13 copying file Annual Wellness Visits Summary by Provider.ipynb to C:/Infrastructure/jupyter_notebook/Annual Wellness Visits Summary by Provider.ipynb
# File #14 copying file Annual Wellness Visits with Excel Automation.ipynb to C:/Infrastructure/jupyter_notebook/Annual Wellness Visits with Excel Automation.ipynb
# File #15 copying file Assign_Table_Name.ipynb to C:/Infrastructure/jupyter_notebook/Assign_Table_Name.ipynb
# File #16 copying file Attribution and Affiliation and Eligibility.ipynb to C:/Infrastructure/jupyter_notebook/Attribution and Affiliation and Eligibility.ipynb
# File #17 copying file Attribution and Affiliation with Excel Automation.ipynb to C:/Infrastructure/jupyter_notebook/Attribution and Affiliation with Excel Automation.ipynb
# File #18 copying file BRFSS.ipynb to C:/Infrastructure/jupyter_notebook/BRFSS.ipynb
# File #19 copying file building_solutions.ipynb to C:/Infrastructure/jupyter_notebook/building_solutions.ipynb
# File #20 copying file Bulk importing of CSV files.ipynb to C:/Infrastructure/jupyter_notebook/Bulk importing of CSV files.ipynb
# File #21 copying file calculator.ipynb to C:/Infrastructure/jupyter_notebook/calculator.ipynb
# File #22 copying file card_deck.ipynb to C:/Infrastructure/jupyter_notebook/card_deck.ipynb
# File #23 copying file Casa Trinity Data Discovery - Version III Date format conversions.ipynb to C:/Infrastructure/jupyter_notebook/Casa Trinity Data Discovery - Version III Date format conversions.ipynb
# File #24 copying file Casa Trinity Data II .ipynb to C:/Infrastructure/jupyter_notebook/Casa Trinity Data II .ipynb
# File #25 copying file chatbot python.ipynb to C:/Infrastructure/jupyter_notebook/chatbot python.ipynb
# File #26 copying file chatbot_demo.ipynb to C:/Infrastructure/jupyter_notebook/chatbot_demo.ipynb
# File #27 copying file CHATGPT.ipynb to C:/Infrastructure/jupyter_notebook/CHATGPT.ipynb
# File #28 copying file chatterbot.ipynb to C:/Infrastructure/jupyter_notebook/chatterbot.ipynb
# File #29 copying file chatter_bot .ipynb to C:/Infrastructure/jupyter_notebook/chatter_bot .ipynb
# File #30 copying file chat_dialog_flow.ipynb to C:/Infrastructure/jupyter_notebook/chat_dialog_flow.ipynb
# File #31 copying file Circadian Rhythm Risk Calculation .ipynb to C:/Infrastructure/jupyter_notebook/Circadian Rhythm Risk Calculation .ipynb
# File #32 copying file Circadian Rhythm Risk Calculator.ipynb to C:/Infrastructure/jupyter_notebook/Circadian Rhythm Risk Calculator.ipynb
# File #33 copying file Color_Settings.ipynb to C:/Infrastructure/jupyter_notebook/Color_Settings.ipynb
# File #34 copying file Computer Video Capture.ipynb to C:/Infrastructure/jupyter_notebook/Computer Video Capture.ipynb
# File #35 copying file Config.ini Creator and Parser.ipynb to C:/Infrastructure/jupyter_notebook/Config.ini Creator and Parser.ipynb
# File #36 copying file Configuring Settings.ipynb to C:/Infrastructure/jupyter_notebook/Configuring Settings.ipynb
# File #37 copying file configuring_settings.ipynb to C:/Infrastructure/jupyter_notebook/configuring_settings.ipynb
# File #38 copying file connect to snowflake.ipynb to C:/Infrastructure/jupyter_notebook/connect to snowflake.ipynb
# File #39 copying file cool_graph.ipynb to C:/Infrastructure/jupyter_notebook/cool_graph.ipynb
# File #40 copying file corpus_learning_chatbot.ipynb to C:/Infrastructure/jupyter_notebook/corpus_learning_chatbot.ipynb
# File #41 copying file correlation_heatmap.ipynb to C:/Infrastructure/jupyter_notebook/correlation_heatmap.ipynb
# File #42 copying file csv_to_dataframe.ipynb to C:/Infrastructure/jupyter_notebook/csv_to_dataframe.ipynb
# File #43 copying file Data Directory Discovery.ipynb to C:/Infrastructure/jupyter_notebook/Data Directory Discovery.ipynb
# File #44 copying file Data Discovery for Importing CSV files into a SQL Database   I.ipynb to C:/Infrastructure/jupyter_notebook/Data Discovery for Importing CSV files into a SQL Database   I.ipynb
# File #45 copying file Data Discovery for Importing CSV files into a SQL Database III.ipynb to C:/Infrastructure/jupyter_notebook/Data Discovery for Importing CSV files into a SQL Database III.ipynb
# File #46 copying file Data Exploration.ipynb to C:/Infrastructure/jupyter_notebook/Data Exploration.ipynb
# File #47 copying file Data File Discovery.ipynb to C:/Infrastructure/jupyter_notebook/Data File Discovery.ipynb
# File #48 copying file Data Science with python week 1 .ipynb to C:/Infrastructure/jupyter_notebook/Data Science with python week 1 .ipynb
# File #49 copying file Data Synthesis - BRFSS RAW for Integration.ipynb to C:/Infrastructure/jupyter_notebook/Data Synthesis - BRFSS RAW for Integration.ipynb
# File #50 copying file Data Synthesis - Demographic with ADA Risk Survey-Copy1.ipynb to C:/Infrastructure/jupyter_notebook/Data Synthesis - Demographic with ADA Risk Survey-Copy1.ipynb
# File #51 copying file Data Synthesis - Demographic with ADA Risk Survey.ipynb to C:/Infrastructure/jupyter_notebook/Data Synthesis - Demographic with ADA Risk Survey.ipynb
# File #52 copying file Data Synthesis - Patient Data Cleansing and Integration.ipynb to C:/Infrastructure/jupyter_notebook/Data Synthesis - Patient Data Cleansing and Integration.ipynb
# File #53 copying file Database Import tool .ipynb to C:/Infrastructure/jupyter_notebook/Database Import tool .ipynb
# File #54 copying file data_discovery.ipynb to C:/Infrastructure/jupyter_notebook/data_discovery.ipynb
# File #55 copying file data_loader.ipynb to C:/Infrastructure/jupyter_notebook/data_loader.ipynb
# File #56 copying file data_profiling.ipynb to C:/Infrastructure/jupyter_notebook/data_profiling.ipynb
# File #57 copying file data_visualizer.ipynb to C:/Infrastructure/jupyter_notebook/data_visualizer.ipynb
# File #58 copying file design_goal-Copy1.ipynb to C:/Infrastructure/jupyter_notebook/design_goal-Copy1.ipynb
# File #59 copying file design_goal.ipynb to C:/Infrastructure/jupyter_notebook/design_goal.ipynb
# File #60 copying file Diabetes Risk Stratification - Demographic with SIM.ipynb to C:/Infrastructure/jupyter_notebook/Diabetes Risk Stratification - Demographic with SIM.ipynb
# File #61 copying file Diabetes Risk Stratification - PIMA Indians-checkpoint.ipynb to C:/Infrastructure/jupyter_notebook/Diabetes Risk Stratification - PIMA Indians-checkpoint.ipynb
# File #62 copying file Diabetes Risk Survey.ipynb to C:/Infrastructure/jupyter_notebook/Diabetes Risk Survey.ipynb
# File #63 copying file Dialogue of Surveys.ipynb to C:/Infrastructure/jupyter_notebook/Dialogue of Surveys.ipynb
# File #64 copying file dialog_script.ipynb to C:/Infrastructure/jupyter_notebook/dialog_script.ipynb
# File #65 copying file digital_chat.ipynb to C:/Infrastructure/jupyter_notebook/digital_chat.ipynb
# File #66 copying file directory_loader.ipynb to C:/Infrastructure/jupyter_notebook/directory_loader.ipynb
# File #67 copying file directory_loader_all_tables.ipynb to C:/Infrastructure/jupyter_notebook/directory_loader_all_tables.ipynb
# File #68 copying file directory_loader_all_tables_test.ipynb to C:/Infrastructure/jupyter_notebook/directory_loader_all_tables_test.ipynb
# File #69 copying file directory_loader_sqlserver.ipynb to C:/Infrastructure/jupyter_notebook/directory_loader_sqlserver.ipynb
# File #70 copying file directory_loader_test_referal.ipynb to C:/Infrastructure/jupyter_notebook/directory_loader_test_referal.ipynb
# File #71 copying file django_chat.ipynb to C:/Infrastructure/jupyter_notebook/django_chat.ipynb
# File #72 copying file docbot.ipynb to C:/Infrastructure/jupyter_notebook/docbot.ipynb
# File #73 copying file Doctor AI .ipynb to C:/Infrastructure/jupyter_notebook/Doctor AI .ipynb
# File #74 copying file Document Management.ipynb to C:/Infrastructure/jupyter_notebook/Document Management.ipynb
# File #75 copying file download_email_attachments.ipynb to C:/Infrastructure/jupyter_notebook/download_email_attachments.ipynb
# File #76 copying file ELIZA_chatbot.ipynb to C:/Infrastructure/jupyter_notebook/ELIZA_chatbot.ipynb
# File #77 copying file Event_Logging.ipynb to C:/Infrastructure/jupyter_notebook/Event_Logging.ipynb
# File #78 copying file face change recognition.ipynb to C:/Infrastructure/jupyter_notebook/face change recognition.ipynb
# File #79 copying file Feature Engineering - Select K Best.ipynb to C:/Infrastructure/jupyter_notebook/Feature Engineering - Select K Best.ipynb
# File #80 copying file File Browser and Navigator.ipynb to C:/Infrastructure/jupyter_notebook/File Browser and Navigator.ipynb
# File #81 copying file file_manager.ipynb to C:/Infrastructure/jupyter_notebook/file_manager.ipynb
# File #82 copying file file_watchdog.ipynb to C:/Infrastructure/jupyter_notebook/file_watchdog.ipynb
# File #83 copying file Flower.ipynb to C:/Infrastructure/jupyter_notebook/Flower.ipynb
# File #84 copying file generate_json.ipynb to C:/Infrastructure/jupyter_notebook/generate_json.ipynb
# File #85 copying file Generating Analytics PDF report.ipynb to C:/Infrastructure/jupyter_notebook/Generating Analytics PDF report.ipynb
# File #86 copying file generating_reports.ipynb to C:/Infrastructure/jupyter_notebook/generating_reports.ipynb
# File #87 copying file generating_reports_2.ipynb to C:/Infrastructure/jupyter_notebook/generating_reports_2.ipynb
# File #88 copying file Generic Feature Engineering and Reduction - Diabetes Patients-Copy1.ipynb to C:/Infrastructure/jupyter_notebook/Generic Feature Engineering and Reduction - Diabetes Patients-Copy1.ipynb
# File #89 copying file Generic Feature Engineering and Reduction - Diabetes Patients.ipynb to C:/Infrastructure/jupyter_notebook/Generic Feature Engineering and Reduction - Diabetes Patients.ipynb
# File #90 copying file Generic Feature Engineering and Reduction - Poisonous or Edible Mushrooms .ipynb to C:/Infrastructure/jupyter_notebook/Generic Feature Engineering and Reduction - Poisonous or Edible Mushrooms .ipynb
# File #91 copying file GeoLocation Street Map API .ipynb to C:/Infrastructure/jupyter_notebook/GeoLocation Street Map API .ipynb
# File #92 copying file github.ipynb to C:/Infrastructure/jupyter_notebook/github.ipynb
# File #93 copying file github_automation.ipynb to C:/Infrastructure/jupyter_notebook/github_automation.ipynb
# File #94 copying file git_commands.ipynb to C:/Infrastructure/jupyter_notebook/git_commands.ipynb
# File #95 copying file glossary_term.ipynb to C:/Infrastructure/jupyter_notebook/glossary_term.ipynb
# File #96 copying file HCC and RAF Improvement Opportunity.ipynb to C:/Infrastructure/jupyter_notebook/HCC and RAF Improvement Opportunity.ipynb
# File #97 copying file Health Quality Measures  with Excel Automation .ipynb to C:/Infrastructure/jupyter_notebook/Health Quality Measures  with Excel Automation .ipynb
# File #98 copying file Healthcare Smart Chat CKD.ipynb to C:/Infrastructure/jupyter_notebook/Healthcare Smart Chat CKD.ipynb
# File #99 copying file HealtheIentent API .ipynb to C:/Infrastructure/jupyter_notebook/HealtheIentent API .ipynb
# File #100 copying file HealtheIntent API.ipynb to C:/Infrastructure/jupyter_notebook/HealtheIntent API.ipynb
# File #101 copying file HIDUU.ipynb to C:/Infrastructure/jupyter_notebook/HIDUU.ipynb
# File #102 copying file Image to Text.ipynb to C:/Infrastructure/jupyter_notebook/Image to Text.ipynb
# File #103 copying file Importing CSV files to SQL Database Advanced II .ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced II .ipynb
# File #104 copying file Importing CSV files to SQL Database Advanced IV.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced IV.ipynb
# File #105 copying file Importing CSV files to SQL Database Advanced V.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced V.ipynb
# File #106 copying file Importing CSV files to SQL Database Advanced VI.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced VI.ipynb
# File #107 copying file Importing CSV files to SQL Database Advanced VII (1).ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced VII (1).ipynb
# File #108 copying file Importing CSV files to SQL Database Advanced VII.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced VII.ipynb
# File #109 copying file Importing CSV files to SQL Database Advanced VIII.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced VIII.ipynb
# File #110 copying file Importing CSV files to SQL Database Advanced.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database Advanced.ipynb
# File #111 copying file Importing CSV files to SQL Database.ipynb to C:/Infrastructure/jupyter_notebook/Importing CSV files to SQL Database.ipynb
# File #112 copying file infrastructure_setup.ipynb to C:/Infrastructure/jupyter_notebook/infrastructure_setup.ipynb
# File #113 copying file instant_summary.ipynb to C:/Infrastructure/jupyter_notebook/instant_summary.ipynb
# File #114 copying file intelligent_dialogue.ipynb to C:/Infrastructure/jupyter_notebook/intelligent_dialogue.ipynb
# File #115 copying file library_installer.ipynb to C:/Infrastructure/jupyter_notebook/library_installer.ipynb
# File #116 copying file library_installer_II.ipynb to C:/Infrastructure/jupyter_notebook/library_installer_II.ipynb
# File #117 copying file library_registry.ipynb to C:/Infrastructure/jupyter_notebook/library_registry.ipynb
# File #118 copying file logging.ipynb to C:/Infrastructure/jupyter_notebook/logging.ipynb
# File #119 copying file logging_and_debugging.ipynb to C:/Infrastructure/jupyter_notebook/logging_and_debugging.ipynb
# File #120 copying file NCQA HEDIS Quality by Organization-Provider.ipynb to C:/Infrastructure/jupyter_notebook/NCQA HEDIS Quality by Organization-Provider.ipynb
# File #121 copying file NCQA HEDIS Quality by Patient.ipynb to C:/Infrastructure/jupyter_notebook/NCQA HEDIS Quality by Patient.ipynb
# File #122 copying file NCQA HEDIS Treated Lives.ipynb to C:/Infrastructure/jupyter_notebook/NCQA HEDIS Treated Lives.ipynb
# File #123 copying file NHANES - Dataset.ipynb to C:/Infrastructure/jupyter_notebook/NHANES - Dataset.ipynb
# File #124 copying file Organization Quality Scorecards Attributed Lives JAE KEY .ipynb to C:/Infrastructure/jupyter_notebook/Organization Quality Scorecards Attributed Lives JAE KEY .ipynb
# File #125 copying file Organization Quality Scorecards.ipynb to C:/Infrastructure/jupyter_notebook/Organization Quality Scorecards.ipynb
# File #126 copying file Patient Gaps in Care.ipynb to C:/Infrastructure/jupyter_notebook/Patient Gaps in Care.ipynb
# File #127 copying file Patient Wellness Visit Panels.ipynb to C:/Infrastructure/jupyter_notebook/Patient Wellness Visit Panels.ipynb
# File #128 copying file patient_gapsincare_new.ipynb to C:/Infrastructure/jupyter_notebook/patient_gapsincare_new.ipynb
# File #129 copying file patient_measures.ipynb to C:/Infrastructure/jupyter_notebook/patient_measures.ipynb
# File #130 copying file patient_measure_detail.ipynb to C:/Infrastructure/jupyter_notebook/patient_measure_detail.ipynb
# File #131 copying file patient_quality_measures.ipynb to C:/Infrastructure/jupyter_notebook/patient_quality_measures.ipynb
# File #132 copying file PDF Generator.ipynb to C:/Infrastructure/jupyter_notebook/PDF Generator.ipynb
# File #133 copying file Pharmacy Claim Month Parser.ipynb to C:/Infrastructure/jupyter_notebook/Pharmacy Claim Month Parser.ipynb
# File #134 copying file Pharmacy Month Partitions.ipynb to C:/Infrastructure/jupyter_notebook/Pharmacy Month Partitions.ipynb
# File #135 copying file photo_editor.ipynb to C:/Infrastructure/jupyter_notebook/photo_editor.ipynb
# File #136 copying file pip_installs.ipynb to C:/Infrastructure/jupyter_notebook/pip_installs.ipynb
# File #137 copying file Postgres Single Upload.ipynb to C:/Infrastructure/jupyter_notebook/Postgres Single Upload.ipynb
# File #138 copying file presentation_maker.ipynb to C:/Infrastructure/jupyter_notebook/presentation_maker.ipynb
# File #139 copying file Prettification  - Openpyxl Spreadsheet  formatting  2.ipynb to C:/Infrastructure/jupyter_notebook/Prettification  - Openpyxl Spreadsheet  formatting  2.ipynb
# File #140 copying file Prettification  - Openpyxl Spreadsheet  formatting .ipynb to C:/Infrastructure/jupyter_notebook/Prettification  - Openpyxl Spreadsheet  formatting .ipynb
# File #141 copying file principal_component_analysis-Copy1.ipynb to C:/Infrastructure/jupyter_notebook/principal_component_analysis-Copy1.ipynb
# File #142 copying file principal_component_analysis.ipynb to C:/Infrastructure/jupyter_notebook/principal_component_analysis.ipynb
# File #143 copying file profiler2.ipynb to C:/Infrastructure/jupyter_notebook/profiler2.ipynb
# File #144 copying file Provider Performance with Excel Automation.ipynb to C:/Infrastructure/jupyter_notebook/Provider Performance with Excel Automation.ipynb
# File #145 copying file Provider Quality Dashboard.ipynb to C:/Infrastructure/jupyter_notebook/Provider Quality Dashboard.ipynb
# File #146 copying file Python API calls and Interpretation.ipynb to C:/Infrastructure/jupyter_notebook/Python API calls and Interpretation.ipynb
# File #147 copying file Python API calls.ipynb to C:/Infrastructure/jupyter_notebook/Python API calls.ipynb
# File #148 copying file Python GUI using TKinter.ipynb to C:/Infrastructure/jupyter_notebook/Python GUI using TKinter.ipynb
# File #149 copying file python-nltk-sentiment-analysis.ipynb to C:/Infrastructure/jupyter_notebook/python-nltk-sentiment-analysis.ipynb
# File #150 copying file pytorch chatbot.ipynb to C:/Infrastructure/jupyter_notebook/pytorch chatbot.ipynb
# File #151 copying file Reading Health Data.ipynb to C:/Infrastructure/jupyter_notebook/Reading Health Data.ipynb
# File #152 copying file remote_process_automation_excel.ipynb to C:/Infrastructure/jupyter_notebook/remote_process_automation_excel.ipynb
# File #153 copying file rpa excel.ipynb to C:/Infrastructure/jupyter_notebook/rpa excel.ipynb
# File #154 copying file server.ipynb to C:/Infrastructure/jupyter_notebook/server.ipynb
# File #155 copying file solution.ipynb to C:/Infrastructure/jupyter_notebook/solution.ipynb
# File #156 copying file solution_registry.ipynb to C:/Infrastructure/jupyter_notebook/solution_registry.ipynb
# File #157 copying file SQLite Introduction .ipynb to C:/Infrastructure/jupyter_notebook/SQLite Introduction .ipynb
# File #158 copying file SQLite Introduction II .ipynb to C:/Infrastructure/jupyter_notebook/SQLite Introduction II .ipynb
# File #159 copying file streamlit demo.ipynb to C:/Infrastructure/jupyter_notebook/streamlit demo.ipynb
# File #160 copying file streamlit.ipynb to C:/Infrastructure/jupyter_notebook/streamlit.ipynb
# File #161 copying file system_information.ipynb to C:/Infrastructure/jupyter_notebook/system_information.ipynb
# File #162 copying file talking_code.ipynb to C:/Infrastructure/jupyter_notebook/talking_code.ipynb
# File #163 copying file task_scheduler.ipynb to C:/Infrastructure/jupyter_notebook/task_scheduler.ipynb
# File #164 copying file Unpacking JSON for the API calls .ipynb to C:/Infrastructure/jupyter_notebook/Unpacking JSON for the API calls .ipynb
# File #165 copying file Untitled1.ipynb to C:/Infrastructure/jupyter_notebook/Untitled1.ipynb
# File #166 copying file Untitled10.ipynb to C:/Infrastructure/jupyter_notebook/Untitled10.ipynb
# File #167 copying file Untitled11.ipynb to C:/Infrastructure/jupyter_notebook/Untitled11.ipynb
# File #168 copying file Untitled12.ipynb to C:/Infrastructure/jupyter_notebook/Untitled12.ipynb
# File #169 copying file Untitled13.ipynb to C:/Infrastructure/jupyter_notebook/Untitled13.ipynb
# File #170 copying file Untitled14.ipynb to C:/Infrastructure/jupyter_notebook/Untitled14.ipynb
# File #171 copying file Untitled15.ipynb to C:/Infrastructure/jupyter_notebook/Untitled15.ipynb
# File #172 copying file Untitled16.ipynb to C:/Infrastructure/jupyter_notebook/Untitled16.ipynb
# File #173 copying file Untitled17.ipynb to C:/Infrastructure/jupyter_notebook/Untitled17.ipynb
# File #174 copying file Untitled18.ipynb to C:/Infrastructure/jupyter_notebook/Untitled18.ipynb
# File #175 copying file Untitled2.ipynb to C:/Infrastructure/jupyter_notebook/Untitled2.ipynb
# File #176 copying file Untitled3.ipynb to C:/Infrastructure/jupyter_notebook/Untitled3.ipynb
# File #177 copying file Untitled4.ipynb to C:/Infrastructure/jupyter_notebook/Untitled4.ipynb
# File #178 copying file Untitled5.ipynb to C:/Infrastructure/jupyter_notebook/Untitled5.ipynb
# File #179 copying file Untitled6.ipynb to C:/Infrastructure/jupyter_notebook/Untitled6.ipynb
# File #180 copying file Untitled7.ipynb to C:/Infrastructure/jupyter_notebook/Untitled7.ipynb
# File #181 copying file Untitled8.ipynb to C:/Infrastructure/jupyter_notebook/Untitled8.ipynb
# File #182 copying file Untitled9.ipynb to C:/Infrastructure/jupyter_notebook/Untitled9.ipynb
# File #183 copying file voice_bot.ipynb to C:/Infrastructure/jupyter_notebook/voice_bot.ipynb
# File #184 copying file word_cloud.ipynb to C:/Infrastructure/jupyter_notebook/word_cloud.ipynb
# File #185 copying file word_cloud_delete.ipynb to C:/Infrastructure/jupyter_notebook/word_cloud_delete.ipynb
#
# Disovering files of extension:html in directory:C:\Users\josep to move to directoryC:/Infrastructure/html/
# File #1 copying file AIHS Data Profiling Report.html to C:/Infrastructure/html/AIHS Data Profiling Report.html
# File #2 copying file design_goal.html to C:/Infrastructure/html/design_goal.html
#
# Disovering files of extension:excel in directory:C:\Users\josep to move to directoryC:/Infrastructure/excel/
#
# Disovering files of extension:doc in directory:C:\Users\josep to move to directoryC:/Infrastructure/documentation/
# File #1 copying file configuring_sttings_documentation.doc to C:/Infrastructure/documentation/configuring_sttings_documentation.doc
#
# Disovering files of extension:png in directory:C:\Users\josep to move to directoryC:/Infrastructure/images/
# File #1 copying file ai_brain.png to C:/Infrastructure/images/ai_brain.png
# File #2 copying file boy.png to C:/Infrastructure/images/boy.png
# File #3 copying file chart.png to C:/Infrastructure/images/chart.png
# File #4 copying file chatbot.png to C:/Infrastructure/images/chatbot.png
# File #5 copying file chatlogo.png to C:/Infrastructure/images/chatlogo.png
# File #6 copying file chatuser.png to C:/Infrastructure/images/chatuser.png
# File #7 copying file chat_bot..png to C:/Infrastructure/images/chat_bot..png
# File #8 copying file chat_bot.png to C:/Infrastructure/images/chat_bot.png
# File #9 copying file chat_coach.png to C:/Infrastructure/images/chat_coach.png
# File #10 copying file chat_user.png to C:/Infrastructure/images/chat_user.png
# File #11 copying file configuring_settings.png to C:/Infrastructure/images/configuring_settings.png
# File #12 copying file correlation_heatmap.png to C:/Infrastructure/images/correlation_heatmap.png
# File #13 copying file correlation_heatmap_example.png to C:/Infrastructure/images/correlation_heatmap_example.png
# File #14 copying file credits II .png to C:/Infrastructure/images/credits II .png
# File #15 copying file credits.png to C:/Infrastructure/images/credits.png
# File #16 copying file Data Discovery and Load II.png to C:/Infrastructure/images/Data Discovery and Load II.png
# File #17 copying file Data Profiling.png to C:/Infrastructure/images/Data Profiling.png
# File #18 copying file Data_Discovery.png to C:/Infrastructure/images/Data_Discovery.png
# File #19 copying file descriptive_statistics.png to C:/Infrastructure/images/descriptive_statistics.png
# File #20 copying file design_goal.png to C:/Infrastructure/images/design_goal.png
# File #21 copying file design_goals.png to C:/Infrastructure/images/design_goals.png
# File #22 copying file Directory_Discovery II.png to C:/Infrastructure/images/Directory_Discovery II.png
# File #23 copying file Directory_Discovery.png to C:/Infrastructure/images/Directory_Discovery.png
# File #24 copying file Docbot.png to C:/Infrastructure/images/Docbot.png
# File #25 copying file File_Management.png to C:/Infrastructure/images/File_Management.png
# File #26 copying file git  and github.png to C:/Infrastructure/images/git  and github.png
# File #27 copying file github.png to C:/Infrastructure/images/github.png
# File #28 copying file github_automation.png to C:/Infrastructure/images/github_automation.png
# File #29 copying file glossary_term.png to C:/Infrastructure/images/glossary_term.png
# File #30 copying file heart.png to C:/Infrastructure/images/heart.png
# File #31 copying file Infrastructure_setup.png to C:/Infrastructure/images/Infrastructure_setup.png
# File #32 copying file Intelligent.png to C:/Infrastructure/images/Intelligent.png
# File #33 copying file joe_logo.png to C:/Infrastructure/images/joe_logo.png
# File #34 copying file library_installation.png to C:/Infrastructure/images/library_installation.png
# File #35 copying file library_registry.png to C:/Infrastructure/images/library_registry.png
# File #36 copying file logging_and_debugging.png to C:/Infrastructure/images/logging_and_debugging.png
# File #37 copying file making_presentations.png to C:/Infrastructure/images/making_presentations.png
# File #38 copying file pandas.png to C:/Infrastructure/images/pandas.png
# File #39 copying file Patient Gaps in Care.png to C:/Infrastructure/images/Patient Gaps in Care.png
# File #40 copying file Python GUI Dialog pyQT5.png to C:/Infrastructure/images/Python GUI Dialog pyQT5.png
# File #41 copying file python pandas openpyxl.png to C:/Infrastructure/images/python pandas openpyxl.png
# File #42 copying file python pands openpyxl.png to C:/Infrastructure/images/python pands openpyxl.png
# File #43 copying file pytorch chatbot.png to C:/Infrastructure/images/pytorch chatbot.png
# File #44 copying file remote_process_automation excel.png to C:/Infrastructure/images/remote_process_automation excel.png
# File #45 copying file remote_process_automation.png to C:/Infrastructure/images/remote_process_automation.png
# File #46 copying file robot.png to C:/Infrastructure/images/robot.png
# File #47 copying file solution_registry.png to C:/Infrastructure/images/solution_registry.png
# File #48 copying file sqllite_pandas.png to C:/Infrastructure/images/sqllite_pandas.png
# File #49 copying file sqllite_pandas_openpyxl.png to C:/Infrastructure/images/sqllite_pandas_openpyxl.png
# File #50 copying file system_infomation.png to C:/Infrastructure/images/system_infomation.png
# File #51 copying file task_scheduler.png to C:/Infrastructure/images/task_scheduler.png
# File #52 copying file Text_to_Speech.png to C:/Infrastructure/images/Text_to_Speech.png
# File #53 copying file user.png to C:/Infrastructure/images/user.png
# File #54 copying file watchdog.png to C:/Infrastructure/images/watchdog.png
# File #55 copying file wordcloud_output.png to C:/Infrastructure/images/wordcloud_output.png
# File #56 copying file word_cloud.png to C:/Infrastructure/images/word_cloud.png
# File #57 copying file your_logo.png to C:/Infrastructure/images/your_logo.png
#
# Disovering files of extension:parquet in directory:C:\Users\josep to move to directoryC:/Infrastructure/parquet/
#
# Disovering files of extension:feather in directory:C:\Users\josep to move to directoryC:/Infrastructure/feather/
#
# Disovering files of extension:pickle in directory:C:\Users\josep to move to directoryC:/Infrastructure/pickle/
#
# Disovering files of extension:py in directory:C:\Users\josep to move to directoryC:/Infrastructure/py/
# File #1 copying file bot.py to C:/Infrastructure/py/bot.py
# File #2 copying file chat.py to C:/Infrastructure/py/chat.py
# File #3 copying file chat_gui.py to C:/Infrastructure/py/chat_gui.py
# File #4 copying file Color_Settings.py to C:/Infrastructure/py/Color_Settings.py
# File #5 copying file design_goal.py to C:/Infrastructure/py/design_goal.py
# File #6 copying file display_descriptive.py to C:/Infrastructure/py/display_descriptive.py
# File #7 copying file docbot.py to C:/Infrastructure/py/docbot.py
# File #8 copying file file_manager.py to C:/Infrastructure/py/file_manager.py
# File #9 copying file glossary_of_terms.py to C:/Infrastructure/py/glossary_of_terms.py
# File #10 copying file gui.py to C:/Infrastructure/py/gui.py
# File #11 copying file library_registry.py to C:/Infrastructure/py/library_registry.py
# File #12 copying file logger.py to C:/Infrastructure/py/logger.py
# File #13 copying file model.py to C:/Infrastructure/py/model.py
# File #14 copying file nltk_utils.py to C:/Infrastructure/py/nltk_utils.py
# File #15 copying file quick_logger.py to C:/Infrastructure/py/quick_logger.py
# File #16 copying file rpa_excel.py to C:/Infrastructure/py/rpa_excel.py
# File #17 copying file settings.py to C:/Infrastructure/py/settings.py
# File #18 copying file solution_documentation_configuring_settings.py to C:/Infrastructure/py/solution_documentation_configuring_settings.py
# File #19 copying file solution_documentation_library_installer.py to C:/Infrastructure/py/solution_documentation_library_installer.py
# File #20 copying file solution_documentation_logging.py to C:/Infrastructure/py/solution_documentation_logging.py
# File #21 copying file solution_documentation_logging_and_debugging.py to C:/Infrastructure/py/solution_documentation_logging_and_debugging.py
# File #22 copying file solution_documentation_rpa_excel.py to C:/Infrastructure/py/solution_documentation_rpa_excel.py
# File #23 copying file solution_documentation_system_information.py to C:/Infrastructure/py/solution_documentation_system_information.py
# File #24 copying file solution_registry.py to C:/Infrastructure/py/solution_registry.py
# File #25 copying file system_info.py to C:/Infrastructure/py/system_info.py
# File #26 copying file talking_code.py to C:/Infrastructure/py/talking_code.py
# File #27 copying file talking_code_configuring_settings.py to C:/Infrastructure/py/talking_code_configuring_settings.py
# File #28 copying file talking_code_data_discovery.py to C:/Infrastructure/py/talking_code_data_discovery.py
# File #29 copying file train.py to C:/Infrastructure/py/train.py
#
# Disovering files of extension:py in directory:C:\Users\josep to move to directoryC:/Infrastructure/jaepy/
# File #1 copying file bot.py to C:/Infrastructure/jaepy/bot.py
# File #2 copying file chat.py to C:/Infrastructure/jaepy/chat.py
# File #3 copying file chat_gui.py to C:/Infrastructure/jaepy/chat_gui.py
# File #4 copying file Color_Settings.py to C:/Infrastructure/jaepy/Color_Settings.py
# File #5 copying file design_goal.py to C:/Infrastructure/jaepy/design_goal.py
# File #6 copying file display_descriptive.py to C:/Infrastructure/jaepy/display_descriptive.py
# File #7 copying file docbot.py to C:/Infrastructure/jaepy/docbot.py
# File #8 copying file file_manager.py to C:/Infrastructure/jaepy/file_manager.py
# File #9 copying file glossary_of_terms.py to C:/Infrastructure/jaepy/glossary_of_terms.py
# File #10 copying file gui.py to C:/Infrastructure/jaepy/gui.py
# File #11 copying file library_registry.py to C:/Infrastructure/jaepy/library_registry.py
# File #12 copying file logger.py to C:/Infrastructure/jaepy/logger.py
# File #13 copying file model.py to C:/Infrastructure/jaepy/model.py
# File #14 copying file nltk_utils.py to C:/Infrastructure/jaepy/nltk_utils.py
# File #15 copying file quick_logger.py to C:/Infrastructure/jaepy/quick_logger.py
# File #16 copying file rpa_excel.py to C:/Infrastructure/jaepy/rpa_excel.py
# File #17 copying file settings.py to C:/Infrastructure/jaepy/settings.py
# File #18 copying file solution_documentation_configuring_settings.py to C:/Infrastructure/jaepy/solution_documentation_configuring_settings.py
# File #19 copying file solution_documentation_library_installer.py to C:/Infrastructure/jaepy/solution_documentation_library_installer.py
# File #20 copying file solution_documentation_logging.py to C:/Infrastructure/jaepy/solution_documentation_logging.py
# File #21 copying file solution_documentation_logging_and_debugging.py to C:/Infrastructure/jaepy/solution_documentation_logging_and_debugging.py
# File #22 copying file solution_documentation_rpa_excel.py to C:/Infrastructure/jaepy/solution_documentation_rpa_excel.py
# File #23 copying file solution_documentation_system_information.py to C:/Infrastructure/jaepy/solution_documentation_system_information.py
# File #24 copying file solution_registry.py to C:/Infrastructure/jaepy/solution_registry.py
# File #25 copying file system_info.py to C:/Infrastructure/jaepy/system_info.py
# File #26 copying file talking_code.py to C:/Infrastructure/jaepy/talking_code.py
# File #27 copying file talking_code_configuring_settings.py to C:/Infrastructure/jaepy/talking_code_configuring_settings.py
# File #28 copying file talking_code_data_discovery.py to C:/Infrastructure/jaepy/talking_code_data_discovery.py
# File #29 copying file train.py to C:/Infrastructure/jaepy/train.py
#
# Disovering files of extension:pbix in directory:C:\Users\josep to move to directoryC:/Infrastructure/powerbi/
#
# Disovering files of extension:tbwx in directory:C:\Users\josep to move to directoryC:/Infrastructure/tableua/
#
# Disovering files of extension:txt in directory:C:\Users\josep to move to directoryC:/Infrastructure/text/
# File #1 copying file finals.txt to C:/Infrastructure/text/finals.txt
# File #2 copying file modules pythons.txt to C:/Infrastructure/text/modules pythons.txt
# File #3 copying file nlp python answer finals.txt to C:/Infrastructure/text/nlp python answer finals.txt
# File #4 copying file pythons.txt to C:/Infrastructure/text/pythons.txt
# File #5 copying file settings.py.txt to C:/Infrastructure/text/settings.py.txt
# File #6 copying file settings.txt to C:/Infrastructure/text/settings.txt
# File #7 copying file solution_documention_configuring_settings.txt to C:/Infrastructure/text/solution_documention_configuring_settings.txt
#
# Disovering files of extension:pptx in directory:C:\Users\josep to move to directoryC:/Infrastructure/presentation/
# File #1 copying file Data AnalYTICS SOLUTIONS INFRASTRUCTURE.pptx to C:/Infrastructure/presentation/Data AnalYTICS SOLUTIONS INFRASTRUCTURE.pptx
#
# Disovering files of extension:csv in directory:C:\Users\josep to move to directoryC:/Infrastructure/csv/
# File #1 copying file UNIGME-2021.csv to C:/Infrastructure/csv/UNIGME-2021.csv
#
# Disovering files of extension:log in directory:C:\Users\josep to move to directoryC:/Infrastructure/log/
# File #1 copying file ADT_Manager.log to C:/Infrastructure/log/ADT_Manager.log
# File #2 copying file aihs_patient_measures.log to C:/Infrastructure/log/aihs_patient_measures.log
# File #3 copying file configuring_settings.log to C:/Infrastructure/log/configuring_settings.log
# File #4 copying file configuring_settings_history.log to C:/Infrastructure/log/configuring_settings_history.log
# File #5 copying file correlation_heatmap.log to C:/Infrastructure/log/correlation_heatmap.log
# File #6 copying file correlation_heatmap_history.log to C:/Infrastructure/log/correlation_heatmap_history.log
# File #7 copying file correlation_heatmp.log to C:/Infrastructure/log/correlation_heatmp.log
# File #8 copying file correlation_heatmp_history.log to C:/Infrastructure/log/correlation_heatmp_history.log
# File #9 copying file data_discovery.log to C:/Infrastructure/log/data_discovery.log
# File #10 copying file data_discovery_history.log to C:/Infrastructure/log/data_discovery_history.log
# File #11 copying file data_profiling.log to C:/Infrastructure/log/data_profiling.log
# File #12 copying file data_profiling_history.log to C:/Infrastructure/log/data_profiling_history.log
# File #13 copying file file_manager.log to C:/Infrastructure/log/file_manager.log
# File #14 copying file file_mover.log to C:/Infrastructure/log/file_mover.log
# File #15 copying file file_mover_history.log to C:/Infrastructure/log/file_mover_history.log
# File #16 copying file file_watchdog.log to C:/Infrastructure/log/file_watchdog.log
# File #17 copying file file_watchdog_history.log to C:/Infrastructure/log/file_watchdog_history.log
# File #18 copying file github_automation.log to C:/Infrastructure/log/github_automation.log
# File #19 copying file git_commands.log to C:/Infrastructure/log/git_commands.log
# File #20 copying file infrastructure_setup.log to C:/Infrastructure/log/infrastructure_setup.log
# File #21 copying file infrastructure_setup_history.log to C:/Infrastructure/log/infrastructure_setup_history.log
# File #22 copying file Instant_Summary.log to C:/Infrastructure/log/Instant_Summary.log
# File #23 copying file logging_and_debugging.log to C:/Infrastructure/log/logging_and_debugging.log
# File #24 copying file logging_and_debugging_history.log to C:/Infrastructure/log/logging_and_debugging_history.log
# File #25 copying file patient_measures.log to C:/Infrastructure/log/patient_measures.log
# File #26 copying file presentation_maker.log to C:/Infrastructure/log/presentation_maker.log
# File #27 copying file principal component analysis.log to C:/Infrastructure/log/principal component analysis.log
# File #28 copying file principal component analysis_history.log to C:/Infrastructure/log/principal component analysis_history.log
# File #29 copying file principal_component_analysis.log to C:/Infrastructure/log/principal_component_analysis.log
# File #30 copying file principal_component_analysis_history.log to C:/Infrastructure/log/principal_component_analysis_history.log
# File #31 copying file pytorch chatbot.log to C:/Infrastructure/log/pytorch chatbot.log
# File #32 copying file remote_process_automation_excel.log to C:/Infrastructure/log/remote_process_automation_excel.log
# File #33 copying file remote_process_automation_excel_history.log to C:/Infrastructure/log/remote_process_automation_excel_history.log
# File #34 copying file system_information.log to C:/Infrastructure/log/system_information.log
# File #35 copying file system_information_history.log to C:/Infrastructure/log/system_information_history.log
# File #36 copying file talking code.log to C:/Infrastructure/log/talking code.log
# File #37 copying file talking code_history.log to C:/Infrastructure/log/talking code_history.log
# File #38 copying file talking_code.log to C:/Infrastructure/log/talking_code.log
# File #39 copying file talking_code_history.log to C:/Infrastructure/log/talking_code_history.log
# File #40 copying file testlog.log to C:/Infrastructure/log/testlog.log
# File #41 copying file word_cloud.log to C:/Infrastructure/log/word_cloud.log
# File #42 copying file word_cloud_history.log to C:/Infrastructure/log/word_cloud_history.log

# %% [markdown]
# ## Step 3 Rename the py files to make easier to email

# %%
# Move all python .py libraries for easy location  
def rename_files(directory, file_extension, new_file_extension):
    logging.info(f'{solution_name} - Step 2 Rename the py files to make easier to email')      
    return(fm.copy_and_rename_all_files(directory,"py","jaepy"))

def rename_py_files():
    import os 
    status = rename_files('c:\\infrastructure\\jaepy\\', 'py', 'jaepy')
    return status
    
developing_and_testing = True # Unit test for this function  - set this to True or False to turn testing on or off 
if developing_and_testing: 
    print(rename_py_files())
# Out:
# Discovering files of extension: py in directory: c:\infrastructure\jaepy\
# File #1 copy-rename:bot.py to:bot.jaepy
# File #2 copy-rename:chat.py to:chat.jaepy
# File #3 copy-rename:chat_gui.py to:chat_gui.jaepy
# File #4 copy-rename:Color_Settings.py to:Color_Settings.jaepy
# File #5 copy-rename:design_goal.py to:design_goal.jaepy
# File #6 copy-rename:display_descriptive.py to:display_descriptive.jaepy
# File #7 copy-rename:docbot.py to:docbot.jaepy
# File #8 copy-rename:file_manager.py to:file_manager.jaepy
# File #9 copy-rename:glossary_of_terms.py to:glossary_of_terms.jaepy
# File #10 copy-rename:gui.py to:gui.jaepy
# File #11 copy-rename:library_registry.py to:library_registry.jaepy
# File #12 copy-rename:logger.py to:logger.jaepy
# File #13 copy-rename:model.py to:model.jaepy
# File #14 copy-rename:nltk_utils.py to:nltk_utils.jaepy
# File #15 copy-rename:quick_logger.py to:quick_logger.jaepy
# File #16 copy-rename:rpa_excel.py to:rpa_excel.jaepy
# File #17 copy-rename:settings.py to:settings.jaepy
# File #18 copy-rename:solution_documentation_configuring_settings.py to:solution_documentation_configuring_settings.jaepy
# File #19 copy-rename:solution_documentation_library_installer.py to:solution_documentation_library_installer.jaepy
# File #20 copy-rename:solution_documentation_logging.py to:solution_documentation_logging.jaepy
# File #21 copy-rename:solution_documentation_logging_and_debugging.py to:solution_documentation_logging_and_debugging.jaepy
# File #22 copy-rename:solution_documentation_rpa_excel.py to:solution_documentation_rpa_excel.jaepy
# File #23 copy-rename:solution_documentation_system_information.py to:solution_documentation_system_information.jaepy
# File #24 copy-rename:solution_registry.py to:solution_registry.jaepy
# File #25 copy-rename:system_info.py to:system_info.jaepy
# File #26 copy-rename:talking_code.py to:talking_code.jaepy
# File #27 copy-rename:talking_code_configuring_settings (2).py to:talking_code_configuring_settings (2).jaepy
# File #28 copy-rename:talking_code_configuring_settings.py to:talking_code_configuring_settings.jaepy
# File #29 copy-rename:talking_code_data_discovery.py to:talking_code_data_discovery.jaepy
# File #30 copy-rename:talking_code_talking_code.py to:talking_code_talking_code.jaepy
# File #31 copy-rename:talking_code_talk_to_me.py to:talking_code_talk_to_me.jaepy
# File #32 copy-rename:train.py to:train.jaepy

# %% [markdown]
# ## Step 4 copy and backup all infrastructure to a team shareable location

# %%
# This will copy entire source directory to a backup destination and an archive 
def backup_infrastructure():
    status = 'Backing up entire infrastructure directory: \n'
    logging.info(f'{solution_name} - Step 4 copy and backup all infrastructure to a team shareable location')       

    infrastructure_directory = config.get('global_infrastructure', 'infrastructure_directory') 
    print(infrastructure_directory)
    infrastructure_directory_backup = config.get('global_infrastructure', 'infrastructure_directory_backup') 
    print(infrastructure_directory_backup)    
    infrastructure_directory_archive = infrastructure_directory_backup.replace('backup','archive')
    print(infrastructure_directory_archive)    
    copytree(infrastructure_directory, infrastructure_directory_backup, dirs_exist_ok=True)
    copytree(infrastructure_directory, infrastructure_directory_archive, dirs_exist_ok=True)  
    copytree(infrastructure_directory, 'C://working_directory', dirs_exist_ok=True)   
  
    return(status)

developing_and_testing = True # Unit test for this function  - set this to True or False to turn testing on or off 
if developing_and_testing: 
    print(backup_infrastructure())
# Out:
# c://infrastructure
# c://infrastructure_backup
# c://infrastructure_archive
# Backing up entire infrastructure directory:

# %%
# # optional education - The following code will only run if educating is set to True for this solution
# if config.get('global_infrastructure', 'documenting') == 'True':
#     import os 
#     import solution_documentation_infrastructure_setup as sd    # Establish the solutions documentation as sd 
#     solution_documentation = sd.get_solution_documentation()  
#     print(solution_documentation) 
#     solution_document_file_name =  config.get('global_infrastructure', 'infrastructure_directory') + '/' + config.get('global_infrastructure', 'documentation_directory')+ '/' + solution_name + config.get('global_infrastructure', 'documentation_extension')
#     sd.save_documentation(solution_document_file_name) 
#     print(f'Solution Documention saved to file: {solution_document_file_name}')      
#     documentation_file_name = f'C://working_directory//documentation//documentation_{solution_name}.doc'
#     sd.create_solution_documentation_file(documentation_file_name, solution_name)
 
    
# if config.get(solution_name, 'talking_code') == 'True': 
#     import talking_code as tc  
#     tc.say(solution_documentation)

# %% [markdown]
# ## Optional Step - Schedule frequent backups or Backups for specific Times

# %%
def show_time(): 
    import datetime
    current_time = datetime.datetime.now()
    show_time = f'year:{current_time.year}' + f' month:{current_time.month}' + f' day:{current_time.day}'
    show_time = show_time + f' hour:{current_time.hour}' + f' minute:{current_time.minute}' + f' second:{current_time.second}' 
    show_time = show_time + f' microsecond:{current_time.microsecond}' 
    print(show_time)
    return(show_time)

# %%
# schedule.every(2).minutes.do(backup_infrastructure)
# schedule.every(1).minutes.do(show_time)
# schedule.every(2).minutes.do(rename_py_files)
# schedule.every().day.at('07:00').do(backup_infrastructure)
# schedule.every().day.at('21:00').do(backup_infrastructure)

# %%
# import time
# scheduled_backup = False
# if scheduled_backup: 
#     print('Running Scheduled jobs') 
# else:
#     print('Not configured to schedule backups') 
# while scheduled_backup:
#     schedule.run_pending()
#     time.sleep(1)

# %%
# Calculate and classify the process performance 
os.chdir(cwd)
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-08-20 14:12:53,064 - INFO - START infrastructure_setup =============================================
# 2023-08-20 14:12:53,064 - INFO - START infrastructure_setup Start Time = 2023-08-20 14:12:53
# 2023-08-20 14:12:53,064 - INFO - infrastructure_setup Step 0 - Initialize the configuration file parser
# 2023-08-20 14:12:53,075 - INFO - infrastructure_setup - Step 1 establish infrastructure directory to organize all files
# 2023-08-20 14:12:53,075 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/html
# 2023-08-20 14:12:53,075 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/excel
# 2023-08-20 14:12:53,075 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/jupyter_notebook
# 2023-08-20 14:12:53,075 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/documentation
# 2023-08-20 14:12:53,076 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/database
# 2023-08-20 14:12:53,076 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/powerbi
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/tableau
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/images
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/csv
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/parquet
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/feather
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/pickle
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/text
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/presentation
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/jaepy
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/py
# 2023-08-20 14:12:53,077 - INFO - infrastructure_setup - Creating if non-existent : c://infrastructure/log
# 2023-08-20 14:12:53,092 - INFO - infrastructure_setup - Step 3 Organize (copy all file types) into appropriate infrastructure directories
# 2023-08-20 14:12:55,269 - INFO - infrastructure_setup - Step 2 Rename the py files to make easier to email
# 2023-08-20 14:12:55,363 - INFO - infrastructure_setup - Step 4 copy and backup all infrastructure to a team shareable location
# 2023-08-20 14:12:57,625 - INFO - PERFORMANCE infrastructure_setup The total process duration was:4.56
# 2023-08-20 14:12:57,625 - INFO - PERFORMANCE infrastructure_setup Stop Time = 2023-08-20 14:12:57
# 2023-08-20 14:12:57,625 - INFO - PERFORMANCE infrastructure_setup Low process duration less than 3 minutes:4.56
# 2023-08-20 14:12:57,625 - INFO - PERFORMANCE infrastructure_setup Performance optimization is optional
# 2023-08-20 14:12:57,625 - INFO - END infrastructure_setup =============================================

# %% [markdown]
# ![credits%20II%20.png](attachment:credits%20II%20.png)
