# %% [markdown]
# ## This notebook parses the HEDIS Quality Measures by Organization - Provider
# ##### Added Excel Automation including Filtering, Styling, Security, Pre-filtering
# #### Joe Eberle - 3/22/2022

# %%
# Import Libraries for Spreadsheet Automation 
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date
import random
import math
import os
import glob
from openpyxl import load_workbook
from openpyxl.styles import colors
from openpyxl.utils import get_column_letter
from openpyxl.styles import NamedStyle, Font, Border, Side, PatternFill, GradientFill, Alignment, Color, Fill
from openpyxl import Workbook
from openpyxl.utils.dataframe import dataframe_to_rows 
from openpyxl.formatting.rule import DataBarRule
from openpyxl.formatting.rule import ColorScaleRule
import time

# %%
# Configure the code and visual settings to have consistency 
path = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv/'
Path_to_Excel = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv/'
Path_to_Save_Excel = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv_ft/'

# Path_to_Share_Excel =  'https://kaleidahealth.sharefile.com/fo54e2c6-ffc7-4025-8649-443d1d382dff//'
Path_to_Raw_Data = 'c:/Users/josep/Documents/Kaleida/'
Raw_Data_File_Name_1 = 'NCQA HEDIS Quality Measures by Provider.xlsx'
Raw_Data_File_Name_2 = 'Organization_Provider_Summary.xlsx'

print(Path_to_Raw_Data + Raw_Data_File_Name_1)
print(Path_to_Raw_Data + Raw_Data_File_Name_2)

LIGHT_BLUE = "C5D9F1"
YELLOW = "FFFF00"
GRAY = "E4DFEC"
DEEP_BLUE = "1072BA"
WHITE = "FFFFFF"
ROW_FILL_COLOR = "F2F2F2"     # very light gray

CONTENT_TAB_COLOR = DEEP_BLUE
USER_TAB_COLOR = YELLOW
BLANK_WHITE = WHITE 
HEADER_COLOR = LIGHT_BLUE  # Light Blue - Light Blue indicates relevant content for validation 
HEADER_COLOR_USER_ENTRY = YELLOW # Yellow - Yellow indicates a field for User Entry 
HEADER_COLOR_INFORMATIONAL_ONLY = GRAY # Gray - Indicates a field that maybe helpful but for information purposes only
# Out:
# c:/Users/josep/Documents/Kaleida/NCQA HEDIS Quality Measures by Provider.xlsx
# c:/Users/josep/Documents/Kaleida/Organization_Provider_Summary.xlsx

# %%
# Read in the CSV SQL output for NCQA HEDIS Quality Measures 
Organizational_Quality = pd.read_excel(Path_to_Raw_Data + Raw_Data_File_Name_1)

# %%
# Read in the EXCEL  SQL output for Organization Provider Summary 
Organization_Provider_Summary = pd.read_excel(Path_to_Raw_Data + Raw_Data_File_Name_2)

# %%
# Filter to Measures that are analytics only , calculate Percent complete and round 
Organizational_Quality['Measure_Completion_Percentage'] = ((Organizational_Quality['Total_Met_Count'] / Organizational_Quality['Total_Measure_Count']) * 100.0) 
Organizational_Quality['Measure_Completion_Percentage'] = Organizational_Quality['Measure_Completion_Percentage'].round(2)

# %%
Organizational_Quality
# Out:
#                Organization_Class  \
# 0      Erie County Medical Center
# 1      Erie County Medical Center
# 2      Erie County Medical Center
# 3      Erie County Medical Center
# 4      Erie County Medical Center
# ...                           ...
# 11248                         NaN
# 11249                         NaN
# 11250                         NaN
# 11251                         NaN
# 11252                         NaN
#
#                                  Organization_Name      Provider_Name  \
# 0      EC PCP Erie County Medical Center FM Clinic  Abdelsayed, Sarah
# 1      EC PCP Erie County Medical Center FM Clinic  Abdelsayed, Sarah
# 2      EC PCP Erie County Medical Center FM Clinic  Abdelsayed, Sarah
# 3      EC PCP Erie County Medical Center FM Clinic  Abdelsayed, Sarah
# 4      EC PCP Erie County Medical Center FM Clinic  Abdelsayed, Sarah
# ...                                            ...                ...
# 11248                                          NaN    Walczyk, Rachel
# 11249                                          NaN    Walczyk, Rachel
# 11250                                          NaN    Walczyk, Rachel
# 11251                                          NaN    Walczyk, Rachel
# 11252                                          NaN    Walczyk, Rachel
#
#                                   Measure_Qualified_Name  \
# 0      hedis.my2021.admin.measures/aap-health-service...
# 1      hedis.my2021.admin.measures/aap-health-service...
# 2      hedis.my2021.admin.measures/antidepressant-med...
# 3      hedis.my2021.admin.measures/antidepressant-med...
# 4      hedis.my2021.admin.measures/breast-cancer-scre...
# ...                                                  ...
# 11248  hedis.my2021.admin.measures/statin-therapy-for...
# 11249  hedis.my2021.admin.measures/statin-therapy-for...
# 11250  hedis.my2021.admin.measures/use-of-high-risk-m...
# 11251  hedis.my2021.admin.measures/use-of-high-risk-m...
# 11252  wny.analytics.hedismy2021content.hedis.event.1...
#
#                                             Measure_Name  \
# 0      HEDIS MY2021 Adults' Access to Preventive/Ambu...
# 1      HEDIS MY2021 Adults' Access to Preventive/Ambu...
# 2      HEDIS MY2021 Antidepressant Medication Managem...
# 3      HEDIS MY2021 Antidepressant Medication Managem...
# 4      HEDIS MY2021 Breast Cancer Screening (BCS) - U...
# ...                                                  ...
# 11248  HEDIS MY2021 Statin Therapy for Patients With ...
# 11249  HEDIS MY2021 Statin Therapy for Patients With ...
# 11250  HEDIS MY2021 Use of High-Risk Medications in O...
# 11251  HEDIS MY2021 Use of High-Risk Medications in O...
# 11252  HEDIS MY2021 Appropriate Testing for Pharyngit...
#
#       Is_Registries_Measure  Total_Measure_Count  Total_Not_Met_Count  \
# 0            Analytics Only                    7                    0
# 1            Analytics Only                   88                   48
# 2            Analytics Only                    4                    2
# 3            Analytics Only                    4                    2
# 4            Analytics Only                   54                   42
# ...                     ...                  ...                  ...
# 11248        Analytics Only                   26                   25
# 11249        Analytics Only                    5                    5
# 11250        Analytics Only                  120                  120
# 11251        Analytics Only                  120                  120
# 11252        Analytics Only                    1                    1
#
#        Total_Not_Met_Has_Email  Total_Not_Met_Has_Phone  \
# 0                            0                        0
# 1                           22                       48
# 2                            2                        2
# 3                            2                        2
# 4                           15                       42
# ...                        ...                      ...
# 11248                        4                       25
# 11249                        0                        5
# 11250                       17                      120
# 11251                       17                      120
# 11252                        0                        1
#
#        Total_Not_Met_Has_Email_And_Phone  Total_Met_Count  \
# 0                                      0                7
# 1                                     22               40
# 2                                      2                2
# 3                                      2                2
# 4                                     15               12
# ...                                  ...              ...
# 11248                                  4                1
# 11249                                  0                0
# 11250                                 17                0
# 11251                                 17                0
# 11252                                  0                0
#
#        Measure_Completion_Percentage
# 0                             100.00
# 1                              45.45
# 2                              50.00
# 3                              50.00
# 4                              22.22
# ...                              ...
# 11248                           3.85
# 11249                           0.00
# 11250                           0.00
# 11251                           0.00
# 11252                           0.00
#
# [11253 rows x 13 columns]

# %%
# Filter to Measures that are analytics only , calculate Percent complete and round 
Organizational_Quality = Organizational_Quality[(Organizational_Quality.Is_Registries_Measure == 'Analytics Only')]   
# Filter to Measures that are analytics only 
Organizational_Quality['Is_Registries_Measure'].value_counts()
# Out:
# Analytics Only    11253
# Name: Is_Registries_Measure, dtype: int64

# %%
# simplify and Organize the organization quality Panels 
Organizational_Quality = Organizational_Quality[['Provider_Name','Measure_Name', 'Total_Measure_Count',
       'Total_Not_Met_Count', 'Total_Met_Count', 'Measure_Completion_Percentage',   'Organization_Class', 'Organization_Name']]
#       'Total_Not_Met_Has_Email','Total_Not_Met_Has_Email', 'Total_Not_Met_Has_Phone', 'Total_Not_Met_Has_Email_And_Phone','Measure_Qualified_Name','Is_Registries_Measure'

#Organizational_Quality = Organizational_Quality[['Measure_Name', 'Total_Measure_Count',
#       'Total_Not_Met_Count', 'Total_Met_count', 'Measure_Completion_Percentage',
#       'Total_Not_Met_Has_Email','Total_Not_Met_Has_Email',
#       'Total_Not_Met_Has_Phone', 'Total_Not_Met_Has_Email_And_Phone',
#       'Organization_Class', 'Organization_Name','Measure_Qualified_Name','Is_Registries_Measure']]

# %%
# Optional Verify the input file structures 
#Organizational_Quality.info()
#Organization_Provider_Summary.head()
Organizational_Quality.columns
# Out:
# Index(['Provider_Name', 'Measure_Name', 'Total_Measure_Count',
#        'Total_Not_Met_Count', 'Total_Met_Count',
#        'Measure_Completion_Percentage', 'Organization_Class',
#        'Organization_Name'],
#       dtype='object')

# %%
Color_Scale_Rule = ColorScaleRule(start_type="min",start_color="FF0000",end_type="max",end_color="99FF33")
Data_Bar_Rule = DataBarRule(start_type="min", end_type="max", color="00CC00")

# %%
# The following function creates patient panels based upon organization name 
def create_organization_panel(org_name):
    Organization_panel = Organizational_Quality[(Organizational_Quality.Organization_Name == org_name)]    
    patient_rows = len(Organization_panel) - 1 
    report_name = '_org_prv_quality'
    if patient_rows > 2:
        spread_name = Organization_panel['Organization_Name'].iloc[0]
        if spread_name == '':
            spread_name = 'No_ORG_NAME_'  
        spread_name = spread_name.replace('/','')  
       
        spath =  Path_to_Excel

        csv_name = spath + spread_name.replace(' ','_') + report_name + '.csv'        
        spread_name = spath + spread_name.replace(' ','_') + report_name + '.xlsx'
        spread_name = spread_name.replace(' ','')
        csv_name = csv_name.replace(' ','')        
        Organization_panel.to_excel(spread_name,sheet_name='Provider Quality', index = False)  
        Organization_panel.to_csv(csv_name, index = False)  
        print(spread_name)
        return org_name

# %%
Org_names = Organizational_Quality.Organization_Name.unique()
for org in Org_names:
    create_organization_panel(org)
# Out:
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/EC_PCP_Erie_County_Medical_Center_FM_Clinic_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/EC_PCP_Erie_County_Medical_Center
PC_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/SP_PCP_Stephen_Pearl_MD_3085_Southwestern_Blvd_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/SS_PCP_Suresh_Sofat_MD_64_Davison_Ct_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Sheridan_Medical_Group,_LLP_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/TC_PCP_Tri_County_Family_Medicine_Associates_1_School_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UR_PCP_Umamaheswara_Rao_Vejendla_Physician_Foote_Ave_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WG_PCP_Winston_G_Douglas_MD_PC_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med__4979_Harlem_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_1310_French_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3218_Walden_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3320_N_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3595_Eggert_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3884_Broadway_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_4247_Maple_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_6970_Erie_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/YP_PCP_Yasmin_Pervez,_MD_Wheatfield_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Independent_Providers_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Limestone_Primary_Care_Physicians_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Niagara_Family_Medicine_Associates_PC_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Thomas_E_Dougherty_MD_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Westfield_Family_Physicians,_PC_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PCP_Hertel_Elmwood_Internal_Medicine_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PED_Broadway_Pediatrics_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PED_Niagara_Street_Pediatrics_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_BGH_Primary_Care_Center_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_Niagara_Street_Pediatrics_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_North_Buffalo_Medical_Park_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_Towne_Garden_Pediatrics_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Lewiston_Primary_Care_4600_Military_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Niagara_Falls_Primary_Care__Golisano_Center_533_Tenth_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Summit_Healthplex_6934_Williams_Rd_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC_Grand_Island_Primary_Care_2608_Grand_Island_Blvd_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_449_Broad_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_45_W_Main_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_535_Main_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_Franklinville_12_Main_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Olean_Medical_Group,_LLP_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Amherst_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Conventus_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Niagara_St_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Sheridan_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Adult_Primary_&_Specialty_Medicine_at_Conventus_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UBMD_Internal_Medicine_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_263_Liberty_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_34_Duncan_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_401_Main_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_Family_Medicine_PC_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PED_Wyoming_County_408_N_Main_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Pamela_L_Stevens_MD_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Tri-County_Family_Medicine_Associates_PC_org_prv_quality.xlsx

# %%
# Add the Provider Summary Excel Tab  
path = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv/'
extension = 'xlsx'
os.chdir(path)
files = glob.glob('*.{}'.format(extension))

for x in range(len(files)): 
#    print(files[x]) 
    file_path = Path_to_Excel + files[x]
    org_name =  files[x].replace('org prv quality','')      
    org_name =  org_name.replace('_org_prv_quality','')   
     
    org_name =  org_name.replace('.xlsx','')
    org_name =  org_name.replace('_',' ')    
    print (org_name)
    print (file_path)
    Organization_panel = Organization_Provider_Summary[(Organization_Provider_Summary.Organization_Name == org_name)]  
    Organization_panel = Organization_panel.reset_index(drop=True)
  
    writer = pd.ExcelWriter(file_path, engine='openpyxl', mode='a')
    writer.book = load_workbook(file_path)
    Organization_panel.to_excel(writer,sheet_name='Provider Summary', index = False)
    writer.save()
    writer.close()
# Out:
# AA PCP Alan M Antfleck Physician PLLC Delaware Ave
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv
C
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/General_Physician_PC_org_prv_quality.xlsx
# GJ PCP Gregory T Jehrio MD LLC 393 Davison Rd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GJ_PCP_Gregory_T_Jehrio_MD_LLC_393_Davison_Rd_org_prv_quality.xlsx
# GPPC PCP Amherst Sheridan
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Amherst_Sheridan_org_prv_quality.xlsx
# GPPC PCP Buffalo Main
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Buffalo_Main_org_prv_quality.xlsx
# GPPC PCP Dunkirk Vineyard Ste 1
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Dunkirk_Vineyard_Ste_1_org_prv_quality.xlsx
# GPPC PCP East Aurora Main
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_East_Aurora_Main_org_prv_quality.xlsx
# GPPC PCP Elma Transit
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Elma_Transit_org_prv_quality.xlsx
# GPPC PCP Hamburg Camp
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Hamburg_Camp_org_prv_quality.xlsx
# GPPC PCP Hamburg Southwestern
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Hamburg_Southwestern_org_prv_quality.xlsx
# GPPC PCP Lancaster Transit
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Lancaster_Transit_org_prv_quality.xlsx
# GPPC PCP Lockport Olcott
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Lockport_Olcott_org_prv_quality.xlsx
# GPPC PCP Lockport Snyder
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Lockport_Snyder_org_prv_quality.xlsx
# GPPC PCP Medina Ohio
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Medina_Ohio_org_prv_quality.xlsx
# GPPC PCP Orchard Park Big Tree Ste 107
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Orchard_Park_Big_Tree_Ste_107_org_prv_quality.xlsx
# GPPC PCP Springville South Cascade
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Springville_South_Cascade_org_prv_quality.xlsx
# GPPC PCP Tonawanda Colvin
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Tonawanda_Colvin_org_prv_quality.xlsx
# GPPC PCP Willamsville Maple
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Willamsville_Maple_org_prv_quality.xlsx
# GPPC PCP Williamsville Youngs
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_PCP_Williamsville_Youngs_org_prv_quality.xlsx
# GPPC Peds Dunkirk Vineyard Ste 3
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_Peds_Dunkirk_Vineyard_Ste_3_org_prv_quality.xlsx
# GPPC Post-Acute
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GPPC_Post-Acute_org_prv_quality.xlsx
# Great Lakes Physician PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Great_Lakes_Physician_PC_org_prv_quality.xlsx
# GY PCP Ghous A Yasin 277 Division St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/GY_PCP_Ghous_A_Yasin_277_Division_St_org_prv_quality.xlsx
# HC PCP Harnath Clerk William St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/HC_PCP_Harnath_Clerk_William_St_org_prv_quality.xlsx
# Highgate Medical Group PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Highgate_Medical_Group_PC_org_prv_quality.xlsx
# HS PCP Health System Physician, PC 401 N 8th St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/HS_PCP_Health_System_Physician,_PC_401_N_8th_St_org_prv_quality.xlsx
# IM PCP Internal Med ID Associates Millersport Hwy
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/IM_PCP_Internal_Med_ID_Associates_Millersport_Hwy_org_prv_quality.xlsx
# Independent Providers
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Independent_Providers_org_prv_quality.xlsx
# IT PCP Indra Tambar MD 415 Tremont St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/IT_PCP_Indra_Tambar_MD_415_Tremont_St_org_prv_quality.xlsx
# JM PCP Joseph V Mure MD PLLC Delaware Rd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/JM_PCP_Joseph_V_Mure_MD_PLLC_Delaware_Rd_org_prv_quality.xlsx
# JW PCP Janet B Westenberger DO N Buffalo Road
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/JW_PCP_Janet_B_Westenberger_DO_N_Buffalo_Road_org_prv_quality.xlsx
# Kaleida Health - BGH Primary Care Center
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_BGH_Primary_Care_Center_org_prv_quality.xlsx
# Kaleida Health - Niagara Street Pediatrics
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_Niagara_Street_Pediatrics_org_prv_quality.xlsx
# Kaleida Health - North Buffalo Medical Park
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_North_Buffalo_Medical_Park_org_prv_quality.xlsx
# Kaleida Health - Towne Garden Pediatrics
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Kaleida_Health_-_Towne_Garden_Pediatrics_org_prv_quality.xlsx
# KH PCP Hertel Elmwood Internal Medicine
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PCP_Hertel_Elmwood_Internal_Medicine_org_prv_quality.xlsx
# KH PED Broadway Pediatrics
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PED_Broadway_Pediatrics_org_prv_quality.xlsx
# KH PED Niagara Street Pediatrics
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KH_PED_Niagara_Street_Pediatrics_org_prv_quality.xlsx
# KZ PCP Kenneth S Zimmerman 6760 Main St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/KZ_PCP_Kenneth_S_Zimmerman_6760_Main_St_org_prv_quality.xlsx
# Limestone Primary Care Physicians
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Limestone_Primary_Care_Physicians_org_prv_quality.xlsx
# LI PCP Louis W Irmisch MD W Spring St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/LI_PCP_Louis_W_Irmisch_MD_W_Spring_St_org_prv_quality.xlsx
# LR PCP Canalside Primary Care PC 43 Niagara St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/LR_PCP_Canalside_Primary_Care_PC_43_Niagara_St_org_prv_quality.xlsx
# Maple Internal Medicine & Pediatrics PLLC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Maple_Internal_Medicine_&_Pediatrics_PLLC_org_prv_quality.xlsx
# MH PED Medical Health Assoc 13404 Broadway
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MH_PED_Medical_Health_Assoc_13404_Broadway_org_prv_quality.xlsx
# MH PED Medical Health Assoc 2271 Grand Island
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MH_PED_Medical_Health_Assoc_2271_Grand_Island_org_prv_quality.xlsx
# MH PED Medical Health Assoc 2733 Wehrle
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MH_PED_Medical_Health_Assoc_2733_Wehrle_org_prv_quality.xlsx
# MH PED Medical Health Assoc 3950 Robinson
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MH_PED_Medical_Health_Assoc_3950_Robinson_org_prv_quality.xlsx
# MH PED Medical Health Assoc 5800 Big Tree
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MH_PED_Medical_Health_Assoc_5800_Big_Tree_org_prv_quality.xlsx
# MM PCP Martin N Mango, MD 6333 Main St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/MM_PCP_Martin_N_Mango,_MD_6333_Main_St_org_prv_quality.xlsx
# ND PCP Premier Family Physicians 8750 Transit Road
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/ND_PCP_Premier_Family_Physicians_8750_Transit_Road_org_prv_quality.xlsx
# NFM PCP NFMMC Grand Island Primary Care 2608 Grand Island Blvd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC_Grand_Island_Primary_Care_2608_Grand_Island_Blvd_org_prv_quality.xlsx
# NFM PCP NFMMC  Lewiston Primary Care 4600 Military
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Lewiston_Primary_Care_4600_Military_org_prv_quality.xlsx
# NFM PCP NFMMC  Niagara Falls Primary Care  Golisano Center 533 Tenth St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Niagara_Falls_Primary_Care__Golisano_Center_533_Tenth_St_org_prv_quality.xlsx
# NFM PCP NFMMC  Summit Healthplex 6934 Williams Rd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NFM_PCP_NFMMC__Summit_Healthplex_6934_Williams_Rd_org_prv_quality.xlsx
# NG PCP Neera Gulati 350 Alberta
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NG_PCP_Neera_Gulati_350_Alberta_org_prv_quality.xlsx
# Niagara Family Medicine Associates PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Niagara_Family_Medicine_Associates_PC_org_prv_quality.xlsx
# NM PCP Nora E Meaney-Elman 8171 Sheridan Drive
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NM_PCP_Nora_E_Meaney-Elman_8171_Sheridan_Drive_org_prv_quality.xlsx
# NW PCP Buffalo Community Health Care Center Niagara St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NW_PCP_Buffalo_Community_Health_Care_Center_Niagara_St_org_prv_quality.xlsx
# NW PCP NW Buffalo Community 300 Niagara St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/NW_PCP_NW_Buffalo_Community_300_Niagara_St_org_prv_quality.xlsx
# OB PCP Olivia Smith-Blackwell 601 Division St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OB_PCP_Olivia_Smith-Blackwell_601_Division_St_org_prv_quality.xlsx
# Olean Medical Group, LLP
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Olean_Medical_Group,_LLP_org_prv_quality.xlsx
# OMG PCP Olean Medical Group 449 Broad St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_449_Broad_St_org_prv_quality.xlsx
# OMG PCP Olean Medical Group 45 W Main St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_45_W_Main_St_org_prv_quality.xlsx
# OMG PCP Olean Medical Group 535 Main St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_535_Main_St_org_prv_quality.xlsx
# OMG PCP Olean Medical Group Franklinville 12 Main St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/OMG_PCP_Olean_Medical_Group_Franklinville_12_Main_St_org_prv_quality.xlsx
# Pamela L Stevens MD
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Pamela_L_Stevens_MD_org_prv_quality.xlsx
# PD PCP Patricia J Danaher MD PC 5949 Campbell Blvd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/PD_PCP_Patricia_J_Danaher_MD_PC_5949_Campbell_Blvd_org_prv_quality.xlsx
# Philip A Penepent Jr
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Philip_A_Penepent_Jr_org_prv_quality.xlsx
# Quaker Medical Associates PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Quaker_Medical_Associates_PC_org_prv_quality.xlsx
# Sheridan Medical Group, LLP
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Sheridan_Medical_Group,_LLP_org_prv_quality.xlsx
# SP PCP Stephen Pearl MD 3085 Southwestern Blvd
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/SP_PCP_Stephen_Pearl_MD_3085_Southwestern_Blvd_org_prv_quality.xlsx
# SS PCP Suresh Sofat MD 64 Davison Ct
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/SS_PCP_Suresh_Sofat_MD_64_Davison_Ct_org_prv_quality.xlsx
# TC PCP Tri County Family Medicine Associates 1 School St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/TC_PCP_Tri_County_Family_Medicine_Associates_1_School_St_org_prv_quality.xlsx
# Thomas E Dougherty MD
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Thomas_E_Dougherty_MD_org_prv_quality.xlsx
# Tri-County Family Medicine Associates PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Tri-County_Family_Medicine_Associates_PC_org_prv_quality.xlsx
# UBMD Internal Medicine
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UBMD_Internal_Medicine_org_prv_quality.xlsx
# UB PCP Adult Primary & Specialty Medicine at Conventus
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Adult_Primary_&_Specialty_Medicine_at_Conventus_org_prv_quality.xlsx
# UB PCP Family Medicine at Amherst
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Amherst_org_prv_quality.xlsx
# UB PCP Family Medicine at Conventus
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Conventus_org_prv_quality.xlsx
# UB PCP Family Medicine at Niagara St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Niagara_St_org_prv_quality.xlsx
# UB PCP Family Medicine at Sheridan
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UB_PCP_Family_Medicine_at_Sheridan_org_prv_quality.xlsx
# UR PCP Umamaheswara Rao Vejendla Physician Foote Ave
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/UR_PCP_Umamaheswara_Rao_Vejendla_Physician_Foote_Ave_org_prv_quality.xlsx
# WC PCP Wyoming County 263 Liberty
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_263_Liberty_org_prv_quality.xlsx
# WC PCP Wyoming County 34 Duncan
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_34_Duncan_org_prv_quality.xlsx
# WC PCP Wyoming County 401 Main
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_401_Main_org_prv_quality.xlsx
# WC PCP Wyoming County Family Medicine PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PCP_Wyoming_County_Family_Medicine_PC_org_prv_quality.xlsx
# WC PED Wyoming County 408 N Main
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WC_PED_Wyoming_County_408_N_Main_org_prv_quality.xlsx
# Westfield Family Physicians, PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/Westfield_Family_Physicians,_PC_org_prv_quality.xlsx
# WG PCP Winston G Douglas MD PC
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WG_PCP_Winston_G_Douglas_MD_PC_org_prv_quality.xlsx
# WN PCP Western NY Med 1310 French
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_1310_French_org_prv_quality.xlsx
# WN PCP Western NY Med 3218 Walden
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3218_Walden_org_prv_quality.xlsx
# WN PCP Western NY Med 3320 N
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3320_N_org_prv_quality.xlsx
# WN PCP Western NY Med 3595 Eggert
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3595_Eggert_org_prv_quality.xlsx
# WN PCP Western NY Med 3884 Broadway
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_3884_Broadway_org_prv_quality.xlsx
# WN PCP Western NY Med 4247 Maple
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_4247_Maple_org_prv_quality.xlsx
# WN PCP Western NY Med 6970 Erie
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med_6970_Erie_org_prv_quality.xlsx
# WN PCP Western NY Med  4979 Harlem
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/WN_PCP_Western_NY_Med__4979_Harlem_org_prv_quality.xlsx
# YP PCP Yasmin Pervez, MD Wheatfield St
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv/YP_PCP_Yasmin_Pervez,_MD_Wheatfield_St_org_prv_quality.xlsx

# %%
# The following function creates patient panels based upon organization name 
def create_sheet_one(work_book):
   
    ws1 = work_book.active
    ws1.title = "NCQA HEDIS Quality Measures"
    ws1.sheet_properties.tabColor = CONTENT_TAB_COLOR
    
# Format the Header as bold blue centered wordwrap     
    max_cols = ws1.max_column + 1 
    for col in range(1,max_cols):
        ws1[get_column_letter(col) + '1'].font = Font(bold=True ) 
        ws1[get_column_letter(col) + '1'].fill = PatternFill("solid", start_color=HEADER_COLOR) 
        ws1[get_column_letter(col) + '1'].alignment = Alignment(horizontal='center', wrap_text=True)  
    
    
# Work Sheet 1 - Set Column Widths and Header Hieght
    ws1.column_dimensions['A'].width = 25
    ws1.column_dimensions['B'].width = 120
    ws1.column_dimensions['C'].width = 10
    ws1.column_dimensions['D'].width = 10
    ws1.column_dimensions['E'].width = 10
    ws1.column_dimensions['F'].width = 15
    ws1.column_dimensions['G'].width = 30
    ws1.column_dimensions['H'].width = 30

    ws1.row_dimensions[1].height = 75   

# Replaces all underscores in header with two spaces 
    for col in range(1,max_cols):
        ws1[get_column_letter(col) + '1'].value = ws1[get_column_letter(col) + '1'].value.replace('_','  ')
    
# Set Filtering on 
    FullRange = "A1:" + get_column_letter(ws1.max_column) \
    + str(ws1.max_row)
    ws1.auto_filter.ref = FullRange    

  
    ws1.freeze_panes = 'A2'
    ws1.conditional_formatting.add("F1:F" + str(ws1.max_row), Color_Scale_Rule )
    
# Replaces all underscores in header with two spaces
    for row in range(3,ws1.max_row + 1, 2):   # fill every other row background 
        for col in range(1,max_cols):
            ws1.cell(row=row, column=col).fill = PatternFill("solid", start_color=ROW_FILL_COLOR)
            
        
    return work_book

# %%
# The following function formats provider summary 
def create_sheet_two(work_book):
    from openpyxl.utils import get_column_letter
    from openpyxl.styles import Border, Side, PatternFill, Font, GradientFill, Alignment    
    import openpyxl
    
    sheets = work_book.sheetnames
   
    ws2 = work_book[sheets[1]]
   # ws = wb[sheets[n]]
    ws2.title = "Provider Summary"
    ws2.sheet_properties.tabColor = CONTENT_TAB_COLOR
     
# Format the Header as bold blue centered wordwrap 
    ws2.row_dimensions[1].height = 60 
    max_cols = ws2.max_column + 1 
    for col in range(1,max_cols):
        ws2[get_column_letter(col) + '1'].font = Font(bold=True ) 
        ws2[get_column_letter(col) + '1'].fill = PatternFill("solid", start_color=HEADER_COLOR) 
        ws2[get_column_letter(col) + '1'].alignment = Alignment(horizontal='center', wrap_text=True) 
# Replaces all underscores in header with two spaces         
        ws2[get_column_letter(col) + '1'].value = ws2[get_column_letter(col) + '1'].value.replace('_','  ')        
    
# Work Sheet 1 - Patient Attribution - Set Column Widths and Header Hieght
    ws2.column_dimensions['A'].width = 30
    ws2.column_dimensions['B'].width = 30
    ws2.column_dimensions['C'].width = 30
    ws2.column_dimensions['D'].width = 30
    ws2.column_dimensions['E'].width = 30
    ws2.column_dimensions['F'].width = 30

# Set Filtering on 
    FullRange = "A1:" + get_column_letter(ws2.max_column) \
    + str(ws2.max_row)
    ws2.auto_filter.ref = FullRange    

    return work_book

# %%
def create_sheet_feedback(work_book):
    
    # Create The Tab 
    ws_feedback = work_book.create_sheet("Feedback")
    ws_feedback.title = "Feedback or Issues" 
    ws_feedback.sheet_properties.tabColor = USER_TAB_COLOR
    
    # Blank the Canvas 
    fontStyle = Font(size = "12", bold = True)
    for col in range(1,25):
        for row in range(1,25):
            ws_feedback[get_column_letter(col) + str(row)].alignment = Alignment(horizontal='left', vertical='top', wrap_text=True)          
            ws_feedback[get_column_letter(col) + str(row)].font = fontStyle
            ws_feedback[get_column_letter(col) + str(row)].fill = PatternFill("solid", fgColor=BLANK_WHITE)
    
    
    # Create The Title 
    ws_feedback.merge_cells('A1:B1')
    ws_feedback.row_dimensions[1].height = 20
    top_left_cell = ws_feedback['A1']
    top_left_cell.value = "Feedback or Issues"

    top_left_cell.fill = PatternFill("solid", fgColor=USER_TAB_COLOR)
    top_left_cell.fill = fill = GradientFill(stop=(USER_TAB_COLOR, BLANK_WHITE))
    top_left_cell.font  = Font(b=True, color="000000")
    top_left_cell.alignment = Alignment(horizontal="center", vertical="center")
    fontStyle = Font(size = "18", bold = "True")
    top_left_cell.font = fontStyle

    ws_feedback['A2'] = 'User Name'
    ws_feedback['B2'] = 'Issue or Feedback'
  
    for col in range(1,3):
        ws_feedback[get_column_letter(col) + '2'].font = Font(size = "12", bold=True ) 
        ws_feedback[get_column_letter(col) + '2'].alignment = Alignment(horizontal='center', vertical='bottom', wrap_text=True)
        ws_feedback[get_column_letter(col) + '2'].fill = PatternFill("solid", fgColor=HEADER_COLOR)
    
    ws_feedback.column_dimensions['A'].width = 30
    ws_feedback.column_dimensions['B'].width = 120 

    ws_feedback.row_dimensions[2].height = 30
 
   
    return work_book

# %%
def create_instruction_sheet(work_book):
    
    ws_instruction  = work_book.create_sheet("Instructions")
    ws_instruction.title = "Instructions" 
    ws_instruction.sheet_properties.tabColor = USER_TAB_COLOR
    
    # Blank the Canvas 
    fontStyle = Font(size = "12", bold = True)
    for col in range(1,25):
        for row in range(1,25):
            ws_instruction[get_column_letter(col) + str(row)].alignment = Alignment(horizontal='left', vertical='top', wrap_text=True)          
            ws_instruction[get_column_letter(col) + str(row)].font = fontStyle
            ws_instruction[get_column_letter(col) + str(row)].fill = PatternFill("solid", fgColor=BLANK_WHITE)
            
    for row in range(1,25):
            ws_instruction.row_dimensions[row].height = 20         
            
    ws_instruction.column_dimensions['A'].width = 3
    ws_instruction.column_dimensions['B'].width = 3
    ws_instruction.column_dimensions['C'].width = 80            
    
    
    ws_instruction.merge_cells('A1:F1')
    top_left_cell = ws_instruction['A1']
    top_left_cell.value = "Instructions for Validation"

    top_left_cell.fill = PatternFill("solid", fgColor=USER_TAB_COLOR)
    top_left_cell.fill = fill = GradientFill(stop=(USER_TAB_COLOR, BLANK_WHITE))
    top_left_cell.font  = Font(b=True, color="000000")
    top_left_cell.alignment = Alignment(horizontal="center", vertical="center")
    fontStyle = Font(size = "18", bold = "True")
    top_left_cell.font = fontStyle

    fontStyle = Font(size = "14", bold = "True")
    ws_instruction.merge_cells('A3:F3')
    ws_instruction['A3'].font = fontStyle
    ws_instruction['A3'] = 'Spreadsheet instructions:'


    ws_instruction['B4'] = 1
    ws_instruction['B5'] = 2 
    
    ws_instruction['C4'] = 'Use Filter column A  \'Provider Name \' to select the provider you want'
    ws_instruction['C5'] = 'If any issues or problems are identified, please enter them on the \'Feedback\' tab. '       
    
    return work_book

# %%
# Automate the worksheet 
def create_work_book(work_book):
    create_sheet_one(wb)
    create_sheet_two(wb)
    create_instruction_sheet(wb) 
    create_sheet_feedback(wb)    
    return work_book

# %%
Path_to_Excel = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv/'
Path_to_Save_Excel = 'c:/Users/josep/Documents/Kaleida/HEDIS_Prv_ft/'
extension = 'xlsx'
os.chdir(Path_to_Excel)
files = glob.glob('*.{}'.format(extension))

for x in range(len(files)): 
#    print(files[x]) 
#    print(Path_to_Excel + files[x])     
    wb = load_workbook(Path_to_Excel + files[x])
    org_name =  files[x].replace('.xlsx','')
    create_work_book(wb)
    wb.save(Path_to_Save_Excel + files[x])
    print(Path_to_Save_Excel + files[x])
# Out:
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv_ft/AA_PCP_Alan_M_Antfleck_Physician_PLLC_Delaware_Ave_org_prv_quality.xlsx
# c:/Users/josep/Documents/Kaleida/HEDIS_Prv_ft