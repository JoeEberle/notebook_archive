# %% [markdown]
# ![Text_to_Speech.png](attachment:Text_to_Speech.png)
# ## Talking Python Code
# #### Joe Eberle started on:10_27_2022 updated on:  10_27_2022

# %% [markdown]
# Process Steps :
# 1. Import the pyttsx3 text to speech module
# 2. Instantiate the text to speech engine
# 3. Configure the TTS dialogues and settings
# 4. Test the Text to Speech Engine

# %%
first_install = True
if first_install:
    # !pip install pyttsx3
    # !pip install configparser
# Out:
# Requirement already satisfied: pyttsx3 in c:\users\josep\anaconda3\lib\site-packages (2.90)
# Requirement already satisfied: pypiwin32 in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (223)
# Requirement already satisfied: pywin32 in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (305.1)
# Requirement already satisfied: comtypes in c:\users\josep\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
# Requirement already satisfied: configparser in c:\users\josep\anaconda3\lib\site-packages (5.3.0)

# %%
import pyttsx3
import talking_code_talking_code as talking_code
import configparser as configparser
import os

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'talking code'
cwd = os.getcwd()

# %% [markdown]
# ## Step 0 - Optional - Establish Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(False)
ql.set_speaking_steps(True)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Process.')
# Out:
# Process talking code Step 0 - Initializing and starting Process.

# %% [markdown]
# ## Step 1 - Initialize The Text to Speech Engine

# %%
# Set text to speech preferences for project 
ql.pvlog('info',f'Process {solution_name} Step 1 - Initialize The Text to Speech Engine.') 
Text_to_Speech = talking_code.Initialize_Text_to_Speach()
# Out:
# Process talking code Step 1 - Initialize The Test to Speech Engine.

# %%
if config.get('talk_to_me','Talking_Code'):  
        ql.pvlog('info',f'Process {solution_name} Step 2 - Read the Solution documentation.')     
        talking_code.read_introduction()
        talking_code.read_credits()  
        talking_code.read_process_steps()  
        talking_code.read_terms()
# Out:
# Process talking code Step 2 - Read the Solution documentation.
#
#
# This jupiter notebook will quickly and easily setup text to speech so that the code can explain itself and reduce learning curve.
#
#
#
# This Jupiter Notebook Was:
# Developed in Collaboration by Joe Eberle
# Developed in Python 3 starting on 9/20/2022
# This package is free AND Open Source and the code is openly available for general Use.
#
#
#
# The steps of this process are :
# Optional Install: Pip or conda install the latest pytsx3 library if not already Loaded
# Step 1: Import the pytsx3 text to speech library.
# Step 2: Instantiate the text to speech engine.
# Step 3: Test the Project dialogues to ensure text to speech is working.
#
#
#
# The terminology for this process is :
# Python. Python is a general-purpose programming language that is widely used for data science.
# pyttsx3 PACKAGE - The pyttsx3 library is a text to speech engine that is customizable to multiple voices and settings.

# %%
ql.pvlog('info',f'Process {solution_name} Step 3 - If speaking occurred then this process was successfull - End Process')
# Out:
# Process talking code Step 3 - If speaking occurred then this process was successfull - End Process

# %% [markdown]
# ## Optional - Log overall performance and Append the Log File to Historical Log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2023-07-24 09:32:44,656 - INFO - START talking code =============================================
# 2023-07-24 09:32:44,656 - INFO - START talking code Start Time = 2023-07-24 09:32:44
# 2023-07-24 09:32:44,656 - INFO - talking code Step 0 - Initialize the configuration file parser
# 2023-07-24 09:32:44,780 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2023-07-24 09:32:44,780 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2023-07-24 09:32:49,968 - INFO - Process talking code Step 0 - Initializing and starting Process.
# 2023-07-24 09:32:54,370 - INFO - Process talking code Step 1 - Initialize The Test to Speech Engine.
# 2023-07-24 09:33:03,457 - INFO - Process talking code Step 2 - Read the Solution documentation.
# 2023-07-24 09:34:04,715 - INFO - Process talking code Step 3 - If speaking occurred then this process was successfull - End Process
# 2023-07-24 09:34:04,732 - INFO - PERFORMANCE talking code The total process duration was:80.08
# 2023-07-24 09:34:04,732 - INFO - PERFORMANCE talking code Stop Time = 2023-07-24 09:34:04
# 2023-07-24 09:34:04,733 - INFO - PERFORMANCE talking code Low process duration less than 3 minutes:80.08
# 2023-07-24 09:34:04,733 - INFO - PERFORMANCE talking code Performance optimization is optional
# 2023-07-24 09:34:04,733 - INFO - END talking code =============================================
