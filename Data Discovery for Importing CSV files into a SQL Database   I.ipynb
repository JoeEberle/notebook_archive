# %% [markdown]
# ## Optional Precursor Step  - Import Dependent Python Libraries  (If Not Installed)
# #####  PIP Install any Python Libraries below that you dont already have installed

# %%
#PIP Install any Python Libraries you dont already have installed 
#!pip install pyttsx3
#!pip install pandas
#!pip install pyodbc
#!pip import sqlalchemy

# %% [markdown]
# ## Create SQL Schema from CSV Files
# #### Joe Eberle, Alan Calhoun, Helmi (Al)  Seoud
# ##### Refactored ON  : 9/20/2022  ---  Revised ON  : 10/6/2022

# %% [markdown]
# ## Project Setup - Importing Libraries and Initializing Global Variables

# %%
#install dependent Libraries is not already installed 
#!pip install pyttsx3

# Import the necessary Libraries 
import glob, os
import pandas as pd
# import logging 
from pathlib import Path
import pyttsx3
import pyodbc 
import timeit
import time
from datetime import date
from datetime import datetime
import sqlalchemy

# Establish some import parameters 

importing_xlsx_files = False 
importing_csv_files = True 
Data_Import_Starting_Directory = 'Y:/_Kaleida_Input/'
#Data_Import_Starting_Directory = 'C:/Data/'
Process_Name = 'Importing CSV data into SQL'

step_debugging = True
detail_debugging = True
detail_Talking = False # only talk on major steps 
Process_Step_Name = ''  
Reading_Intro = False
Reading_Credits =  False
Reading_Steps = False 
Reading_Terms = False 
printing_output = True
Talking_Code = True
Talking_Voice_Male_Gender = True        # Set to False for Female Voice 
Code_Logging  = True 
event_log_row = 0 

# Create some Global Variables for SQL Constructs 
column_inserts = ''
column_question_mark   = ''
create_table_SQL  = ''
create_real_table_SQL  = ''
insert_records_SQL  = ''
create_schema_SQL  = '' 
create_real_schema_SQL  = '' 
Table_Name_Extension_Daily = '_DI'
Table_Name_Extension_Historical = '_HX'
Table_Name_Extension_Rejected = '_RJ'
Table_Name_Extension_Administrative = '_AD'
Table_Name_Prefix = '[pbic_1_0].'

# Create some Global Variables for SQL Connection
server = 'Kalpwvsqlgppc01' 
database  = 'GPPC_DEV' 
username ='GPPC'
pwd = 'Elephant-Trunk-06'
sql_connector = 'DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection=No;UID='+username+';PWD='+pwd
# log_filename='data_importing_log.log'

# Configure the Logging to the DEBUG Level 
# logging.basicConfig(level=logging.DEBUG, filename=log_filename, format= '%(asctime)s %(clientip)-15s %(user)-8s %(message)s')
Text_to_Speech = pyttsx3.init()

## Dictionary For character_replacements List 
character_replacements = { " ":"_","#":"Number","%":"Percentage" \
                         ,'_Unnamed':'','_Level':'',"$":"Dollar",'_1':'' \
                         ,'_2':'','_3':'','_4':'','_5':''  \
                         ,'_6':'','_7':'','_8':'','_9':''  \
                         ,'_0':'',':7':'',':8':'',':':'' }
## Dictionary For replacing data types in databases 
data_type_replacements = { "object":"varchar","float64":"float","int64":"int","%":"Percentage" \
                         ,'_Unnamed':'','datetime64':'timestamp',"timedelta64[ns]":"varchar"}    

## add the glaobal data frames for event loggging and Schema Creation 
df_event_log = pd.DataFrame(columns = ('Event_ID','Process_Name','Event_Name','Event_Date','Event_Time','Task_Start_Time','Task_End_Time','TASk_Duration','Comments'))
df_import_directories = pd.DataFrame(columns = ('Root_Directory','Sub_Directory'))
df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','Import_File_Name','File_Size','File_Modified_Date','File_Created_Date'))
import_directory_file_Number  = 0
import_file_Number  = 0 
event_log_row = 0
sub_directory_count = 0

# %% [markdown]
# ## Customization - Special Formulas for GPPC

# %%
def customize_table_names(table_name):
    table_name.replace('ADPDaily_Time_Card','Time_Card').replace('Available_Slots_Past','Available_Slots')  \
    .replace('Available_Slots_Past','Available_Slots').replace('DailyAppointments','Appointments') \
    .replace('DailyAppointments','Appointments').replace('HXDX','Historical') \
    .replace('PatientInformationMain18Under','Patient_Information')  \
    .replace('QualityPrimaryCareAnnualVisitReport','Primary_Care_Annual_Visit') \
    .replace('RCM_Adujstments','RCM_Adjustments') \
    .replace('SurgicalAppointmentSummar2DaysAgo','Surgical_Appointment') \
    .replace('SurgicalAppointmentSummar2DaysAgo','Primary_Care_Annual_Visit') \
    .replace('Third_Next_Available','Third_Next_Available') \
    .replace('Third_Next_Available','Third_Next_Available') \
    .replace('Third_Next_Available','Third_Next_Available') \
    .replace('Third_Next_Available','Third_Next_Available') 

    return table_name


def customize_column_name_clean_up(df_to_clean):
    df_to_clean.rename(columns={'Name_':'Name','Appt_Date':'Appointment_Date','Appt_Type':'Appointment_Type' \
                                ,'EbillEsuperbillNumber':'Ebill_Esuper_Bill_Number' \
                                ,'Referral_FromTodo_Selection':'Referral_From_To_Do_Selection' \
                                ,'Wellnow_LocationTodo_Selection':'Wellnow_Location_To_Do_Selection' \
                                ,'Access_Vip':'Access_VIP' \
                                ,'Vip':'VIP' \
                                ,'Todo_DateCreate_Date':'To_Do_Date_Create_Date' \
                               }, inplace = True)
    return df_to_clean

# %% [markdown]
# ## Project Setup -    Establishing DataFrames & Establishing Global Functions

# %%
global Talking_Code
global import_directory_file_Number 
global event_log_row 
global printing_output


def set_up_python_infrastructure():
    initialize_replacement_Dictionaries()    # Set up control libraries for syntactic Consistency 
    Initialize_Text_to_Speach()              # Intitialize Text to Speech Engine 
    df_e_log = create_event_log_dataframe()  # Set up the Event Logging 
    
# Say Whatever the user wants 
def say(speech):
    if Talking_Code:
        Text_to_Speech.say(speech)
        Text_to_Speech.runAndWait()    
    
# Intitialize Text to Speech Engine 
def Initialize_Text_to_Speach():
    Text_to_Speech = pyttsx3.init()
    Text_to_Speech.setProperty('Rate',187)
    voices = Text_to_Speech.getProperty('voices')
    if Talking_Voice_Male_Gender:
        Text_to_Speech.setProperty('voice', voices[0].id)    # Default Male voice registered as 'Dave'
    else: 
        Text_to_Speech.setProperty('voice', voices[1].id)    # Alternate Female voice registered as 'Tina'
    speech = 'The text to speech engine is initialized using pythons pyttsx3 engine'
    Text_to_Speech.say(speech)
    Text_to_Speech.runAndWait()    
    
    
# Say Whatever the user wants 
def say(speech):
    Text_to_Speech.say(speech)
    Text_to_Speech.runAndWait()       
    
# Create dataframe to house Directories 
def create_directory_dataframe():
    df_import_directories = pd.DataFrame(columns = ('Root_Directory','Sub_Directory'))
    return df_import_directories  

def create_import_files_dataframe():
    df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','File_Name','File_Size_Bytes','File_Created','File_Modified'))
    return df_import_files  

def add_import_directory(Root_Directory,Sub_Directory):
    global import_directory_file_Number 
    import_directory_file_Number += 1  
    df_import_directories.loc[import_directory_file_Number] = [Root_Directory,Sub_Directory]
    return import_directory_file_Number 

def add_import_file(Root_Directory,Sub_Directory,Table_Name,File_Name,File_Size_Bytes,File_Created,File_Modified):
    global import_file_Number 
    import_file_Number += 1  
    df_import_files.loc[import_file_Number] = [Root_Directory,Sub_Directory,Table_Name,File_Name,File_Size_Bytes,File_Created,File_Modified]
    return import_directory_file_Number  

# Create dataframe to house Directories 
def create_event_log_dataframe():
    df_event_log = pd.DataFrame(columns = ('Event_ID','Process_Name','Event_Name','Event_Date','Event_Time','Task_Start_Time','Task_End_Time','TASk_Duration','Comments'))
    return df_event_log


df_event_log = create_event_log_dataframe()

# Create dataframe to database schema 
def create_database_schema_dataframe():
    df_schema = pd.DataFrame(columns = ('Database_Name','Table_Name','Column_Number','Column_Name','Column_Data_Type','Column_Sample_Data','Column_Description'))
    return df_schema

# Create dataframe to house Directories 
def add_log_event(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]

    
# Add Log Events 
def add_log_event_timer(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    Event_Date = date.today()
    Event_Time = time.time() 
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]
    
# Reset the Event timer start time 
def reset_event_timer(Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments ):
    global event_log_row  
    event_log_row += 1  
    Event_Date = date.today()
    Event_Time = time.time() 
    Task_Start_Time    = time.time()  
    df_event_log.loc[event_log_row] = [event_log_row,Process_Name,Event_Name,Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , Comments]

    # Get a list of all the Subfiles to iterate through 
def list_all_csv_files(path):
    extension = 'csv'
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        out('CSV File #{} filename: {}  '.format(str(csv_file_count),file))

# Get a list of all the Subfiles to iterate through 
def register_all_csv_files_for_import(path, table_name):
    extension = 'csv'
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        File_Size = os.path.getsize(file)
        File_Last_Modified =  time.ctime(os.path.getmtime(file))
        File_Create_Date =  time.ctime(os.path.getctime(file))
        out('CSV File #{} filename: {}  '.format(str(csv_file_count),file)) 
        file_Number = add_import_file(path,path,table_name,file,File_Size,File_Last_Modified,File_Create_Date)
        
def create_import_files_dataframe():
    df_import_files = pd.DataFrame(columns = ('Root_Directory','Sub_Directory','Table_Name','File_Name'))
    return df_import_files  

def add_import_directory(Root_Directory,Sub_Directory):
    global import_directory_file_Number 
    import_directory_file_Number += 1  
    df_import_directories.loc[import_directory_file_Number] = [Root_Directory,Sub_Directory]
    return import_directory_file_Number 

def add_import_File(Root_Directory,Sub_Directory,Table_Name,File_Name):
    global import_file_Number 
    import_file_Number += 1  
    df_import_files.loc[import_file_Number] = [Root_Directory,Sub_Directory,Table_Name,File_Name]
    return import_directory_file_Number          
        
    
def infer_table_name_from_path(path):
    table_name = path.replace(Data_Import_Starting_Directory,"").replace('Y:/_Kaleida_Input/','').replace('Y:_Kaleida_Input','').replace(' ','_').replace('/','').replace('\\','')
    table_name = customize_table_names(table_name)
    return table_name 
        
# Introduction - Overview of CSV to SQL Import Process Steps 
def read_credits(): 
    Dialog = 'This Jupiter Notebook Was  : '
    Dialog = Dialog + 'Developed in Collaboration by Joe Eberle, Alan Calhoun, Helmi (Al) Seoud  '
    Dialog = Dialog + 'Developed in Python starting on 9/20/2022 '
    Dialog = Dialog + 'This package is free AND Open Source and the code is openly available for general Use. '    
    say(Dialog)         
    
# Introduction - Overview of CSV to SQL Import Process Steps 
def read_terms(): 
    Dialog = 'The terminology for this process is : '
    Dialog = Dialog + 'Python. Python is a general-purpose programming language that is widely used for data science.  '
    Dialog = Dialog + 'Structured Query Language (SQL) is one of the worlds most widely used programming languages for manipulating and querying data. '
    Dialog = Dialog + 'CSV. A Comma-Separated Values (CSV)  file is a text file in which information is separated by commas. '
    Dialog = Dialog + 'PANDAS. Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.  '
    Dialog = Dialog + 'OS PACKAGE - The OS python library provides a portable way of using operating system dependent functionality to allow your python code to run on all platforms '
    say(Dialog)  
    
# Process Steps - Overview of CSV to SQL Import Process Steps 
def read_process_steps():
    Dialog = 'The data flow for this process is : '
    Dialog = Dialog + 'Precursor Step 1: The clinician or administrator enters the patients data into the Electronic Medical Record (EMR). '
    Dialog = Dialog + 'Precursor Step 2: At the end of the day the EMR data is exported into Comma Seperated Values (CSV) files and shared via SFTP. '
    Dialog = Dialog + 'Step 1: Establish The Root Directory. '
    Dialog = Dialog + 'Step 2: Walk the directory structure discovering data to discover all data directories  '
    Dialog = Dialog + 'Step 3: Read the CSV data from each directory into python a PANDAS Dataframe. '
    Dialog = Dialog + 'Step 4: Clean the data and make it consistent in the PANDAS Dataframe. ' 
    Dialog = Dialog + 'Step 5: Check the consistency of the data and perform change control if there are differences. ' 
    Dialog = Dialog + 'Step 6: Convert the pandas dataframes into SQL table Create Statements  '
    Dialog = Dialog + 'Step 7: Creates the SQL tables in the target Database   '
    Dialog = Dialog + 'Step 8: Insert the the PANDAS Rows into SQL using the to_SQL Method.  '
    Dialog = Dialog + 'Step 9: Add event logging to capture the performance of the entire process.  '
    Dialog = Dialog + 'Step 10: Document the SCHEMA into an easy to use Excel Spreadsheet.  '
    Dialog = Dialog + 'Step 11: Check the total number of records imported via SQL to the total raw record count to make sure no data is Left Behind.    '
    say(Dialog)    
    
    
# Introduction - Overview of NoteBooks  
def read_introduction():
    Dialog = 'This jupiter notebook will import all of the CSV files under a specific root directory into a database. '
    Dialog = Dialog +  'This python code will take the CSV files exported froms an Electronic Medical Record platform. '
    Dialog = Dialog + 'and import them into a faster database such as PostgreSQL or SQL Server or SNOW Flake. '
    Dialog = Dialog + 'the data is then available for anaylsis using query tools or ready for visualizations in Power BI or Tableau. '
    say(Dialog)  
    
    
def column_create_SQL (import_df):
    column_name_List = [x.title() for x in import_df.columns] # Create a List of Columns 
    column_Str =  (', '.join(column_name_List)) # Convert List into one String with commas 
    out('Columns =',column_Str)  
    return column_Str            
    
    
def out(dialog):
    global detail_Talking
    if printing_output: 
        print(dialog) 
    if Talking_Code and detail_Talking == True:
        say(dialog)   
    if Talking_Code and (detail_Talking == False) and (dialog.find('step') >= 0):
        say(dialog)     

        
def list_all_xlsx_files(path):
    extension = 'xlsx'
    os.chdir(path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        out('File #{}   is {} '.format(csv_file_count,file))     \
        
        
def explain_the_project():
    if Reading_Intro:
        read_introduction()
    if Reading_Credits:    
        read_credits() 
    if Reading_Steps:
        read_process_steps()
    if Reading_Terms:
        read_terms()        
        
        
        
def convert_data_types(input_df):
    column_datatype_str = str(input_df.dtypes)
    column_datatype_str =  column_datatype_str.replace('dtype: object','').replace('object','varchar[255], ').replace('datetime64[ns]','timestamp, ').replace('float64','float, ')
    out('create column SQL string: {} \n'.format(column_datatype_str))        
        
def read_and_clean_file(data_folder, filename):

    print('Import File =', filename)                 
    df_input_csv = pd.read_csv(filename, nrows=10)
    out('Reading Dataframe Columns before cleanups:{}'.format(df_input_csv.columns))
    df_input_csv.columns = df_input_csv.columns.map('^'.join)
    df_input_csv.columns  = [x.strip().title().replace("^","").replace(" ","_").replace("#","Number").replace("#","Number").replace("%","Percentage") \
                             .replace('_Unnamed','').replace('Unnamed','').replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_input_csv.columns]
    return df_input_csv    
 
        
    
def set_up_python_infrastructure():
    initialize_replacement_Dictionaries()    # Set up control libraries for syntactic Consistency 
    Initialize_Text_to_Speach()              # Intitialize Text to Speech Engine 
    df_event_log = create_event_log_dataframe()  # Set up the Event Logging to housae the events of this process 
    create_database_schema_dataframe()       # Set up the Database Schema dataframe to house the schema

# %% [markdown]
# ## Project Setup -    Database Connectivity & SQL Generation & SQL Execution Functions

# %%
#Execute SQL  Dynamically based upon the Connection string  
def execute_SQL(execute_SQL_command):
    global sql_connector
    print('Execute SQL Connect - Call')
    cnxn = pyodbc.connect(sql_connector)
    cursor = cnxn.cursor()
    sql_execute_result = cursor.execute(execute_SQL_command)
    print('After SQL Call','Result Code: ',sql_execute_result)
    out('Executing SQL - After SQL Execute - Command: {} '.format(execute_SQL_command))    
    
    cnxn.commit()
    cursor.close()
    
# The following code uses a SQL server template for Droping tables and replaces the table name 
# spo that it will create the SQL code will drop ANY Table name that is passed to it 
def Create_Drop_Table_SQL(table_name):  
    # Example ---- DROP TABLE [pbic_1_0].[Access_DI]
    Drop_Table_SQL  = 'DROP TABLE [pbic_1_0].[{}]'.format(table_name)
    return Drop_Table_SQL

# %%
print('Talking Code Setting: ',Talking_Code)
print('Talking Code Detail Setting: ',detail_Talking)
if Talking_Code:
    if Talking_Voice_Male_Gender: 
        out('Talking_Code: Text to Voice set to ON. Voice set  to  Default Male Voice. ')
    else: 
        out('Talking_Code: Text to Voice set to ON. Voice set  to  Alternate Female Voice. ')
    if  detail_Talking:   
        out('Talking  Details is set to True say all detailed outputs..  this will be slow and boring ') 
    else: 
        out('Talking  Details is set to False to say only major steps..  this setting will execute fast and tell you the high level steps of the process. ')
# Out:
# Talking Code Setting:  True
# Talking Code Detail Setting:  False
# Talking_Code: Text to Voice set to ON. Voice set  to  Default Male Voice.
# Talking  Details is set to False to say only major steps..  this setting will execute fast and tell you the high level steps of the process.

# %% [markdown]
# ## Process Reinitialize - Re initialize the Data Frames and all Global Counters to Zero

# %%
global import_directory_file_Number 
global import_file_Number  
global event_log_row 
global sub_directory_count  

# recreate the dataframes 
create_directory_dataframe() 
create_import_files_dataframe() 
create_database_schema_dataframe() 

# reset all the global Counters  
import_directory_file_Number  = 0
import_file_Number  = 0 
event_log_row = 0
sub_directory_count = 0

# %% [markdown]
# ## Optional Precursor Step  - Explain the Project

# %%
explain_the_project()

# %% [markdown]
# ## Step 1 - Establish the root Directory

# %%
add_log_event(Process_Name,'step 1 - Establish the root Directory: {}'.format(Data_Import_Starting_Directory),datetime.now(),datetime.now(),time.time(),time.time(), 0 ,'Step 1 - Establish the root Directory: {}'.format(Data_Import_Starting_Directory))
Process_Step_Name = 'Step 1 - Establish the root Directory' 
out('Step 1 - Establish the root Directory')
out('The root directory to walk is : {}'.format(Data_Import_Starting_Directory))  
df_event_log.head()
# Out:
# Step 1 - Establish the root Directory
# The root directory to walk is : Y:/_Kaleida_Input/
#   Event_ID                 Process_Name  \
# 1        1  Importing CSV data into SQL
#
#                                           Event_Name  \
# 1  step 1 - Establish the root Directory: Y:/_Kal...
#
#                   Event_Date                 Event_Time  Task_Start_Time  \
# 1 2022-10-13 15:28:58.980930 2022-10-13 15:28:58.980930     1.665689e+09
#
#    Task_End_Time TASk_Duration  \
# 1   1.665689e+09             0
#
#                                             Comments
# 1  Step 1 - Establish the root Directory: Y:/_Kal...

# %% [markdown]
# ## Step 2 - Walk the directory structure discovering data to discover all data directories

# %%
global sub_directory_count
# Get a list of all the Subfiles to iterate through 
def walk_sub_directories(root_directory):
    global sub_directory_count
    Process_Step_Name = 'Step 2 - Walk the directory structure discovering data to discover all data directories' 
    df_import_directories = create_directory_dataframe() 
    directory_entry = 0 
 
    for root, subdirectories, files in os.walk(root_directory):
        # hard coded - remove this later!!!!!! 
        # old data and Excel data should NOT BE Included under root 
        if (root.find('old') == -1) and (root.find('excel') == -1):
            out('Registering Directory # {} {}  '.format(directory_entry,root ))            
            directory_entry += 1 
            sub_directory_count += 1     
            num = add_import_directory(root, root)        
         
    return df_import_directories

out('Step 2 - Walk the directory structure  to discover all data directories')
add_log_event(Process_Name,'Step 2 - Walk the directory structure  to discover all data directories',datetime.now(),datetime.now(),time.time(),time.time(), 0 ,'Step 2 - Walk the directory structure  to discover all data directories'.format(Data_Import_Starting_Directory))
walk_sub_directories(Data_Import_Starting_Directory)  
out('Step 2 Done - Listing all Registered data Directories: ')
# Out:
# Step 2 - Walk the directory structure  to discover all data directories
# Registering Directory # 0 Y:/_Kaleida_Input/
# Registering Directory # 1 Y:/_Kaleida_Input/Access
# Registering Directory # 2 Y:/_Kaleida_Input/ADP
# Registering Directory # 3 Y:/_Kaleida_Input/ADP\Daily Time Card
# Registering Directory # 4 Y:/_Kaleida_Input/ADP\Employee Census
# Registering Directory # 5 Y:/_Kaleida_Input/Available_Slots
# Registering Directory # 6 Y:/_Kaleida_Input/Available_Slots_Past
# Registering Directory # 7 Y:/_Kaleida_Input/Call Center
# Registering Directory # 8 Y:/_Kaleida_Input/CPT Visit
# Registering Directory # 9 Y:/_Kaleida_Input/DailyAppointments
# Registering Directory # 10 Y:/_Kaleida_Input/DailyCPT
# Registering Directory # 11 Y:/_Kaleida_Input/DailyMultipleAppointmentSameDay
# Registering Directory # 12 Y:/_Kaleida_Input/DailyScheduledOfficeAppointmentVisit
# Registering Directory # 13 Y:/_Kaleida_Input/DailySuperbill
# Registering Directory # 14 Y:/_Kaleida_Input/EmployeePerformanceforAdminTaskAudit
# Registering Directory # 15 Y:/_Kaleida_Input/HistoryofTransaction
# Registering Directory # 16 Y:/_Kaleida_Input/Hx
# Registering Directory # 17 Y:/_Kaleida_Input/HXDX
# Registering Directory # 18 Y:/_Kaleida_Input/HxTransaction
# Registering Directory # 19 Y:/_Kaleida_Input/Incident
# Registering Directory # 20 Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# Registering Directory # 21 Y:/_Kaleida_Input/LungCancerScreeningTracker
# Registering Directory # 22 Y:/_Kaleida_Input/MissingNPIAudit
# Registering Directory # 23 Y:/_Kaleida_Input/OncologyNavigation
# Registering Directory # 24 Y:/_Kaleida_Input/outstandinglabs_removed
# Registering Directory # 25 Y:/_Kaleida_Input/OutstandingOpenDocuments
# Registering Directory # 26 Y:/_Kaleida_Input/OutstandingOpenLabs
# Registering Directory # 27 Y:/_Kaleida_Input/OutstandingOpenOrders
# Registering Directory # 28 Y:/_Kaleida_Input/OutstandingOpentoDos
# Registering Directory # 29 Y:/_Kaleida_Input/OutstandingOpenTriages
# Registering Directory # 30 Y:/_Kaleida_Input/OutstandingOpenXrays
# Registering Directory # 31 Y:/_Kaleida_Input/PatientExperience
# Registering Directory # 32 Y:/_Kaleida_Input/PatientInformation
# Registering Directory # 33 Y:/_Kaleida_Input/PatientInformation\Main18Under
# Registering Directory # 34 Y:/_Kaleida_Input/PaymentMismatch
# Registering Directory # 35 Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# Registering Directory # 36 Y:/_Kaleida_Input/ProviderPanel
# Registering Directory # 37 Y:/_Kaleida_Input/Quality
# Registering Directory # 38 Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVisitReport
# Registering Directory # 39 Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# Registering Directory # 40 Y:/_Kaleida_Input/RCM-InpatientCharges
# Registering Directory # 41 Y:/_Kaleida_Input/RCM_Adujstments
# Registering Directory # 42 Y:/_Kaleida_Input/RCM_Productivity
# Registering Directory # 43 Y:/_Kaleida_Input/Referrals - Recommendation
# Registering Directory # 44 Y:/_Kaleida_Input/ReferringProviders
# Registering Directory # 45 Y:/_Kaleida_Input/SurgicalAppointmentSummar2DaysAgo
# Registering Directory # 46 Y:/_Kaleida_Input/Third_Next_Available
# Step 2 Done - Listing all Registered data Directories:

# %%
# Persist the directories in an excel file Registry 
Data_Import_Starting_Directory =  'J:/IT GLIN Data Services Shared/TempData/'
Excel_file_Name = Data_Import_Starting_Directory + 'Import_Directory_Registry.xlsx'
out('Registering Directories in excel File:{} '.format(Excel_file_Name))
df_import_directories.to_excel(Excel_file_Name, index=False)
# Out:
# Registering Directories in excel File:J:/IT GLIN Data Services Shared/TempData/Import_Directory_Registry.xlsx

# %%
df_import_directories.shape
# Out:
# (47, 2)

# %%
df_import_directories.head(100)
# Out:
#                                        Root_Directory  \
# 1                                  Y:/_Kaleida_Input/
# 2                            Y:/_Kaleida_Input/Access
# 3                               Y:/_Kaleida_Input/ADP
# 4               Y:/_Kaleida_Input/ADP\Daily Time Card
# 5               Y:/_Kaleida_Input/ADP\Employee Census
# 6                   Y:/_Kaleida_Input/Available_Slots
# 7              Y:/_Kaleida_Input/Available_Slots_Past
# 8                       Y:/_Kaleida_Input/Call Center
# 9                         Y:/_Kaleida_Input/CPT Visit
# 10                Y:/_Kaleida_Input/DailyAppointments
# 11                         Y:/_Kaleida_Input/DailyCPT
# 12  Y:/_Kaleida_Input/DailyMultipleAppointmentSameDay
# 13  Y:/_Kaleida_Input/DailyScheduledOfficeAppointm...
# 14                   Y:/_Kaleida_Input/DailySuperbill
# 15  Y:/_Kaleida_Input/EmployeePerformanceforAdminT...
# 16             Y:/_Kaleida_Input/HistoryofTransaction
# 17                               Y:/_Kaleida_Input/Hx
# 18                             Y:/_Kaleida_Input/HXDX
# 19                    Y:/_Kaleida_Input/HxTransaction
# 20                         Y:/_Kaleida_Input/Incident
# 21     Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# 22       Y:/_Kaleida_Input/LungCancerScreeningTracker
# 23                  Y:/_Kaleida_Input/MissingNPIAudit
# 24               Y:/_Kaleida_Input/OncologyNavigation
# 25          Y:/_Kaleida_Input/outstandinglabs_removed
# 26         Y:/_Kaleida_Input/OutstandingOpenDocuments
# 27              Y:/_Kaleida_Input/OutstandingOpenLabs
# 28            Y:/_Kaleida_Input/OutstandingOpenOrders
# 29             Y:/_Kaleida_Input/OutstandingOpentoDos
# 30           Y:/_Kaleida_Input/OutstandingOpenTriages
# 31             Y:/_Kaleida_Input/OutstandingOpenXrays
# 32                Y:/_Kaleida_Input/PatientExperience
# 33               Y:/_Kaleida_Input/PatientInformation
# 34   Y:/_Kaleida_Input/PatientInformation\Main18Under
# 35                  Y:/_Kaleida_Input/PaymentMismatch
# 36   Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# 37                    Y:/_Kaleida_Input/ProviderPanel
# 38                          Y:/_Kaleida_Input/Quality
# 39  Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVis...
# 40      Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# 41             Y:/_Kaleida_Input/RCM-InpatientCharges
# 42                  Y:/_Kaleida_Input/RCM_Adujstments
# 43                 Y:/_Kaleida_Input/RCM_Productivity
# 44       Y:/_Kaleida_Input/Referrals - Recommendation
# 45               Y:/_Kaleida_Input/ReferringProviders
# 46  Y:/_Kaleida_Input/SurgicalAppointmentSummar2Da...
# 47             Y:/_Kaleida_Input/Third_Next_Available
#
#                                         Sub_Directory
# 1                                  Y:/_Kaleida_Input/
# 2                            Y:/_Kaleida_Input/Access
# 3                               Y:/_Kaleida_Input/ADP
# 4               Y:/_Kaleida_Input/ADP\Daily Time Card
# 5               Y:/_Kaleida_Input/ADP\Employee Census
# 6                   Y:/_Kaleida_Input/Available_Slots
# 7              Y:/_Kaleida_Input/Available_Slots_Past
# 8                       Y:/_Kaleida_Input/Call Center
# 9                         Y:/_Kaleida_Input/CPT Visit
# 10                Y:/_Kaleida_Input/DailyAppointments
# 11                         Y:/_Kaleida_Input/DailyCPT
# 12  Y:/_Kaleida_Input/DailyMultipleAppointmentSameDay
# 13  Y:/_Kaleida_Input/DailyScheduledOfficeAppointm...
# 14                   Y:/_Kaleida_Input/DailySuperbill
# 15  Y:/_Kaleida_Input/EmployeePerformanceforAdminT...
# 16             Y:/_Kaleida_Input/HistoryofTransaction
# 17                               Y:/_Kaleida_Input/Hx
# 18                             Y:/_Kaleida_Input/HXDX
# 19                    Y:/_Kaleida_Input/HxTransaction
# 20                         Y:/_Kaleida_Input/Incident
# 21     Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# 22       Y:/_Kaleida_Input/LungCancerScreeningTracker
# 23                  Y:/_Kaleida_Input/MissingNPIAudit
# 24               Y:/_Kaleida_Input/OncologyNavigation
# 25          Y:/_Kaleida_Input/outstandinglabs_removed
# 26         Y:/_Kaleida_Input/OutstandingOpenDocuments
# 27              Y:/_Kaleida_Input/OutstandingOpenLabs
# 28            Y:/_Kaleida_Input/OutstandingOpenOrders
# 29             Y:/_Kaleida_Input/OutstandingOpentoDos
# 30           Y:/_Kaleida_Input/OutstandingOpenTriages
# 31             Y:/_Kaleida_Input/OutstandingOpenXrays
# 32                Y:/_Kaleida_Input/PatientExperience
# 33               Y:/_Kaleida_Input/PatientInformation
# 34   Y:/_Kaleida_Input/PatientInformation\Main18Under
# 35                  Y:/_Kaleida_Input/PaymentMismatch
# 36   Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# 37                    Y:/_Kaleida_Input/ProviderPanel
# 38                          Y:/_Kaleida_Input/Quality
# 39  Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVis...
# 40      Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# 41             Y:/_Kaleida_Input/RCM-InpatientCharges
# 42                  Y:/_Kaleida_Input/RCM_Adujstments
# 43                 Y:/_Kaleida_Input/RCM_Productivity
# 44       Y:/_Kaleida_Input/Referrals - Recommendation
# 45               Y:/_Kaleida_Input/ReferringProviders
# 46  Y:/_Kaleida_Input/SurgicalAppointmentSummar2Da...
# 47             Y:/_Kaleida_Input/Third_Next_Available

# %% [markdown]
# ## Step 3 - Discover and Register all CSV files to import

# %%
def iterate_directories_to_import_files(Import_Directory_Data_Frame):
    out('Step 3 - Discover and Register all CSV files to import ')
    Process_Step_Name = 'Step 3 - Discover and Register all CSV files to import'  
    list_of_Directories = df_import_directories['Root_Directory']
    dir_count = 0
    for dir in list_of_Directories:
        dir_count += 1
        out('Directory #{} to find import files : {}  \n   '.format(dir_count,dir))
        SQL_Table_Name = infer_table_name_from_path(dir)
        register_all_csv_files_for_import(dir, SQL_Table_Name   )

iterate_directories_to_import_files(df_import_directories)
# Out:
# Step 3 - Discover and Register all CSV files to import
# Directory #1 to find import files : Y:/_Kaleida_Input/
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/
# Directory #2 to find import files : Y:/_Kaleida_Input/Access
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Access
# CSV File #1 filename: 2459631_274_20220220043457_dmhmreport_EHRSUPPORT_5592087.csv
# CSV File #2 filename: 2459638_97_20220227013752_dmhmreport_EHRSUPPORT_5187581.csv
# CSV File #3 filename: 2459646_85_20220307012546_dmhmreport_EHRSUPPORT_4516065.csv
# CSV File #4 filename: 2459652_467_20220313074723_dmhmreport_EHRSUPPORT_2179577.csv
# CSV File #5 filename: 2459659_138_20220320021809_dmhmreport_EHRSUPPORT_877261.csv
# CSV File #6 filename: 2459666_94_20220327013440_dmhmreport_EHRSUPPORT_3985999.csv
# CSV File #7 filename: 2459673_140_20220403022052_dmhmreport_EHRSUPPORT_51141178.csv
# CSV File #8 filename: 2459680_351_20220410055106_dmhmreport_EHRSUPPORT_582566.csv
# CSV File #9 filename: 2459687_93_20220417013342_dmhmreport_EHRSUPPORT_4138013.csv
# CSV File #10 filename: 2459694_105_20220424014521_dmhmreport_EHRSUPPORT_2082480.csv
# CSV File #11 filename: 2459701_89_20220501012947_dmhmreport_EHRSUPPORT_465882.csv
# CSV File #12 filename: 2459708_267_20220508042714_dmhmreport_EHRSUPPORT_1377103.csv
# CSV File #13 filename: 2459715_100_20220515014017_dmhmreport_EHRSUPPORT_16106866.csv
# CSV File #14 filename: 2459722_84_20220522012436_dmhmreport_EHRSUPPORT_3515957.csv
# CSV File #15 filename: 2459729_84_20220529012450_dmhmreport_EHRSUPPORT_4919584.csv
# CSV File #16 filename: 2459736_100_20220605014007_dmhmreport_EHRSUPPORT_683206.csv
# CSV File #17 filename: 2459743_529_20220612084929_dmhmreport_EHRSUPPORT_28136567.csv
# CSV File #18 filename: 2459750_85_20220619012502_dmhmreport_EHRSUPPORT_189436.csv
# CSV File #19 filename: 2459757_86_20220626012633_dmhmreport_EHRSUPPORT_32127412.csv
# CSV File #20 filename: 2459764_86_20220703012644_dmhmreport_EHRSUPPORT_4376748.csv
# Directory #3 to find import files : Y:/_Kaleida_Input/ADP
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/ADP
# Directory #4 to find import files : Y:/_Kaleida_Input/ADP\Daily Time Card
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/ADP\Daily Time Card
# CSV File #1 filename: DailyTimecardReport.050421190755.csv
# CSV File #2 filename: DailyTimecardReport.051821190747.csv
# CSV File #3 filename: DailyTimecardReport.060121190842.csv
# CSV File #4 filename: DailyTimecardReport.061521190831.csv
# CSV File #5 filename: DailyTimecardReport.062921190854.csv
# CSV File #6 filename: DailyTimecardReport.071321190908.csv
# CSV File #7 filename: DailyTimecardReport.072721190859.csv
# CSV File #8 filename: DailyTimecardReport.081021190954.csv
# CSV File #9 filename: DailyTimecardReport.082421190545.csv
# CSV File #10 filename: DailyTimecardReport.090721191026.csv
# CSV File #11 filename: DailyTimecardReport.092121190806.csv
# CSV File #12 filename: DailyTimecardReport.100521190616.csv
# CSV File #13 filename: DailyTimecardReport.101921190707.csv
# CSV File #14 filename: DailyTimecardReport.110221190902.csv
# CSV File #15 filename: DailyTimecardReport.111621190810.csv
# CSV File #16 filename: DailyTimecardReport.113021190601.csv
# CSV File #17 filename: DailyTimecardReport.121421190704.csv
# CSV File #18 filename: DailyTimecardReport.122821191049.csv
# CSV File #19 filename: DailyTimecardReport.csv
# Directory #5 to find import files : Y:/_Kaleida_Input/ADP\Employee Census
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/ADP\Employee Census
# CSV File #1 filename: EmployeeCensus.043021190734.csv
# CSV File #2 filename: EmployeeCensus.053121190439.csv
# CSV File #3 filename: EmployeeCensus.063021190840.csv
# CSV File #4 filename: EmployeeCensus.073121190558.csv
# CSV File #5 filename: EmployeeCensus.083121190751.csv
# CSV File #6 filename: EmployeeCensus.093021190526.csv
# CSV File #7 filename: EmployeeCensus.103121190215.csv
# CSV File #8 filename: EmployeeCensus.113021190508.csv
# CSV File #9 filename: EmployeeCensus.123121190308.csv
# CSV File #10 filename: EmployeeCensus.csv
# Directory #6 to find import files : Y:/_Kaleida_Input/Available_Slots
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Available_Slots
# CSV File #1 filename: February 2022 Available Slot.csv
# CSV File #2 filename: January 2022 available slots.csv
# CSV File #3 filename: Main 4.12 to 10.13.csv
# CSV File #4 filename: Main 4.13 to 10.14.csv
# CSV File #5 filename: Main 4.14 to 10.15.csv
# CSV File #6 filename: Main 4.15 to 10.16.csv
# CSV File #7 filename: Main 4.16 to 10.17.csv
# CSV File #8 filename: Main 4.19 to 10.20.csv
# CSV File #9 filename: Main 4.20 to 10.21.csv
# CSV File #10 filename: Main 4.21 to 10.22.csv
# CSV File #11 filename: Main 4.22 to 10.23.csv
# CSV File #12 filename: Main 4.23 to 10.24.csv
# CSV File #13 filename: Main 4.26 to 10.27.csv
# CSV File #14 filename: Main 4.27 to 10.28.csv
# CSV File #15 filename: Main 4.28 to 10.29.csv
# CSV File #16 filename: Main 4.29 to 10.30.csv
# CSV File #17 filename: Main 4.30 to 10.31.csv
# CSV File #18 filename: Main 4_2 to 10_2.csv
# CSV File #19 filename: Main 4_5 to 10_5.csv
# CSV File #20 filename: Main 4_7 to 10_7.csv
# CSV File #21 filename: Main 5.10 to 11.11.csv
# CSV File #22 filename: Main 5.11 to 11.12.csv
# CSV File #23 filename: Main 5.12 to 11.13.csv
# CSV File #24 filename: Main 5.13 to 11.14.csv
# CSV File #25 filename: Main 5.14 to 11.15.csv
# CSV File #26 filename: Main 5.17 to 11.18.csv
# CSV File #27 filename: Main 5.18 to 11.19.csv
# CSV File #28 filename: Main 5.19 to 11.20.csv
# CSV File #29 filename: Main 5.2 to 11.2.csv
# CSV File #30 filename: Main 5.20 to 11.21.csv
# CSV File #31 filename: Main 5.21 to 11.22.csv
# CSV File #32 filename: Main 5.24 to 11.25.csv
# CSV File #33 filename: Main 5.25 to 11.26.csv
# CSV File #34 filename: Main 5.26 to 11.27.csv
# CSV File #35 filename: Main 5.27 to 11.28.csv
# CSV File #36 filename: Main 5.28 to 11.29.csv
# CSV File #37 filename: Main 5.4 to 11.4.csv
# CSV File #38 filename: Main 5.5 to 11.5.csv
# CSV File #39 filename: Main 5.6 to 11.7.csv
# CSV File #40 filename: Main 5.7 to  11.8.csv
# CSV File #41 filename: Main 6.1 to 12.1.csv
# CSV File #42 filename: Main 6.10 to 12.11.csv
# CSV File #43 filename: Main 6.11 to 12.12.csv
# CSV File #44 filename: Main 6.14 to 12.15.csv
# CSV File #45 filename: Main 6.15 to 12.16.csv
# CSV File #46 filename: Main 6.16 to 12.17.csv
# CSV File #47 filename: Main 6.17 to 12.18.csv
# CSV File #48 filename: Main 6.18 to 12.19.csv
# CSV File #49 filename: Main 6.2 to 12.2.csv
# CSV File #50 filename: Main 6.21 to 12.22.csv
# CSV File #51 filename: Main 6.22 to 12.23.csv
# CSV File #52 filename: Main 6.23 to 12.24.csv
# CSV File #53 filename: Main 6.24 to 12.25.csv
# CSV File #54 filename: Main 6.25 to 12.26.csv
# CSV File #55 filename: Main 6.28 to 12.29.csv
# CSV File #56 filename: Main 6.29 to 12.30.csv
# CSV File #57 filename: Main 6.3 to 12.4.csv
# CSV File #58 filename: Main 6.30 to 12.31.csv
# CSV File #59 filename: Main 6.4 to 12.5.csv
# CSV File #60 filename: Main 6.7 to 12.8.csv
# CSV File #61 filename: Main 6.8 to 12.9.csv
# CSV File #62 filename: Main 6.9 to 12.10.csv
# CSV File #63 filename: Main 7.1 to 1.1.csv
# CSV File #64 filename: Main 7.2 to 1.2.csv
# CSV File #65 filename: Main 7.6 to 1.7.csv
# CSV File #66 filename: Main 7.8 to 1.9.csv
# CSV File #67 filename: Main 7.9 to 1.10.csv
# CSV File #68 filename: Main 7_12 to 1_13.csv
# CSV File #69 filename: Main 7_7 to 1_8.csv
# CSV File #70 filename: March 2022 List of Available Slot.csv
# CSV File #71 filename: Sub II 4.12 to 10.13.csv
# CSV File #72 filename: Sub II 4.13 to 10.14.csv
# CSV File #73 filename: Sub II 4.14 to 10.15.csv
# CSV File #74 filename: Sub II 4.15 to 10.16.csv
# CSV File #75 filename: Sub II 4.16 to 10.17.csv
# CSV File #76 filename: Sub II 4.19 to 10.20.csv
# CSV File #77 filename: Sub II 4.20 to 10.21.csv
# CSV File #78 filename: Sub II 4.21 to 10.22.csv
# CSV File #79 filename: Sub II 4.22 to 10.23.csv
# CSV File #80 filename: Sub II 4.23 to 10.24.csv
# CSV File #81 filename: Sub II 4.26 to 10.27.csv
# CSV File #82 filename: Sub II 4.27 to 10.28.csv
# CSV File #83 filename: Sub II 4.28 to 10.29.csv
# CSV File #84 filename: Sub II 4.29 to 10.30.csv
# CSV File #85 filename: Sub II 4.30 to 10.31.csv
# CSV File #86 filename: Sub II 4.7 to 10.7.csv
# CSV File #87 filename: Sub II 4_1 to 10_2.csv
# CSV File #88 filename: Sub II 4_5 to 10_5.csv
# CSV File #89 filename: Sub II 5.10 to 11.11.csv
# CSV File #90 filename: Sub II 5.11 to 11.12.csv
# CSV File #91 filename: Sub II 5.12 to 11.13.csv
# CSV File #92 filename: Sub II 5.13 to 11.14.csv
# CSV File #93 filename: Sub II 5.14 to 11.15.csv
# CSV File #94 filename: Sub II 5.17 to 11.18.csv
# CSV File #95 filename: Sub II 5.18 to 11.19.csv
# CSV File #96 filename: Sub II 5.19 to 11.20.csv
# CSV File #97 filename: Sub II 5.2 to 11.2.csv
# CSV File #98 filename: Sub II 5.20 to 11.21.csv
# CSV File #99 filename: Sub II 5.21 to 11.22.csv
# CSV File #100 filename: Sub II 5.24 to 11.25.csv
# CSV File #101 filename: Sub II 5.25 to 11.26.csv
# CSV File #102 filename: Sub II 5.26 to 11.27.csv
# CSV File #103 filename: Sub II 5.27 to 11.28.csv
# CSV File #104 filename: SUb II 5.28 to 11.29.csv
# CSV File #105 filename: Sub II 5.4 to 11.4.csv
# CSV File #106 filename: Sub II 5.5 to 11.5.csv
# CSV File #107 filename: Sub II 5.6 to 11.7.csv
# CSV File #108 filename: Sub II 5.7 to 11.8.csv
# CSV File #109 filename: Sub II 6.1 to 12.1.csv
# CSV File #110 filename: Sub II 6.10 to 12.11.csv
# CSV File #111 filename: Sub II 6.11 to 12.12.csv
# CSV File #112 filename: Sub II 6.14 to 12.15.csv
# CSV File #113 filename: Sub II 6.15 to 12.16.csv
# CSV File #114 filename: Sub II 6.16 to 12.17.csv
# CSV File #115 filename: Sub II 6.17 to 12.18.csv
# CSV File #116 filename: Sub II 6.18 to 12.19.csv
# CSV File #117 filename: Sub II 6.2 to 12.2.csv
# CSV File #118 filename: Sub II 6.21 to 12.22.csv
# CSV File #119 filename: Sub II 6.22 to 12.23.csv
# CSV File #120 filename: Sub II 6.23 to 12.24.csv
# CSV File #121 filename: Sub II 6.24 to 12.25.csv
# CSV File #122 filename: Sub II 6.25 to 12.26.csv
# CSV File #123 filename: Sub II 6.28 to 12.29.csv
# CSV File #124 filename: Sub II 6.29 to 12.30.csv
# CSV File #125 filename: Sub II 6.3 to 12.4.csv
# CSV File #126 filename: Sub II 6.30 to 12.31.csv
# CSV File #127 filename: Sub II 6.4 to 12.5.csv
# CSV File #128 filename: Sub II 6.7 to 12.8.csv
# CSV File #129 filename: Sub II 6.8 to 12.9.csv
# CSV File #130 filename: Sub II 6.9 to 12.10.csv
# CSV File #131 filename: Sub II 7.1 to 1.1.csv
# CSV File #132 filename: Sub II 7.2 to 1.2.csv
# CSV File #133 filename: Sub II 7.6 to 1.7.csv
# CSV File #134 filename: Sub II 7.8 to 1.9.csv
# CSV File #135 filename: Sub II 7.9 to 1.10.csv
# CSV File #136 filename: Sub II 7_12 to 1_13.csv
# CSV File #137 filename: Sub II 7_7 to 1_8.csv
# CSV File #138 filename: Sub III 4_1 to 10_2.csv
# Directory #7 to find import files : Y:/_Kaleida_Input/Available_Slots_Past
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Available_Slots_Past
# CSV File #1 filename: February 2022 Available Slot.csv
# CSV File #2 filename: January 2022 available slots.csv
# CSV File #3 filename: Main 4.11.csv
# CSV File #4 filename: Main 4.12.csv
# CSV File #5 filename: Main 4.13.csv
# CSV File #6 filename: Main 4.14.csv
# CSV File #7 filename: Main 4.15.csv
# CSV File #8 filename: Main 4.18.csv
# CSV File #9 filename: Main 4.19.csv
# CSV File #10 filename: Main 4.20.csv
# CSV File #11 filename: Main 4.21.csv
# CSV File #12 filename: Main 4.22.csv
# CSV File #13 filename: Main 4.25.csv
# CSV File #14 filename: Main 4.26.csv
# CSV File #15 filename: Main 4.27.csv
# CSV File #16 filename: Main 4.28..csv
# CSV File #17 filename: Main 4.29.csv
# CSV File #18 filename: Main 4.5.csv
# CSV File #19 filename: Main 4.7 to 4.8.csv
# CSV File #20 filename: Main 5.10.csv
# CSV File #21 filename: Main 5.11.csv
# CSV File #22 filename: Main 5.12.csv
# CSV File #23 filename: Main 5.13.csv
# CSV File #24 filename: Main 5.16.csv
# CSV File #25 filename: Main 5.17.csv
# CSV File #26 filename: Main 5.18.csv
# CSV File #27 filename: Main 5.19.csv
# CSV File #28 filename: Main 5.2.csv
# CSV File #29 filename: Main 5.20.csv
# CSV File #30 filename: Main 5.23.csv
# CSV File #31 filename: Main 5.24.csv
# CSV File #32 filename: Main 5.25.csv
# CSV File #33 filename: Main 5.26.csv
# CSV File #34 filename: Main 5.27 to 5.30.csv
# CSV File #35 filename: Main 5.3.csv
# CSV File #36 filename: Main 5.31.csv
# CSV File #37 filename: Main 5.4.csv
# CSV File #38 filename: Main 5.5.csv
# CSV File #39 filename: Main 5.6.csv
# CSV File #40 filename: Main 5.9.csv
# CSV File #41 filename: Main 6.1.csv
# CSV File #42 filename: Main 6.10.csv
# CSV File #43 filename: Main 6.13.csv
# CSV File #44 filename: Main 6.14.csv
# CSV File #45 filename: Main 6.15.csv
# CSV File #46 filename: Main 6.16.csv
# CSV File #47 filename: Main 6.17.csv
# CSV File #48 filename: Main 6.2.csv
# CSV File #49 filename: Main 6.20.csv
# CSV File #50 filename: Main 6.21.csv
# CSV File #51 filename: Main 6.22.csv
# CSV File #52 filename: Main 6.23.csv
# CSV File #53 filename: Main 6.24.csv
# CSV File #54 filename: Main 6.27.csv
# CSV File #55 filename: Main 6.28.csv
# CSV File #56 filename: Main 6.29.csv
# CSV File #57 filename: Main 6.3.csv
# CSV File #58 filename: Main 6.30.csv
# CSV File #59 filename: Main 6.6.csv
# CSV File #60 filename: Main 6.7.csv
# CSV File #61 filename: Main 6.8.csv
# CSV File #62 filename: Main 6.9.csv
# CSV File #63 filename: Main 7.1.csv
# CSV File #64 filename: Main 7.11.csv
# CSV File #65 filename: Main 7.12.csv
# CSV File #66 filename: Main 7.4.csv
# CSV File #67 filename: Main 7.5.csv
# CSV File #68 filename: Main 7.6.csv
# CSV File #69 filename: Main 7.7.csv
# CSV File #70 filename: Main 7.8.csv
# CSV File #71 filename: March 2022 List of Available Slot.csv
# CSV File #72 filename: Sub II 4.11.csv
# CSV File #73 filename: Sub II 4.12.csv
# CSV File #74 filename: Sub II 4.13.csv
# CSV File #75 filename: Sub II 4.14.csv
# CSV File #76 filename: Sub II 4.15.csv
# CSV File #77 filename: Sub II 4.18.csv
# CSV File #78 filename: Sub II 4.19.csv
# CSV File #79 filename: Sub II 4.20.csv
# CSV File #80 filename: Sub II 4.21.csv
# CSV File #81 filename: Sub II 4.22.csv
# CSV File #82 filename: Sub II 4.25.csv
# CSV File #83 filename: Sub II 4.26.csv
# CSV File #84 filename: Sub II 4.27.csv
# CSV File #85 filename: Sub II 4.28.csv
# CSV File #86 filename: Sub II 4.29.csv
# CSV File #87 filename: Sub II 4.5.csv
# CSV File #88 filename: Sub II 4.7 to 4.8.csv
# CSV File #89 filename: Sub II 5.10.csv
# CSV File #90 filename: Sub II 5.11.csv
# CSV File #91 filename: Sub II 5.12.csv
# CSV File #92 filename: Sub II 5.13.csv
# CSV File #93 filename: Sub II 5.16.csv
# CSV File #94 filename: Sub II 5.17.csv
# CSV File #95 filename: Sub II 5.18.csv
# CSV File #96 filename: Sub II 5.19.csv
# CSV File #97 filename: Sub II 5.2.csv
# CSV File #98 filename: Sub II 5.20.csv
# CSV File #99 filename: Sub II 5.23.csv
# CSV File #100 filename: Sub II 5.24.csv
# CSV File #101 filename: Sub II 5.25.csv
# CSV File #102 filename: Sub II 5.26.csv
# CSV File #103 filename: Sub II 5.27 to 5.30.csv
# CSV File #104 filename: Sub II 5.3.csv
# CSV File #105 filename: Sub II 5.31.csv
# CSV File #106 filename: Sub II 5.4.csv
# CSV File #107 filename: Sub II 5.5.csv
# CSV File #108 filename: Sub II 5.6.csv
# CSV File #109 filename: Sub II 5.9.csv
# CSV File #110 filename: Sub II 6.1.csv
# CSV File #111 filename: Sub II 6.10.csv
# CSV File #112 filename: Sub II 6.13.csv
# CSV File #113 filename: Sub II 6.14.csv
# CSV File #114 filename: Sub II 6.15.csv
# CSV File #115 filename: Sub II 6.16.csv
# CSV File #116 filename: Sub II 6.17.csv
# CSV File #117 filename: Sub II 6.2.csv
# CSV File #118 filename: Sub II 6.20.csv
# CSV File #119 filename: Sub II 6.21.csv
# CSV File #120 filename: Sub II 6.22.csv
# CSV File #121 filename: Sub II 6.23.csv
# CSV File #122 filename: Sub II 6.24.csv
# CSV File #123 filename: Sub II 6.27.csv
# CSV File #124 filename: Sub II 6.28.csv
# CSV File #125 filename: Sub II 6.29.csv
# CSV File #126 filename: Sub II 6.3.csv
# CSV File #127 filename: Sub II 6.30.csv
# CSV File #128 filename: Sub II 6.6.csv
# CSV File #129 filename: Sub II 6.7.csv
# CSV File #130 filename: Sub II 6.8.csv
# CSV File #131 filename: Sub II 6.9.csv
# CSV File #132 filename: Sub II 7.1.csv
# CSV File #133 filename: Sub II 7.11.csv
# CSV File #134 filename: Sub II 7.12.csv
# CSV File #135 filename: Sub II 7.4.csv
# CSV File #136 filename: Sub II 7.5.csv
# CSV File #137 filename: Sub II 7.6.csv
# CSV File #138 filename: Sub II 7.7.csv
# CSV File #139 filename: Sub II 7.8.csv
# Directory #8 to find import files : Y:/_Kaleida_Input/Call Center
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Call Center
# Directory #9 to find import files : Y:/_Kaleida_Input/CPT Visit
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/CPT Visit
# Directory #10 to find import files : Y:/_Kaleida_Input/DailyAppointments
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/DailyAppointments
# CSV File #1 filename: April 2019.csv
# CSV File #2 filename: April 2020.csv
# CSV File #3 filename: April 2021.csv
# CSV File #4 filename: April 2022.csv
# CSV File #5 filename: August 2019.csv
# CSV File #6 filename: August 2020.csv
# CSV File #7 filename: August 2021.csv
# CSV File #8 filename: August 2022.csv
# CSV File #9 filename: December 2019.csv
# CSV File #10 filename: December 2020.csv
# CSV File #11 filename: December 2021.csv
# CSV File #12 filename: February 2019.csv
# CSV File #13 filename: february 2020.csv
# CSV File #14 filename: February 2021.csv
# CSV File #15 filename: February 2022.csv
# CSV File #16 filename: January 2019.csv
# CSV File #17 filename: January 2020.csv
# CSV File #18 filename: January 2021.csv
# CSV File #19 filename: January 2022.csv
# CSV File #20 filename: July 2019.csv
# CSV File #21 filename: July 2020.csv
# CSV File #22 filename: July 2021.csv
# CSV File #23 filename: July 2022.csv
# CSV File #24 filename: June 2019.csv
# CSV File #25 filename: June 2020.csv
# CSV File #26 filename: June 2021.csv
# CSV File #27 filename: June 2022.csv
# CSV File #28 filename: March 2019.csv
# CSV File #29 filename: March 2020.csv
# CSV File #30 filename: March 2021.csv
# CSV File #31 filename: March 2022.csv
# CSV File #32 filename: May 2019.csv
# CSV File #33 filename: May 2020.csv
# CSV File #34 filename: May 2021.csv
# CSV File #35 filename: May 2022.csv
# CSV File #36 filename: November 2019.csv
# CSV File #37 filename: November 2020.csv
# CSV File #38 filename: November 2021.csv
# CSV File #39 filename: October 2019.csv
# CSV File #40 filename: October 2020.csv
# CSV File #41 filename: October 2021.csv
# CSV File #42 filename: September 2019.csv
# CSV File #43 filename: September 2020.csv
# CSV File #44 filename: September 2021.csv
# CSV File #45 filename: Sub II 2019.csv
# CSV File #46 filename: Sub II 2020.csv
# CSV File #47 filename: Sub II 2021.csv
# CSV File #48 filename: Sub II 2022 YTD 8_16_22.csv
# Directory #11 to find import files : Y:/_Kaleida_Input/DailyCPT
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/DailyCPT
# Directory #12 to find import files : Y:/_Kaleida_Input/DailyMultipleAppointmentSameDay
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/DailyMultipleAppointmentSameDay
# Directory #13 to find import files : Y:/_Kaleida_Input/DailyScheduledOfficeAppointmentVisit
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/DailyScheduledOfficeAppointmentVisit
# Directory #14 to find import files : Y:/_Kaleida_Input/DailySuperbill
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/DailySuperbill
# Directory #15 to find import files : Y:/_Kaleida_Input/EmployeePerformanceforAdminTaskAudit
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/EmployeePerformanceforAdminTaskAudit
# Directory #16 to find import files : Y:/_Kaleida_Input/HistoryofTransaction
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/HistoryofTransaction
# Directory #17 to find import files : Y:/_Kaleida_Input/Hx
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Hx
# Directory #18 to find import files : Y:/_Kaleida_Input/HXDX
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/HXDX
# CSV File #1 filename: 2018 Sub II.csv
# CSV File #2 filename: 65 April 2019.csv
# CSV File #3 filename: 65 April 2020.csv
# CSV File #4 filename: 65 April 2021.csv
# CSV File #5 filename: 65 April 2022.csv
# CSV File #6 filename: 65 August 2019.csv
# CSV File #7 filename: 65 August 2020.csv
# CSV File #8 filename: 65 August 2021.csv
# CSV File #9 filename: 65 December 2019.csv
# CSV File #10 filename: 65 December 2020.csv
# CSV File #11 filename: 65 December 2021.csv
# CSV File #12 filename: 65 Feb 2020.csv
# CSV File #13 filename: 65 February 2019.csv
# CSV File #14 filename: 65 February 2021.csv
# CSV File #15 filename: 65 February 2022.csv
# CSV File #16 filename: 65 Jan 2020.csv
# CSV File #17 filename: 65 January 2019.csv
# CSV File #18 filename: 65 January 2021.csv
# CSV File #19 filename: 65 January 2022.csv
# CSV File #20 filename: 65 July 2019.csv
# CSV File #21 filename: 65 July 2020.csv
# CSV File #22 filename: 65 July 2021.csv
# CSV File #23 filename: 65 July 2022.csv
# CSV File #24 filename: 65 June 2019.csv
# CSV File #25 filename: 65 June 2020.csv
# CSV File #26 filename: 65 June 2021.csv
# CSV File #27 filename: 65 June 2022.csv
# CSV File #28 filename: 65 Main 8.10.csv
# CSV File #29 filename: 65 Main 8.11.csv
# CSV File #30 filename: 65 Main 8.12.csv
# CSV File #31 filename: 65 Main 8.15.csv
# CSV File #32 filename: 65 Main 8.16.csv
# CSV File #33 filename: 65 March 2019.csv
# CSV File #34 filename: 65 March 2020.csv
# CSV File #35 filename: 65 March 2021.csv
# CSV File #36 filename: 65 March 2022.csv
# CSV File #37 filename: 65 May 2019.csv
# CSV File #38 filename: 65 May 2020.csv
# CSV File #39 filename: 65 May 2021.csv
# CSV File #40 filename: 65 May 2022.csv
# CSV File #41 filename: 65 November 2019.csv
# CSV File #42 filename: 65 November 2020.csv
# CSV File #43 filename: 65 November 2021.csv
# CSV File #44 filename: 65 October 2019.csv
# CSV File #45 filename: 65 October 2020.csv
# CSV File #46 filename: 65 October 2021.csv
# CSV File #47 filename: 65 September 2019.csv
# CSV File #48 filename: 65 September 2020.csv
# CSV File #49 filename: 65 September 2021.csv
# CSV File #50 filename: 65 Sub II 2018.csv
# CSV File #51 filename: 65 Sub II 2019.csv
# CSV File #52 filename: 65 Sub II 2020.csv
# CSV File #53 filename: 65 Sub II 2021.csv
# CSV File #54 filename: 65 Sub II 8.10.csv
# CSV File #55 filename: 65 Sub II 8.12.csv
# CSV File #56 filename: 65 Sub II 8.15.csv
# CSV File #57 filename: 65 Sub II 8.16.csv
# CSV File #58 filename: 65 Sub II Jan to July 2022.csv
# Directory #19 to find import files : Y:/_Kaleida_Input/HxTransaction
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/HxTransaction
# Directory #20 to find import files : Y:/_Kaleida_Input/Incident
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Incident
# Directory #21 to find import files : Y:/_Kaleida_Input/InsuranceIDVerificationAudit
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/InsuranceIDVerificationAudit
# Directory #22 to find import files : Y:/_Kaleida_Input/LungCancerScreeningTracker
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/LungCancerScreeningTracker
# Directory #23 to find import files : Y:/_Kaleida_Input/MissingNPIAudit
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/MissingNPIAudit
# Directory #24 to find import files : Y:/_Kaleida_Input/OncologyNavigation
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OncologyNavigation
# Directory #25 to find import files : Y:/_Kaleida_Input/outstandinglabs_removed
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/outstandinglabs_removed
# Directory #26 to find import files : Y:/_Kaleida_Input/OutstandingOpenDocuments
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpenDocuments
# Directory #27 to find import files : Y:/_Kaleida_Input/OutstandingOpenLabs
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpenLabs
# Directory #28 to find import files : Y:/_Kaleida_Input/OutstandingOpenOrders
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpenOrders
# Directory #29 to find import files : Y:/_Kaleida_Input/OutstandingOpentoDos
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpentoDos
# Directory #30 to find import files : Y:/_Kaleida_Input/OutstandingOpenTriages
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpenTriages
# Directory #31 to find import files : Y:/_Kaleida_Input/OutstandingOpenXrays
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/OutstandingOpenXrays
# Directory #32 to find import files : Y:/_Kaleida_Input/PatientExperience
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/PatientExperience
# Directory #33 to find import files : Y:/_Kaleida_Input/PatientInformation
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/PatientInformation
# Directory #34 to find import files : Y:/_Kaleida_Input/PatientInformation\Main18Under
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/PatientInformation\Main18Under
# CSV File #1 filename: 2459588_144_20220108022428_dmhmreport_EHRSUPPORT_2697197.csv
# CSV File #2 filename: 2459605_158_20220125023834_dmhmreport_JENNIFERDUP_3361737.csv
# CSV File #3 filename: 2459612_209_20220201032944_dmhmreport_JENNIFERDUP_4325181.csv
# CSV File #4 filename: 2459612_20_20220201002044_dmhmreport_DAVIDK_433365.csv
# CSV File #5 filename: 2459612_21_20220201002151_dmhmreport_DAVIDK_499798.csv
# CSV File #6 filename: 2459619_104_20220208014459_dmhmreport_JENNIFERDUP_5855729.csv
# CSV File #7 filename: 2459619_18_20220208001819_dmhmreport_DAVIDK_1831086.csv
# CSV File #8 filename: 2459619_19_20220208001921_dmhmreport_DAVIDK_2038850.csv
# CSV File #9 filename: 2459626_122_20220215020227_dmhmreport_JENNIFERDUP_2584879.csv
# CSV File #10 filename: 2459626_22_20220215002203_dmhmreport_DAVIDK_38819.csv
# CSV File #11 filename: 2459626_22_20220215002253_dmhmreport_DAVIDK_5113408.csv
# CSV File #12 filename: 2459633_124_20220222020422_dmhmreport_JENNIFERDUP_21132572.csv
# CSV File #13 filename: 2459633_16_20220222001618_dmhmreport_DAVIDK_1714096.csv
# CSV File #14 filename: 2459633_17_20220222001735_dmhmreport_DAVIDK_3418948.csv
# CSV File #15 filename: 2459640_15_20220301001518_dmhmreport_DAVIDK_1729049.csv
# CSV File #16 filename: 2459640_17_20220301001720_dmhmreport_DAVIDK_1837058.csv
# CSV File #17 filename: 2459641_133_20220302021357_dmhmreport_JENNIFERDUP_56136086.csv
# CSV File #18 filename: 2459647_118_20220308015854_dmhmreport_JENNIFERDUP_5226934.csv
# CSV File #19 filename: 2459647_34_20220308003437_dmhmreport_DAVIDK_3632288.csv
# CSV File #20 filename: 2459647_35_20220308003545_dmhmreport_DAVIDK_4435478.csv
# CSV File #21 filename: 2459654_129_20220315020902_dmhmreport_JENNIFERDUP_2103776.csv
# CSV File #22 filename: 2459654_19_20220315001932_dmhmreport_DAVIDK_306521.csv
# CSV File #23 filename: 2459654_20_20220315002024_dmhmreport_DAVIDK_2310723.csv
# CSV File #24 filename: 2459661_16_20220322001638_dmhmreport_DAVIDK_3632411.csv
# CSV File #25 filename: 2459661_17_20220322001729_dmhmreport_DAVIDK_2738465.csv
# CSV File #26 filename: 2459662_100_20220323014037_dmhmreport_JENNIFERDUP_3528384.csv
# CSV File #27 filename: 2459668_115_20220329015543_dmhmreport_JENNIFERDUP_43128332.csv
# CSV File #28 filename: 2459668_32_20220329003239_dmhmreport_DAVIDK_3734607.csv
# CSV File #29 filename: 2459668_33_20220329003329_dmhmreport_DAVIDK_2836880.csv
# CSV File #30 filename: 2459675_139_20220405021929_dmhmreport_JENNIFERDUP_28126786.csv
# CSV File #31 filename: 2459675_14_20220405001429_dmhmreport_DAVIDK_2822850.csv
# CSV File #32 filename: 2459682_116_20220412015648_dmhmreport_JENNIFERDUP_4659373.csv
# CSV File #33 filename: 2459682_12_20220412001221_dmhmreport_DAVIDK_20802.csv
# CSV File #34 filename: 2459689_103_20220419014345_dmhmreport_JENNIFERDUP_4492272.csv
# CSV File #35 filename: 2459689_12_20220419001226_dmhmreport_DAVIDK_2530599.csv
# CSV File #36 filename: 2459696_116_20220426015650_dmhmreport_JENNIFERDUP_4992385.csv
# CSV File #37 filename: 2459696_12_20220426001225_dmhmreport_DAVIDK_2320695.csv
# CSV File #38 filename: 2459703_111_20220503015122_dmhmreport_JENNIFERDUP_2029802.csv
# CSV File #39 filename: 2459703_8_20220503000836_dmhmreport_DAVIDK_3421354.csv
# CSV File #40 filename: 2459710_115_20220510015541_dmhmreport_JENNIFERDUP_39133312.csv
# CSV File #41 filename: 2459710_7_20220510000801_dmhmreport_DAVIDK_5946802.csv
# CSV File #42 filename: 2459717_107_20220517014702_dmhmreport_JENNIFERDUP_04504.csv
# CSV File #43 filename: 2459717_18_20220517001830_dmhmreport_DAVIDK_2845364.csv
# CSV File #44 filename: 2459724_102_20220524014250_dmhmreport_JENNIFERDUP_4965729.csv
# CSV File #45 filename: 2459724_24_20220524002412_dmhmreport_DAVIDK_1134348.csv
# CSV File #46 filename: 2459731_103_20220531014338_dmhmreport_JENNIFERDUP_38106016.csv
# CSV File #47 filename: 2459731_20_20220531002018_dmhmreport_DAVIDK_178381.csv
# CSV File #48 filename: 2459738_107_20220607014749_dmhmreport_JENNIFERDUP_48132209.csv
# CSV File #49 filename: 2459738_12_20220607001217_dmhmreport_DAVIDK_1615568.csv
# CSV File #50 filename: 2459745_10_20220614001059_dmhmreport_DAVIDK_5744004.csv
# CSV File #51 filename: 2459745_122_20220614020225_dmhmreport_JENNIFERDUP_2435128.csv
# CSV File #52 filename: 2459752_107_20220621014800_dmhmreport_JENNIFERDUP_58120923.csv
# CSV File #53 filename: 2459752_7_20220621000733_dmhmreport_DAVIDK_324883.csv
# CSV File #54 filename: 2459759_109_20220628014930_dmhmreport_JENNIFERDUP_28105215.csv
# CSV File #55 filename: 2459759_8_20220628000822_dmhmreport_DAVIDK_2149121.csv
# CSV File #56 filename: 2459766_143_20220705022337_dmhmreport_JENNIFERDUP_36130429.csv
# CSV File #57 filename: 2459766_17_20220705001724_dmhmreport_DAVIDK_2231437.csv
# CSV File #58 filename: 2459773_108_20220712014851_dmhmreport_JENNIFERDUP_50125094.csv
# CSV File #59 filename: 2459773_14_20220712001444_dmhmreport_DAVIDK_4320319.csv
# CSV File #60 filename: Patient Info All Ages All Status but Active.csv
# Directory #35 to find import files : Y:/_Kaleida_Input/PaymentMismatch
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/PaymentMismatch
# Directory #36 to find import files : Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Pre-surgicalFinancialClearance
# Directory #37 to find import files : Y:/_Kaleida_Input/ProviderPanel
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/ProviderPanel
# Directory #38 to find import files : Y:/_Kaleida_Input/Quality
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Quality
# Directory #39 to find import files : Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVisitReport
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Quality\PrimaryCareAnnualVisitReport
# CSV File #1 filename: 2459275_258_20210301041828_dmhmreport_EHRSUPPORT_20102675.csv
# CSV File #2 filename: 2459276_34_20210302003421_dmhmreport_EHRSUPPORT_1936599.csv
# CSV File #3 filename: 2459276_42_20210302004248_dmhmreport_EHRSUPPORT_476587.csv
# CSV File #4 filename: 2459306_344_20210401054505_dmhmreport_EHRSUPPORT_5659833.csv
# CSV File #5 filename: 2459306_44_20210401004454_dmhmreport_EHRSUPPORT_5237285.csv
# CSV File #6 filename: 2459306_59_20210401005952_dmhmreport_EHRSUPPORT_5143739.csv
# CSV File #7 filename: 2459336_27_20210501002734_dmhmreport_EHRSUPPORT_334384.csv
# CSV File #8 filename: 2459336_292_20210501045259_dmhmreport_EHRSUPPORT_5289514.csv
# CSV File #9 filename: 2459336_39_20210501003909_dmhmreport_EHRSUPPORT_726698.csv
# CSV File #10 filename: 2459346_563_dmhmrep_ROBERTA_47126639.csv
# CSV File #11 filename: 2459347_496_dmhmrep_ROBERTA_46134641.csv
# CSV File #12 filename: 2459347_529_dmhmrep_ROBERTA_4020659.csv
# CSV File #13 filename: 2459348_522_dmhmrep_ROBERTA_5835924.csv
# CSV File #14 filename: 2459367_291_20210601045109_dmhmreport_EHRSUPPORT_012904.csv
# CSV File #15 filename: 2459367_33_20210601003400_dmhmreport_EHRSUPPORT_5814395.csv
# CSV File #16 filename: 2459367_44_20210601004451_dmhmreport_EHRSUPPORT_5029134.csv
# CSV File #17 filename: 2459397_322_20210701052229_dmhmreport_EHRSUPPORT_2348145.csv
# CSV File #18 filename: 2459397_41_20210701004138_dmhmreport_EHRSUPPORT_3725242.csv
# CSV File #19 filename: 2459397_54_20210701005423_dmhmreport_EHRSUPPORT_2140565.csv
# CSV File #20 filename: 2459428_32_20210801003245_dmhmreport_EHRSUPPORT_449705.csv
# CSV File #21 filename: 2459428_367_20210801060719_dmhmreport_EHRSUPPORT_1144537.csv
# CSV File #22 filename: 2459428_43_20210801004313_dmhmreport_EHRSUPPORT_1226611.csv
# CSV File #23 filename: 2459459_329_20210901052915_dmhmreport_EHRSUPPORT_6121399.csv
# CSV File #24 filename: 2459459_54_20210901005424_dmhmreport_EHRSUPPORT_2330304.csv
# CSV File #25 filename: 2459459_73_20210901011320_dmhmreport_EHRSUPPORT_183400.csv
# CSV File #26 filename: 2459489_360_20211001060009_dmhmreport_EHRSUPPORT_119159.csv
# CSV File #27 filename: 2459489_47_20211001004747_dmhmreport_EHRSUPPORT_4631150.csv
# CSV File #28 filename: 2459489_62_20211001010214_dmhmreport_EHRSUPPORT_139427.csv
# CSV File #29 filename: 2459520_362_20211101060232_dmhmreport_EHRSUPPORT_2481136.csv
# CSV File #30 filename: 2459520_40_20211101004055_dmhmreport_EHRSUPPORT_5318172.csv
# CSV File #31 filename: 2459520_54_20211101005439_dmhmreport_EHRSUPPORT_3836059.csv
# CSV File #32 filename: 2459550_375_20211201061529_dmhmreport_EHRSUPPORT_2128918.csv
# CSV File #33 filename: 2459550_44_20211201004428_dmhmreport_EHRSUPPORT_2744668.csv
# CSV File #34 filename: 2459550_57_20211201005705_dmhmreport_EHRSUPPORT_313122.csv
# CSV File #35 filename: 2459612_33_20220201003332_dmhmreport_EHRSUPPORT_3033211.csv
# CSV File #36 filename: 2459612_39_20220201003948_dmhmreport_EHRSUPPORT_4548543.csv
# CSV File #37 filename: 2459612_532_20220201085244_dmhmreport_EHRSUPPORT_3424247.csv
# CSV File #38 filename: 2459640_51_20220301005105_dmhmreport_EHRSUPPORT_425889.csv
# CSV File #39 filename: 2459640_53_20220301005341_dmhmreport_EHRSUPPORT_3942776.csv
# CSV File #40 filename: 2459641_376_20220302061611_dmhmreport_EHRSUPPORT_234503.csv
# CSV File #41 filename: 2459671_62_20220401010243_dmhmreport_EHRSUPPORT_428943.csv
# CSV File #42 filename: 2459671_77_20220401011759_dmhmreport_EHRSUPPORT_5743399.csv
# CSV File #43 filename: 2459672_361_20220402060116_dmhmreport_EHRSUPPORT_832432.csv
# CSV File #44 filename: 2459701_33_20220501003328_dmhmreport_EHRSUPPORT_27874.csv
# CSV File #45 filename: 2459701_498_20220501081829_dmhmreport_EHRSUPPORT_2243187.csv
# CSV File #46 filename: 2459732_387_20220601062745_dmhmreport_EHRSUPPORT_3850985.csv
# CSV File #47 filename: 2459732_65_20220601010518_dmhmreport_EHRSUPPORT_1730697.csv
# CSV File #48 filename: 2459762_429_20220701070935_dmhmreport_EHRSUPPORT_2933347.csv
# CSV File #49 filename: December Report.csv
# Directory #40 to find import files : Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/RCM-EDDandAntepartumBilling
# Directory #41 to find import files : Y:/_Kaleida_Input/RCM-InpatientCharges
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/RCM-InpatientCharges
# Directory #42 to find import files : Y:/_Kaleida_Input/RCM_Adujstments
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/RCM_Adujstments
# CSV File #1 filename: GP April 2022 Adjustments.csv
# CSV File #2 filename: GP August 2021 Adjustments.csv
# CSV File #3 filename: GP December 2021 Adjustments.csv
# CSV File #4 filename: GP February 2022 Adjustments.csv
# CSV File #5 filename: GP January 2022 Adjustments.csv
# CSV File #6 filename: GP July 2021 Adjustments.csv
# CSV File #7 filename: GP June 2021 Adjustments.csv
# CSV File #8 filename: GP June 2022 Adjustments.csv
# CSV File #9 filename: GP March 2022 Adjustments.csv
# CSV File #10 filename: GP May 2021 Adjustments.csv
# CSV File #11 filename: GP May 2022 Adjustments.csv
# CSV File #12 filename: GP November 2021 Adjustments.csv
# CSV File #13 filename: GP October 2021 Adjustments.csv
# CSV File #14 filename: GP September 2021 Adjustments.csv
# CSV File #15 filename: Medent Export Adj Report October GPPC Main.csv
# CSV File #16 filename: Sub 1 April 2022 Adjustments.csv
# CSV File #17 filename: Sub 1 August 2021 Adjustments.csv
# CSV File #18 filename: Sub 1 December 2021 Adjustments.csv
# CSV File #19 filename: Sub 1 February 2022 Adjustments.csv
# CSV File #20 filename: Sub 1 July 2021 Adjustments.csv
# CSV File #21 filename: Sub 1 June 2021 Adjustments.csv
# CSV File #22 filename: Sub 1 June 2022 Adjustments.csv
# CSV File #23 filename: Sub 1 March 2022 Adjustments.csv
# CSV File #24 filename: Sub 1 May 2021 Adjustments.csv
# CSV File #25 filename: Sub 1 May 2022 Adjustments.csv
# CSV File #26 filename: Sub 1 November 2021 Adjustments.csv
# CSV File #27 filename: Sub 1 October 2021 Adjustments.csv
# CSV File #28 filename: Sub 1 September 2021 Adjustments.csv
# CSV File #29 filename: Sub 2 April 2022 Adjustments.csv
# CSV File #30 filename: Sub 2 August 2021 Adjustments.csv
# CSV File #31 filename: Sub 2 December 2021 Adjustments.csv
# CSV File #32 filename: Sub 2 February 2022 Adjustments.csv
# CSV File #33 filename: Sub 2 January 2022 Adjustments.csv
# CSV File #34 filename: Sub 2 July 2021 Adjustments.csv
# CSV File #35 filename: Sub 2 June 2021 Adjustments.csv
# CSV File #36 filename: Sub 2 June 2022 Adjustments.csv
# CSV File #37 filename: Sub 2 March 2022 Adjustments.csv
# CSV File #38 filename: Sub 2 May 2021 Adjustments.csv
# CSV File #39 filename: Sub 2 May 2022 Adjustments.csv
# CSV File #40 filename: Sub 2 November 2021 Adjustments.csv
# CSV File #41 filename: Sub 2 October 2021 Adjustments.csv
# CSV File #42 filename: Sub 2 September 2021 Adjustments.csv
# CSV File #43 filename: Sub 3 April 2022 Adjustments.csv
# CSV File #44 filename: Sub 3 August 2021 Adjustments.csv
# CSV File #45 filename: Sub 3 December 2021 Adjustments.csv
# CSV File #46 filename: Sub 3 February 2022 Adjustments.csv
# CSV File #47 filename: Sub 3 January 2022 Adjustments.csv
# CSV File #48 filename: Sub 3 July 2021 Adjustments.csv
# CSV File #49 filename: Sub 3 June 2021 Adjustments.csv
# CSV File #50 filename: Sub 3 June 2022 Adjustments.csv
# CSV File #51 filename: Sub 3 March 2022 Adjustments.csv
# CSV File #52 filename: Sub 3 May 2021 Adjustments.csv
# CSV File #53 filename: Sub 3 May 2022 Adjustments.csv
# CSV File #54 filename: Sub 3 November 2021 Adjustments.csv
# CSV File #55 filename: Sub 3 October 2021 Adjustments.csv
# CSV File #56 filename: Sub 3 September 2021 Adjustments.csv
# Directory #43 to find import files : Y:/_Kaleida_Input/RCM_Productivity
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/RCM_Productivity
# CSV File #1 filename: 2021_Imports By Month (2020 Rates).csv
# CSV File #2 filename: April 2022 Productivity.csv
# CSV File #3 filename: February 2022 Productivity.csv
# CSV File #4 filename: January 2022 Productivity.csv
# CSV File #5 filename: June 2022 Productivity.csv
# CSV File #6 filename: March 2022 Productivity.csv
# CSV File #7 filename: May 2022 Productivity.csv
# CSV File #8 filename: Sub 1 April 2022.csv
# CSV File #9 filename: Sub 1 February 2022.csv
# CSV File #10 filename: Sub 1 January 2022.csv
# CSV File #11 filename: Sub 1 March 2022.csv
# CSV File #12 filename: Sub II April 2022.csv
# CSV File #13 filename: Sub II February 2022.csv
# CSV File #14 filename: Sub II January 2022.csv
# CSV File #15 filename: Sub II June 2022.csv
# CSV File #16 filename: Sub II March 2022.csv
# CSV File #17 filename: Sub II May 2022.csv
# Directory #44 to find import files : Y:/_Kaleida_Input/Referrals - Recommendation
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/Referrals - Recommendation
# Directory #45 to find import files : Y:/_Kaleida_Input/ReferringProviders
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/ReferringProviders
# Directory #46 to find import files : Y:/_Kaleida_Input/SurgicalAppointmentSummar2DaysAgo
#
# CSV Files to Import from Directory: Y:/_Kaleida_Input/SurgicalAppointmentSummar2DaysAgo
# CSV File #1 filename: 2459258_656_dmhmrep_MICHAELO_41146806.csv
# CSV File #2 filename: 2459258_657_dmhmrep_MICHAELO_3623363.csv
# CSV File #3 filename: 2459259_72_20210213011221_dmhmreport_MICHAELO_1918694.csv
# CSV File #4 filename: 2459259_84_20210213012436_dmhmreport_EHRSUPPORT_34144238.csv
# CSV File #5 filename: 2459260_346_20210214054615_dmhmreport_EHRSUPPORT_1490842.csv
# CSV File #6 filename: 2459260_34_20210214003457_dmhmreport_MICHAELO_5535058.csv
# CSV File #7 filename: 2459261_108_20210215014834_dmhmreport_EHRSUPPORT_3058120.csv
# CSV File #8 filename: 2459261_32_20210215003205_dmhmreport_MICHAELO_331442.csv
# CSV File #9 filename: 2459262_85_20210216012515_dmhmreport_EHRSUPPORT_1419310.csv
# CSV File #10 filename: 2459263_85_20210217012508_dmhmreport_EHRSUPPORT_712292.csv
# CSV File #11 filename: 2459264_107_20210218014708_dmhmreport_EHRSUPPORT_2111206.csv
# CSV File #12 filename: 2459265_117_20210219015725_dmhmreport_EHRSUPPORT_195157.csv
# CSV File #13 filename: 2459266_124_20210220020407_dmhmreport_EHRSUPPORT_5101165.csv
# CSV File #14 filename: 2459267_87_20210221012730_dmhmreport_EHRSUPPORT_20110196.csv
# CSV File #15 filename: 2459268_82_20210222012258_dmhmreport_EHRSUPPORT_5711451.csv
# CSV File #16 filename: 2459269_146_20210223022631_dmhmreport_EHRSUPPORT_2991841.csv
# CSV File #17 filename: 2459270_84_20210224012458_dmhmreport_EHRSUPPORT_5746348.csv
# CSV File #18 filename: 2459271_127_20210225020726_dmhmreport_EHRSUPPORT_2634363.csv
# CSV File #19 filename: 2459272_85_20210226012535_dmhmreport_EHRSUPPORT_33138346.csv
# CSV File #20 filename: 2459273_85_20210227012541_dmhmreport_EHRSUPPORT_3978967.csv
# CSV File #21 filename: 2459275_85_20210301012538_dmhmreport_EHRSUPPORT_36135169.csv
# CSV File #22 filename: 2459276_85_20210302012518_dmhmreport_EHRSUPPORT_1685734.csv
# CSV File #23 filename: 2459277_85_20210303012515_dmhmreport_EHRSUPPORT_14128395.csv
# CSV File #24 filename: 2459278_22_20210304002203_dmhmreport_MICHAELO_243307.csv
# CSV File #25 filename: 2459278_85_20210304012524_dmhmreport_EHRSUPPORT_22131418.csv
# CSV File #26 filename: 2459279_138_20210305021811_dmhmreport_EHRSUPPORT_883322.csv
# CSV File #27 filename: 2459279_35_20210305003524_dmhmreport_MICHAELO_2328092.csv
# CSV File #28 filename: 2459280_100_20210306014039_dmhmreport_EHRSUPPORT_3815659.csv
# CSV File #29 filename: 2459280_18_20210306001801_dmhmreport_MICHAELO_031999.csv
# CSV File #30 filename: 2459281_115_20210307015520_dmhmreport_EHRSUPPORT_16108149.csv
# CSV File #31 filename: 2459281_17_20210307001800_dmhmreport_MICHAELO_5813360.csv
# CSV File #32 filename: 2459282_122_20210308020210_dmhmreport_EHRSUPPORT_1057576.csv
# CSV File #33 filename: 2459282_25_20210308002559_dmhmreport_MICHAELO_5827423.csv
# CSV File #34 filename: 2459283_23_20210309002307_dmhmreport_MICHAELO_52741.csv
# CSV File #35 filename: 2459283_84_20210309012417_dmhmreport_EHRSUPPORT_15146302.csv
# CSV File #36 filename: 2459284_105_20210310014505_dmhmreport_EHRSUPPORT_449673.csv
# CSV File #37 filename: 2459284_25_20210310002511_dmhmreport_MICHAELO_1040637.csv
# CSV File #38 filename: 2459285_114_20210311015420_dmhmreport_EHRSUPPORT_1575854.csv
# CSV File #39 filename: 2459285_26_20210311002640_dmhmreport_MICHAELO_3912112.csv
# CSV File #40 filename: 2459286_26_20210312002653_dmhmreport_MICHAELO_5115747.csv
# CSV File #41 filename: 2459286_80_20210312012026_dmhmreport_EHRSUPPORT_23141996.csv
# CSV File #42 filename: 2459287_30_20210313003007_dmhmreport_MICHAELO_745016.csv
# CSV File #43 filename: 2459287_86_20210313012622_dmhmreport_EHRSUPPORT_1955524.csv
# CSV File #44 filename: 2459288_20_20210314002054_dmhmreport_MICHAELO_5314151.csv
# CSV File #45 filename: 2459288_367_20210314060723_dmhmreport_EHRSUPPORT_2145867.csv
# CSV File #46 filename: 2459289_26_20210315002627_dmhmreport_MICHAELO_2648658.csv
# CSV File #47 filename: 2459289_96_20210315013614_dmhmreport_EHRSUPPORT_1216257.csv
# CSV File #48 filename: 2459290_29_20210316002951_dmhmreport_MICHAELO_5045521.csv
# CSV File #49 filename: 2459290_93_20210316013331_dmhmreport_EHRSUPPORT_3027559.csv
# CSV File #50 filename: 2459291_27_20210317002717_dmhmreport_MICHAELO_1733666.csv
# CSV File #51 filename: 2459291_85_20210317012515_dmhmreport_EHRSUPPORT_1364272.csv
# CSV File #52 filename: 2459292_21_20210318002109_dmhmreport_MICHAELO_740577.csv
# CSV File #53 filename: 2459292_97_20210318013718_dmhmreport_EHRSUPPORT_17129754.csv
# CSV File #54 filename: 2459293_27_20210319002722_dmhmreport_MICHAELO_2110697.csv
# CSV File #55 filename: 2459293_86_20210319012609_dmhmreport_EHRSUPPORT_71183.csv
# CSV File #56 filename: 2459294_100_20210320014039_dmhmreport_EHRSUPPORT_3873020.csv
# CSV File #57 filename: 2459294_26_20210320002627_dmhmreport_MICHAELO_2510661.csv
# CSV File #58 filename: 2459295_30_20210321003025_dmhmreport_MICHAELO_2443415.csv
# CSV File #59 filename: 2459295_87_20210321012752_dmhmreport_EHRSUPPORT_4716498.csv
# CSV File #60 filename: 2459296_24_20210322002448_dmhmreport_MICHAELO_476067.csv
# CSV File #61 filename: 2459296_79_20210322011947_dmhmreport_EHRSUPPORT_46142745.csv
# CSV File #62 filename: 2459297_28_20210323002814_dmhmreport_MICHAELO_1344898.csv
# CSV File #63 filename: 2459297_87_20210323012738_dmhmreport_EHRSUPPORT_3853035.csv
# CSV File #64 filename: 2459298_30_20210324003012_dmhmreport_MICHAELO_1037662.csv
# CSV File #65 filename: 2459298_86_20210324012606_dmhmreport_EHRSUPPORT_421102.csv
# CSV File #66 filename: 2459299_104_20210325014437_dmhmreport_EHRSUPPORT_33138412.csv
# CSV File #67 filename: 2459299_28_20210325002847_dmhmreport_MICHAELO_4620088.csv
# CSV File #68 filename: 2459300_26_20210326002630_dmhmreport_MICHAELO_284859.csv
# CSV File #69 filename: 2459300_85_20210326012517_dmhmreport_EHRSUPPORT_1597542.csv
# CSV File #70 filename: 2459301_31_20210327003137_dmhmreport_MICHAELO_3639001.csv
# CSV File #71 filename: 2459301_84_20210327012410_dmhmreport_EHRSUPPORT_8116404.csv
# CSV File #72 filename: 2459302_33_20210328003354_dmhmreport_MICHAELO_5321853.csv
# CSV File #73 filename: 2459302_87_20210328012744_dmhmreport_EHRSUPPORT_329217.csv
# CSV File #74 filename: 2459303_29_20210329002927_dmhmreport_MICHAELO_2631324.csv
# CSV File #75 filename: 2459303_79_20210329011944_dmhmreport_EHRSUPPORT_4340196.csv
# CSV File #76 filename: 2459304_102_20210330014221_dmhmreport_EHRSUPPORT_19108369.csv
# CSV File #77 filename: 2459304_27_20210330002715_dmhmreport_MICHAELO_1523321.csv
# CSV File #78 filename: 2459305_29_20210331002913_dmhmreport_MICHAELO_111216.csv
# CSV File #79 filename: 2459305_86_20210331012631_dmhmreport_EHRSUPPORT_2953832.csv
# CSV File #80 filename: 2459306_116_20210401015715_dmhmreport_EHRSUPPORT_5992108.csv
# CSV File #81 filename: 2459306_35_20210401003525_dmhmreport_MICHAELO_2438922.csv
# CSV File #82 filename: 2459307_31_20210402003129_dmhmreport_MICHAELO_2723949.csv
# CSV File #83 filename: 2459307_84_20210402012450_dmhmreport_EHRSUPPORT_4935498.csv
# CSV File #84 filename: 2459308_29_20210403002944_dmhmreport_MICHAELO_4210187.csv
# CSV File #85 filename: 2459308_84_20210403012421_dmhmreport_EHRSUPPORT_207214.csv
# CSV File #86 filename: 2459309_30_20210404003023_dmhmreport_MICHAELO_2216375.csv
# CSV File #87 filename: 2459309_99_20210404013931_dmhmreport_EHRSUPPORT_2718516.csv
# CSV File #88 filename: 2459310_101_20210405014147_dmhmreport_EHRSUPPORT_4615985.csv
# CSV File #89 filename: 2459310_33_20210405003324_dmhmreport_MICHAELO_2231739.csv
# ...
# CSV File #1 filename: Main 12.21.csv
# CSV File #2 filename: Main Third Next 1.10.csv
# CSV File #3 filename: Main Third Next 1.11.csv
# CSV File #4 filename: Main Third Next 1.12.csv
# CSV File #5 filename: Main Third Next 1.13.csv
# CSV File #6 filename: Main third next 1.18.csv
# CSV File #7 filename: Main Third Next 1.19.csv
# CSV File #8 filename: Main Third Next 1.20.csv
# CSV File #9 filename: Main Third Next 1.21.csv
# CSV File #10 filename: Main third next 1.24.csv
# CSV File #11 filename: Main Third Next 1.25.csv
# CSV File #12 filename: Main Third next 1.26.csv
# CSV File #13 filename: Main Third Next 1.27.csv
# CSV File #14 filename: Main Third Next 1.3.csv
# CSV File #15 filename: Main Third Next 1.31.csv
# CSV File #16 filename: Main Third Next 1.4.csv
# CSV File #17 filename: Main Third Next 1.5.csv
# CSV File #18 filename: Main Third next 1.6.csv
# CSV File #19 filename: Main Third Next 12.20.csv
# CSV File #20 filename: Main Third Next 12.30.csv
# CSV File #21 filename: Main Third Next 2.1.csv
# CSV File #22 filename: Main Third Next 2.10.csv
# CSV File #23 filename: Main Third Next 2.11.csv
# CSV File #24 filename: Main Third Next 2.14.csv
# CSV File #25 filename: Main Third next 2.15.csv
# CSV File #26 filename: Main Third Next 2.16.csv
# CSV File #27 filename: Main Third Next 2.17.csv
# CSV File #28 filename: Main Third Next 2.18.csv
# CSV File #29 filename: Main Third next 2.2.csv
# CSV File #30 filename: Main Third Next 2.21.csv
# CSV File #31 filename: Main Third Next 2.22.csv
# CSV File #32 filename: Main Third Next 2.23.csv
# CSV File #33 filename: Main Third Next 2.24.csv
# CSV File #34 filename: Main Third Next 2.25.csv
# CSV File #35 filename: Main Third Next 2.28.csv
# CSV File #36 filename: Main Third Next 2.3.csv
# CSV File #37 filename: Main Third Next 2.4.csv
# CSV File #38 filename: Main Third Next 2.7.csv
# CSV File #39 filename: Main Third Next 2.8.csv
# CSV File #40 filename: Main Third Next 2.9.csv
# CSV File #41 filename: Main Third Next 3.1.csv
# CSV File #42 filename: Main Third Next 3.10.csv
# CSV File #43 filename: Main Third Next 3.11.csv
# CSV File #44 filename: Main Third Next 3.14.csv
# CSV File #45 filename: Main Third Next 3.15.csv
# CSV File #46 filename: Main Third Next 3.16.csv
# CSV File #47 filename: Main Third Next 3.17.csv
# CSV File #48 filename: Main Third Next 3.2.csv
# CSV File #49 filename: Main Third next 3.22.csv
# CSV File #50 filename: Main Third Next 3.23.csv
# CSV File #51 filename: Main Third Next 3.24.csv
# CSV File #52 filename: Main Third Next 3.25.csv
# CSV File #53 filename: Main Third Next 3.29.csv
# CSV File #54 filename: Main Third Next 3.3.csv
# CSV File #55 filename: Main Third Next 3.30.csv
# CSV File #56 filename: Main Third Next 3.31.csv
# CSV File #57 filename: Main Third Next 3.4.csv
# CSV File #58 filename: Main Third Next 3.7.csv
# CSV File #59 filename: Main Third Next 3.8.csv
# CSV File #60 filename: Main Third Next 3.9.csv
# CSV File #61 filename: Main Third Next 4.1.csv
# CSV File #62 filename: Main Third Next 4.11.csv
# CSV File #63 filename: Main Third Next 4.12.csv
# CSV File #64 filename: Main Third Next 4.13.csv
# CSV File #65 filename: Main Third Next 4.14.csv
# CSV File #66 filename: Main Third Next 4.15.csv
# CSV File #67 filename: Main Third Next 4.18.csv
# CSV File #68 filename: Main Third Next 4.19.csv
# CSV File #69 filename: Main Third Next 4.20.csv
# CSV File #70 filename: Main Third Next 4.21.csv
# CSV File #71 filename: Main Third Next 4.22.csv
# CSV File #72 filename: Main Third Next 4.25.csv
# CSV File #73 filename: Main Third Next 4.26.csv
# CSV File #74 filename: Main third next 4.27.csv
# CSV File #75 filename: Main Third Next 4.28.csv
# CSV File #76 filename: Main Third Next 4.29.csv
# CSV File #77 filename: Main Third Next 4.5.csv
# CSV File #78 filename: Main Third Next 4.6.csv
# CSV File #79 filename: Main Third Next 5.10.csv
# CSV File #80 filename: Main Third Next 5.11.csv
# CSV File #81 filename: Main Third Next 5.12.csv
# CSV File #82 filename: Main Third Next 5.13.csv
# CSV File #83 filename: Main Third Next 5.16.csv
# CSV File #84 filename: Main Third Next 5.17.csv
# CSV File #85 filename: Main Third Next 5.18.csv
# CSV File #86 filename: Main Third Next 5.19.csv
# CSV File #87 filename: Main Third Next 5.2.csv
# CSV File #88 filename: Main Third Next 5.20.csv
# CSV File #89 filename: Main Third Next 5.23.csv
# CSV File #90 filename: Main Third Next 5.24.csv
# CSV File #91 filename: Main Third Next 5.25.csv
# CSV File #92 filename: Main Third Next 5.26.csv
# CSV File #93 filename: Main Third Next 5.27.csv
# CSV File #94 filename: Main Third Next 5.3.csv
# CSV File #95 filename: Main Third Next 5.31.csv
# CSV File #96 filename: Main Third Next 5.4.csv
# CSV File #97 filename: Main Third Next 5.5.csv
# CSV File #98 filename: Main Third Next 5.6.csv
# CSV File #99 filename: Main Third Next 5.9.csv
# CSV File #100 filename: Main Third Next 6.1.csv
# CSV File #101 filename: Main Third Next 6.10.csv
# CSV File #102 filename: Main Third Next 6.13.csv
# CSV File #103 filename: Main Third Next 6.14.csv
# CSV File #104 filename: Main Third Next 6.15.csv
# CSV File #105 filename: Main Third Next 6.16.csv
# CSV File #106 filename: Main Third Next 6.17.csv
# CSV File #107 filename: Main Third Next 6.2.csv
# CSV File #108 filename: Main Third Next 6.20.csv
# CSV File #109 filename: Main Third Next 6.21.csv
# CSV File #110 filename: Main Third Next 6.22.csv
# CSV File #111 filename: Main Third Next 6.23.csv
# CSV File #112 filename: Main Third Next 6.24.csv
# CSV File #113 filename: Main Third Next 6.27.csv
# CSV File #114 filename: Main Third Next 6.28.csv
# CSV File #115 filename: Main Third Next 6.29.csv
# CSV File #116 filename: Main Third Next 6.3.csv
# CSV File #117 filename: Main Third Next 6.30.csv
# CSV File #118 filename: Main Third Next 6.6.csv
# CSV File #119 filename: Main Third Next 6.7.csv
# CSV File #120 filename: Main Third Next 6.8.csv
# CSV File #121 filename: Main Third Next 6.9.csv
# CSV File #122 filename: Main Third Next 7.1.csv
# CSV File #123 filename: Main Third Next 7.11.csv
# CSV File #124 filename: Main Third Next 7.12.csv
# CSV File #125 filename: Main Third Next 7.13.csv
# CSV File #126 filename: Main Third Next 7.5.csv
# CSV File #127 filename: Main Third Next 7.6.csv
# CSV File #128 filename: Main Third Next 7.7.csv
# CSV File #129 filename: Main Third Next 7.8.csv
# CSV File #130 filename: Sub II  Third Next 6.8.csv
# CSV File #131 filename: Sub II 12.21.csv
# CSV File #132 filename: Sub II 2.15.csv
# CSV File #133 filename: Sub II 2.17.csv
# CSV File #134 filename: Sub II 2.22.csv
# CSV File #135 filename: Sub II 2.25.csv
# CSV File #136 filename: Sub II 2.28.csv
# CSV File #137 filename: SUB II 2.4.csv
# CSV File #138 filename: Sub II 3.1.csv
# CSV File #139 filename: Sub II 3.10.csv
# CSV File #140 filename: Sub II 3.11.csv
# CSV File #141 filename: Sub II 5.4.csv
# CSV File #142 filename: Sub II 5.5.csv
# CSV File #143 filename: Sub II 6.29.csv
# CSV File #144 filename: Sub II 6.30.csv
# CSV File #145 filename: Sub II Third Available 7.1.csv
# CSV File #146 filename: Sub II Third Next 1.10.csv
# CSV File #147 filename: Sub II Third Next 1.11.csv
# CSV File #148 filename: Sub II Third Next 1.13.csv
# CSV File #149 filename: Sub II third next 1.18.csv
# CSV File #150 filename: Sub II Third next 1.19.csv
# CSV File #151 filename: Sub II third next 1.20.csv
# CSV File #152 filename: SUb II Third Next 1.21.csv
# CSV File #153 filename: SUb II Third Next 1.24.csv
# CSV File #154 filename: Sub II Third Next 1.25.csv
# CSV File #155 filename: Sub II Third Next 1.26.csv
# CSV File #156 filename: Sub II Third Next 1.27.csv
# CSV File #157 filename: Sub II Third Next 1.3.csv
# CSV File #158 filename: Sub II Third Next 1.4.csv
# CSV File #159 filename: Sub II Third next 1.5.csv
# CSV File #160 filename: Sub II Third next 1.6.csv
# CSV File #161 filename: Sub II Third Next 12.20.csv
# CSV File #162 filename: SUb II Third Next 12.30.csv
# CSV File #163 filename: Sub II Third Next 2.10.csv
# CSV File #164 filename: Sub II Third next 2.11.csv
# CSV File #165 filename: Sub II Third Next 2.16.csv
# CSV File #166 filename: Sub II Third Next 2.18.csv
# CSV File #167 filename: Sub II Third next 2.2.csv
# CSV File #168 filename: Sub II Third Next 2.21.csv
# CSV File #169 filename: Sub II Third Next 2.23.csv
# CSV File #170 filename: Sub II Third Next 2.24.csv
# CSV File #171 filename: Sub II Third Next 2.3.csv
# CSV File #172 filename: SUb II Third Next 2.7.csv
# CSV File #173 filename: Sub II Third Next 2.8.csv
# CSV File #174 filename: Sub II Third Next 2.9.csv
# CSV File #175 filename: Sub II Third Next 3.14.csv
# CSV File #176 filename: Sub II Third Next 3.15.csv
# CSV File #177 filename: Sub II Third Next 3.16.csv
# CSV File #178 filename: Sub II Third Next 3.17.csv
# CSV File #179 filename: Sub II Third Next 3.2.csv
# CSV File #180 filename: Sub II Third Next 3.22.csv
# CSV File #181 filename: Sub II Third Next 3.23.csv
# CSV File #182 filename: Sub II Third next 3.24.csv
# CSV File #183 filename: Sub II Third Next 3.25.csv
# CSV File #184 filename: Sub II Third Next 3.29.csv
# CSV File #185 filename: Sub II Third Next 3.3.csv
# CSV File #186 filename: Sub II Third Next 3.30.csv
# CSV File #187 filename: Sub II Third Next 3.31.csv
# CSV File #188 filename: Sub II third Next 3.4.csv
# CSV File #189 filename: Sub II Third Next 3.7.csv
# CSV File #190 filename: Sub II Third Next 3.8.csv
# CSV File #191 filename: Sub II Third Next 3.9.csv
# CSV File #192 filename: Sub II Third Next 4.1.csv
# CSV File #193 filename: Sub II Third Next 4.11.csv
# CSV File #194 filename: Sub II Third Next 4.12.csv
# CSV File #195 filename: Sub II Third Next 4.13.csv
# CSV File #196 filename: Sub II Third Next 4.14.csv
# CSV File #197 filename: Sub II Third Next 4.15.csv
# CSV File #198 filename: Sub II Third Next 4.18.csv
# CSV File #199 filename: Sub II Third Next 4.19.csv
# CSV File #200 filename: Sub II Third Next 4.20.csv
# CSV File #201 filename: SUb II Third Next 4.21.csv
# CSV File #202 filename: Sub II Third Next 4.22.csv
# CSV File #203 filename: Sub II Third Next 4.25.csv
# CSV File #204 filename: Sub II Third Next 4.26.csv
# CSV File #205 filename: Sub II Third Next 4.27.csv
# CSV File #206 filename: Sub II Third Next 4.28.csv
# CSV File #207 filename: Sub II Third Next 4.29.csv
# CSV File #208 filename: Sub II Third Next 4.5.csv
# CSV File #209 filename: Sub II Third Next 4.6.csv
# CSV File #210 filename: Sub II Third Next 5.10.csv
# CSV File #211 filename: Sub II Third Next 5.11.csv
# CSV File #212 filename: Sub II Third Next 5.12.csv
# CSV File #213 filename: Sub II Third Next 5.13.csv
# CSV File #214 filename: Sub II Third Next 5.16.csv
# CSV File #215 filename: Sub II Third Next 5.17.csv
# CSV File #216 filename: Sub II Third Next 5.18.csv
# CSV File #217 filename: Sub II Third Next 5.19.csv
# CSV File #218 filename: Sub II Third Next 5.20.csv
# CSV File #219 filename: SUb II Third Next 5.23.csv
# CSV File #220 filename: Sub II Third Next 5.24.csv
# CSV File #221 filename: Sub II Third Next 5.25.csv
# CSV File #222 filename: Sub II Third Next 5.26.csv
# CSV File #223 filename: Sub II Third Next 5.27.csv
# CSV File #224 filename: Sub II Third Next 5.3.csv
# CSV File #225 filename: Sub II Third Next 5.31.csv
# CSV File #226 filename: Sub II Third Next 5.6.csv
# CSV File #227 filename: Sub II Third Next 5.9.csv
# CSV File #228 filename: Sub II Third Next 6.1.csv
# CSV File #229 filename: Sub II Third Next 6.10.csv
# CSV File #230 filename: Sub II Third Next 6.13.csv
# CSV File #231 filename: Sub II Third Next 6.14.csv
# CSV File #232 filename: Sub II Third Next 6.15.csv
# CSV File #233 filename: Sub II Third Next 6.16.csv
# CSV File #234 filename: Sub II Third Next 6.17.csv
# CSV File #235 filename: Sub II Third Next 6.2.csv
# CSV File #236 filename: Sub II Third Next 6.20.csv
# CSV File #237 filename: Sub II Third Next 6.21.csv
# CSV File #238 filename: Sub II Third Next 6.22.csv
# CSV File #239 filename: Sub II Third Next 6.23.csv
# CSV File #240 filename: Sub II Third Next 6.24.csv
# CSV File #241 filename: Sub II Third Next 6.27.csv
# CSV File #242 filename: Sub II Third Next 6.28.csv
# CSV File #243 filename: Sub II Third Next 6.3.csv
# CSV File #244 filename: Sub II Third Next 6.6.csv
# CSV File #245 filename: Sub II Third Next 6.7.csv
# CSV File #246 filename: Sub II Third Next 6.9.csv
# CSV File #247 filename: Sub II Third Next 7.11.csv
# CSV File #248 filename: Sub II Third Next 7.12.csv
# CSV File #249 filename: Sub II Third Next 7.13.csv
# CSV File #250 filename: Sub II Third Next 7.5.csv
# CSV File #251 filename: Sub II Third Next 7.6.csv
# CSV File #252 filename: Sub II Third Next 7.7.csv
# CSV File #253 filename: Sub II Third Next 7.8.csv
# CSV File #254 filename: Sub III 1.3.csv
# CSV File #255 filename: Sub III 12.20.csv
# CSV File #256 filename: sub III 12.29.csv
# CSV File #257 filename: Sub III 2.10.csv
# CSV File #258 filename: Sub III 2.11.csv
# CSV File #259 filename: Sub III 2.17.csv
# CSV File #260 filename: Sub III 2.18.csv
# CSV File #261 filename: Sub III 2.22.csv
# CSV File #262 filename: Sub III 2.25.csv
# CSV File #263 filename: Sub III 2.28.csv
# CSV File #264 filename: Sub III 3.1.csv
# CSV File #265 filename: Sub III 3.10.csv
# CSV File #266 filename: Sub III 3.3.csv
# CSV File #267 filename: Sub III 3.4.csv
# CSV File #268 filename: Sub III 3.7.csv
# CSV File #269 filename: Sub III Third 2.8.csv
# CSV File #270 filename: Sub III Third Next  3.2.csv
# CSV File #271 filename: Sub III Third Next 1.10.csv
# CSV File #272 filename: Sub III Third Next 1.11.csv
# CSV File #273 filename: Sub III Third Next 1.13.csv
# CSV File #274 filename: Sub III Third Next 1.19.csv
# CSV File #275 filename: SUb III Third Next 1.20.csv
# CSV File #276 filename: Sub III Third Next 1.21.csv
# CSV File #277 filename: Sub III Third next 1.24.csv
# CSV File #278 filename: Sub III Third Next 1.25.csv
# CSV File #279 filename: Sub III Third Next 1.26.csv
# CSV File #280 filename: Sub III Third Next 1.27.csv
# CSV File #281 filename: Sub III Third Next 1.4.csv
# CSV File #282 filename: sub III Third Next 1.5.csv
# CSV File #283 filename: sub III third next 1.6.csv
# CSV File #284 filename: Sub III Third Next 12.17.csv
# CSV File #285 filename: SUb III Third Next 12.20.csv
# CSV File #286 filename: Sub III Third Next 2.15.csv
# CSV File #287 filename: Sub III Third Next 2.16.csv
# CSV File #288 filename: Sub III Third next 2.2.csv
# CSV File #289 filename: Sub III Third Next 2.21.csv
# CSV File #290 filename: Sub III Third Next 2.23.csv
# CSV File #291 filename: Sub III Third Next 2.24.csv
# CSV File #292 filename: Sub III Third Next 2.3.csv
# CSV File #293 filename: Sub III Third Next 2.4.csv
# CSV File #294 filename: SUb III Third Next 2.7.csv
# CSV File #295 filename: Sub III Third Next 2.9.csv
# CSV File #296 filename: Sub III Third Next 3.11.csv
# CSV File #297 filename: Sub III Third Next 3.14.csv
# CSV File #298 filename: Sub III Third Next 3.15.csv
# CSV File #299 filename: Sub III Third Next 3.16.csv
# CSV File #300 filename: Sub III Third Next 3.17.csv
# CSV File #301 filename: Sub III Third Next 3.22.csv
# CSV File #302 filename: Sub III Third Next 3.23.csv
# CSV File #303 filename: Sub III Third Next 3.24.csv
# CSV File #304 filename: Sub III Third Next 3.25.csv
# CSV File #305 filename: Sub III Third Next 3.29.csv
# CSV File #306 filename: Sub III Third Next 3.30.csv
# CSV File #307 filename: Sub III Third Next 3.8.csv
# CSV File #308 filename: Sub III Third Next 3.9.csv
# CSV File #309 filename: Sub III Third Next 4.1.csv
# CSV File #310 filename: Sub III third next1.18.csv
# CSV File #311 filename: Sub III Third Next3.31.csv
# CSV File #312 filename: Sub III Third Nxt 1.12.csv
# CSV File #313 filename: Third Next Available 12.13.csv
# CSV File #314 filename: Third Next Available 12.17.csv
# CSV File #315 filename: Third Next Available 12.6.21.csv

# %%
# Persist the csv files in an excel import file Registry 
Data_Import_Starting_Directory =  'J:/IT GLIN Data Services Shared/TempData/'
Excel_file_Name = Data_Import_Starting_Directory + 'Discovered_CSV_files_to_import.xlsx'
out('Registering Directories in excel File:{} '.format(Excel_file_Name))
df_import_files.to_excel(Excel_file_Name, index=False)
# Out:
# Registering Directories in excel File:J:/IT GLIN Data Services Shared/TempData/Discovered_CSV_files_to_import.xlsx

# %%
#df_import_files.loc[1  , ['Root_Directory','Import_file_Name']]
df_import_files.head(2)
# Out:
#              Root_Directory             Sub_Directory Table_Name  \
# 1  Y:/_Kaleida_Input/Access  Y:/_Kaleida_Input/Access     Access
# 2  Y:/_Kaleida_Input/Access  Y:/_Kaleida_Input/Access     Access
#
#                                     Import_File_Name File_Size  \
# 1  2459631_274_20220220043457_dmhmreport_EHRSUPPO...     10262
# 2  2459638_97_20220227013752_dmhmreport_EHRSUPPOR...      6014
#
#          File_Modified_Date         File_Created_Date
# 1  Thu Jul  7 09:18:16 2022  Thu Jul  7 09:18:16 2022
# 2  Thu Jul  7 09:18:19 2022  Thu Jul  7 09:18:19 2022

# %%
#df_import_files.loc[1  , ['Root_Directory','Import_file_Name']]
df_import_files.shape

# %%
def inspect_raw_file(raw_csv_file_to_import , table_name , Head_Rows):
    out('About to Read File:{}'.format(raw_csv_file_to_import))   
    if Head_Rows == 2:
        df_import_file = pd.read_csv(raw_csv_file_to_import ,header=[0,1] )
        df_import_file.columns = df_import_file.columns.map('^'.join)
        
        
        df_import_file.columns = [x.strip().title().replace("^","").replace(" ","_").replace("#","Number").replace("#","Number").replace("%","Percentage") \
                             .replace('_Unnamed','').replace('Unnamed','').replace('_level_','').replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','').replace('_Level','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace('0_','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_import_file.columns]  
        
    else: 
        df_import_file = pd.read_csv(raw_csv_file_to_import   )   
        df_import_file.columns = [x.strip().title().replace("^","").replace(" ","_").replace("#","Number").replace("#","Number").replace("%","Percentage") \
                             .replace('_Unnamed','').replace('Unnamed','').replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_import_file.columns]          
    
    out('Read in raw csv file:{} rows:{} columns:{}'.format(raw_csv_file_to_import,df_import_file.shape[0], df_import_file.shape[1]))
    
    return df_import_file

# %%
global detail_debugging

for i, row in df_import_files.iterrows():
#    print(' Iter = {}'.format(i))
    Index = i 
    Root_Dir   =   row[0]      
    Sub_Dir    =   row[1]    
    Table_Name =   row[2]
    Import_CSV =   row[3]  
    #print('Detail Debugging:', detail_debugging ) 
    
    if detail_debugging:    
        out('Iter:{}, Root Dir:{}, Sub_Dir:{}, Table:{}, Import_CSV:{} '.format(i,Root_Dir,Sub_Dir,Table_Name,Import_CSV))
    if Table_Name == 'Access':
        Header_Row_Count = 2
    else:         
        Header_Row_Count = 1
    
    if i == 1:
        file_to_import = Root_Dir + '/' + Import_CSV
        if detail_debugging:
            out(' File to Import: {} '.format(file_to_import))
        df_import_raw = inspect_raw_file(file_to_import, Table_Name, Header_Row_Count)
# Out:
# Iter:1, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459631_274_20220220043457_dmhmreport_EHRSUPPORT_5592087.csv
#  File to Import: Y:/_Kaleida_Input/Access/2459631_274_20220220043457_dmhmreport_EHRSUPPORT_5592087.csv
# About to Read File:Y:/_Kaleida_Input/Access/2459631_274_20220220043457_dmhmreport_EHRSUPPORT_5592087.csv
# Read in raw csv file:Y:/_Kaleida_Input/Access/2459631_274_20220220043457_dmhmreport_EHRSUPPORT_5592087.csv rows:73 columns:19
# Iter:2, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459638_97_20220227013752_dmhmreport_EHRSUPPORT_5187581.csv
# Iter:3, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459646_85_20220307012546_dmhmreport_EHRSUPPORT_4516065.csv
# Iter:4, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459652_467_20220313074723_dmhmreport_EHRSUPPORT_2179577.csv
# Iter:5, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459659_138_20220320021809_dmhmreport_EHRSUPPORT_877261.csv
# Iter:6, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459666_94_20220327013440_dmhmreport_EHRSUPPORT_3985999.csv
# Iter:7, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459673_140_20220403022052_dmhmreport_EHRSUPPORT_51141178.csv
# Iter:8, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459680_351_20220410055106_dmhmreport_EHRSUPPORT_582566.csv
# Iter:9, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459687_93_20220417013342_dmhmreport_EHRSUPPORT_4138013.csv
# Iter:10, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459694_105_20220424014521_dmhmreport_EHRSUPPORT_2082480.csv
# Iter:11, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459701_89_20220501012947_dmhmreport_EHRSUPPORT_465882.csv
# Iter:12, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459708_267_20220508042714_dmhmreport_EHRSUPPORT_1377103.csv
# Iter:13, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459715_100_20220515014017_dmhmreport_EHRSUPPORT_16106866.csv
# Iter:14, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459722_84_20220522012436_dmhmreport_EHRSUPPORT_3515957.csv
# Iter:15, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459729_84_20220529012450_dmhmreport_EHRSUPPORT_4919584.csv
# Iter:16, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459736_100_20220605014007_dmhmreport_EHRSUPPORT_683206.csv
# Iter:17, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459743_529_20220612084929_dmhmreport_EHRSUPPORT_28136567.csv
# Iter:18, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459750_85_20220619012502_dmhmreport_EHRSUPPORT_189436.csv
# Iter:19, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459757_86_20220626012633_dmhmreport_EHRSUPPORT_32127412.csv
# Iter:20, Root Dir:Y:/_Kaleida_Input/Access, Sub_Dir:Y:/_Kaleida_Input/Access, Table:Access, Import_CSV:2459764_86_20220703012644_dmhmreport_EHRSUPPORT_4376748.csv
# Iter:21, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.050421190755.csv
# Iter:22, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.051821190747.csv
# Iter:23, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.060121190842.csv
# Iter:24, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.061521190831.csv
# Iter:25, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.062921190854.csv
# Iter:26, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.071321190908.csv
# Iter:27, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.072721190859.csv
# Iter:28, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.081021190954.csv
# Iter:29, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.082421190545.csv
# Iter:30, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.090721191026.csv
# Iter:31, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.092121190806.csv
# Iter:32, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.100521190616.csv
# Iter:33, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.101921190707.csv
# Iter:34, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.110221190902.csv
# Iter:35, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.111621190810.csv
# Iter:36, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.113021190601.csv
# Iter:37, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.121421190704.csv
# Iter:38, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.122821191049.csv
# Iter:39, Root Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Sub_Dir:Y:/_Kaleida_Input/ADP\Daily Time Card, Table:ADPDaily_Time_Card, Import_CSV:DailyTimecardReport.csv
# Iter:40, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.043021190734.csv
# Iter:41, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.053121190439.csv
# Iter:42, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.063021190840.csv
# Iter:43, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.073121190558.csv
# Iter:44, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.083121190751.csv
# Iter:45, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.093021190526.csv
# Iter:46, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.103121190215.csv
# Iter:47, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.113021190508.csv
# Iter:48, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.123121190308.csv
# Iter:49, Root Dir:Y:/_Kaleida_Input/ADP\Employee Census, Sub_Dir:Y:/_Kaleida_Input/ADP\Employee Census, Table:ADPEmployee_Census, Import_CSV:EmployeeCensus.csv
# Iter:50, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:February 2022 Available Slot.csv
# Iter:51, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:January 2022 available slots.csv
# Iter:52, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.12 to 10.13.csv
# Iter:53, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.13 to 10.14.csv
# Iter:54, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.14 to 10.15.csv
# Iter:55, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.15 to 10.16.csv
# Iter:56, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.16 to 10.17.csv
# Iter:57, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.19 to 10.20.csv
# Iter:58, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.20 to 10.21.csv
# Iter:59, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.21 to 10.22.csv
# Iter:60, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.22 to 10.23.csv
# Iter:61, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.23 to 10.24.csv
# Iter:62, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.26 to 10.27.csv
# Iter:63, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.27 to 10.28.csv
# Iter:64, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.28 to 10.29.csv
# Iter:65, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.29 to 10.30.csv
# Iter:66, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4.30 to 10.31.csv
# Iter:67, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4_2 to 10_2.csv
# Iter:68, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4_5 to 10_5.csv
# Iter:69, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 4_7 to 10_7.csv
# Iter:70, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.10 to 11.11.csv
# Iter:71, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.11 to 11.12.csv
# Iter:72, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.12 to 11.13.csv
# Iter:73, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.13 to 11.14.csv
# Iter:74, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.14 to 11.15.csv
# Iter:75, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.17 to 11.18.csv
# Iter:76, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.18 to 11.19.csv
# Iter:77, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.19 to 11.20.csv
# Iter:78, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.2 to 11.2.csv
# Iter:79, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.20 to 11.21.csv
# Iter:80, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.21 to 11.22.csv
# Iter:81, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.24 to 11.25.csv
# Iter:82, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.25 to 11.26.csv
# Iter:83, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.26 to 11.27.csv
# Iter:84, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.27 to 11.28.csv
# Iter:85, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.28 to 11.29.csv
# Iter:86, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.4 to 11.4.csv
# Iter:87, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.5 to 11.5.csv
# Iter:88, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.6 to 11.7.csv
# Iter:89, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 5.7 to  11.8.csv
# Iter:90, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.1 to 12.1.csv
# Iter:91, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.10 to 12.11.csv
# Iter:92, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.11 to 12.12.csv
# Iter:93, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.14 to 12.15.csv
# Iter:94, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.15 to 12.16.csv
# Iter:95, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.16 to 12.17.csv
# Iter:96, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.17 to 12.18.csv
# Iter:97, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.18 to 12.19.csv
# Iter:98, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.2 to 12.2.csv
# Iter:99, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.21 to 12.22.csv
# Iter:100, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.22 to 12.23.csv
# Iter:101, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.23 to 12.24.csv
# Iter:102, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.24 to 12.25.csv
# Iter:103, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.25 to 12.26.csv
# Iter:104, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.28 to 12.29.csv
# Iter:105, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.29 to 12.30.csv
# Iter:106, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.3 to 12.4.csv
# Iter:107, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.30 to 12.31.csv
# Iter:108, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.4 to 12.5.csv
# Iter:109, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.7 to 12.8.csv
# Iter:110, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.8 to 12.9.csv
# Iter:111, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 6.9 to 12.10.csv
# Iter:112, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7.1 to 1.1.csv
# Iter:113, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7.2 to 1.2.csv
# Iter:114, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7.6 to 1.7.csv
# Iter:115, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7.8 to 1.9.csv
# Iter:116, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7.9 to 1.10.csv
# Iter:117, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7_12 to 1_13.csv
# Iter:118, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Main 7_7 to 1_8.csv
# Iter:119, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:March 2022 List of Available Slot.csv
# Iter:120, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.12 to 10.13.csv
# Iter:121, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.13 to 10.14.csv
# Iter:122, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.14 to 10.15.csv
# Iter:123, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.15 to 10.16.csv
# Iter:124, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.16 to 10.17.csv
# Iter:125, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.19 to 10.20.csv
# Iter:126, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.20 to 10.21.csv
# Iter:127, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.21 to 10.22.csv
# Iter:128, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.22 to 10.23.csv
# Iter:129, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.23 to 10.24.csv
# Iter:130, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.26 to 10.27.csv
# Iter:131, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.27 to 10.28.csv
# Iter:132, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.28 to 10.29.csv
# Iter:133, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.29 to 10.30.csv
# Iter:134, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.30 to 10.31.csv
# Iter:135, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4.7 to 10.7.csv
# Iter:136, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4_1 to 10_2.csv
# Iter:137, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 4_5 to 10_5.csv
# Iter:138, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.10 to 11.11.csv
# Iter:139, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.11 to 11.12.csv
# Iter:140, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.12 to 11.13.csv
# Iter:141, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.13 to 11.14.csv
# Iter:142, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.14 to 11.15.csv
# Iter:143, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.17 to 11.18.csv
# Iter:144, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.18 to 11.19.csv
# Iter:145, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.19 to 11.20.csv
# Iter:146, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.2 to 11.2.csv
# Iter:147, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.20 to 11.21.csv
# Iter:148, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.21 to 11.22.csv
# Iter:149, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.24 to 11.25.csv
# Iter:150, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.25 to 11.26.csv
# Iter:151, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.26 to 11.27.csv
# Iter:152, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.27 to 11.28.csv
# Iter:153, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:SUb II 5.28 to 11.29.csv
# Iter:154, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.4 to 11.4.csv
# Iter:155, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.5 to 11.5.csv
# Iter:156, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.6 to 11.7.csv
# Iter:157, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 5.7 to 11.8.csv
# Iter:158, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.1 to 12.1.csv
# Iter:159, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.10 to 12.11.csv
# Iter:160, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.11 to 12.12.csv
# Iter:161, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.14 to 12.15.csv
# Iter:162, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.15 to 12.16.csv
# Iter:163, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.16 to 12.17.csv
# Iter:164, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.17 to 12.18.csv
# Iter:165, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.18 to 12.19.csv
# Iter:166, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.2 to 12.2.csv
# Iter:167, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.21 to 12.22.csv
# Iter:168, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.22 to 12.23.csv
# Iter:169, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.23 to 12.24.csv
# Iter:170, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.24 to 12.25.csv
# Iter:171, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.25 to 12.26.csv
# Iter:172, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.28 to 12.29.csv
# Iter:173, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.29 to 12.30.csv
# Iter:174, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.3 to 12.4.csv
# Iter:175, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.30 to 12.31.csv
# Iter:176, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.4 to 12.5.csv
# Iter:177, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.7 to 12.8.csv
# Iter:178, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.8 to 12.9.csv
# Iter:179, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 6.9 to 12.10.csv
# Iter:180, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7.1 to 1.1.csv
# Iter:181, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7.2 to 1.2.csv
# Iter:182, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7.6 to 1.7.csv
# Iter:183, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7.8 to 1.9.csv
# Iter:184, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7.9 to 1.10.csv
# Iter:185, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7_12 to 1_13.csv
# Iter:186, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub II 7_7 to 1_8.csv
# Iter:187, Root Dir:Y:/_Kaleida_Input/Available_Slots, Sub_Dir:Y:/_Kaleida_Input/Available_Slots, Table:Available_Slots, Import_CSV:Sub III 4_1 to 10_2.csv
# Iter:188, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:February 2022 Available Slot.csv
# Iter:189, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:January 2022 available slots.csv
# Iter:190, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.11.csv
# Iter:191, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.12.csv
# Iter:192, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.13.csv
# Iter:193, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.14.csv
# Iter:194, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.15.csv
# Iter:195, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.18.csv
# Iter:196, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.19.csv
# Iter:197, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.20.csv
# Iter:198, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.21.csv
# Iter:199, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.22.csv
# Iter:200, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.25.csv
# Iter:201, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.26.csv
# Iter:202, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.27.csv
# Iter:203, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.28..csv
# Iter:204, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.29.csv
# Iter:205, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.5.csv
# Iter:206, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 4.7 to 4.8.csv
# Iter:207, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.10.csv
# Iter:208, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.11.csv
# Iter:209, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.12.csv
# Iter:210, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.13.csv
# Iter:211, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.16.csv
# Iter:212, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.17.csv
# Iter:213, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.18.csv
# Iter:214, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.19.csv
# Iter:215, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.2.csv
# Iter:216, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.20.csv
# Iter:217, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.23.csv
# Iter:218, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.24.csv
# Iter:219, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.25.csv
# Iter:220, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.26.csv
# Iter:221, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.27 to 5.30.csv
# Iter:222, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.3.csv
# Iter:223, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.31.csv
# Iter:224, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.4.csv
# Iter:225, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.5.csv
# Iter:226, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.6.csv
# Iter:227, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 5.9.csv
# Iter:228, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.1.csv
# Iter:229, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.10.csv
# Iter:230, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.13.csv
# Iter:231, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.14.csv
# Iter:232, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.15.csv
# Iter:233, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.16.csv
# Iter:234, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.17.csv
# Iter:235, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.2.csv
# Iter:236, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.20.csv
# Iter:237, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.21.csv
# Iter:238, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.22.csv
# Iter:239, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.23.csv
# Iter:240, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.24.csv
# Iter:241, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.27.csv
# Iter:242, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.28.csv
# Iter:243, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.29.csv
# Iter:244, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.3.csv
# Iter:245, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.30.csv
# Iter:246, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.6.csv
# Iter:247, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.7.csv
# Iter:248, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.8.csv
# Iter:249, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 6.9.csv
# Iter:250, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.1.csv
# Iter:251, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.11.csv
# Iter:252, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.12.csv
# Iter:253, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.4.csv
# Iter:254, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.5.csv
# Iter:255, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.6.csv
# Iter:256, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.7.csv
# Iter:257, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Main 7.8.csv
# Iter:258, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:March 2022 List of Available Slot.csv
# Iter:259, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.11.csv
# Iter:260, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.12.csv
# Iter:261, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.13.csv
# Iter:262, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.14.csv
# Iter:263, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.15.csv
# Iter:264, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.18.csv
# Iter:265, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.19.csv
# Iter:266, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.20.csv
# Iter:267, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.21.csv
# Iter:268, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.22.csv
# Iter:269, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.25.csv
# Iter:270, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.26.csv
# Iter:271, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.27.csv
# Iter:272, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.28.csv
# Iter:273, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.29.csv
# Iter:274, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.5.csv
# Iter:275, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 4.7 to 4.8.csv
# Iter:276, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.10.csv
# Iter:277, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.11.csv
# Iter:278, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.12.csv
# Iter:279, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.13.csv
# Iter:280, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.16.csv
# Iter:281, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.17.csv
# Iter:282, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.18.csv
# Iter:283, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.19.csv
# Iter:284, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.2.csv
# Iter:285, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.20.csv
# Iter:286, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.23.csv
# Iter:287, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.24.csv
# Iter:288, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.25.csv
# Iter:289, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.26.csv
# Iter:290, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.27 to 5.30.csv
# Iter:291, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.3.csv
# Iter:292, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.31.csv
# Iter:293, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.4.csv
# Iter:294, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.5.csv
# Iter:295, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.6.csv
# Iter:296, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 5.9.csv
# Iter:297, Root Dir:Y:/_Kaleida_Input/Available_Slots_Past, Sub_Dir:Y:/_Kaleida_Input/Available_Slots_Past, Table:Available_Slots_Past, Import_CSV:Sub II 6.1.csv
# ...
# Iter:1843, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 5.3.csv
# Iter:1844, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 5.31.csv
# Iter:1845, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 5.6.csv
# Iter:1846, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 5.9.csv
# Iter:1847, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.1.csv
# Iter:1848, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.10.csv
# Iter:1849, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.13.csv
# Iter:1850, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.14.csv
# Iter:1851, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.15.csv
# Iter:1852, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.16.csv
# Iter:1853, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.17.csv
# Iter:1854, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.2.csv
# Iter:1855, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.20.csv
# Iter:1856, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.21.csv
# Iter:1857, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.22.csv
# Iter:1858, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.23.csv
# Iter:1859, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.24.csv
# Iter:1860, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.27.csv
# Iter:1861, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.28.csv
# Iter:1862, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.3.csv
# Iter:1863, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.6.csv
# Iter:1864, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.7.csv
# Iter:1865, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 6.9.csv
# Iter:1866, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.11.csv
# Iter:1867, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.12.csv
# Iter:1868, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.13.csv
# Iter:1869, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.5.csv
# Iter:1870, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.6.csv
# Iter:1871, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.7.csv
# Iter:1872, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub II Third Next 7.8.csv
# Iter:1873, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 1.3.csv
# Iter:1874, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 12.20.csv
# Iter:1875, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:sub III 12.29.csv
# Iter:1876, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.10.csv
# Iter:1877, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.11.csv
# Iter:1878, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.17.csv
# Iter:1879, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.18.csv
# Iter:1880, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.22.csv
# Iter:1881, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.25.csv
# Iter:1882, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 2.28.csv
# Iter:1883, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 3.1.csv
# Iter:1884, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 3.10.csv
# Iter:1885, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 3.3.csv
# Iter:1886, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 3.4.csv
# Iter:1887, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III 3.7.csv
# Iter:1888, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third 2.8.csv
# Iter:1889, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next  3.2.csv
# Iter:1890, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.10.csv
# Iter:1891, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.11.csv
# Iter:1892, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.13.csv
# Iter:1893, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.19.csv
# Iter:1894, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:SUb III Third Next 1.20.csv
# Iter:1895, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.21.csv
# Iter:1896, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third next 1.24.csv
# Iter:1897, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.25.csv
# Iter:1898, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.26.csv
# Iter:1899, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.27.csv
# Iter:1900, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 1.4.csv
# Iter:1901, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:sub III Third Next 1.5.csv
# Iter:1902, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:sub III third next 1.6.csv
# Iter:1903, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 12.17.csv
# Iter:1904, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:SUb III Third Next 12.20.csv
# Iter:1905, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.15.csv
# Iter:1906, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.16.csv
# Iter:1907, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third next 2.2.csv
# Iter:1908, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.21.csv
# Iter:1909, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.23.csv
# Iter:1910, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.24.csv
# Iter:1911, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.3.csv
# Iter:1912, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.4.csv
# Iter:1913, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:SUb III Third Next 2.7.csv
# Iter:1914, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 2.9.csv
# Iter:1915, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.11.csv
# Iter:1916, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.14.csv
# Iter:1917, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.15.csv
# Iter:1918, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.16.csv
# Iter:1919, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.17.csv
# Iter:1920, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.22.csv
# Iter:1921, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.23.csv
# Iter:1922, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.24.csv
# Iter:1923, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.25.csv
# Iter:1924, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.29.csv
# Iter:1925, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.30.csv
# Iter:1926, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.8.csv
# Iter:1927, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 3.9.csv
# Iter:1928, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next 4.1.csv
# Iter:1929, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III third next1.18.csv
# Iter:1930, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Next3.31.csv
# Iter:1931, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Sub III Third Nxt 1.12.csv
# Iter:1932, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Third Next Available 12.13.csv
# Iter:1933, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Third Next Available 12.17.csv
# Iter:1934, Root Dir:Y:/_Kaleida_Input/Third_Next_Available, Sub_Dir:Y:/_Kaleida_Input/Third_Next_Available, Table:Third_Next_Available, Import_CSV:Third Next Available 12.6.21.csv

# %%
df_import_raw = customize_column_name_clean_up(df_import_raw)
df_import_raw.head(3)
# Out:
#                 Name  Account Appointment_Date Booked_Date  \
# 0  Adamczak, Jillian   927293       02/14/2022  02/10/2022
# 1    Alwasim, Hesham   909327       02/14/2022  02/11/2022
# 2     Bender, Easton   931590       02/18/2022  02/18/2022
#
#    Number_Days_To_Get_In             Appointment_Type  VIP Direct  \
# 0                      4  WellNow - New Patient Visit  Yes     No
# 1                      3                       Access   No     No
# 2                      0  WellNow - New Patient Visit   No     No
#
#                Provider Access_SpecialtyTodo_Selection  \
# 0        Daye, Lisa, MD                            NaN
# 1         Team Jennings                 Cardiovascular
# 2  Aduddle, Melissa, PA                            NaN
#
#   Wellnow_SpecialtyTodo_Selection Wellnow_Location_To_Do_Selection  \
# 0                  Orthopedic Vip                          Lantran
# 1                             NaN                              NaN
# 2                             NaN                              NaN
#
#    Wellnow_Ticket_Number Wellnow_Uc_Visit_Date To_Do_Date_Create_Date  \
# 0                    NaN            02/08/2022             02/14/2022
# 1                    NaN                   NaN             01/06/2022
# 2                    NaN                   NaN                    NaN
#
#    Ebill_Esuper_Bill_Number Referral_From_To_Do_Selection Access_VIP  \
# 0                 9664835.0                           NaN         No
# 1                 9669640.0                         Other        Yes
# 2                 9692062.0                           NaN         No
#
#   Access_Direct
# 0            No
# 1            No
# 2            No

# %%
global detail_debugging 
detail_debugging = True

# %% [markdown]
# ##  Step 4: Clean the data and make it consistent in the PANDAS Dataframe.

# %%
column_datatype_Str = str(df_event_log.dtypes)
column_datatype_Str =  column_datatype_Str.replace('dtype: object','').replace('object','varchar[255], ').replace('datetime64[ns]','timestamp, ').replace('float64','float, ')
print('create column SQL string:\n', column_datatype_Str)
# Out:
# create column SQL string:
#  Event_ID                   varchar[255],
# Process_Name               varchar[255],
# Event_Name                 varchar[255],
# Event_Date         timestamp,
# Event_Time         timestamp,
# Task_Start_Time           float,
# Task_End_Time             float,
# TASk_Duration              varchar[255],
# Comments                   varchar[255],

# %%
file_Name = df_import_files[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_31888/2609346552.py in <module>
# ----> 1 file_Name = df_import_files[1]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 1

# %%
df_import_files.head()

# %% [markdown]
# ## Step 5: Check the data consistency and perform change control if there are differences.

# %% [markdown]
# ## Step 6: Convert the pandas dataframes into SQL table Create Statements

# %% [markdown]
# ## Step 7: Creates the SQL tables in the target Database

# %% [markdown]
# ## Step 8: Insert the the PANDAS Rows into SQL using the to_SQL Method.

# %% [markdown]
# ## Step 9: Add event logging to capture the performance of the entire process.

# %% [markdown]
# ## Step 10: Document the SCHEMA into an easy to use Excel Spreadsheet.

# %% [markdown]
# ## Step 11: Check the total number of records imported via SQL to the total raw record count to make sure no data is Left Behind.

# %%
sql_columns = column_create_SQL(df_e_log)
sql_columns_cleaned = ' '.join([character_replacements.get(i, i) for i in sql_columns.split()])
sql_dtypes =  df_e_log.dtypes 
sql_column_data_types_cleaned = ' '.join([data_type_replacements.get(i, i) for i in sql_dtypes])

print('SQL Columns  =',sql_columns ,' /n ' 'SQL Columns Cleaned =',sql_columns_cleaned)

# %%
def determine_table_name_for_path(path):

    table_name = path.replace(Data_Import_Starting_Directory,"").replace(' ','_').replace('/','').replace('\\','')
    return table_name 


path = 'Y:/_Kaleida_Input/Available_Slots/'
table_name_for_path = determine_table_name_for_path(path)
print('Table Name:{} is determined from path:{}'.format(table_name_for_path,path) )

# %%
def read_and_import_all_csv_files(path):
    
    if importing_xlsx_files: 
        extension = 'xlsx'
    if importing_csv_files: 
        extension = 'csv'        
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        print('File',str(csv_file_count),": ", file)
        add_log_event(Process_Name,'Found Table to Import',Event_Date,Event_Time,Task_Start_Time,Task_End_Time, Task_Duration , 'Found Table to Import :' + file):
   
        
read_and_import_all_csv_files('Y:/_Kaleida_Input/Available_Slots/')

# %%
Drop_Table_SQL  = Create_Drop_Table_SQL('Access_DI')
# SQL_Result = execute_SQL(Drop_Table_SQL)
# out('SQL Execute Result: {} '.format(SQL_Result))

# %%
print('Starting Iport Walk at Directory:',Data_Import_Starting_Directory)
list_all_subdirectories(Data_Import_Starting_Directory)
df_import_directories

# %%
df_import_directories.head(100)

# %%
# Get a list of all the Subfiles to iterate through 
def execute_table_Create_SQL(path, table_name):
    
    executing_SQL = False 
    
    extension = 'csv'
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        if csv_file_count == 1:
            print('Creating_Table',table_name,' based upon 1st sample','File',str(csv_file_count),": ", file)     
            data_folder =  path
            filename = data_folder + table_name +'.csv'
            print ('raw file name to rcreate from:',filename)
            DROP_table_SQL = build_DROP_table_SQL(file, table_name,'_DI]')  
            create_table_SQL = build_table_create_SQL(file, table_name,'_DI]')

    if executing_SQL:     
            print ('/n DROP SQL = ',DROP_table_SQL  )         
            print ('/n create SQL = ',create_table_SQL  )     
            execute_SQL(DROP_table_SQL)            
            execute_SQL(create_table_SQL)
        
execute_table_Create_SQL('Y:/_Kaleida_Input/Access/','Access')

# %%
# Get a list of all the Subfiles to iterate through 
def walk_sub_directories(root_directory): 
 #print('list_sub_directories for root Ditrectory {} \n'.format(root_directory) )   
 directory_entry = 0 
 Table_Name = ''
 print('About to Walk')
 for root,directory, file in os.walk(root_directory):
    print('Walking....   ')
    #print('Root Directory: {} subdir: {} \n'.format(root_directory,directory_entry) )
    
    if root.find('Access') >= 0:
        Table_Name = 'Access'
    elif root.find('Daily Time Card') >= 0:
        Table_Name = 'Daily_Time_Card'                
    elif root.find('Employee Census') >= 0:
        Table_Name = 'Employee_Census'               
    elif root.find('ADP') >= 0:
        Table_Name = 'ADP'  
    elif root.find('Employee Census') >= 0:
        Table_Name = 'Employee_Census'   
    elif root.find('Available_Slots') >= 0:
        Table_Name = 'Available_Slots'     
    elif root.find('Available_Slots_Past') >= 0:
        Table_Name = 'Available_Slots_Past'    
    elif root.find('Call Center') >= 0:
        Table_Name = 'Call_Center'    
    elif root.find('CPT Visit') >= 0:
        Table_Name = 'CPT_Visit'    
    elif root.find('Visit') >= 0:
        Table_Name = 'Visit'  
    elif root.find('DailyAppointments') >= 0:
        Table_Name = 'Daily_Appointments'    
    elif root.find('DailyCPT') >= 0:
        Table_Name = 'Daily_CPT'    
    elif root.find('DailyMultipleAppointmentSameDay') >= 0:
        Table_Name = 'Daily_Multiple_Appointment_Same_Day'   
    elif root.find('DailyScheduledOfficeAppointmentVisit') >= 0:
        Table_Name = 'Daily_Scheduled_Office_Appointment_Visit'               
        PatientExperienceDefault
    else:
        Table_Name = 'Unknown Table Name'
    print('Root Directory'+str(directory_entry) +':',root+'Default Table Name for Directory :', Table_Name,' \n')            
    #list_all_csv_files(root)  
    if Table_Name != 'Unknown Table Name':
        execute_table_Create_SQL(root,Table_Name)  
    directory_entry += 1     
 
# Test function call     
list_sub_directories('Y:/_Kaleida_Input/')

# %%
# Get a list of all the Subfiles to iterate through 
def walk_sub_directories(root_directory):
    df_import_directories = create_directory_dataframe() 
    print('list_sub_directories for root Directory {} \n'.format(root_directory) )   
    directory_entry = 0 
    files_to_import = 0 
    Table_Name = ''
    for root, subdirectories, files in os.walk(root_directory):
        directory_entry += 1 
        print('Directory entry# {} {} .'.format(directory_entry,root ))
        #print('Root: {} has subdirs{}'.format(root, subdirectories)
              
    print('End of function ')              
    return df_import_directories
              
walk_sub_directories('Y:/_Kaleida_Input/')              

#         for subdir in subdirectories:
#               print('S---- Subdir: {}'.format(subdir)
#               for file in files:
#                    if dir_entry.find('.csv') >= 1:
#                        files_to_import += 1 
#                        print('F---- ----- file# {} to import: {}'.format(files_to_import,file) 
#                    else:
#                        print('NF--- ----- file#   to NOT import: {}'.format(file)                           
                             
                             
                 
        
        
#         for dir_entry in directory_contents:
#             print('Walking directory{} entry {}'.format(directory_entry, dir_entry))
#             if os.path.isfile(dir_entry):
#                 if dir_entry.find('.csv') >= 1:
#                     print('File #{} to Import: {}'.format(directory_entry, dir_entry))
             
            
#         row_values = [root,directory, file,'Pretend Tablename']
#         df_import_directories.loc[directory_entry] = row_values

#         print('Walking Root Directory: {} subdir: {} '.format(root_directory,directory_entry) )
#         if root.find('Access') >= 0:
#             Table_Name = 'Access'
#         elif root.find('Daily Time Card') >= 0:
#             Table_Name = 'Daily_Time_Card'                
#         elif root.find('Employee Census') >= 0:
#             Table_Name = 'Employee_Census'               
#         elif root.find('ADP') >= 0:
#             Table_Name = 'ADP'  
#         elif root.find('Employee Census') >= 0:
#             Table_Name = 'Employee_Census'   
#         elif root.find('Available_Slots') >= 0:
#             Table_Name = 'Available_Slots'     
#         elif root.find('Available_Slots_Past') >= 0:
#             Table_Name = 'Available_Slots_Past'    
#         elif root.find('Call Center') >= 0:
#             Table_Name = 'Call_Center'    
#         elif root.find('CPT Visit') >= 0:
#             Table_Name = 'CPT_Visit'    
#         elif root.find('Visit') >= 0:
#             Table_Name = 'Visit'  
#         elif root.find('DailyAppointments') >= 0:
#             Table_Name = 'Daily_Appointments'    
#         elif root.find('DailyCPT') >= 0:
#             Table_Name = 'Daily_CPT'    
#         elif root.find('DailyMultipleAppointmentSameDay') >= 0:
#             Table_Name = 'Daily_Multiple_Appointment_Same_Day'   
#         elif root.find('DailyScheduledOfficeAppointmentVisit') >= 0:
#             Table_Name = 'Daily_Scheduled_Office_Appointment_Visit'               
#             PatientExperienceDefault
#         else:
#             Table_Name = 'Unknown Table Name'
#         #print('Root Directory'+str(directory_entry) +':',root+'Default Table Name for Directory :', Table_Name,' \n')            
#         #list_all_csv_files(root)  
#         if Table_Name != 'Unknown Table Name':
#             execute_table_Create_SQL(root,Table_Name)  
#         directory_entry += 1     

#         # Test function call   \

# %%
def build_table_create_SQL(filename , table_name, table_Postfix ):
    Table_Schema_Prefix = '[pbic_1_0].[' 
    Table_Name = table_name        # 'Daily_Appointments'
    Table_Name_Postfix = table_Postfix  # Passed in as '_DI]' or '_HX]'
    Table_Name = Table_Name + Table_Name_Postfix
    column_str = '' 
    print('Import File =', filename)   

    df_input_csv = pd.read_csv(filename, nrows=10)
    number_of_columns = df_input_csv.shape[1]
    header_columns = df_input_csv.columns
    row1_columns = df_input_csv.iloc[0:1, : ]
    print('Header: ',header_columns)
    print('row1_columns: ',row1_columns)    

    #column_list = [x.strip().title().replace("^","") for x in df_input_csv.columns]
    for col in range(0,number_of_columns):
        #column_str = column_str + str(df_input_csv.columns[col]) + ' ' + str(df_input_csv.dtypes[col]) + ' NULL, ' 
        column_str = column_str + str(df_input_csv.columns[col]) + ' ' + str(df_input_csv.dtypes[col]) + ', ' 
    if table_Postfix == '_DI]':
        column_str = column_str.replace("object","nvarchar(255) ").replace("float64","nvarchar(255)  ").replace("int64","nvarchar(255)  ")
    if table_Postfix == '_HX]':
        column_str = column_str.replace("object","nvarchar(255) ").replace("float64","float  ").replace("int64","int  ")
        
    Create_table_SQL  = 'Create Table ' + Table_Schema_Prefix + Table_Name + "("  + column_str + "); "
    Create_table_SQL = Create_table_SQL.replace(", );",");") 
    return Create_table_SQL

data_folder =  Path('Y:\_Kaleida_Input\DailyAppointments')
filename = data_folder / 'July 2022.csv'
create_table_SQL = build_table_create_SQL(filename, 'Daily_Appointments','_DI]')
print("\n Historical Table" + create_table_SQL)

# %%
df_import_directories.head()

# %%
#DROP the table Dynamically 
def drop_table_SQL(drop_SQL):
    global sql_connector
    print('Drop Table - Before SQL Connect - Call')
 #   logging.debug('Drop Table - Before SQL Connect - Call')
    cnxn = pyodbc.connect(sql_connector)
    cursor = cnxn.cursor()
    sql_execute_result = cursor.execute(drop_SQL)
    print('After SQL Call','Result Code: ',sql_execute_result)
 #   logging.debug('Drop Table - After SQL Connect - Call')    
    
    cnxn.commit()
    cursor.close()

# %%
#Execute SQL  Dynamically 
def execute_SQL(execute_SQL_command):
    global sql_connector
    print('Execute SQL Connect - Call')
    cnxn = pyodbc.connect(sql_connector)
    cursor = cnxn.cursor()
    sql_execute_result = cursor.execute(execute_SQL_command)
    print('After SQL Call','Result Code: ',sql_execute_result)
 #   logging.debug('Drop Table - After SQL Connect - Call')    
    
    cnxn.commit()
    cursor.close()

# %%
drop_SQL = 'DROP TABLE [pbic_1_0].[Access_DI]'

drop_table_SQL(drop_SQL)

# %%
def Create_Drop_Table_SQL(Table_Name):
    #drop_SQL = 'DROP TABLE [pbic_1_0].[' + Table_Name + ']'
    
    
    drop_SQL =  'DROP TABLE [pbic_1_0].[{}]'.format("'", Table_Name)
 
# IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[pbic_1_0].[Access_DI]') AND type in (N'U'))
# DROP TABLE [pbic_1_0].[Access_DI]    
    return drop_SQL

# %%
Drop_Table_SQL = Create_Drop_Table_SQL('Access_DI')

print(Drop_Table_SQL) 
#execute_SQL(Drop_Table_SQL)

# %%
drop_SQL = 'DROP TABLE [pbic_1_0].[Daily_Appointments_DI]'
drop_table_SQL(drop_SQL)

# %%
def read_and_clean_file(data_folder, filename):

    print('Import File =', filename)                 
    df_input_csv = pd.read_csv(filename, nrows=10)
    #print(df_input_csv.columns)
    df_input_csv.columns = df_input_csv.columns.map('^'.join)
    df_input_csv.columns  = [x.strip().title().replace("^","").replace(" ","_").replace("#","Number").replace("#","Number").replace("%","Percentage") \
                             .replace('_Unnamed','').replace('Unnamed','').replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_input_csv.columns]

    print(df_input_csv.columns)

# %%
def build_Dataframe_table_create_SQL(dataframe_to_Create, table_name, table_Postfix  ):
    Table_Schema_Prefix = '[pbic_1_0].[' 
    Table_Name = table_name        # 'Daily_Appointments'
    Table_Name_Postfix = table_Postfix  # Passed in as '_DI]' or '_HX]'
    Table_Name = Table_Name + Table_Name_Postfix
    column_str = '' 
 

    df_input_csv = pd.read_csv(filename, nrows=10)
    number_of_columns = df_input_csv.shape[1]
    header_columns = df_input_csv.columns
    row1_columns = df_input_csv.iloc[0:1, : ]
    print('Header: ',header_columns)
    print('row1_columns: ',row1_columns)    

    
    df_input_csv.columns  = [x.strip().title().replace("Address 1","Street_Address").replace("Address 2","Address_Two") \
                             .replace("^","").replace("-","_").replace(" ","_").replace("#","Number").replace("#","Number") \
                             .replace("%","Percentage").replace('_Unnamed','').replace('Unnamed','') \
                             .replace('Unnamed:','').replace('_Level','').replace("$","Dollar") \
                             .replace('_1','').replace('_2','').replace('_3','').replace('_4','').replace('_5','')  \
                             .replace('_6','').replace('_7','').replace('_8','').replace('_9','')  \
                             .replace('1','').replace('2','').replace('3','').replace('4','').replace('5','')  \
                             .replace('6','').replace('7','').replace('8','').replace('9','').replace('0','')  \
                             .replace('_0','').replace(':7','').replace(':8','').replace(':','').replace('Unnamed: ','')  \
                             for x in df_input_csv.columns]
    
         
            
    #column_list = [x.strip().title().replace("^","") for x in df_input_csv.columns]
    for col in range(0,number_of_columns):
        #column_str = column_str + str(df_input_csv.columns[col]) + ' ' + str(df_input_csv.dtypes[col]) + ' NULL, ' 
        column_str = column_str + str(df_input_csv.columns[col]) + ' ' + str(df_input_csv.dtypes[col]) + ', ' 
    if table_Postfix == '_DI]':
        column_str = column_str.replace("object","nvarchar(255) ").replace("float64","nvarchar(255)  ").replace("int64","nvarchar(255)  ")
    if table_Postfix == '_HX]':
        column_str = column_str.replace("object","nvarchar(255) ").replace("float64","float  ").replace("int64","int  ")
        
    Create_table_SQL  = 'Create Table ' + Table_Schema_Prefix + Table_Name + "("  + column_str + "); "
    Create_table_SQL = Create_table_SQL.replace(", );",");") 
    return Create_table_SQL

data_folder =  Path('Y:\_Kaleida_Input\DailyAppointments')
filename = data_folder / 'July 2022.csv'
create_table_SQL = build_table_create_SQL(filename, 'Daily_Appointments','_DI]')
print("\n Historical Table" + create_table_SQL)

# %%
def build_DROP_table_SQL(filename , table_name, table_Postfix ):
    Table_Schema_Prefix = '[pbic_1_0].[' 
    Table_Name = table_name        # 'Daily_Appointments'
    Table_Name_Postfix = table_Postfix  # Passed in as '_DI]' or '_HX]'
    Table_Name = Table_Name + Table_Name_Postfix
    DROP_table_SQL  = 'DROP Table ' + Table_Schema_Prefix + Table_Name  
    return DROP_table_SQL

# %%
data_folder =  Path('Y:\_Kaleida_Input\DailyAppointments')
filename = data_folder / 'July 2022.csv'
create_table_SQL = build_table_create_SQL(filename, 'Daily_Appointments','_DI]')

print("\nDaily Table Create SQL: \n" + create_table_SQL)

create_table_SQL = build_table_create_SQL(filename, 'Daily_Appointments','_HX]')

print("\nHistorical Table Create SQL: \n" + create_table_SQL)

# %%
# Y:/_Kaleida_Input/Access/2459652_467_20220313074723_dmhmreport_EHRSUPPORT_2179577.csv
data_folder =  Path('Y:\_Kaleida_Input\Access')
filename = data_folder / '2459652_467_20220313074723_dmhmreport_EHRSUPPORT_2179577.csv'
create_table_SQL = build_table_create_SQL(filename, 'Daily_Appointments')

print("\n" + create_table_SQL)

# %%
# IF  EXISTS (SELECT * FROM sys.objects WHERE object_id = OBJECT_ID(N'[pbic_1_0].[Daily_Appointments_DI]') AND type in (N'U'))
# DROP TABLE [pbic_1_0].[Daily_Appointments_DI]


drop_SQL = 'DROP TABLE [pbic_1_0].[Daily_Appointments_DI]'
drop_table_SQL(drop_SQL)

# %%
execute_SQL(create_table_SQL)
print("\n" + create_table_SQL)

# %%
# data_folder = Path('Y:\_Kaleida_Input\Access')
# filename = data_folder / '2459638_97_20220227013752_dmhmreport_EHRSUPPORT_5187581.csv'

data_folder =  Path('Y:\_Kaleida_Input\DailyAppointments')
filename = data_folder / 'July 2022.csv'
 
read_and_clean_file(data_folder,filename)

# %%
 def create_table_headers(input_data_frame):
    global column_inserts
    global column_question_mark
    global create_table_SQL
    global create_real_table_SQL
    global insert_records_SQL
    global Table_Name_Prefix
    global Table_Name_Extension_Daily
    global Table_Name_Extension_Historical
    global create_schema_SQL
    global create_real_schema_SQL
        
    Table_Name = 'Access'
    sample_row = 3
    create_table_SQL = ''
    create_real_table_SQL = ''
    insert_records_SQL = ''
    Table_Name_Daily = Table_Name_Prefix + Table_Name + Table_Name_Extension_Daily
    Table_Name_Historical = Table_Name_Prefix + Table_Name + Table_Name_Extension_Historical
    df_cols = input_data_frame.columns
    df_types = input_data_frame.dtypes
    col_number = 0
    column_creates = ''
    column_values = ''
    column_inserts = ''
    real_column_creates = ''
    column_question_mark = ''
    for column_name in df_cols:
        col_number = col_number + 1


        if df_types[col_number-1] == 'object':
            sql_column_type = 'Varchar(255)'
        elif df_types[col_number-1] == 'float64': 
            sql_column_type = 'Varchar(255)'
        else:
            sql_column_type = 'Varchar(255)'

        if df_types[col_number-1] == 'object':
            real_sql_column_type = 'Varchar(255)'
        elif df_types[col_number-1] == 'float64': 
            real_sql_column_type = 'Varchar(255)'
        else:
            real_sql_column_type = 'Varchar(255)'                
                

        column_name = column_name.title()
        column_name = column_name.replace(' ','_')
        column_name = column_name.replace('#','Number')
        column_inserts = column_inserts + column_name
        column_value = str(input_data_frame.iloc[sample_row,col_number-1])
        column_creates = column_creates + column_name + " "  + sql_column_type
        real_column_creates = real_column_creates + column_name + " "  + real_sql_column_type
        column_values = column_values + "'" + column_value + "'"
        print(col_number, '  ', column_name)
            
    insert_records_SQL = 'INSERT INTO ' + Table_Name_Daily + '  (' + column_inserts + ') + VALUES (' + column_values + '); '
    create_table_SQL = 'CREATE TABLE ' + Table_Name_Daily + '  (' + column_creates + '); '
    create_real_table_SQL = 'CREATE TABLE ' + Table_Name_Historical + '  (' + real_column_creates + '); '
    create_schema_SQL = create_schema_SQL + create_table_SQL
    create_real_schema_SQL = create_real_schema_SQL + create_real_table_SQL
    #logging.debug('Table Create Finished')

# %%
#filename = 'Y:\_Kaleida_Input\Access\2459638_97_20220227013752_dmhmreport_EHRSUPPORT_5187581.csv'
start_time1 = time.time()

data_folder = Path('Y:\_Kaleida_Input\Access')
filename = data_folder / '2459638_97_20220227013752_dmhmreport_EHRSUPPORT_5187581.csv'

print('Import File =', filename)                 
df_input_csv = pd.read_csv(filename, nrows=10, header=[0,1])
df_input_csv.columns = df_input_csv.columns.map('_'.join)
create_table_headers(df_input_csv) 


#print('\n' + ' column_inserts:  ', column_inserts, '\n') 
#print('\n' + 'column_question_mark:  ', column_question_mark, '\n') 
#print('\n' + 'insert_records_SQL:  ', insert_records_SQL, '\n')
print('\n' + 'create_table_SQL:  ', create_table_SQL, '\n')
print('\n' + 'create_real_table_SQL:  ', create_real_table_SQL, '\n')

# logging.debug('Table Create Finished')
end_time2 = time.time()
print(f'{start_time1-end_time2:.5f}')

# %%
df_input_csv.head(2)

# %%
dailyappointment_df = pd.read_csv(r'C:\DailyAppointment_A_J_Test\Main 3.1 to 9.1.xlsx', low_memory = False, header = [0,1])
Main 3.1 to 9.1.xlsx

Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots
dailyappointment_df.columns = dailyappointment_df.columns.map('_'.join)
dailyappointment_df = dailyappointment_df.fillna(0)
dailyappointment_df['Unnamed: 3_Appt Length'] = dailyappointment_df['Unnamed: 3_Appt Length'].astype(int)
#...
engine = sqlalchemy.create_engine(
               "mssql+pyodbc://gppc:Elephant-Trunk-06@Kalpwvsqlgppc01/GPPC_DEV?DRIVER={ODBC Driver 17 for SQL Server}",
               echo=False)
# # df = pd.read_sql_query('SELECT * FROM pbic_1_0.Access',conn)
import time 
start_time1 = time.time()
#dailyappointment_df.to_sql('dailyappointment_test', con=engine, if_exists='replace')
end_time2 = time.time()
print(f'{start_time1-end_time2:.5f}')

# %%
start_time1 = time.time()
# Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Main 2.28 to 8.28.xlsx' )
# Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Main 3.1 to 9.1.xlsx' )
#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Main 3.2 to 9.2.xlsx' )

#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub II 2.28 to 8.28.xlsx' )
#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub II 3.1 to 9.1.xlsx' )
#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub II 3.2 to 8.2.xlsx' )

# Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub III 2.28 to 8.28.xlsx' )
#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub III 3.1 to 9.1.xlsx' )
#Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Sub III 3.2.xlsx' )

Available_Slots_df = pd.read_excel(r'Z:\GPPC_SOURCE_FILES\Oneday_data_04072022\Oneday_data\Available_Slots\Main 3.1 to 9.1.xlsx' )
Available_Slots_df.rename(columns={'Doctor Name' : 'Doctor_Name','Loc UId' : 'Loc_UId'}, inplace = True)
 
shape = Available_Slots_df.shape
print('\nDataFrame Shape :', shape)
print('\nNumber of rows :', shape[0])
print('\nNumber of columns :', shape[1])

# logging.debug('Table Create Finished')
end_time2 = time.time()
# row_count = Available_Slots_df.shape[1]
file_read_time = end_time2-start_time1
print(' Rows Count:{}'.format(row_count) )

print('Read raw file to Pandas Read Time',f'{file_read_time :.5f}')
print(' Rows per second:',str(row_count/execute_time) )

create_table_headers(Available_Slots_df)

# %%
# Get a list of all the Subfiles to iterate through 
def list_all_csv_files(path):
    
    extension = 'xlsx'
    os.chdir(path)
    print('CSV Files to Import from Directory:', path)
    csv_file_count = 0
    for file in glob.glob('*.{}'.format(extension)):
        csv_file_count += 1 
        print('File',str(csv_file_count),": ", file)
   
        
list_all_csv_files('Z:/GPPC_SOURCE_FILES/Oneday_data4_1_22/Available_Slots/')

# %%
constring = "mssql+pyodbc://gppc:Elephant-Trunk-06@Kalpwvsqlgppc01/GPPC_DEV?DRIVER={ODBC Driver 17 for SQL Server}"  
engine = sqlalchemy.create_engine(constring,fast_executemany=True,echo=False)

start_time1 = time.time()


Available_Slots_df.to_sql('Available_Slots', con=engine, if_exists="append",index=False,chunksize=20000, dtype =  
                             {'datefld': sqlalchemy.DateTime(), 
                             'intfld':  sqlalchemy.types.INTEGER(),
                             'strfld': sqlalchemy.types.NVARCHAR(length=255),
                             'floatfld': sqlalchemy.types.Float(precision=3, asdecimal=True),
                             'booleanfld': sqlalchemy.types.Boolean,
                             'bool' : sqlalchemy.types.Boolean,
                             'float64' : sqlalchemy.types.NVARCHAR(length=255),
                             'int64' : sqlalchemy.types.INTEGER(),
                             'object' : sqlalchemy.types.NVARCHAR(length=50000)})


# shape = Available_Slots_df.shape
# print('\nDataFrame Shape :', shape)
# print('\nNumber of rows :', shape[0])
# print('\nNumber of columns :', shape[1])
 
# logging.debug('Table Create Finished')
end_time2 = time.time()
# row_count = Available_Slots_df.shape[1]
execute_time = end_time2-start_time1
print(' Rows Count:{}'.format(row_count) )

print('SQL Insert Execution Time',f'{execute_time :.5f}')
print(' Rows per second:',str(row_count/execute_time) )

# %%
create_table_headers(Available_Slots_df)

# %%
CREATE TABLE [pbic_1_0].[Available_Slots](
	[Date] [nvarchar](20) NULL,
	[Day] [nvarchar](50) NULL,
	[Time] [nvarchar](20) NULL,
	[Length] [int] NULL,
	[Dr] [nvarchar](50) NULL,
	[Doctor_Name] [nvarchar](max) NULL,
	[Loc] [nvarchar](50) NULL,
	[Loc_UId] [nvarchar](50) NULL,
	[Type] [nvarchar](50) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

# %%
Available_Slots_df.info

# %%
constring = "mssql+pyodbc://gppc:Elephant-Trunk-06@Kalpwvsqlgppc01/GPPC_DEV?DRIVER={ODBC Driver 17 for SQL Server}"  
engine = sqlalchemy.create_engine(constring,fast_executemany=True,echo=False)

df.to_sql('Available_Slots', con=engine, if_exists="append",index=False,chunksize=1000, dtype =  
                             {'datefld': sqlalchemy.DateTime(), 
                             'intfld':  sqlalchemy.types.INTEGER(),
                             'strfld': sqlalchemy.types.NVARCHAR(length=255),
                             'floatfld': sqlalchemy.types.Float(precision=3, asdecimal=True),
                             'booleanfld': sqlalchemy.types.Boolean,
                             'bool' : sqlalchemy.types.Boolean,
                             'float64' : sqlalchemy.types.NVARCHAR(length=255),
                             'int64' : sqlalchemy.types.INTEGER(),
                             'object' : sqlalchemy.types.NVARCHAR(length=50000)})

# %%
#Insert a row of values 
def insert_row_SQL(insert_row_SQL):
    global server #= 'Kalpwvsqlgppc01' 
    global database #database = 'GPPC_DEV' 
    global username # =  'GPPC'
    global pwd # ='Elephant-Trunk-06'
    cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection=No;UID='+username+';PWD='+pwd)
    cursor = cnxn.cursor()
    sql_execute_result = cursor.execute(insert_row_SQL)
    print('After SQL Call','Result Code: ',sql_execute_result)
    cnxn.commit()
    cursor.close()

# %%
#Insert a row of values 
def insert_row_SQL(insert_row_SQL):
    global server #= 'Kalpwvsqlgppc01' 
    global database #database = 'GPPC_DEV' 
    global username # =  'GPPC'
    global pwd # ='Elephant-Trunk-06'
    cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';Trusted_Connection=No;UID='+username+';PWD='+pwd)
    cursor = cnxn.cursor()
    sql_execute_result = cursor.execute(insert_row_SQL)
    print('After SQL Call','Result Code: ',sql_execute_result)
    cnxn.commit()
    cursor.close()

# %%
drop_table_SQL = 'DROP TABLE [pbic_1_0].[Access_DI]'
drop_table_SQL(drop_table_SQL)

# %%
drop_table_SQL = 'DROP TABLE [pbic_1_0].[dailyappointment_test]'
drop_SQL_table(drop_table_SQL)

# %%
constring = "mssql+pyodbc://gppc:Elephant-Trunk-06@Kalpwvsqlgppc01/GPPC_DEV?DRIVER={ODBC Driver 17 for SQL Server}"  
engine = sqlalchemy.create_engine(constring,fast_executemany=True,echo=False)

df.to_sql('Hx', con=engine, if_exists="append",index=False,chunksize=1000, dtype = 
{'datefld': sqlalchemy.DateTime(), 
'intfld': sqlalchemy.types.INTEGER(),
'strfld': sqlalchemy.types.NVARCHAR(length=255),
'floatfld': sqlalchemy.types.Float(precision=3, asdecimal=True),
'booleanfld': sqlalchemy.types.Boolean,
'bool' : sqlalchemy.types.Boolean,
'float64' : sqlalchemy.types.NVARCHAR(length=255),
'int64' : sqlalchemy.types.INTEGER(),
'object' : sqlalchemy.types.NVARCHAR(length=50000)})

# %%
insert_SQL = create_insert_row(df_input_csv, 3, 'Access_DI')
print('Insert SQL: ', insert_SQL)

# %%
create_SQL_table(create_table_SQL)

# %%
global Process_Name 

today = date.today()

start_time1 = time.time() 
time.sleep(3)
end_time2 = time.time() 
execute_time = end_time2-start_time1
add_log_event(Process_Name,'Starting Import Process',date.today(),datetime.now(),start_time1,end_time2, execute_time , "Starting Import Process")
start_time1 = time.time() 
time.sleep(2)
end_time2 = time.time() 
execute_time = end_time2-start_time1
add_log_event(Process_Name,'Reading the CSV files',date.today(),datetime.now(),start_time1,end_time2, execute_time , "Reading the CSV filesS")
start_time1 = time.time() 
time.sleep(1)
end_time2 = time.time() 
execute_time = end_time2-start_time1
add_log_event(Process_Name,'Writing to SQL Server',date.today(),datetime.now(),start_time1,end_time2, execute_time , "Writing to SQL Server")
start_time1 = time.time() 
time.sleep(2)
end_time2 = time.time() 
execute_time = end_time2-start_time1
add_log_event(Process_Name,'Import Process END ',date.today(),datetime.now(),start_time1,end_time2, execute_time , "Import Process END")

df_e_log.head()

# %%
insert_SQL = create_insert_row(df_input_csv, 3, 'Access_DI')
print('Insert SQL: ', insert_SQL)

# %%
def insert_rows(insert_SQL):

# %%
#Identify the parent directory for all the data subdirectories 
parent_dir = 'Y:/_Kaleida_Input/' #path to folder that contians the data folders

path = parent_dir
import_file_type = '\*.csv'
create_table_SQL = ''
insert_records_SQL = '' 
create_schema_SQL = '' 
column_inserts  = ''
column_question_mark  = ''

# %%
def iterate_import_files(data_directory_path, import_file_type ):
    all_files = glob.glob(data_directory_path + import_file_type)
    return all_files

# %%
insert_SQL = create_insert_row(df_input_csv, 3, 'Access_DI')
   ...: print('Insert SQL: ', insert_SQL)
   ...: insert_row_SQL(insert_SQL)

# %%
 create_SQL_table(create_table_SQL)

# %%
def create_table_headers(input_data_frame):
    global column_inserts  
    global column_question_mark  
    global create_table_SQL 
    global insert_records_SQL 

    Table_Name = 'Access'
    df_cols = input_data_frame.columns
    df_types = input_data_frame.dtypes 
    col_number = 0 
    column_inserts = '' 
    column_creates = '' 
    column_question_mark = '' 
    for column_name in df_cols:
        col_number = col_number + 1
        if len(column_inserts) > 1:
            column_inserts = column_inserts + ", "
        if len(column_creates) > 1:
            column_creates = column_creates + ", "     
        if df_types[col_number-1] == 'object':
            sql_column_type = 'Varchar(255)'
        elif df_types[col_number-1] == 'float64':  
            sql_column_type = 'Varchar(255)' 
        else:
            sql_column_type = 'Varchar(255)' 
        column_name = column_name.title()
        column_name = column_name.replace(' ','_')
        column_name = column_name.replace('#','Number')
        column_inserts = column_inserts + column_name 
        
        column_creates = column_creates + column_name + " "  + sql_column_type 
        column_question_mark = column_question_mark + "?, "
        print(col_number, '  ', column_name) 
    #print('column_inserts:  ', column_inserts) 
    #print('column_question_mark:  ', column_question_mark) 
    print('column_creates:  ', column_creates)  

    insert_records_SQL = 'INSERT INTO ' + Table_Name + '(' + column_inserts + ') VALUES (' + column_question_mark + ');' 
    create_table_SQL = 'CREATE TABLE ' + Table_Name + '(' + column_creates + ');'

# %%
df_input_csv.dtypes

# %%
# %who str

# %%
all_files = iterate_import_files('Y:\_Kaleida_Input\Access','\\*.csv')
# print(all_files[1])
for filename in all_files:
    print(filename)
    df = pd.read_csv(filename, nrows=10)
df.head()

# %%
all_files = glob.glob('C:\Data\Behavioral Health'+ '\*.csv')
print(all_files)
print(all_files[1])

# %%
#remove all csv files from dir and unzip folder
parent_dir = 'C:/Power BI/' #path to folder
path = parent_dir

#get csv list
for file in os.listdir(path):
    if file.endswith('.csv'):
        os.remove(path+file)    
        
with ZipFile(path+'PowerBiDownload.zip', 'r') as zipObj:
   zipObj.extractall(path)   

#remove files
#remove files not in list
csv_path = r'S:\Data Team\Source Data\python sql\needed tables.csv'
ext = ".csv"
with open(csv_path, 'r') as csvfile:
    good_files = []
    for n in csv.reader(csvfile):
        if len(n) > 0: good_files.append(n[0])
    all_files = os.listdir(path)
    for filename in all_files:
        if filename.endswith(ext) and filename not in good_files:
            full_file_path = os.path.join(path, filename)
            os.remove(full_file_path)

print('Old files removed, new files unzipped')

# %%
#Pull in helper tables, covert to csv and delete old helper tables
with open('S:/Data Team/Source Data/python sql/helper tables.csv', newline='', encoding='utf-8-sig') as csvfile:
    linereader = csv.reader(csvfile, delimiter=',')
    for row in linereader:
        name = row[0]
        shutil.copy(name, 'C:\Power BI\\' + os.path.basename(name))
                
print('All Helper Tables Moved')

searchdir = 'C:\Power BI\\'

for xls_file in glob.glob(os.path.join(searchdir,"*.xlsx")):
    data_xls = pd.read_excel(xls_file, index_col = None)
    csv_file = os.path.splitext(xls_file)[0]+".csv"
    data_xls.to_csv(csv_file, encoding = 'utf-8', index = False)
    
print('All Helper Tables Changed to CSV')

df_pipe = pd.read_csv('C:/Power BI/hec daily.txt', delimiter = '|', index_col = None, header = None, on_bad_lines='skip')

df_pipe.to_csv('C:/Power BI/hec daily.csv', sep = ',', header = False, index = False)    
    
print('HeC Daily Converted to CSV')

pathtodelete =r"C:\Power BI"
filenames_xlsx = glob.glob(pathtodelete + "/*.xlsx")
for i in filenames_xlsx:
    os.remove(i)
    
filenames_txt = glob.glob(pathtodelete + "/*.txt")
for k in filenames_txt:
    os.remove(k)    
    
print('Old Helper Tables Removed')

# %%
#rename files longer than >=63 char
for filename in os.listdir(path):
    if len(filename) > 63:
        os.rename(path+filename, path+filename[-60:])
        print(filename+' renamed to '+filename[-60:])
            
#get csv list
csv_files = []
for file in os.listdir(path):
    if file.endswith('.csv'):
        csv_files.append(file)
        
data_path = path
#create dataframes
df = {}
for file in csv_files:
    try:
        df[file] = pd.read_csv(data_path+file, low_memory=False, index_col=False)
        
    except UnicodeDecodeError:
        df[file] = pd.read_csv(data_path+file, encoding="cp437", low_memory=False, index_col=False, errors='ignore')
    
    print('Loading ' + file + ' into dataframe')    
print('loading completed')

# %%
for k in csv_files:
    
    dataframe = df[k]
    
    clean_tbl_name = k.lower().replace(" ","_").replace("-","").replace(".", "_").replace("(", "").replace(")", "").replace(",", "")\
    .replace("_csv", "").replace("___", "_").replace("__", "_")    
    
    tbl_name = clean_tbl_name
    
    print(k + ' changing to ' + clean_tbl_name)

    #clean column names
    dataframe.columns = [x.lower().replace(" ", "_").replace("-", "").replace("#","num").replace("?", "")\
                     .replace("=","").replace("\n","").replace("\r","").replace("\r\n","").replace("]","_")\
                     .replace("]","_").replace("[","_").replace("\\","_").replace(".","_").replace("$","")\
                     .replace("%","").replace("#","").replace("(","").replace(")","").replace("?","")\
                     .replace(",","").replace("*","").replace(":","").replace("'","").replace("&","")\
                     .replace(";","").replace("__", "_").replace("/", "")
                     for x in dataframe.columns]

     #limit column length to 64 and reading right to left
    dataframe.columns = dataframe.columns.str[-60:] 

     #adding a number if duplicated column name
    def uniquify(dataframe):
        seen = set()

        for item in dataframe:
            fudge = 1
            newitem = item

            while newitem in seen:
                fudge += 1
                newitem = "{}_{}".format(item, fudge)

            yield newitem
            seen.add(newitem)

    dataframe.columns = uniquify(dataframe)

    dataframe.columns = dataframe.columns.str[-60:] 
    
    #db settings and connection
    #get password
    f=open("S:/Data Team Secure/secrets/postgres.txt","r")
    lines=f.readlines()
    password=lines[1]
    f.close()
    
   
    user="Joes_User_Name"
    host = 'Joes_Host_Name'
    dbname = 'postgres'
        
    engine = create_engine('postgresql://'+user+':'+password+'@'+host+'/'+dbname)
   
    #print('opened database successfully')
    
    #create table
    #dataframe.to_sql(k, engine, schema = None, if_exists='append', index=False, dtype = 'text')
    dataframe.to_sql(clean_tbl_name, engine, schema = None, if_exists='append', index=False, dtype =  
                             {'datefld': sqlalchemy.DateTime(), 
                             'intfld':  sqlalchemy.types.INTEGER(),
                             'strfld': sqlalchemy.types.NVARCHAR(length=255),
                             'floatfld': sqlalchemy.types.Float(precision=3, asdecimal=True),
                             'booleanfld': sqlalchemy.types.Boolean,
                             'bool' : sqlalchemy.types.Boolean,
                             'float64' : sqlalchemy.types.NVARCHAR(length=255),
                             'int64' : sqlalchemy.types.INTEGER(),
                             'object' : sqlalchemy.types.NVARCHAR(length=50000)})
    
    print(clean_tbl_name+' uploaded to database')
    
print('All uploads complete')

## for automation, send email to email list when complete
#get email and file list
email_list = pd.read_csv('S:/Data Team/Source Data/python sql/email_db_upload.csv')
emails = email_list['email']

# email loop
for i in range(len(emails)):
    
    email = emails[i]
    
    # Open the Outlook
    outlook = win32.Dispatch('outlook.application')

    # Create the email
    mail = outlook.CreateItem(0)

    # Set the email subject
    mail.Subject = 'AUTOMATED EMAIL: Database Updated '+ datetime.now().strftime('%b %#d %Y %H:%M')

    # Set the receiver email
    mail.To = email

    # Write the email content
    mail.HTMLBody = r"""
    <p>Hello</p>
    <p>The database has had been updated successfully.</p>
    <p>Thanks</p>
    <p>The Data Team</p>
    """

    # Send the email
    mail.Send()
    print('Email sent to ' + email)
print('All Emails Processed')

# %%
filepath = 'J:/OPA/GLIN Reporting Data Services Output/GPPC Scorecards/Sample report structure and colors.xlsx'

 
File_Size = os.path.getsize(filepath)
File_Last_Modified =  time.ctime(os.path.getmtime(filepath))
File_Create_Date =  time.ctime(os.path.getctime(filepath))
print('File Size ',File_Size)
print('File Modified: ',File_Last_Modified)
print('File Created: ',File_Create_Date)
