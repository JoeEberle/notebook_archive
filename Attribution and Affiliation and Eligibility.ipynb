# %%
# Import Libraries for Spreadsheet Automation 
import pandas as pd
import numpy as np
import datetime as dt
import random
import math
from openpyxl import load_workbook
from openpyxl.styles import colors
from openpyxl.styles import Font, Color, Fill
from openpyxl.utils import get_column_letter
from openpyxl.styles import Border, Side, PatternFill, Font, GradientFill, Alignment
from openpyxl import Workbook

# %%
# Read in the CSV SQL output for Patient Attribution 
patient_panel = pd.read_excel('\\Users\josep\Documents\Kaleida\COPE Sample  Eligibility.xlsx')

# %%
patient_panel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Organization_Class       100 non-null    object
#  1   Organization_Name        100 non-null    object
#  2   Provider_Name            100 non-null    object
#  3   Patient_Name             100 non-null    object
#  4   Birth_Date               100 non-null    datetime64[ns]
#  5   Age                      100 non-null    int64
#  6   Gender                   100 non-null    object
#  7   Phone                    100 non-null    object
#  8   Deceased                 99 non-null     float64
#  9   Deceased_Date            1 non-null      object
#  10  Number_of_Conditions     96 non-null     float64
#  11  MARA_Risk_Score          100 non-null    float64
#  12  Number_of_HCC            19 non-null     float64
#  13  Actual_CMS_RAF_Score     23 non-null     float64
# ...

# %%
# Add Additional fields to support User Validation 
patient_panel['Member_ID'] = 'MBR_'+'453512345' + np.random.randint(0, 200, df.shape[0])
patient_panel['Subscriber_ID'] = 'SUB_'+'12351' + np.random.randint(0, 200, df.shape[0])
patient_panel['Optional Comments'] = ' '
patient_panel['Flagged for Test'] = 'No'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-19fdb9dc16d2> in <module>
#       1 # Add Additional fields to support User Validation
# ----> 2 patient_panel['Member_ID'] = 'MBR_'+'453512345' + np.random.randint(0, 200, df.shape[0])
#       3 patient_panel['Subscriber_ID'] = 'SUB_'+'12351' + np.random.randint(0, 200, df.shape[0])
#       4 patient_panel['Optional Comments'] = ' '
#       5 patient_panel['Flagged for Test'] = 'No'
#
# NameError: name 'df' is not defined

# %%
patient_panel['Member_ID'] = 'MBR_'+'453515'+ str(np.random.randint(0, 200))
patient_panel['Subscriber_ID'] = 'SUB_'+'12351' + str(np.random.randint(0, 200))

# %%
patient_panel['Patient Name']  = 'PT_' + 'patient_name' 
patient_panel['Patient_Name']  = 'PT_' + 'patient_name' 
patient_panel['Birth_Date']  = '1961-10-17' 
patient_panel['Relationship_Type']  = 'Relationship_Type' 
patient_panel['Product']  = 'Product'
patient_panel['Plan ID']  = 'PLN_1234655'
patient_panel['Line of Business']  = 'BCBS'
patient_panel['Attributed PCP NPI']  = '264354723'
patient_panel['Attributed PCP TIN']  = '22223723'
patient_panel['Attributed PCP Name']  = 'Michael Del Reo'
patient_panel['PCPAddress1']  = '123 Hertel Avenue'
patient_panel['PCPAddress2']  = ''
patient_panel['Attributed PCP Name']  = patient_panel['Provider_Name']
patient_panel['PCPCity']  = 'Buffalo'
patient_panel['PCPState']  = 'NY'
patient_panel['PCPState']  = '14221'

# %%
Member Coverage Start Date
Member Coverage End Date
PCPEffectiveDate
PCPExpirationDate
MembersSex
MemberName
BirthDate
DateOfDeath
Address1
Address2
MemberCity
MemberState
MemberZip
Medicare Original Entitlement Code
RAF Factor Type
RAF Factor Type Code
MemberLastName
MemberFirstName
MemberHomePhone
MemberOtherPhone
MemberEmail
SSN

# %%
patient_panel = patient_panel[['Member_ID','Subscriber_ID','Provider_Name',
                               'Patient_Name', 'Birth_Date', 'Age',
                               'Gender','Deceased','Deceased_Date',
                               'Organization_Class', 'Organization_Name',
                               'Plan_Name', 'Payer_Name','Relationship_Type','Product',
                               'Plan ID','Line of Business','Attributed PCP NPI',
                               'Attributed PCP TIN']]

# %%
patient_panel.head()
# Out:
#        Member_ID Subscriber_ID      Provider_Name     Patient_Name  \
# 0  MBR_453515143   SUB_1235178  Abdelsayed, Sarah  PT_patient_name
# 1  MBR_453515143   SUB_1235178  Abdelsayed, Sarah  PT_patient_name
# 2  MBR_453515143   SUB_1235178  Abdelsayed, Sarah  PT_patient_name
# 3  MBR_453515143   SUB_1235178  Abdelsayed, Sarah  PT_patient_name
# 4  MBR_453515143   SUB_1235178  Abdelsayed, Sarah  PT_patient_name
#
#    Birth_Date  Age  Gender  Deceased Deceased_Date  \
# 0  1961-10-17   23  Female       0.0           NaN
# 1  1961-10-17    2  Female       0.0           NaN
# 2  1961-10-17   54  Female       0.0           NaN
# 3  1961-10-17   40  Female       0.0           NaN
# 4  1961-10-17   66  Female       0.0           NaN
#
#            Organization_Class                            Organization_Name  \
# 0  Erie County Medical Center  EC PCP Erie County Medical Center FM Clinic
# 1  Erie County Medical Center  EC PCP Erie County Medical Center FM Clinic
# ...

# %%
patient_panel.to_excel('\\Users\josep\Documents\Kaleida\COPE Sample  Eligibility2.xlsx')

# %%
Member ID
Subscriber ID
Relationship_Type
Product
Plan ID
Line of Business
Attributed PCP NPI
Attributed PCP TIN
Attributed PCP Name
PCPAddress1
PCPAddress2
PCPCity
PCPState
PCPZIP
Member Coverage Start Date
Member Coverage End Date
PCPEffectiveDate
PCPExpirationDate
MembersSex
MemberName
BirthDate
DateOfDeath
Address1
Address2
MemberCity
MemberState
MemberZip
Medicare Original Entitlement Code
RAF Factor Type
RAF Factor Type Code
MemberLastName
MemberFirstName
MemberHomePhone
MemberOtherPhone
MemberEmail
SSN
