# %%
! pip install pillow
! pip install pytesseract

# %%
import pytesseract 
from PIL import Image

# %%
# Configure the code and visual settings to have consistency 
path = 'c:/Users/josep/Documents/Kaleida/Image_Files/'
file_name = path + "love.png"

# %%
image = Image.open("c:/Users/josep/Documents/Kaleida/Image_Files/love.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=921x550 at 0x2488DDFFFA0>

# %%
image = Image.open("c:/Users/josep/Documents/Kaleida/Image_Files/test_ocr.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1152x648 at 0x248912DDE50>

# %%
"C:\Users\josep\Documents\Kaleida\hello beautiful.png"

# %%
text = pytesseract.image_to_string(image)
print(text)
# Out:
# WATERCOLOR =~
# FLOWER IMAGES le
# PNG Clipart Graphics :
#
# WWW.ARTSYINSPIRED.COM

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image = Image.open("C:/Users/josep/Documents/Kaleida/Image_Files/Watercolor-flowers.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x248903EE670>

# %%
text = pytesseract.image_to_string(image)
print(text)
# Out:
# WATERCOLOR =~
# FLOWER IMAGES le
# PNG Clipart Graphics :
#
# WWW.ARTSYINSPIRED.COM
