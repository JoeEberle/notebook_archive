# %%
#df = pd.read_csv("C:/Users/josep/documents/datasets/dg.csv", nrows=5000)
df = pd.read_csv("C:/Users/josep/documents/datasets/NHANES/demographic.csv")
df.head(5)
# Out:
#     SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  73557         8         2         1        69       NaN         4
# 1  73558         8         2         1        54       NaN         3
# 2  73559         8         2         1        72       NaN         3
# 3  73560         8         2         1         9       NaN         3
# 4  73561         8         2         2        73       NaN         3
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0         4       1.0       NaN  ...       3.0       4.0       NaN
# 1         3       1.0       NaN  ...       3.0       1.0       1.0
# 2         3       2.0       NaN  ...       4.0       1.0       3.0
# 3         3       1.0     119.0  ...       3.0       1.0       4.0
# 4         3       1.0       NaN  ...       5.0       1.0       5.0
#
#        WTINT2YR      WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
import pandas as pd
import numpy as np

# %%
df.rename(columns={"RIAGENDR": "GENDER"}, inplace=True)
df.rename(columns={"RIDAGEYR": "AGE"}, inplace=True)
df.rename(columns={"RIDAGEMN": "AGE in Months"}, inplace=True)
df.rename(columns={'AIALANGA':'Language'}, inplace=True)
df.rename(columns={'DMDBORN4':'Country of Birth'}, inplace=True)
df.rename(columns={'DMDCITZN':'US Citizen'}, inplace=True)
df.rename(columns={'DMDEDUC2':'Highest Grade'}, inplace=True)
df.rename(columns={'DMDEDUC3':'Highest Grade'}, inplace=True)
df.rename(columns={'DMDFMSIZ':'Family Size'}, inplace=True)
df.rename(columns={'DMDHHSIZ':'Number of people in House'}, inplace=True)
df.rename(columns={'DMDHHSZA':'Number of Children under 5'}, inplace=True)
df.rename(columns={'DMDHHSZB':'Number of people between 6 an 17'}, inplace=True)
df.rename(columns={'DMDHHSZE':'Number of Adults over 60'}, inplace=True)
df.rename(columns={'DMDHRAGZ':'Age in years'}, inplace=True)
df.rename(columns={'DMDHREDZ':'Education'}, inplace=True)
df.rename(columns={'DMDHRGND':'Gender'}, inplace=True)
df.rename(columns={'DMDHRMAZ':'Marital Status'}, inplace=True)
df.rename(columns={'DMDHSEDZ':'Spouse Education'}, inplace=True)
df.rename(columns={'DMDMARTL':'Marital Status'}, inplace=True)
df.rename(columns={'DMDYRSUS':'Length in USA'}, inplace=True)
df.rename(columns={'DMQADFC':'foreign conflict'}, inplace=True)
df.rename(columns={'DMQMILIZ':'US Armed Forces'}, inplace=True)
df.rename(columns={'FIAINTRP':'Interpreter'}, inplace=True)
df.rename(columns={'FIALANG':'family language'}, inplace=True)
df.rename(columns={'FIAPROXY':'Proxy'}, inplace=True)
df.rename(columns={'INDFMIN2':'Family Income'}, inplace=True)
df.rename(columns={'INDFMPIR':'income to poverty'}, inplace=True)
df.rename(columns={'INDHHIN2':'Household income'}, inplace=True)
df.rename(columns={'MIAINTRP':'interpreter'}, inplace=True)
df.rename(columns={'MIALANG':'language int'}, inplace=True)
df.rename(columns={'MIAPROXY':'Proxy'}, inplace=True)
df.rename(columns={'RIAGENDR':'Gender'}, inplace=True)
df.rename(columns={'RIDAGEMN':'Age in Months'}, inplace=True)
df.rename(columns={'RIDAGEYR':'Age in Years'}, inplace=True)
df.rename(columns={'RIDEXAGM':'NA'}, inplace=True)
df.rename(columns={'RIDEXMON':'na'}, inplace=True)
df.rename(columns={'RIDEXPRG':'Pregnant'}, inplace=True)
df.rename(columns={'RIDRETH1':'Race'}, inplace=True)
df.rename(columns={'RIDRETH3':'Race Asian'}, inplace=True)
df.rename(columns={'RIDSTATR':'Exam status'}, inplace=True)
df.rename(columns={'SDDSRVYR':'Data  '}, inplace=True)
df.rename(columns={'SDMVPSU':'PSU'}, inplace=True)
df.rename(columns={'SDMVSTRA':'PSU NA'}, inplace=True)
df.rename(columns={'SEQN':'SEQN Number'}, inplace=True)
df.rename(columns={'SIAINTRP':'Interpreter SP'}, inplace=True)
df.rename(columns={'SIALANG':'Language SP'}, inplace=True)
df.rename(columns={'SIAPROXY':'Proxy Res'}, inplace=True)
df.rename(columns={'WTINT2YR':'Weight 2 yr interview'}, inplace=True)
df.rename(columns={'WTMEC2YR':'Weight 2 yr Exam'}, inplace=True)





df.head()
# Out:
#    SEQN Number  Data    Exam status  GENDER  AGE  AGE in Months  Race  \
# 0        73557       8            2       1   69            NaN     4
# 1        73558       8            2       1   54            NaN     3
# 2        73559       8            2       1   72            NaN     3
# 3        73560       8            2       1    9            NaN     3
# 4        73561       8            2       2   73            NaN     3
#
#    Race Asian   na     NA  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0           4  1.0    NaN  ...       3.0       4.0       NaN
# 1           3  1.0    NaN  ...       3.0       1.0       1.0
# 2           3  2.0    NaN  ...       4.0       1.0       3.0
# 3           3  1.0  119.0  ...       3.0       1.0       4.0
# 4           3  1.0    NaN  ...       5.0       1.0       5.0
#
#    Weight 2 yr interview  Weight 2 yr Exam  PSU  PSU NA  Household income  \
# 0           13281.237386      13481.042095    1     112               4.0
# ...
